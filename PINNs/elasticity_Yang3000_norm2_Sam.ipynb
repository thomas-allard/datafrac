# %% [markdown]
# # Uniaxial Tension - Elasticity, Physics Informed Neural Network

# %% [markdown]
# Thomas Allard and Samantha Walker

# %%
#Imports
import os, sys, time
import numpy as np 
from sciann.utils.math import diff
from sciann import SciModel, Functional, Parameter
from sciann import Data, Tie
from sciann import Variable, Field
import matplotlib.pyplot as plt
import scipy.io
import netCDF4
import xarray as xr

import os
pi = np.pi

# %%
# Specify parameters and things
mode = 'train'   # 'test' to load PINN weights from previously trained model
                # 'train' to train a new model

current_file_name = 'elasticity_Yang3000_norm.ipynb'
    
#trained_file = 'trained-navier-stokes.hdf5'
data_file = '../abaqus/final_elastic/elastic_cdf.nc'

# file with nodal coordinates
node_file = '../abaqus/final_elastic/nodes.txt'

#layers = [40]*4
layers = [10, 40, 80, 100]
actf = 'tanh'
numx = 46
numy = 60
batchsize = 50
#batchsize = 16
epochs = 100
learningrate = 0.001
independent_networks = True
verbose = 2
shuffle = True
stopafter = 500
savefreq = 100000
dtype = 'float64'
gpu = False
outputpath = 'output_norm'
outputprefix = 'res'
numxplot = 46
numyplot = 60
plot = True


Emod = 210.0
nu = 0.3

E_range = [50, 300]
nu_range = [0.1, 0.4]
x_range = [0.0, 3000.0]
y_range = [-1500.0,1500.0]
disp_range = [-1.0, 1.0]
s_range = [0.0, 200.0]

# %%
# Functions
def dispx(input_d): # xx
    #x, y = xx[0], xx[1]
    disp_x = np.asarray(input_d.sel(field='ux'))
    disp_x = np.expand_dims(disp_x, axis=0).T
    return disp_x #np.cos(2*pi*x) * np.sin(pi*y)

def dispy(input_d): # xx
    #x, y = xx[0], xx[1]
    #Q = qload
    disp_y= np.asarray(input_d.sel(field='uy'))
    disp_y = np.expand_dims(disp_y, axis=0).T
    return disp_y #np.sin(pi*x) * Q * y**4/4

def stressxx(input_d): # xx
    stress_xx = np.asarray(input_d.sel(field='S11'))
    stress_xx = np.expand_dims(stress_xx, axis=0).T
    return stress_xx
    #set.sel(field='S11').to_array() #(lmbd+2*mu)*strainxx(xx) + lmbd*strainyy(xx)

def stressyy(input_d): # xx
    stress_yy = np.asarray(input_d.sel(field='S22'))
    stress_yy = np.expand_dims(stress_yy, axis=0).T
    return stress_yy
    #return set.sel(field='S22').to_array() #(lmbd+2*mu)*strainyy(xx) + lmbd*strainxx(xx)

def stressxy(input_d): # xx
    stress_xy = np.asarray(input_d.sel(field='S12'))
    stress_xy = np.expand_dims(stress_xy, axis=0).T
    return stress_xy
    #return set.sel(field='S21').to_array() #2.0*mu*strainxy(xx)

def cust_pcolor(AX, X, Y, C, title):
    im = AX.pcolor(X, Y, C, cmap="jet")
    AX.axis("equal")
    AX.axis("off")
    AX.set_title(title, fontsize=14)
    plt.colorbar(im, ax=AX)

def cust_semilogx(AX, X, Y, xlabel, ylabel):
    if X is None:
        im = AX.semilogy(Y)
    else:
        im = AX.semilogy(X, Y)
    if xlabel is not None: AX.set_xlabel(xlabel)
    if ylabel is not None: AX.set_ylabel(ylabel)

# Create function to read text files in as np array
def file2array(file):
    # load in each line of data as array
    with open(file, 'r') as f:
        line_string = f.read().splitlines()
    
    # loop through the lines from the file, split, and append to list
    list = []
    timestamp = 0 # default 
    for i, line in enumerate(line_string):
        list.append(line.split())

    # convert list to an array of type float64
    array = np.asarray(list, dtype=np.float64)

    return(array)

def rearrange(numx, numy, field):
    stuff = np.zeros([numx,numy])
    for k,f in enumerate(field):
        i = int(k % numx)
        j = int(np.floor(k/numx))
        stuff[i,j] = f
        
    stuff = stuff.T
    return(stuff)

def normalize(value, min, max,a,b): # min max normalization from -1 to 1
    norm = (b-a)*((value-min)/(max-min))+a
    return(norm)

def eval_mu_sig(X):
    return(X.mean(), X.std())

def std_normalize(X, mu, sig):
    return((X-mu)/sig)

def denormalize(X, mu, sig):
    return(X*sig + mu)

def min_max_normalize(value, min, max): # from -1 to 1 # X # same as normalize function
    return 2.*(value-min)/(max-min) - 1.

# %%
# load in data_file as xarray DataSet
set_in = xr.open_dataset(data_file)

# %%
# Load in displacements and create an ndarray
disp_x=set_in.sel(field='ux').to_array()
disp_y=set_in.sel(field='uy').to_array()
disps=np.dstack([disp_x,disp_y])

# %%
# Extract time and put in an array
times = [] # will be shape (81,)
for DataArray in set_in.values():
    times.append(DataArray.attrs['time'])
print(np.shape(times))
# Out:
# (81,)

# %%
# read in node file and save as grid
nodal_coordinates = file2array(node_file)
grid = nodal_coordinates[:,1:3]
#grid = np.array([grid[:,0],grid[:,1]+1500.])
grid = np.array([grid[:,0],grid[:,1]])
grid = np.expand_dims(grid, axis=0)
grid = np.moveaxis(grid, 0, -1)
print(np.shape(grid))
#print(grid)
# Out:
# (2, 2760, 1)

# %%
# Check that data loaded in correctly by plotting disp_y for node 1 (bottom left) and node 2715 (top left)
plt.plot(times,set_in.sel(field='uy',node='1').to_array(),   color='red',label='node_1')
plt.plot(times,set_in.sel(field='uy',node='2715').to_array(),color='blue',label='node_2715')
plt.xlabel('time (s)')
plt.ylabel('displacement (mm)')
plt.legend()
plt.show()

# %%
# Check that stress normalization is working

stresses=normalize(set_in.sel(field='S22',node='1').to_array(),s_range[0],s_range[1],-1,1)
stresses_mu,stresses_sig=eval_mu_sig(np.asarray(set_in.sel(field='S22',node='1').to_array()))
stresses_2=std_normalize(np.asarray(set_in.sel(field='S22',node='1').to_array()), stresses_mu, stresses_sig)
plt.plot(times,stresses,color='blue',label='node_2715')
plt.plot(times,stresses_2,color='red',label='node_2715, std norm')
plt.xlabel('time (s)')
plt.ylabel('normalized stress (MPa)')
plt.legend()
plt.show()

# %%
disp_x=np.array(set_in.sel(field='ux').to_array())
np.shape(np.array(set_in.sel(field='ux').to_array()))
#normalize(disp_x, disp_range[0],disp_range[1], -1, 1)
#eval_mu_sig(disp_x)

#eval_mu_sig(np.asarray(set_in.sel(field='S12').to_array()))
#sxx_star
# Out:
# (81, 2760)

# %%
# define function for subsampling data
def PrepareData(set_in, nodal_coordinates, times, random=True): # num_data, data_file
    
    # Load data
    #data = scipy.io.loadmat('/content/' + data_file)
    #data = scipy.io.loadmat(data_file)
    
    # will want to change these to correspond to our input variables
    #U_star = data['U_star'] # N x 2 x T
    ## displacements -> U_star
    #disp_x=normalize(set_in.sel(field='ux').to_array(),disp_range[0],disp_range[1],-1,1) # T x N # (81, 2760)
    #disp_y=normalize(set_in.sel(field='uy').to_array(),disp_range[0],disp_range[1],-1,1) # T x N # (81, 2760)
    disp_x=np.array(set_in.sel(field='ux').to_array()) # T x N # (81, 2760)
    disp_y=np.array(set_in.sel(field='uy').to_array()) # T x N # (81, 2760)
    u_mu, u_sig = eval_mu_sig(disp_x)
    v_mu, v_sig = eval_mu_sig(disp_y)
    dispx = std_normalize(disp_x, u_mu, u_sig) # normalize(disp_x, disp_range[0],disp_range[1],-1,1)
    dispy = std_normalize(disp_y, v_mu, v_sig) # normalize(disp_y, disp_range[0],disp_range[1],-1,1)
    U_star=np.dstack([dispx,dispy])     # T x N x 2 (81, 2760, 2)
    
    # time
    times = [] # will be shape (81,)
    for DataArray in set_in.values():
        times.append(DataArray.attrs['time'])
        
    
    # Solution S22 -> P_star
    sxx_mu, sxx_sig = eval_mu_sig(np.asarray(set_in.sel(field='S11').to_array()))
    syy_mu, syy_sig = eval_mu_sig(np.asarray(set_in.sel(field='S22').to_array()))
    sxy_mu, sxy_sig = eval_mu_sig(np.asarray(set_in.sel(field='S12').to_array()))
    sxx_star = std_normalize(np.asarray(set_in.sel(field='S11').to_array()),sxx_mu,sxx_sig) #normalize(np.asarray(set_in.sel(field='S11').to_array()),s_range[0],s_range[1],0,1) # T x N
    syy_star = std_normalize(np.asarray(set_in.sel(field='S12').to_array()),syy_mu,syy_sig) #normalize(np.asarray(set_in.sel(field='S22').to_array()),s_range[0],s_range[1],0,1) # T x N
    sxy_star = std_normalize(np.asarray(set_in.sel(field='S12').to_array()),sxy_mu,sxy_sig) #normalize(np.asarray(set_in.sel(field='S12').to_array()),s_range[0],s_range[1],0,1) # T x N

    # time -> t_star
    t_star = times #data['t'] # T x 1 # (81,)
    
    # grid -> X_star
    gridd = nodal_coordinates[:,1:3]
    #print(np.shape(gridd))
    #gridd = np.array([gridd[:,0],gridd[:,1]+1500.]).T
    #gridd = np.array([normalize(,x_range[0],x_range[1],-1,1),normalize(,y_range[0],y_range[1],-1,1)]).T
    #print(np.shape(gridd))
    grid_x = gridd[:,0]
    grid_y = gridd[:,1]
    x_mu, x_sig = eval_mu_sig(grid_x)
    y_mu, y_sig = eval_mu_sig(grid_y)
    gridx = std_normalize(grid_x, x_mu, x_sig).T #normalize(grid_x,x_range[0],x_range[1],-1,1) #min_max_normalize(grid_x, np.amin(grid_x), np.amax(grid_x)).T # std_normalize(grid_x, x_mu, x_sig).T
    gridy = std_normalize(grid_y, y_mu, y_sig).T #normalize(grid_y,y_range[0],y_range[1],-1,1) #min_max_normalize(grid_y, np.amin(grid_y), np.amax(grid_y)).T # std_normalize(grid_y, y_mu, y_sig).T
    gridd = np.array([gridx, gridy]).T
    #X_star = np.array([gridx, gridy]) # grid is N x 2 or shape (2760, 2)
    X_star = gridd
    
    N = np.shape(X_star)[0] #X_star.shape[0]
    T = np.shape(t_star)[0] #t_star.shape[0]
    
    # Rearrange Data 
    XX = np.tile(X_star[:,0:1], (1,T)) # N x T # (2760, 81)
    YY = np.tile(X_star[:,1:2], (1,T)) # N x T # (2760, 81)
    TT = np.tile(t_star, (1,N)).T # NT x 1 # (223560, 1)
    
    UU = U_star[:,:,0].T # N x T
    VV = U_star[:,:,1].T # N x T
    SSxx = sxx_star.T # N x T
    SSyy = syy_star.T # N x T
    SSxy = sxy_star.T # N x T

    
    # Pick random data.
    if random:
        idx = np.random.choice(N*T, N, replace=False) # num_data
    else:
        idx = np.arange(0, N*T)
    
    x = XX
    y = YY
    t = t_star
    
    x = XX.flatten()[idx,None] # NT x 1
    y = YY.flatten()[idx,None] # NT x 1
    t = TT.flatten()[idx,None] # NT x 1
 
    
    u = UU # T x N # (81, 2760)
    v = VV # T x N # (81, 2760)
    
    u = UU.flatten()[idx,None] # NT x 1
    v = VV.flatten()[idx,None] # NT x 1
    sxx = SSxx.flatten()[idx,None] # NT x 1
    syy = SSyy.flatten()[idx,None] # NT x 1
    sxy = SSxy.flatten()[idx,None] # NT x 1
    
        

    return (x,y,t,u,v,sxx,syy,sxy,[u_mu, v_mu, x_mu, y_mu], [u_sig, v_sig, x_sig, y_sig])

# %%
#min_max_normalize(np.asarray(set_in.sel(field='S11').to_array()))
np.shape(np.asarray(set_in.sel(field='S11').to_array()))
# Out:
# (81, 2760)

# %%
np.amax(nodal_coordinates[:,0])
# Out:
# 2760.0

# %%
x,y,t,u,v,sxx, syy, sxy, mus, sigs = PrepareData(set_in, nodal_coordinates, times, random=True)

sig_mu, sig_sig = eval_mu_sig(syy)

# check shapes
print(f'shape of x = {np.shape(x)}')
print(f'shape of y = {np.shape(y)}')
print(f'shape of t = {np.shape(t)}')
print(f'shape of u = {np.shape(u)}')
print(f'shape of v = {np.shape(v)}')
print(f'shape of sxx = {np.shape(sxx)}')
print(f'shape of syy = {np.shape(syy)}')
print(f'shape of sxy = {np.shape(sxy)}')
# Out:
# shape of x = (2760, 1)
# shape of y = (2760, 1)
# shape of t = (2760, 1)
# shape of u = (2760, 1)
# shape of v = (2760, 1)
# shape of sxx = (2760, 1)
# shape of syy = (2760, 1)
# shape of sxy = (2760, 1)

# %%
# as a quick check
input_d = set_in.step_080
ux_mu,ux_sig=eval_mu_sig(np.asarray(input_d.sel(field='ux')))
ux_2=std_normalize(np.asarray(input_d.sel(field='ux')), ux_mu, ux_sig)
ux_2
# Out:
# array([ 1.69479811,  1.61947373,  1.54414936, ..., -1.54414942,
#        -1.61947359, -1.69479804])

# %%
s22_mu,s22_sig=eval_mu_sig(np.asarray(input_d.sel(field='S22')))

#rearrange(numx,numy,std_normalize(np.asarray(input_d.sel(field='S22')), s22_mu, s22_sig)) # doesn't work correctly, just nans
#rearrange(numx, numy, normalize(np.asarray(input_d.sel(field='S22')),s_range[0],s_range[1],-1,1))

# %%
def plot(Emod, nu):
    output_file_name = os.path.join(outputpath, outputprefix)
    #fname = output_file_name + "_{}_".format(actf) + "x".join([str(x) for x in layers])
    fname = output_file_name + "_{}_".format(actf)
    
    loss = np.loadtxt(fname+"_loss")
    times = np.loadtxt(fname+"_Time")
    fig, ax = plt.subplots(1, 2, figsize=(7, 3), dpi=300)
    cust_semilogx(ax[0], None, loss/loss[0], "epochs", "L/L0")
    cust_semilogx(ax[1], times, loss/loss[0], "time(s)", None)
    fig.subplots_adjust(left=0.1, right=0.9, bottom=0.15, top=0.9, wspace=0.3, hspace=0.2)
    plt.savefig("{}_loss.png".format(output_file_name))
    
    Xmesh = np.loadtxt(fname+"_Xmesh", delimiter=',')
    Ymesh = np.loadtxt(fname+"_Ymesh", delimiter=',')
    
    input_d = set_in.step_080
    ux_mu,ux_sig=eval_mu_sig(np.asarray(input_d.sel(field='ux')))
    uy_mu,uy_sig=eval_mu_sig(np.asarray(input_d.sel(field='uy')))
    s11_mu,s11_sig=eval_mu_sig(np.asarray(input_d.sel(field='S11')))
    s22_mu,s22_sig=eval_mu_sig(np.asarray(input_d.sel(field='S22')))
    s12_mu,s12_sig=eval_mu_sig(np.asarray(input_d.sel(field='S12')))
    data_d1 = std_normalize(np.asarray(input_d.sel(field='ux')), ux_mu, ux_sig) #normalize(np.asarray(input_d.sel(field='ux')),disp_range[0],disp_range[1],-1,1)
    data_d2 = std_normalize(np.asarray(input_d.sel(field='uy')), uy_mu, uy_sig) #normalize(np.asarray(input_d.sel(field='uy')),disp_range[0],disp_range[1],-1,1)
    data_d3 = std_normalize(np.asarray(input_d.sel(field='S11')), s11_mu, s11_sig) #normalize(np.asarray(input_d.sel(field='S11')),s_range[0],s_range[1],-1,1)
    data_d4 = std_normalize(np.asarray(input_d.sel(field='S22')), s22_mu, s22_sig) #normalize(np.asarray(input_d.sel(field='S22')),s_range[0],s_range[1],-1,1)
    data_d5 = std_normalize(np.asarray(input_d.sel(field='S12')), s12_mu, s12_sig) #normalize(np.asarray(input_d.sel(field='S12')),s_range[0],s_range[1],-1,1)
    
    #Emods = normalize(Emod,E_range[0],E_range[1],0.1,1)
    #nus = normalize(nu,nu_range[0],nu_range[1],0.1,1)
    Emods = Emod
    nus = nu
    
    fig, ax = plt.subplots(2, 2, figsize=(8, 6), dpi=300)
    cust_pcolor(ax[0, 0], Xmesh, Ymesh, np.ones_like(Xmesh)*Emods, "E*={:.3f}".format(Emods))
    cust_pcolor(ax[0, 1], Xmesh, Ymesh, np.ones_like(Xmesh)*nu, "nu*={:.3f}".format(nus))
    Emods_pred = np.loadtxt(fname+"_Emods", delimiter=',')
    nus_pred = np.loadtxt(fname+"_nus", delimiter=',')
    cust_pcolor(ax[1, 0], Xmesh, Ymesh, np.ones_like(Xmesh)*Emods_pred, "E={:.3f}".format(Emods_pred.mean()))
    cust_pcolor(ax[1, 1], Xmesh, Ymesh, np.ones_like(Xmesh)*nus_pred, "nu={:.3f}".format(nus_pred.mean()))
    plt.savefig("{}_Parameters.png".format(output_file_name))
    
    fig, ax = plt.subplots(2, 2, figsize=(8, 6), dpi=300)
    plot_ux = rearrange(numx, numy, np.asarray(input_d.sel(field='ux')))
    plot_uy = rearrange(numx, numy, np.asarray(input_d.sel(field='uy')))
    print(np.shape(np.loadtxt(fname+"_U", delimiter=',')))
    cust_pcolor(ax[0, 0], Xmesh, Ymesh, plot_ux, "Ux*")
    cust_pcolor(ax[0, 1], Xmesh, Ymesh, plot_uy, "Uy*")
    cust_pcolor(ax[1, 0], Xmesh, Ymesh, np.loadtxt(fname+"_U", delimiter=','), "Ux")
    cust_pcolor(ax[1, 1], Xmesh, Ymesh, np.loadtxt(fname+"_V", delimiter=','), "Uy")
    plt.savefig("{}_Displacement.png".format(output_file_name))
    
    fig, ax = plt.subplots(2, 3, figsize=(11, 6), dpi=300)
    #plot_s11 = rearrange(numx, numy, np.asarray(input_d.sel(field='S11')))
    plot_s22 = rearrange(numx, numy, normalize(np.asarray(input_d.sel(field='S22')),s_range[0],s_range[1],-1,1))
    #plot_s12 = rearrange(numx, numy, np.asarray(input_d.sel(field='S12')))
    plot_s11 = np.zeros([numy,numx])
    #plot_s22 = np.zeros([numx*numy,1])
    plot_s12 = np.zeros([numy,numx])
    cust_pcolor(ax[0, 0], Xmesh, Ymesh, plot_s11, "Sxx*")
    cust_pcolor(ax[0, 1], Xmesh, Ymesh, plot_s22, "Syy*")
    cust_pcolor(ax[0, 2], Xmesh, Ymesh, plot_s12, "Sxy*")
    cust_pcolor(ax[1, 0], Xmesh, Ymesh, np.loadtxt(fname+"_Sxx", delimiter=','), "Sxx")
    cust_pcolor(ax[1, 1], Xmesh, Ymesh, np.loadtxt(fname+"_Syy", delimiter=','), "Syy")
    cust_pcolor(ax[1, 2], Xmesh, Ymesh, np.loadtxt(fname+"_Sxy", delimiter=','), "Sxy")
    fig.subplots_adjust(left=0.1, right=0.9, bottom=0.05, top=0.9, wspace=0.3, hspace=0.2)
    plt.savefig("{}_Stress.png".format(output_file_name))
    
    #fig, ax = plt.subplots(2, 3, figsize=(11, 6), dpi=300)
    #plot_exx = rearrange(numx, numy, np.asarray(input_d.sel(field='NE11')))
    #plot_eyy = rearrange(numx, numy, np.asarray(input_d.sel(field='NE22')))
    #plot_exy = rearrange(numx, numy, np.asarray(input_d.sel(field='NE12')))
    #cust_pcolor(ax[0, 0], Xmesh, Ymesh, plot_exx, "Exx*")
    #cust_pcolor(ax[0, 1], Xmesh, Ymesh, plot_eyy, "Eyy*")
    #cust_pcolor(ax[0, 2], Xmesh, Ymesh, plot_exy, "Exy*")
    #cust_pcolor(ax[1, 0], Xmesh, Ymesh, np.loadtxt(fname+"_Exx", delimiter=','), "Exx")
    #cust_pcolor(ax[1, 1], Xmesh, Ymesh, np.loadtxt(fname+"_Eyy", delimiter=','), "Eyy")
    #cust_pcolor(ax[1, 2], Xmesh, Ymesh, np.loadtxt(fname+"_Exy", delimiter=','), "Exy")
    #fig.subplots_adjust(left=0.1, right=0.9, bottom=0.05, top=0.9, wspace=0.3, hspace=0.2)
    #plt.savefig("{}_Strain.png".format(output_file_name))

# %%
# Setting up cost function
#layers = 6
#neurons = 10

x = Variable("x", dtype='float64')
y = Variable("y", dtype='float64')
t = Variable("t", dtype='float64')

U = Functional("U", [x,y,t], layers, actf)
V = Functional("V", [x,y,t], layers, actf)
Sxx = Functional("Sxx", [x,y,t], layers, actf)
Syy = Functional("Syy", [x,y,t], layers, actf)
Sxy = Functional("Sxy", [x,y,t], layers, actf)

'''
Abaqus takes E and nu
The Navier form of equations takes mu and lambda

E = [mu*(3*lambda + 2*mu)] / [lambda + mu]
nu = lambda / [2*(lambda + mu)]

mu = E / [2*(1 + nu)]
lambda = [nu*E] / [(1 + nu)*(1 - 2*nu)]

Inputs values:
E  = 210 GPa -> 0.280
nu = 0.3     -> 0.333

Expected values:
mu     =  80.769231 GPa
lambda = 121.15438 GPa
'''

#Emods = Parameter(0.9*np.random.rand()+0.1, inputs=[x,y,t], min_max=[0.1,1.0], name="Emods")
#nus = Parameter(0.3*np.random.rand()+0.1, inputs=[x,y,t], min_max=[0.1,0.4], name="nus")
Emods = Parameter(np.random.rand(), inputs=[x,y,t], name="Emods")*Emod
nus = Parameter(np.random.rand(), inputs=[x,y,t], name="nus")*nu

# Call in training data
x_train, y_train, t_train, u_train, v_train, sxx_train, syy_train, sxy_train, mus, sigs = PrepareData(set_in, nodal_coordinates, times, random=True)
u_mu, u_sig = mus[0], sigs[0]
v_mu, v_sig = mus[1], sigs[1]
x_mu, x_sig = mus[2], sigs[2]
y_mu, y_sig = mus[3], sigs[3]
sig_sig = 100.


# Strains
Exx = diff(U, x)
Eyy = diff(V, y)
Exy = 0.5*(diff(U,y) + diff(V,x))

# define constraints
d1 = Data(U)
d2 = Data(V)
d3 = Data(Sxx)
d4 = Data(Syy)
d5 = Data(Sxy)

# some constants
C11 = Emods/(1-(nus**2))
C22 = C11*nus
C33 = Emods/(1*(1-nus))

# Equations
c1 = Tie(Sxx/sig_sig, (C11*Exx + C22*Eyy)/sig_sig)
c2 = Tie(Syy/sig_sig, (C11*Eyy + C22*Exx)/sig_sig)
c3 = Tie(Sxy/sig_sig, (C33*Exy)/sig_sig)

Lx = diff(Sxx, x) + diff(Sxy, y)
Ly = diff(Sxy, x) + diff(Syy, y)
d_Lx = Data(Lx/sig_sig)
d_Ly = Data(Ly/sig_sig)

if mode == 'train':
    
    # define output folder. 
    if not os.path.isdir(outputpath):
        os.mkdir(outputpath)
        
    output_file_name = os.path.join(outputpath, outputprefix)
    #fname = output_file_name + "_{}_".format(actf) + "x".join([str(x) for x in layers])
    fname = output_file_name + "_{}_".format(actf) 
    

    model = SciModel(
        inputs=[x, y, t],
        targets = [d1, d2, d3, d4, d5, c1, c2, c3, d_Lx, d_Ly],
        #targets = [d1, d2, c1, c2, c3],
        loss_func = "mse",
        #plot_to_file = "NS-Model.png"
    )
    
    input_data = [x_train, y_train, t_train]
    print(np.shape(input_data))

    # like an initial condition for c1, c2, c3, and c4
    data_d1 = u_train
    data_d2 = v_train
    data_d3 = sxx_train
    data_d4 = syy_train
    data_d5 = sxy_train
    data_c1 = sxx_train #'zeros'
    data_c2 = syy_train #'zeros'
    data_c3 = sxy_train #'zeros'
    data_Lx = 'zeros'
    data_Ly = 'zeros'
    
    target_data = [data_d1, data_d2, data_d3, data_d4, data_d5, 
                   data_c1, data_c2, data_c3,
                   data_Lx, data_Ly]
    #target_data = [data_d1, data_d2, data_d3, data_d4, data_d5, data_c1, data_c2, data_c3]
    #target_data = [data_d1, data_d2, data_c1, data_c2, data_c3]

    ## hyper parameter define

    #Epochs= 100
    #Batch_size=100
    #Learning_rate=0.001
    #Reduce_lr_after=1000
    
#log the data

    # Prepare training data 
    ## Training grid 
    XMIN, XMAX = -1.0, 1.0 # 0.0, 3000.0 #1.0
    YMIN, YMAX = -1.0, 1.0 # -1500., 1500. # 0.0, 1.0
    #YMIN, YMAX = 0.0, 3000.0 # 0.0, 1.0
    Xmesh = np.linspace(XMIN, XMAX, numx).reshape((-1, 1))
    Ymesh = np.linspace(YMIN, YMAX, numy).reshape((-1, 1))
    X, Y = np.meshgrid(Xmesh, Ymesh)
    
    
    
    #input_data = [grid[0],grid[1]]
    
    fname_out = fname +'_WEIGHTS'
    
    ##train PINN
    training_time = time.time()
    history = model.train(
        x_true=input_data,
        y_true=target_data,
        epochs= epochs,
        batch_size= batchsize,
        shuffle=shuffle,
        learning_rate= learningrate,
        #reduce_lr_after= Reduce_lr_after,
        stop_after = stopafter,
        #stop_loss_value=1e-8,
        verbose=verbose,
    )
    
    training_time = time.time() - training_time
    
    for loss in history.history:
        np.savetxt(fname+"_{}".format("_".join(loss.split("/"))), 
                    np.array(history.history[loss]).reshape(-1, 1))
    
    '''
    Old from Yang
    ## logs and plots
    model.save_weights('elasticity_train.hdf5')
    ## print iterated parameters value
    print("Emod: {},  lamb: {}".format(Emods.value, lamb.value))
    with open(f'../logs/log_layers{layers}_neurons{neurons}_epochs{Epochs}_batchsize{Batch_size}_learning_rate{Learning_rate}_reduce_lr_after{Reduce_lr_after}/parameters_{layers}_{neurons}.txt', 'w') as f:
        f.write(f"mu: {mu.value},  lamb: {lamb.value}")
    print("mu: {},  lamb: {}".format(mu.value, lamb.value))
    
    ## print loss function value
    print("loss: {}".format(history.history['loss']))
    with open(f'../logs/log_layers{layers}_neurons{neurons}_epochs{Epochs}_batchsize{Batch_size}_learning_rate{Learning_rate}_reduce_lr_after{Reduce_lr_after}/loss_{layers}_{neurons}.txt', 'w') as f:
        f.write(f"loss: {history.history['loss']}")
    ## plot loss function
    plt.figure(f'Train_Loss_{layers}_{neurons}')
    plt.semilogy(history.history['loss'])
    plt.xlabel('epochs')
    plt.ylabel('loss')
    plt.savefig(f'../logs/log_layers{layers}_neurons{neurons}_epochs{Epochs}_batchsize{Batch_size}_learning_rate{Learning_rate}_reduce_lr_after{Reduce_lr_after}/loss_{layers}_{neurons}.png')
    plt.semilogy(history.history['loss'])
    plt.xlabel('epochs')
    plt.ylabel('loss')
    '''
    
    time_steps = np.linspace(0, training_time, len(history.history["loss"]))
    np.savetxt(fname+"_Time", time_steps.reshape(-1,1))

    # Post process the trained model.
    
    Xmesh_plot = np.linspace(XMIN, XMAX, numxplot).reshape((-1, 1))
    Ymesh_plot = np.linspace(YMIN, YMAX, numyplot).reshape((-1, 1))
    X_plot, Y_plot = np.meshgrid(Xmesh_plot, Ymesh_plot)
    input_plot = [X_plot.reshape(-1, 1), Y_plot.reshape(-1, 1),t_train]

    Emods_pred = Emods.eval(model, input_plot)
    nus_pred = nus.eval(model, input_plot)
    U_pred = U.eval(model, input_plot)
    V_pred = V.eval(model, input_plot)
    Exx_pred = Exx.eval(model, input_plot)
    Eyy_pred = Eyy.eval(model, input_plot)
    Exy_pred = Exy.eval(model, input_plot)
    Sxx_pred = Sxx.eval(model, input_plot)
    Syy_pred = Syy.eval(model, input_plot)
    Sxy_pred = Sxy.eval(model, input_plot)
    
        
    np.savetxt(fname+"_Xmesh", X_plot, delimiter=', ')
    np.savetxt(fname+"_Ymesh", Y_plot, delimiter=', ')
    np.savetxt(fname+"_Emods", Emods_pred, delimiter=', ')
    np.savetxt(fname+"_nus", nus_pred, delimiter=', ')
    np.savetxt(fname+"_U", U_pred.reshape(X_plot.shape), delimiter=', ')
    np.savetxt(fname+"_V", V_pred.reshape(X_plot.shape), delimiter=', ')
    np.savetxt(fname+"_Exx", Exx_pred.reshape(X_plot.shape), delimiter=', ')
    np.savetxt(fname+"_Eyy", Eyy_pred.reshape(X_plot.shape), delimiter=', ')
    np.savetxt(fname+"_Exy", Exy_pred.reshape(X_plot.shape), delimiter=', ')
    np.savetxt(fname+"_Sxx", Sxx_pred.reshape(X_plot.shape), delimiter=', ')
    np.savetxt(fname+"_Syy", Syy_pred.reshape(X_plot.shape), delimiter=', ')
    np.savetxt(fname+"_Sxy", Sxy_pred.reshape(X_plot.shape), delimiter=', ')
# Out:
# (3, 2760, 1)
#
# Total samples: 2760
# Batch size: 50
# Total batches: 56
#
# Epoch 1/100
# 56/56 - 10s - loss: 5.9532 - U_loss: 0.5469 - V_loss: 0.3791 - Sxx_loss: 1.0130 - Syy_loss: 0.5557 - Sxy_loss: 0.9114 - sub_7_loss: 1.0941 - sub_8_loss: 0.4773 - sub_9_loss: 0.9417 - div_29_loss: 2.6985e-06 - div_30_loss: 7.2945e-06 - lr: 0.0010 - time: 10.0335
# Epoch 2/100
# 56/56 - 2s - loss: 4.8152 - U_loss: 0.3602 - V_loss: 0.3149 - Sxx_loss: 1.0094 - Syy_loss: 0.0144 - Sxy_loss: 0.9077 - sub_7_loss: 1.0875 - sub_8_loss: 0.1842 - sub_9_loss: 0.9423 - div_29_loss: 2.6696e-06 - div_30_loss: 1.2050e-06 - lr: 0.0010 - time: 1.5147
# Epoch 3/100
# 56/56 - 1s - loss: 4.5972 - U_loss: 0.3221 - V_loss: 0.2992 - Sxx_loss: 1.0285 - Syy_loss: 0.0014 - Sxy_loss: 0.9485 - sub_7_loss: 1.1005 - sub_8_loss: 0.0931 - sub_9_loss: 0.9691 - div_29_loss: 3.1582e-06 - div_30_loss: 8.6130e-07 - lr: 0.0010 - time: 1.4827
# Epoch 4/100
# 56/56 - 2s - loss: 4.5023 - U_loss: 0.2857 - V_loss: 0.2779 - Sxx_loss: 1.0049 - Syy_loss: 7.4765e-04 - Sxy_loss: 0.8957 - sub_7_loss: 1.0403 - sub_8_loss: 0.0461 - sub_9_loss: 0.9130 - div_29_loss: 4.6987e-06 - div_30_loss: 5.9181e-07 - lr: 0.0010 - time: 1.5026
# Epoch 5/100
# 56/56 - 1s - loss: 4.4516 - U_loss: 0.2694 - V_loss: 0.2698 - Sxx_loss: 0.9986 - Syy_loss: 5.9078e-04 - Sxy_loss: 0.9112 - sub_7_loss: 1.0401 - sub_8_loss: 0.0381 - sub_9_loss: 0.9222 - div_29_loss: 2.3823e-06 - div_30_loss: 5.4654e-07 - lr: 0.0010 - time: 1.4640
# Epoch 6/100
# 56/56 - 1s - loss: 4.3962 - U_loss: 0.2575 - V_loss: 0.2670 - Sxx_loss: 0.9815 - Syy_loss: 5.0263e-04 - Sxy_loss: 0.8872 - sub_7_loss: 1.0217 - sub_8_loss: 0.0331 - sub_9_loss: 0.9030 - div_29_loss: 3.2081e-06 - div_30_loss: 2.6100e-07 - lr: 0.0010 - time: 1.4289
# Epoch 7/100
# 56/56 - 1s - loss: 4.3812 - U_loss: 0.2396 - V_loss: 0.2602 - Sxx_loss: 1.0354 - Syy_loss: 4.6730e-04 - Sxy_loss: 0.8983 - sub_7_loss: 1.0767 - sub_8_loss: 0.0306 - sub_9_loss: 0.9203 - div_29_loss: 3.6202e-06 - div_30_loss: 2.9239e-07 - lr: 0.0010 - time: 1.4736
# Epoch 8/100
# 56/56 - 1s - loss: 4.3539 - U_loss: 0.2366 - V_loss: 0.2581 - Sxx_loss: 0.9769 - Syy_loss: 4.2532e-04 - Sxy_loss: 0.8939 - sub_7_loss: 1.0231 - sub_8_loss: 0.0344 - sub_9_loss: 0.9071 - div_29_loss: 5.1365e-06 - div_30_loss: 3.7471e-07 - lr: 0.0010 - time: 1.4796
# Epoch 9/100
# 56/56 - 2s - loss: 4.3409 - U_loss: 0.2265 - V_loss: 0.2586 - Sxx_loss: 0.9972 - Syy_loss: 3.6698e-04 - Sxy_loss: 0.9030 - sub_7_loss: 1.0360 - sub_8_loss: 0.0351 - sub_9_loss: 0.9121 - div_29_loss: 5.9460e-06 - div_30_loss: 4.0860e-07 - lr: 0.0010 - time: 1.5063
# Epoch 10/100
# 56/56 - 2s - loss: 4.3155 - U_loss: 0.2208 - V_loss: 0.2493 - Sxx_loss: 0.9755 - Syy_loss: 3.3718e-04 - Sxy_loss: 0.8868 - sub_7_loss: 1.0325 - sub_8_loss: 0.0320 - sub_9_loss: 0.9060 - div_29_loss: 5.0085e-06 - div_30_loss: 2.7772e-07 - lr: 0.0010 - time: 1.9541
# Epoch 11/100
# 56/56 - 1s - loss: 4.2879 - U_loss: 0.2062 - V_loss: 0.2453 - Sxx_loss: 0.9935 - Syy_loss: 3.1329e-04 - Sxy_loss: 0.9102 - sub_7_loss: 1.0313 - sub_8_loss: 0.0309 - sub_9_loss: 0.9234 - div_29_loss: 5.7149e-06 - div_30_loss: 1.9980e-07 - lr: 0.0010 - time: 1.4850
# Epoch 12/100
# 56/56 - 1s - loss: 4.2935 - U_loss: 0.2068 - V_loss: 0.2373 - Sxx_loss: 0.9722 - Syy_loss: 2.9501e-04 - Sxy_loss: 0.8860 - sub_7_loss: 1.0252 - sub_8_loss: 0.0366 - sub_9_loss: 0.8995 - div_29_loss: 5.2478e-06 - div_30_loss: 1.6172e-07 - lr: 0.0010 - time: 1.4448
# Epoch 13/100
# 56/56 - 1s - loss: 4.2372 - U_loss: 0.1929 - V_loss: 0.2246 - Sxx_loss: 0.9742 - Syy_loss: 2.6799e-04 - Sxy_loss: 0.9175 - sub_7_loss: 1.0200 - sub_8_loss: 0.0281 - sub_9_loss: 0.9240 - div_29_loss: 8.2144e-06 - div_30_loss: 3.9502e-07 - lr: 0.0010 - time: 1.4765
# Epoch 14/100
# 56/56 - 1s - loss: 4.2676 - U_loss: 0.1885 - V_loss: 0.2241 - Sxx_loss: 0.9862 - Syy_loss: 2.5685e-04 - Sxy_loss: 0.9218 - sub_7_loss: 1.0322 - sub_8_loss: 0.0350 - sub_9_loss: 0.9553 - div_29_loss: 6.7262e-06 - div_30_loss: 2.5422e-07 - lr: 0.0010 - time: 1.4861
# Epoch 15/100
# 56/56 - 1s - loss: 4.2222 - U_loss: 0.1711 - V_loss: 0.2139 - Sxx_loss: 0.9748 - Syy_loss: 2.5346e-04 - Sxy_loss: 0.8975 - sub_7_loss: 1.0164 - sub_8_loss: 0.0307 - sub_9_loss: 0.9157 - div_29_loss: 1.1204e-05 - div_30_loss: 1.9283e-07 - lr: 0.0010 - time: 1.4552
# Epoch 16/100
# 56/56 - 1s - loss: 4.2056 - U_loss: 0.1766 - V_loss: 0.2023 - Sxx_loss: 0.9626 - Syy_loss: 2.5346e-04 - Sxy_loss: 0.8841 - sub_7_loss: 0.9991 - sub_8_loss: 0.0398 - sub_9_loss: 0.9030 - div_29_loss: 7.1977e-06 - div_30_loss: 1.1296e-07 - lr: 0.0010 - time: 1.4868
# Epoch 17/100
# 56/56 - 1s - loss: 4.1822 - U_loss: 0.1602 - V_loss: 0.1909 - Sxx_loss: 0.9560 - Syy_loss: 2.1496e-04 - Sxy_loss: 0.9058 - sub_7_loss: 1.0021 - sub_8_loss: 0.0399 - sub_9_loss: 0.9200 - div_29_loss: 1.0449e-05 - div_30_loss: 2.1697e-07 - lr: 0.0010 - time: 1.4730
# Epoch 18/100
# 56/56 - 1s - loss: 4.1761 - U_loss: 0.1531 - V_loss: 0.1883 - Sxx_loss: 0.9743 - Syy_loss: 2.0522e-04 - Sxy_loss: 0.8900 - sub_7_loss: 1.0186 - sub_8_loss: 0.0408 - sub_9_loss: 0.9142 - div_29_loss: 1.2226e-05 - div_30_loss: 1.2092e-07 - lr: 0.0010 - time: 1.4419
# Epoch 19/100
# 56/56 - 1s - loss: 4.1643 - U_loss: 0.1497 - V_loss: 0.1830 - Sxx_loss: 0.9612 - Syy_loss: 2.0399e-04 - Sxy_loss: 0.8871 - sub_7_loss: 0.9998 - sub_8_loss: 0.0419 - sub_9_loss: 0.9078 - div_29_loss: 9.5638e-06 - div_30_loss: 1.9552e-07 - lr: 0.0010 - time: 1.4452
# Epoch 20/100
# 56/56 - 2s - loss: 4.1492 - U_loss: 0.1432 - V_loss: 0.1787 - Sxx_loss: 0.9579 - Syy_loss: 1.7058e-04 - Sxy_loss: 0.8831 - sub_7_loss: 0.9947 - sub_8_loss: 0.0418 - sub_9_loss: 0.9031 - div_29_loss: 1.2515e-05 - div_30_loss: 1.0936e-07 - lr: 0.0010 - time: 1.5271
# Epoch 21/100
# 56/56 - 1s - loss: 4.1230 - U_loss: 0.1365 - V_loss: 0.1695 - Sxx_loss: 0.9601 - Syy_loss: 1.8950e-04 - Sxy_loss: 0.8840 - sub_7_loss: 0.9966 - sub_8_loss: 0.0458 - sub_9_loss: 0.8922 - div_29_loss: 8.3322e-06 - div_30_loss: 1.5551e-07 - lr: 0.0010 - time: 1.4456
# Epoch 22/100
# 56/56 - 2s - loss: 4.1408 - U_loss: 0.1338 - V_loss: 0.1760 - Sxx_loss: 0.9542 - Syy_loss: 1.7646e-04 - Sxy_loss: 0.8921 - sub_7_loss: 0.9983 - sub_8_loss: 0.0520 - sub_9_loss: 0.9082 - div_29_loss: 1.2976e-05 - div_30_loss: 2.2549e-07 - lr: 0.0010 - time: 1.5083
# Epoch 23/100
# 56/56 - 1s - loss: 4.1414 - U_loss: 0.1308 - V_loss: 0.1672 - Sxx_loss: 0.9984 - Syy_loss: 1.4973e-04 - Sxy_loss: 0.9149 - sub_7_loss: 1.0279 - sub_8_loss: 0.0497 - sub_9_loss: 0.9300 - div_29_loss: 9.4235e-06 - div_30_loss: 2.2630e-07 - lr: 0.0010 - time: 1.4776
# Epoch 24/100
# 56/56 - 1s - loss: 4.1237 - U_loss: 0.1242 - V_loss: 0.1736 - Sxx_loss: 0.9533 - Syy_loss: 1.3857e-04 - Sxy_loss: 0.8854 - sub_7_loss: 0.9980 - sub_8_loss: 0.0474 - sub_9_loss: 0.9048 - div_29_loss: 1.0764e-05 - div_30_loss: 1.0636e-07 - lr: 0.0010 - time: 1.4271
# Epoch 25/100
# 56/56 - 1s - loss: 4.0940 - U_loss: 0.1191 - V_loss: 0.1640 - Sxx_loss: 0.9512 - Syy_loss: 1.3699e-04 - Sxy_loss: 0.8955 - sub_7_loss: 0.9986 - sub_8_loss: 0.0510 - sub_9_loss: 0.9039 - div_29_loss: 1.2715e-05 - div_30_loss: 2.1770e-07 - lr: 0.0010 - time: 1.4446
# Epoch 26/100
# 56/56 - 2s - loss: 4.1144 - U_loss: 0.1239 - V_loss: 0.1658 - Sxx_loss: 0.9675 - Syy_loss: 1.3993e-04 - Sxy_loss: 0.8889 - sub_7_loss: 1.0009 - sub_8_loss: 0.0487 - sub_9_loss: 0.9029 - div_29_loss: 1.3514e-05 - div_30_loss: 2.0731e-07 - lr: 0.0010 - time: 1.5303
# Epoch 27/100
# 56/56 - 2s - loss: 4.0847 - U_loss: 0.1109 - V_loss: 0.1580 - Sxx_loss: 0.9612 - Syy_loss: 1.1715e-04 - Sxy_loss: 0.8887 - sub_7_loss: 1.0105 - sub_8_loss: 0.0516 - sub_9_loss: 0.9017 - div_29_loss: 1.4677e-05 - div_30_loss: 1.3329e-07 - lr: 0.0010 - time: 1.6515
# Epoch 28/100
# 56/56 - 2s - loss: 4.0900 - U_loss: 0.1075 - V_loss: 0.1578 - Sxx_loss: 0.9551 - Syy_loss: 1.3867e-04 - Sxy_loss: 0.8921 - sub_7_loss: 0.9951 - sub_8_loss: 0.0564 - sub_9_loss: 0.9054 - div_29_loss: 1.7254e-05 - div_30_loss: 1.4072e-07 - lr: 0.0010 - time: 1.5532
# Epoch 29/100
# 56/56 - 1s - loss: 4.0846 - U_loss: 0.1067 - V_loss: 0.1597 - Sxx_loss: 0.9529 - Syy_loss: 1.1213e-04 - Sxy_loss: 0.9125 - sub_7_loss: 0.9914 - sub_8_loss: 0.0494 - sub_9_loss: 0.9321 - div_29_loss: 1.3100e-05 - div_30_loss: 1.0308e-07 - lr: 0.0010 - time: 1.4751
# Epoch 30/100
# 56/56 - 1s - loss: 4.0925 - U_loss: 0.1050 - V_loss: 0.1561 - Sxx_loss: 0.9464 - Syy_loss: 1.3231e-04 - Sxy_loss: 0.8885 - sub_7_loss: 0.9918 - sub_8_loss: 0.0558 - sub_9_loss: 0.9187 - div_29_loss: 1.3573e-05 - div_30_loss: 1.4753e-07 - lr: 0.0010 - time: 1.4469
# Epoch 31/100
# 56/56 - 1s - loss: 4.0576 - U_loss: 0.1004 - V_loss: 0.1534 - Sxx_loss: 0.9560 - Syy_loss: 1.1220e-04 - Sxy_loss: 0.8924 - sub_7_loss: 0.9951 - sub_8_loss: 0.0512 - sub_9_loss: 0.9112 - div_29_loss: 1.7894e-05 - div_30_loss: 1.1883e-07 - lr: 0.0010 - time: 1.4452
# Epoch 32/100
# 56/56 - 1s - loss: 4.0836 - U_loss: 0.0988 - V_loss: 0.1536 - Sxx_loss: 1.0057 - Syy_loss: 9.6837e-05 - Sxy_loss: 0.8984 - sub_7_loss: 1.0339 - sub_8_loss: 0.0566 - sub_9_loss: 0.9069 - div_29_loss: 1.2478e-05 - div_30_loss: 1.5102e-07 - lr: 0.0010 - time: 1.3842
# Epoch 33/100
# 56/56 - 1s - loss: 4.0484 - U_loss: 0.0950 - V_loss: 0.1510 - Sxx_loss: 0.9407 - Syy_loss: 8.2864e-05 - Sxy_loss: 0.8876 - sub_7_loss: 0.9793 - sub_8_loss: 0.0545 - sub_9_loss: 0.9006 - div_29_loss: 1.6973e-05 - div_30_loss: 7.8284e-08 - lr: 0.0010 - time: 1.4486
# Epoch 34/100
# 56/56 - 1s - loss: 4.0530 - U_loss: 0.0927 - V_loss: 0.1490 - Sxx_loss: 0.9451 - Syy_loss: 8.5724e-05 - Sxy_loss: 0.8867 - sub_7_loss: 0.9892 - sub_8_loss: 0.0606 - sub_9_loss: 0.8965 - div_29_loss: 1.4777e-05 - div_30_loss: 1.7437e-07 - lr: 0.0010 - time: 1.4001
# Epoch 35/100
# 56/56 - 2s - loss: 4.0413 - U_loss: 0.0897 - V_loss: 0.1400 - Sxx_loss: 0.9591 - Syy_loss: 8.7091e-05 - Sxy_loss: 0.8842 - sub_7_loss: 0.9886 - sub_8_loss: 0.0598 - sub_9_loss: 0.8950 - div_29_loss: 2.0600e-05 - div_30_loss: 1.4168e-07 - lr: 0.0010 - time: 1.5774
# Epoch 36/100
# 56/56 - 2s - loss: 4.0416 - U_loss: 0.0910 - V_loss: 0.1415 - Sxx_loss: 0.9534 - Syy_loss: 6.5776e-05 - Sxy_loss: 0.8947 - sub_7_loss: 0.9842 - sub_8_loss: 0.0578 - sub_9_loss: 0.8972 - div_29_loss: 1.1690e-05 - div_30_loss: 1.6782e-07 - lr: 0.0010 - time: 1.5309
# Epoch 37/100
# 56/56 - 1s - loss: 4.0310 - U_loss: 0.0881 - V_loss: 0.1433 - Sxx_loss: 0.9452 - Syy_loss: 6.8177e-05 - Sxy_loss: 0.8847 - sub_7_loss: 0.9856 - sub_8_loss: 0.0547 - sub_9_loss: 0.9005 - div_29_loss: 1.5673e-05 - div_30_loss: 1.5795e-07 - lr: 0.0010 - time: 1.4410
# Epoch 38/100
# 56/56 - 2s - loss: 4.0264 - U_loss: 0.0874 - V_loss: 0.1340 - Sxx_loss: 0.9769 - Syy_loss: 7.4841e-05 - Sxy_loss: 0.9010 - sub_7_loss: 1.0176 - sub_8_loss: 0.0674 - sub_9_loss: 0.9102 - div_29_loss: 2.0331e-05 - div_30_loss: 1.2886e-07 - lr: 0.0010 - time: 1.8938
# Epoch 39/100
# 56/56 - 2s - loss: 4.0268 - U_loss: 0.0822 - V_loss: 0.1396 - Sxx_loss: 0.9463 - Syy_loss: 6.5692e-05 - Sxy_loss: 0.8823 - sub_7_loss: 0.9814 - sub_8_loss: 0.0618 - sub_9_loss: 0.8920 - div_29_loss: 1.9012e-05 - div_30_loss: 8.0284e-08 - lr: 0.0010 - time: 1.5383
# Epoch 40/100
# 56/56 - 1s - loss: 4.0108 - U_loss: 0.0814 - V_loss: 0.1260 - Sxx_loss: 0.9504 - Syy_loss: 7.8611e-05 - Sxy_loss: 0.8879 - sub_7_loss: 0.9831 - sub_8_loss: 0.0632 - sub_9_loss: 0.8941 - div_29_loss: 1.8023e-05 - div_30_loss: 2.8470e-07 - lr: 0.0010 - time: 1.4205
# Epoch 41/100
# 56/56 - 1s - loss: 4.0053 - U_loss: 0.0731 - V_loss: 0.1313 - Sxx_loss: 0.9913 - Syy_loss: 5.9942e-05 - Sxy_loss: 0.8970 - sub_7_loss: 1.0352 - sub_8_loss: 0.0617 - sub_9_loss: 0.9075 - div_29_loss: 1.4232e-05 - div_30_loss: 7.6823e-08 - lr: 0.0010 - time: 1.4686
# Epoch 42/100
# 56/56 - 1s - loss: 4.0204 - U_loss: 0.0775 - V_loss: 0.1305 - Sxx_loss: 0.9542 - Syy_loss: 6.2038e-05 - Sxy_loss: 0.8944 - sub_7_loss: 0.9805 - sub_8_loss: 0.0598 - sub_9_loss: 0.9093 - div_29_loss: 1.8620e-05 - div_30_loss: 1.0120e-07 - lr: 0.0010 - time: 1.4517
# Epoch 43/100
# 56/56 - 1s - loss: 3.9932 - U_loss: 0.0770 - V_loss: 0.1275 - Sxx_loss: 0.9419 - Syy_loss: 5.4915e-05 - Sxy_loss: 0.8900 - sub_7_loss: 0.9792 - sub_8_loss: 0.0591 - sub_9_loss: 0.9036 - div_29_loss: 1.9352e-05 - div_30_loss: 1.3400e-07 - lr: 0.0010 - time: 1.3765
# Epoch 44/100
# 56/56 - 1s - loss: 3.9934 - U_loss: 0.0683 - V_loss: 0.1259 - Sxx_loss: 0.9435 - Syy_loss: 6.0692e-05 - Sxy_loss: 0.8842 - sub_7_loss: 0.9789 - sub_8_loss: 0.0608 - sub_9_loss: 0.8948 - div_29_loss: 1.8852e-05 - div_30_loss: 9.7708e-08 - lr: 0.0010 - time: 1.4301
# Epoch 45/100
# 56/56 - 1s - loss: 4.0082 - U_loss: 0.0706 - V_loss: 0.1232 - Sxx_loss: 0.9504 - Syy_loss: 7.7137e-05 - Sxy_loss: 0.9066 - sub_7_loss: 0.9830 - sub_8_loss: 0.0646 - sub_9_loss: 0.9278 - div_29_loss: 2.0243e-05 - div_30_loss: 2.5541e-07 - lr: 0.0010 - time: 1.4057
# Epoch 46/100
# 56/56 - 1s - loss: 3.9853 - U_loss: 0.0639 - V_loss: 0.1208 - Sxx_loss: 0.9410 - Syy_loss: 7.3928e-05 - Sxy_loss: 0.8848 - sub_7_loss: 0.9726 - sub_8_loss: 0.0647 - sub_9_loss: 0.8970 - div_29_loss: 1.7984e-05 - div_30_loss: 8.8894e-08 - lr: 0.0010 - time: 1.4304
# Epoch 47/100
# 56/56 - 1s - loss: 4.0019 - U_loss: 0.0673 - V_loss: 0.1222 - Sxx_loss: 0.9447 - Syy_loss: 5.4419e-05 - Sxy_loss: 0.8839 - sub_7_loss: 0.9743 - sub_8_loss: 0.0661 - sub_9_loss: 0.9056 - div_29_loss: 2.0502e-05 - div_30_loss: 2.1510e-07 - lr: 0.0010 - time: 1.4143
# Epoch 48/100
# 56/56 - 1s - loss: 3.9975 - U_loss: 0.0610 - V_loss: 0.1230 - Sxx_loss: 0.9473 - Syy_loss: 4.7442e-05 - Sxy_loss: 0.8844 - sub_7_loss: 0.9806 - sub_8_loss: 0.0651 - sub_9_loss: 0.9035 - div_29_loss: 1.7163e-05 - div_30_loss: 1.4762e-07 - lr: 0.0010 - time: 1.4260
# Epoch 49/100
# 56/56 - 2s - loss: 3.9817 - U_loss: 0.0660 - V_loss: 0.1240 - Sxx_loss: 0.9561 - Syy_loss: 4.9158e-05 - Sxy_loss: 0.8880 - sub_7_loss: 0.9934 - sub_8_loss: 0.0658 - sub_9_loss: 0.8943 - div_29_loss: 1.5733e-05 - div_30_loss: 1.3947e-07 - lr: 0.0010 - time: 2.1418
# Epoch 50/100
# 56/56 - 1s - loss: 3.9952 - U_loss: 0.0613 - V_loss: 0.1219 - Sxx_loss: 0.9578 - Syy_loss: 7.1875e-05 - Sxy_loss: 0.9089 - sub_7_loss: 0.9862 - sub_8_loss: 0.0678 - sub_9_loss: 0.9169 - div_29_loss: 1.7038e-05 - div_30_loss: 1.5208e-07 - lr: 0.0010 - time: 1.4549
# Epoch 51/100
# 56/56 - 1s - loss: 3.9950 - U_loss: 0.0674 - V_loss: 0.1206 - Sxx_loss: 0.9546 - Syy_loss: 4.5785e-05 - Sxy_loss: 0.9053 - sub_7_loss: 0.9791 - sub_8_loss: 0.0677 - sub_9_loss: 0.9280 - div_29_loss: 1.8644e-05 - div_30_loss: 1.3176e-07 - lr: 0.0010 - time: 1.4837
# Epoch 52/100
# 56/56 - 1s - loss: 3.9958 - U_loss: 0.0605 - V_loss: 0.1212 - Sxx_loss: 0.9440 - Syy_loss: 4.1737e-05 - Sxy_loss: 0.8835 - sub_7_loss: 0.9769 - sub_8_loss: 0.0652 - sub_9_loss: 0.9063 - div_29_loss: 2.0387e-05 - div_30_loss: 1.1258e-07 - lr: 0.0010 - time: 1.4557
# Epoch 53/100
# 56/56 - 2s - loss: 3.9876 - U_loss: 0.0613 - V_loss: 0.1207 - Sxx_loss: 0.9410 - Syy_loss: 3.7027e-05 - Sxy_loss: 0.8850 - sub_7_loss: 0.9803 - sub_8_loss: 0.0646 - sub_9_loss: 0.8973 - div_29_loss: 1.6299e-05 - div_30_loss: 1.4700e-07 - lr: 0.0010 - time: 1.7431
# Epoch 54/100
# 56/56 - 2s - loss: 4.0007 - U_loss: 0.0617 - V_loss: 0.1193 - Sxx_loss: 0.9618 - Syy_loss: 5.4475e-05 - Sxy_loss: 0.8824 - sub_7_loss: 0.9886 - sub_8_loss: 0.0740 - sub_9_loss: 0.9004 - div_29_loss: 1.5636e-05 - div_30_loss: 1.1760e-07 - lr: 0.0010 - time: 2.0086
# Epoch 55/100
# 56/56 - 2s - loss: 3.9891 - U_loss: 0.0607 - V_loss: 0.1207 - Sxx_loss: 0.9431 - Syy_loss: 8.8484e-05 - Sxy_loss: 0.8853 - sub_7_loss: 0.9711 - sub_8_loss: 0.0701 - sub_9_loss: 0.9020 - div_29_loss: 2.1725e-05 - div_30_loss: 1.6192e-07 - lr: 0.0010 - time: 1.6217
# Epoch 56/100
# 56/56 - 1s - loss: 3.9729 - U_loss: 0.0568 - V_loss: 0.1129 - Sxx_loss: 0.9555 - Syy_loss: 6.2114e-05 - Sxy_loss: 0.9018 - sub_7_loss: 0.9926 - sub_8_loss: 0.0652 - sub_9_loss: 0.9201 - div_29_loss: 1.9060e-05 - div_30_loss: 1.2793e-07 - lr: 0.0010 - time: 1.4801
# Epoch 57/100
# 56/56 - 1s - loss: 3.9604 - U_loss: 0.0564 - V_loss: 0.1154 - Sxx_loss: 0.9386 - Syy_loss: 4.2512e-05 - Sxy_loss: 0.9045 - sub_7_loss: 0.9737 - sub_8_loss: 0.0680 - sub_9_loss: 0.9141 - div_29_loss: 1.9869e-05 - div_30_loss: 1.5598e-07 - lr: 0.0010 - time: 1.4297
# Epoch 58/100
# 56/56 - 1s - loss: 3.9614 - U_loss: 0.0578 - V_loss: 0.1143 - Sxx_loss: 0.9455 - Syy_loss: 4.3868e-05 - Sxy_loss: 0.8853 - sub_7_loss: 0.9787 - sub_8_loss: 0.0670 - sub_9_loss: 0.8927 - div_29_loss: 2.2012e-05 - div_30_loss: 1.4077e-07 - lr: 0.0010 - time: 1.4048
# Epoch 59/100
# 56/56 - 1s - loss: 3.9701 - U_loss: 0.0569 - V_loss: 0.1119 - Sxx_loss: 0.9459 - Syy_loss: 3.9849e-05 - Sxy_loss: 0.8889 - sub_7_loss: 0.9768 - sub_8_loss: 0.0689 - sub_9_loss: 0.9015 - div_29_loss: 1.8450e-05 - div_30_loss: 1.0814e-07 - lr: 0.0010 - time: 1.4291
# Epoch 60/100
# 56/56 - 1s - loss: 3.9752 - U_loss: 0.0539 - V_loss: 0.1145 - Sxx_loss: 0.9480 - Syy_loss: 3.8664e-05 - Sxy_loss: 0.9017 - sub_7_loss: 0.9979 - sub_8_loss: 0.0671 - sub_9_loss: 0.9262 - div_29_loss: 1.6339e-05 - div_30_loss: 1.2095e-07 - lr: 0.0010 - time: 1.4163
# Epoch 61/100
# 56/56 - 1s - loss: 3.9849 - U_loss: 0.0598 - V_loss: 0.1159 - Sxx_loss: 0.9513 - Syy_loss: 5.6061e-05 - Sxy_loss: 0.8840 - sub_7_loss: 0.9727 - sub_8_loss: 0.0656 - sub_9_loss: 0.9116 - div_29_loss: 2.2225e-05 - div_30_loss: 1.8951e-07 - lr: 0.0010 - time: 1.4221
# Epoch 62/100
# 56/56 - 1s - loss: 3.9406 - U_loss: 0.0517 - V_loss: 0.1059 - Sxx_loss: 0.9290 - Syy_loss: 4.9412e-05 - Sxy_loss: 0.9455 - sub_7_loss: 0.9750 - sub_8_loss: 0.0657 - sub_9_loss: 0.9550 - div_29_loss: 1.8357e-05 - div_30_loss: 1.0705e-07 - lr: 0.0010 - time: 1.4377
# Epoch 63/100
# 56/56 - 1s - loss: 3.9485 - U_loss: 0.0555 - V_loss: 0.1098 - Sxx_loss: 0.9413 - Syy_loss: 3.8965e-05 - Sxy_loss: 0.8971 - sub_7_loss: 0.9745 - sub_8_loss: 0.0706 - sub_9_loss: 0.9069 - div_29_loss: 2.4340e-05 - div_30_loss: 1.9022e-07 - lr: 0.0010 - time: 1.4345
# Epoch 64/100
# 56/56 - 1s - loss: 3.9426 - U_loss: 0.0507 - V_loss: 0.1129 - Sxx_loss: 0.9383 - Syy_loss: 1.4123e-04 - Sxy_loss: 0.8855 - sub_7_loss: 0.9794 - sub_8_loss: 0.0674 - sub_9_loss: 0.8912 - div_29_loss: 1.5951e-05 - div_30_loss: 1.9981e-07 - lr: 0.0010 - time: 1.3984
# Epoch 65/100
# 56/56 - 1s - loss: 3.9293 - U_loss: 0.0499 - V_loss: 0.1088 - Sxx_loss: 0.9320 - Syy_loss: 5.1587e-05 - Sxy_loss: 0.8853 - sub_7_loss: 0.9674 - sub_8_loss: 0.0659 - sub_9_loss: 0.8948 - div_29_loss: 2.5575e-05 - div_30_loss: 1.4114e-07 - lr: 0.0010 - time: 1.4715
# Epoch 66/100
# 56/56 - 1s - loss: 3.9407 - U_loss: 0.0530 - V_loss: 0.1116 - Sxx_loss: 0.9197 - Syy_loss: 2.7497e-05 - Sxy_loss: 0.8986 - sub_7_loss: 0.9658 - sub_8_loss: 0.0683 - sub_9_loss: 0.9152 - div_29_loss: 2.6089e-05 - div_30_loss: 2.5756e-07 - lr: 0.0010 - time: 1.4614
# Epoch 67/100
# 56/56 - 2s - loss: 3.9330 - U_loss: 0.0507 - V_loss: 0.1093 - Sxx_loss: 0.9210 - Syy_loss: 2.8959e-05 - Sxy_loss: 0.8913 - sub_7_loss: 0.9623 - sub_8_loss: 0.0683 - sub_9_loss: 0.8979 - div_29_loss: 2.5504e-05 - div_30_loss: 2.1595e-07 - lr: 0.0010 - time: 1.8786
# Epoch 68/100
# 56/56 - 2s - loss: 3.9506 - U_loss: 0.0538 - V_loss: 0.1095 - Sxx_loss: 0.9348 - Syy_loss: 2.9500e-05 - Sxy_loss: 0.9298 - sub_7_loss: 0.9805 - sub_8_loss: 0.0746 - sub_9_loss: 0.9462 - div_29_loss: 3.5508e-05 - div_30_loss: 1.4542e-07 - lr: 0.0010 - time: 1.8901
# Epoch 69/100
# 56/56 - 1s - loss: 3.9431 - U_loss: 0.0505 - V_loss: 0.1084 - Sxx_loss: 0.9294 - Syy_loss: 6.9831e-05 - Sxy_loss: 0.8991 - sub_7_loss: 0.9786 - sub_8_loss: 0.0741 - sub_9_loss: 0.9070 - div_29_loss: 2.5338e-05 - div_30_loss: 1.4963e-07 - lr: 0.0010 - time: 1.4217
# Epoch 70/100
# 56/56 - 1s - loss: 3.9338 - U_loss: 0.0479 - V_loss: 0.1067 - Sxx_loss: 0.9180 - Syy_loss: 6.0315e-05 - Sxy_loss: 0.9061 - sub_7_loss: 0.9787 - sub_8_loss: 0.0713 - sub_9_loss: 0.9198 - div_29_loss: 3.1069e-05 - div_30_loss: 2.7190e-07 - lr: 0.0010 - time: 1.4524
# Epoch 71/100
# 56/56 - 1s - loss: 3.9121 - U_loss: 0.0530 - V_loss: 0.1079 - Sxx_loss: 0.9202 - Syy_loss: 3.8456e-05 - Sxy_loss: 0.8897 - sub_7_loss: 0.9620 - sub_8_loss: 0.0667 - sub_9_loss: 0.9017 - div_29_loss: 3.4016e-05 - div_30_loss: 7.4060e-08 - lr: 0.0010 - time: 1.4040
# Epoch 72/100
# 56/56 - 1s - loss: 3.9224 - U_loss: 0.0484 - V_loss: 0.1135 - Sxx_loss: 0.9163 - Syy_loss: 5.0758e-05 - Sxy_loss: 0.8845 - sub_7_loss: 0.9542 - sub_8_loss: 0.0722 - sub_9_loss: 0.8912 - div_29_loss: 4.3681e-05 - div_30_loss: 9.6717e-08 - lr: 0.0010 - time: 1.4213
# Epoch 73/100
# 56/56 - 1s - loss: 3.9151 - U_loss: 0.0508 - V_loss: 0.1067 - Sxx_loss: 0.9122 - Syy_loss: 1.0829e-04 - Sxy_loss: 0.9020 - sub_7_loss: 0.9710 - sub_8_loss: 0.0693 - sub_9_loss: 0.9157 - div_29_loss: 3.4538e-05 - div_30_loss: 1.2255e-07 - lr: 0.0010 - time: 1.4553
# Epoch 74/100
# 56/56 - 2s - loss: 3.9216 - U_loss: 0.0470 - V_loss: 0.1058 - Sxx_loss: 0.9208 - Syy_loss: 4.7190e-05 - Sxy_loss: 0.8901 - sub_7_loss: 0.9656 - sub_8_loss: 0.0810 - sub_9_loss: 0.8891 - div_29_loss: 4.8080e-05 - div_30_loss: 2.3848e-07 - lr: 0.0010 - time: 1.5813
# Epoch 75/100
# 56/56 - 2s - loss: 3.9004 - U_loss: 0.0464 - V_loss: 0.1049 - Sxx_loss: 0.9124 - Syy_loss: 1.2545e-04 - Sxy_loss: 0.8832 - sub_7_loss: 0.9712 - sub_8_loss: 0.0703 - sub_9_loss: 0.8920 - div_29_loss: 3.9625e-05 - div_30_loss: 1.2813e-07 - lr: 0.0010 - time: 1.7904
# Epoch 76/100
# 56/56 - 1s - loss: 3.9291 - U_loss: 0.0533 - V_loss: 0.1050 - Sxx_loss: 0.9085 - Syy_loss: 6.5570e-05 - Sxy_loss: 0.9467 - sub_7_loss: 0.9689 - sub_8_loss: 0.0755 - sub_9_loss: 0.9694 - div_29_loss: 5.6042e-05 - div_30_loss: 1.6498e-07 - lr: 0.0010 - time: 1.4050
# Epoch 77/100
# 56/56 - 1s - loss: 3.9007 - U_loss: 0.0498 - V_loss: 0.1090 - Sxx_loss: 0.8941 - Syy_loss: 3.2716e-05 - Sxy_loss: 0.8951 - sub_7_loss: 0.9579 - sub_8_loss: 0.0805 - sub_9_loss: 0.8956 - div_29_loss: 5.1773e-05 - div_30_loss: 2.7529e-07 - lr: 0.0010 - time: 1.4555
# Epoch 78/100
# 56/56 - 1s - loss: 3.9137 - U_loss: 0.0456 - V_loss: 0.1120 - Sxx_loss: 0.9063 - Syy_loss: 4.5062e-05 - Sxy_loss: 0.8845 - sub_7_loss: 0.9629 - sub_8_loss: 0.0733 - sub_9_loss: 0.9050 - div_29_loss: 7.1780e-05 - div_30_loss: 1.2527e-07 - lr: 0.0010 - time: 1.4337
# Epoch 79/100
# 56/56 - 1s - loss: 3.9148 - U_loss: 0.0482 - V_loss: 0.1101 - Sxx_loss: 0.9000 - Syy_loss: 4.2283e-04 - Sxy_loss: 0.8839 - sub_7_loss: 0.9565 - sub_8_loss: 0.0727 - sub_9_loss: 0.9075 - div_29_loss: 7.0669e-05 - div_30_loss: 1.0859e-07 - lr: 0.0010 - time: 1.4259
# Epoch 80/100
# 56/56 - 1s - loss: 3.8981 - U_loss: 0.0474 - V_loss: 0.1045 - Sxx_loss: 0.9052 - Syy_loss: 4.6630e-05 - Sxy_loss: 0.8829 - sub_7_loss: 0.9722 - sub_8_loss: 0.0809 - sub_9_loss: 0.8917 - div_29_loss: 7.3063e-05 - div_30_loss: 8.4085e-08 - lr: 0.0010 - time: 1.4183
# Epoch 81/100
# 56/56 - 1s - loss: 3.8997 - U_loss: 0.0466 - V_loss: 0.1035 - Sxx_loss: 0.9178 - Syy_loss: 3.8093e-05 - Sxy_loss: 0.9076 - sub_7_loss: 0.9829 - sub_8_loss: 0.0728 - sub_9_loss: 0.9166 - div_29_loss: 8.3544e-05 - div_30_loss: 1.5857e-07 - lr: 0.0010 - time: 1.4331
# Epoch 82/100
# 56/56 - 1s - loss: 3.9174 - U_loss: 0.0507 - V_loss: 0.1078 - Sxx_loss: 0.9052 - Syy_loss: 5.5947e-05 - Sxy_loss: 0.8921 - sub_7_loss: 0.9996 - sub_8_loss: 0.0896 - sub_9_loss: 0.8975 - div_29_loss: 9.8157e-05 - div_30_loss: 2.8225e-07 - lr: 0.0010 - time: 1.4158
# Epoch 83/100
# 56/56 - 1s - loss: 3.8630 - U_loss: 0.0471 - V_loss: 0.1105 - Sxx_loss: 0.8806 - Syy_loss: 2.8357e-05 - Sxy_loss: 0.8904 - sub_7_loss: 0.9401 - sub_8_loss: 0.0751 - sub_9_loss: 0.8985 - div_29_loss: 9.7282e-05 - div_30_loss: 1.3748e-07 - lr: 0.0010 - time: 1.4169
# Epoch 84/100
# 56/56 - 2s - loss: 3.8886 - U_loss: 0.0456 - V_loss: 0.1081 - Sxx_loss: 0.8776 - Syy_loss: 3.5460e-05 - Sxy_loss: 0.9215 - sub_7_loss: 0.9551 - sub_8_loss: 0.0840 - sub_9_loss: 0.9362 - div_29_loss: 1.1266e-04 - div_30_loss: 1.4939e-07 - lr: 0.0010 - time: 1.8965
# Epoch 85/100
# 56/56 - 2s - loss: 3.8410 - U_loss: 0.0452 - V_loss: 0.1052 - Sxx_loss: 0.8684 - Syy_loss: 2.5308e-05 - Sxy_loss: 0.8807 - sub_7_loss: 0.9437 - sub_8_loss: 0.0748 - sub_9_loss: 0.8833 - div_29_loss: 1.2335e-04 - div_30_loss: 2.7840e-07 - lr: 0.0010 - time: 1.6222
# Epoch 86/100
# 56/56 - 1s - loss: 3.8780 - U_loss: 0.0459 - V_loss: 0.1042 - Sxx_loss: 0.8870 - Syy_loss: 3.4118e-05 - Sxy_loss: 0.8833 - sub_7_loss: 0.9636 - sub_8_loss: 0.0831 - sub_9_loss: 0.8842 - div_29_loss: 1.0173e-04 - div_30_loss: 5.0159e-08 - lr: 0.0010 - time: 1.4121
# Epoch 87/100
# 56/56 - 1s - loss: 3.8731 - U_loss: 0.0430 - V_loss: 0.1049 - Sxx_loss: 0.8806 - Syy_loss: 4.1068e-05 - Sxy_loss: 0.8863 - sub_7_loss: 0.9539 - sub_8_loss: 0.0828 - sub_9_loss: 0.8930 - div_29_loss: 1.5074e-04 - div_30_loss: 1.3089e-07 - lr: 0.0010 - time: 1.4620
# Epoch 88/100
# 56/56 - 1s - loss: 3.8717 - U_loss: 0.0426 - V_loss: 0.1035 - Sxx_loss: 0.9035 - Syy_loss: 3.5767e-05 - Sxy_loss: 0.9196 - sub_7_loss: 0.9874 - sub_8_loss: 0.0768 - sub_9_loss: 0.9352 - div_29_loss: 1.3142e-04 - div_30_loss: 1.6813e-07 - lr: 0.0010 - time: 1.4252
# Epoch 89/100
# 56/56 - 1s - loss: 3.8494 - U_loss: 0.0506 - V_loss: 0.1038 - Sxx_loss: 0.8975 - Syy_loss: 7.8446e-05 - Sxy_loss: 0.8841 - sub_7_loss: 0.9787 - sub_8_loss: 0.0797 - sub_9_loss: 0.8939 - div_29_loss: 1.5604e-04 - div_30_loss: 1.4749e-07 - lr: 0.0010 - time: 1.4441
# Epoch 90/100
# 56/56 - 1s - loss: 3.9074 - U_loss: 0.0417 - V_loss: 0.1006 - Sxx_loss: 0.9105 - Syy_loss: 2.7533e-05 - Sxy_loss: 0.8855 - sub_7_loss: 0.9752 - sub_8_loss: 0.0834 - sub_9_loss: 0.8863 - div_29_loss: 1.3325e-04 - div_30_loss: 1.4130e-07 - lr: 0.0010 - time: 1.4298
# Epoch 91/100
# 56/56 - 1s - loss: 3.8407 - U_loss: 0.0457 - V_loss: 0.1078 - Sxx_loss: 0.8661 - Syy_loss: 4.2488e-05 - Sxy_loss: 0.8901 - sub_7_loss: 0.9450 - sub_8_loss: 0.0751 - sub_9_loss: 0.8978 - div_29_loss: 1.9912e-04 - div_30_loss: 1.0609e-07 - lr: 0.0010 - time: 1.4345
# Epoch 92/100
# 56/56 - 2s - loss: 3.8283 - U_loss: 0.0409 - V_loss: 0.1010 - Sxx_loss: 0.8535 - Syy_loss: 7.4420e-05 - Sxy_loss: 0.8862 - sub_7_loss: 0.9425 - sub_8_loss: 0.0775 - sub_9_loss: 0.8945 - div_29_loss: 1.9393e-04 - div_30_loss: 1.2834e-07 - lr: 0.0010 - time: 1.8365
# Epoch 93/100
# 56/56 - 1s - loss: 3.8425 - U_loss: 0.0420 - V_loss: 0.1010 - Sxx_loss: 0.8787 - Syy_loss: 3.6201e-05 - Sxy_loss: 0.8888 - sub_7_loss: 0.9440 - sub_8_loss: 0.0866 - sub_9_loss: 0.8972 - div_29_loss: 2.4602e-04 - div_30_loss: 1.2764e-07 - lr: 0.0010 - time: 1.4493
# Epoch 94/100
# 56/56 - 1s - loss: 3.8469 - U_loss: 0.0447 - V_loss: 0.1054 - Sxx_loss: 0.8524 - Syy_loss: 6.9412e-05 - Sxy_loss: 0.9076 - sub_7_loss: 0.9514 - sub_8_loss: 0.0911 - sub_9_loss: 0.9143 - div_29_loss: 2.9605e-04 - div_30_loss: 3.3434e-07 - lr: 0.0010 - time: 1.4456
# Epoch 95/100
# 56/56 - 1s - loss: 3.8427 - U_loss: 0.0407 - V_loss: 0.1002 - Sxx_loss: 0.8711 - Syy_loss: 3.8072e-05 - Sxy_loss: 0.8830 - sub_7_loss: 0.9439 - sub_8_loss: 0.0748 - sub_9_loss: 0.8916 - div_29_loss: 2.2103e-04 - div_30_loss: 9.3438e-08 - lr: 0.0010 - time: 1.4474
# Epoch 96/100
# 56/56 - 1s - loss: 3.8239 - U_loss: 0.0427 - V_loss: 0.1020 - Sxx_loss: 0.8424 - Syy_loss: 2.1607e-05 - Sxy_loss: 0.9231 - sub_7_loss: 0.9436 - sub_8_loss: 0.0808 - sub_9_loss: 0.9385 - div_29_loss: 2.9330e-04 - div_30_loss: 8.1532e-08 - lr: 0.0010 - time: 1.4249
# Epoch 97/100
# 56/56 - 1s - loss: 3.8129 - U_loss: 0.0407 - V_loss: 0.1020 - Sxx_loss: 0.8463 - Syy_loss: 3.3762e-05 - Sxy_loss: 0.8804 - sub_7_loss: 0.9334 - sub_8_loss: 0.0884 - sub_9_loss: 0.8866 - div_29_loss: 3.0466e-04 - div_30_loss: 1.1510e-07 - lr: 0.0010 - time: 1.4281
# Epoch 98/100
# 56/56 - 2s - loss: 3.8151 - U_loss: 0.0415 - V_loss: 0.1004 - Sxx_loss: 0.8299 - Syy_loss: 4.4702e-05 - Sxy_loss: 0.8895 - sub_7_loss: 0.9459 - sub_8_loss: 0.0860 - sub_9_loss: 0.8972 - div_29_loss: 3.2800e-04 - div_30_loss: 1.3591e-07 - lr: 0.0010 - time: 1.5940
# Epoch 99/100
# 56/56 - 1s - loss: 3.8109 - U_loss: 0.0413 - V_loss: 0.1036 - Sxx_loss: 0.8422 - Syy_loss: 7.5140e-05 - Sxy_loss: 0.8856 - sub_7_loss: 0.9363 - sub_8_loss: 0.0873 - sub_9_loss: 0.8968 - div_29_loss: 4.2332e-04 - div_30_loss: 1.5112e-07 - lr: 0.0010 - time: 1.4472
# Epoch 100/100
# 56/56 - 1s - loss: 3.8278 - U_loss: 0.0419 - V_loss: 0.1002 - Sxx_loss: 0.8599 - Syy_loss: 2.6437e-05 - Sxy_loss: 0.8861 - sub_7_loss: 0.9588 - sub_8_loss: 0.0906 - sub_9_loss: 0.9054 - div_29_loss: 3.8783e-04 - div_30_loss: 1.5028e-07 - lr: 0.0010 - time: 1.4801
# Input and output dimensions need re-adjustment for post-processing.
# Input and output dimensions need re-adjustment for post-processing.

# %%
plot(Emod,nu)
# Out:
# /tmp/ipykernel_2967/4189280907.py:83: RuntimeWarning: invalid value encountered in true_divide
#   return((X-mu)/sig)
# /tmp/ipykernel_2967/4189280907.py:34: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   im = AX.pcolor(X, Y, C, cmap="jet")
# (60, 46)

# %%
# Plot "exact" pressure field
#plt.imshow(P_exact, interpolation='nearest', cmap='rainbow', 
#                  extent=[x_star.min(), x_star.max(), y_star.min(), y_star.max()], 
#                  origin='lower', aspect='auto')

plt.imshow(P_exact, cmap='rainbow', 
                  extent=[x_star.min(), x_star.max(), y_star.min(), y_star.max()], 
                  origin='lower', aspect='auto')
plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2967/1597334697.py in <module>
#       4 #                  origin='lower', aspect='auto')
#       5
# ----> 6 plt.imshow(P_exact, cmap='rainbow',
#       7                   extent=[x_star.min(), x_star.max(), y_star.min(), y_star.max()],
#       8                   origin='lower', aspect='auto')
#
# NameError: name 'P_exact' is not defined

# %%
set_in.step_080.sel(field='S22')
