# %% [markdown]
# # Uniaxial Tension - Elasticity, Physics Informed Neural Network

# %% [markdown]
# Thomas Allard and Samantha Walker

# %%
#Imports
import os, sys, time
import numpy as np 
from sciann.utils.math import diff
from sciann import SciModel, Functional, Parameter
from sciann import Data, Tie
from sciann import Variable, Field
import matplotlib.pyplot as plt
import scipy.io
import netCDF4
import xarray as xr

import os
pi = np.pi

# %%
# Specify parameters and things
mode = 'train'   # 'test' to load PINN weights from previously trained model
                # 'train' to train a new model

current_file_name = 'elasticity_Yang3000_norm.ipynb'
    
#trained_file = 'trained-navier-stokes.hdf5'
data_file = '../abaqus/final_elastic/elastic_cdf.nc'

# file with nodal coordinates
node_file = '../abaqus/final_elastic/nodes.txt'

#layers = [40]*4
layers = [10, 40, 80, 100]
actf = 'tanh'
numx = 46
numy = 60
batchsize = 50
#batchsize = 16
epochs = 1000
learningrate = 0.001
independent_networks = True
verbose = 2
shuffle = True
stopafter = 500
savefreq = 100000
dtype = 'float64'
gpu = False
outputpath = 'output_norm'
outputprefix = 'res'
numxplot = 46
numyplot = 60
plot = True


Emod = 210.0
nu = 0.3

E_range = [50, 300]
nu_range = [0.1, 0.4]
x_range = [0.0, 3000.0]
y_range = [-1500.0,1500.0]
disp_range = [-1.0, 1.0]
s_range = [0.0, 200.0]

# %%
# Functions
def dispx(input_d): # xx
    #x, y = xx[0], xx[1]
    disp_x = np.asarray(input_d.sel(field='ux'))
    disp_x = np.expand_dims(disp_x, axis=0).T
    return disp_x #np.cos(2*pi*x) * np.sin(pi*y)

def dispy(input_d): # xx
    #x, y = xx[0], xx[1]
    #Q = qload
    disp_y= np.asarray(input_d.sel(field='uy'))
    disp_y = np.expand_dims(disp_y, axis=0).T
    return disp_y #np.sin(pi*x) * Q * y**4/4

def stressxx(input_d): # xx
    stress_xx = np.asarray(input_d.sel(field='S11'))
    stress_xx = np.expand_dims(stress_xx, axis=0).T
    return stress_xx
    #set.sel(field='S11').to_array() #(lmbd+2*mu)*strainxx(xx) + lmbd*strainyy(xx)

def stressyy(input_d): # xx
    stress_yy = np.asarray(input_d.sel(field='S22'))
    stress_yy = np.expand_dims(stress_yy, axis=0).T
    return stress_yy
    #return set.sel(field='S22').to_array() #(lmbd+2*mu)*strainyy(xx) + lmbd*strainxx(xx)

def stressxy(input_d): # xx
    stress_xy = np.asarray(input_d.sel(field='S12'))
    stress_xy = np.expand_dims(stress_xy, axis=0).T
    return stress_xy
    #return set.sel(field='S21').to_array() #2.0*mu*strainxy(xx)

def cust_pcolor(AX, X, Y, C, title):
    im = AX.pcolor(X, Y, C, cmap="jet")
    AX.axis("equal")
    AX.axis("off")
    AX.set_title(title, fontsize=14)
    plt.colorbar(im, ax=AX)

def cust_semilogx(AX, X, Y, xlabel, ylabel):
    if X is None:
        im = AX.semilogy(Y)
    else:
        im = AX.semilogy(X, Y)
    if xlabel is not None: AX.set_xlabel(xlabel)
    if ylabel is not None: AX.set_ylabel(ylabel)

# Create function to read text files in as np array
def file2array(file):
    # load in each line of data as array
    with open(file, 'r') as f:
        line_string = f.read().splitlines()
    
    # loop through the lines from the file, split, and append to list
    list = []
    timestamp = 0 # default 
    for i, line in enumerate(line_string):
        list.append(line.split())

    # convert list to an array of type float64
    array = np.asarray(list, dtype=np.float64)

    return(array)

def rearrange(numx, numy, field):
    stuff = np.zeros([numx,numy])
    for k,f in enumerate(field):
        i = int(k % numx)
        j = int(np.floor(k/numx))
        stuff[i,j] = f
        
    stuff = stuff.T
    return(stuff)

def normalize(value, min, max,a,b):
    norm = (b-a)*((value-min)/(max-min))+a
    return(norm)

# %%
# load in data_file as xarray DataSet
set_in = xr.open_dataset(data_file)

# %%
# Load in displacements and create an ndarray
disp_x=set_in.sel(field='ux').to_array()
disp_y=set_in.sel(field='uy').to_array()
disps=np.dstack([disp_x,disp_y])

# %%
# Extract time and put in an array
times = [] # will be shape (81,)
for DataArray in set_in.values():
    times.append(DataArray.attrs['time'])
print(np.shape(times))
# Out:
# (81,)

# %%
# read in node file and save as grid
nodal_coordinates = file2array(node_file)
grid = nodal_coordinates[:,1:3]
grid = np.array([grid[:,0],grid[:,1]+1500.])
grid = np.expand_dims(grid, axis=0)
grid = np.moveaxis(grid, 0, -1)
print(np.shape(grid))
#print(grid)
# Out:
# (2, 2760, 1)

# %%
# Check that data loaded in correctly by plotting disp_y for node 1 (bottom left) and node 2715 (top left)
plt.plot(times,set_in.sel(field='uy',node='1').to_array(),   color='red',label='node_1')
plt.plot(times,set_in.sel(field='uy',node='2715').to_array(),color='blue',label='node_2715')
plt.xlabel('time (s)')
plt.ylabel('displacement (mm)')
plt.legend()
plt.show()

# %%
# Check that stress normalization is working
stresses=normalize(set_in.sel(field='S22',node='1').to_array(),s_range[0],s_range[1],-1,1)
plt.plot(times,stresses,color='blue',label='node_2715')
plt.xlabel('time (s)')
plt.ylabel('normalized stress (MPa)')
plt.legend()
plt.show()

# %%
# define function for subsampling data
def PrepareData(set_in, nodal_coordinates, times, random=True): # num_data, data_file
    
    # Load data
    #data = scipy.io.loadmat('/content/' + data_file)
    #data = scipy.io.loadmat(data_file)
    
    # will want to change these to correspond to our input variables
    #U_star = data['U_star'] # N x 2 x T
    ## displacements -> U_star
    disp_x=normalize(set_in.sel(field='ux').to_array(),disp_range[0],disp_range[1],-1,1) # T x N # (81, 2760)
    disp_y=normalize(set_in.sel(field='uy').to_array(),disp_range[0],disp_range[1],-1,1) # T x N # (81, 2760)
    U_star=np.dstack([disp_x,disp_y])     # T x N x 2 (81, 2760, 2)
    
    # time
    times = [] # will be shape (81,)
    for DataArray in set_in.values():
        times.append(DataArray.attrs['time'])
        

    
    # Solution S22 -> P_star
    sxx_star = normalize(np.asarray(set_in.sel(field='S11').to_array()),s_range[0],s_range[1],-1,1) # T x N
    syy_star = normalize(np.asarray(set_in.sel(field='S22').to_array()),s_range[0],s_range[1],-1,1) # T x N
    sxy_star = normalize(np.asarray(set_in.sel(field='S12').to_array()),s_range[0],s_range[1],-1,1) # T x N

    # time -> t_star
    t_star = times #data['t'] # T x 1 # (81,)
    
    # grid -> X_star
    gridd = nodal_coordinates[:,1:3]
    print(np.shape(gridd))
    #gridd = np.array([gridd[:,0],gridd[:,1]+1500.]).T
    gridd = np.array([normalize(gridd[:,0],x_range[0],x_range[1],-1,1),normalize(gridd[:,1],y_range[0],y_range[1],-1,1)]).T
    print(np.shape(gridd))
    X_star = gridd # grid is N x 2 or shape (2760, 2)
    
    N = np.shape(X_star)[0] #X_star.shape[0]
    T = np.shape(t_star)[0] #t_star.shape[0]
    
    # Rearrange Data 
    XX = np.tile(X_star[:,0:1], (1,T)) # N x T # (2760, 81)
    YY = np.tile(X_star[:,1:2], (1,T)) # N x T # (2760, 81)
    TT = np.tile(t_star, (1,N)).T # NT x 1 # (223560, 1)
    
    UU = U_star[:,:,0].T # N x T
    VV = U_star[:,:,1].T # N x T
    SSxx = sxx_star.T # N x T
    SSyy = syy_star.T # N x T
    SSxy = sxy_star.T # N x T

    
    # Pick random data.
    if random:
        idx = np.random.choice(N*T, N, replace=False) # num_data
    else:
        idx = np.arange(0, N*T)
    
    x = XX
    y = YY
    t = t_star
    
    x = XX.flatten()[idx,None] # NT x 1
    y = YY.flatten()[idx,None] # NT x 1
    t = TT.flatten()[idx,None] # NT x 1
 
    
    u = UU # T x N # (81, 2760)
    v = VV # T x N # (81, 2760)
    
    u = UU.flatten()[idx,None] # NT x 1
    v = VV.flatten()[idx,None] # NT x 1
    sxx = SSxx.flatten()[idx,None] # NT x 1
    syy = SSyy.flatten()[idx,None] # NT x 1
    sxy = SSxy.flatten()[idx,None] # NT x 1
    
        

    return (x,y,t,u,v,sxx,syy,sxy)

# %%
x,y,t,u,v,sxx, syy, sxy = PrepareData(set_in, nodal_coordinates, times, random=True)

# check shapes
print(f'shape of x = {np.shape(x)}')
print(f'shape of y = {np.shape(y)}')
print(f'shape of t = {np.shape(t)}')
print(f'shape of u = {np.shape(u)}')
print(f'shape of v = {np.shape(v)}')
print(f'shape of sxx = {np.shape(sxx)}')
print(f'shape of syy = {np.shape(syy)}')
print(f'shape of sxy = {np.shape(sxy)}')
# Out:
# (2760, 2)
# (2760, 2)
# shape of x = (2760, 1)
# shape of y = (2760, 1)
# shape of t = (2760, 1)
# shape of u = (2760, 1)
# shape of v = (2760, 1)
# shape of sxx = (2760, 1)
# shape of syy = (2760, 1)
# shape of sxy = (2760, 1)

# %%
def plot(Emod, nu):
    output_file_name = os.path.join(outputpath, outputprefix)
    #fname = output_file_name + "_{}_".format(actf) + "x".join([str(x) for x in layers])
    fname = output_file_name + "_{}_".format(actf)
    
    loss = np.loadtxt(fname+"_loss")
    times = np.loadtxt(fname+"_Time")
    fig, ax = plt.subplots(1, 2, figsize=(7, 3), dpi=300)
    cust_semilogx(ax[0], None, loss/loss[0], "epochs", "L/L0")
    cust_semilogx(ax[1], times, loss/loss[0], "time(s)", None)
    fig.subplots_adjust(left=0.1, right=0.9, bottom=0.15, top=0.9, wspace=0.3, hspace=0.2)
    plt.savefig("{}_loss.png".format(output_file_name))
    
    Xmesh = np.loadtxt(fname+"_Xmesh", delimiter=',')
    Ymesh = np.loadtxt(fname+"_Ymesh", delimiter=',')
    
    input_d = set_in.step_080
    data_d1 = normalize(np.asarray(input_d.sel(field='ux')),disp_range[0],disp_range[1],-1,1)
    data_d2 = normalize(np.asarray(input_d.sel(field='uy')),disp_range[0],disp_range[1],-1,1)
    data_d3 = normalize(np.asarray(input_d.sel(field='S11')),s_range[0],s_range[1],-1,1)
    data_d4 = normalize(np.asarray(input_d.sel(field='S22')),s_range[0],s_range[1],-1,1)
    data_d5 = normalize(np.asarray(input_d.sel(field='S12')),s_range[0],s_range[1],-1,1)
    
    Emods = normalize(Emod,E_range[0],E_range[1],0.1,1)
    nus = normalize(nu,nu_range[0],nu_range[1],0.1,1)
    
    fig, ax = plt.subplots(2, 2, figsize=(8, 6), dpi=300)
    cust_pcolor(ax[0, 0], Xmesh, Ymesh, np.ones_like(Xmesh)*Emods, "E*={:.3f}".format(Emods))
    cust_pcolor(ax[0, 1], Xmesh, Ymesh, np.ones_like(Xmesh)*nu, "nu*={:.3f}".format(nus))
    Emods_pred = np.loadtxt(fname+"_Emods", delimiter=',')
    nus_pred = np.loadtxt(fname+"_nus", delimiter=',')
    cust_pcolor(ax[1, 0], Xmesh, Ymesh, np.ones_like(Xmesh)*Emods_pred, "E={:.3f}".format(Emods_pred.mean()))
    cust_pcolor(ax[1, 1], Xmesh, Ymesh, np.ones_like(Xmesh)*nus_pred, "nu={:.3f}".format(nus_pred.mean()))
    plt.savefig("{}_Parameters.png".format(output_file_name))
    
    fig, ax = plt.subplots(2, 2, figsize=(8, 6), dpi=300)
    plot_ux = rearrange(numx, numy, np.asarray(input_d.sel(field='ux')))
    plot_uy = rearrange(numx, numy, np.asarray(input_d.sel(field='uy')))
    print(np.shape(np.loadtxt(fname+"_U", delimiter=',')))
    cust_pcolor(ax[0, 0], Xmesh, Ymesh, plot_ux, "Ux*")
    cust_pcolor(ax[0, 1], Xmesh, Ymesh, plot_uy, "Uy*")
    cust_pcolor(ax[1, 0], Xmesh, Ymesh, np.loadtxt(fname+"_U", delimiter=','), "Ux")
    cust_pcolor(ax[1, 1], Xmesh, Ymesh, np.loadtxt(fname+"_V", delimiter=','), "Uy")
    plt.savefig("{}_Displacement.png".format(output_file_name))
    
    fig, ax = plt.subplots(2, 3, figsize=(11, 6), dpi=300)
    #plot_s11 = rearrange(numx, numy, np.asarray(input_d.sel(field='S11')))
    plot_s22 = rearrange(numx, numy, normalize(np.asarray(input_d.sel(field='S22')),s_range[0],s_range[1],-1,1))
    #plot_s12 = rearrange(numx, numy, np.asarray(input_d.sel(field='S12')))
    plot_s11 = np.zeros([numy,numx])
    #plot_s22 = np.zeros([numx*numy,1])
    plot_s12 = np.zeros([numy,numx])
    cust_pcolor(ax[0, 0], Xmesh, Ymesh, plot_s11, "Sxx*")
    cust_pcolor(ax[0, 1], Xmesh, Ymesh, plot_s22, "Syy*")
    cust_pcolor(ax[0, 2], Xmesh, Ymesh, plot_s12, "Sxy*")
    cust_pcolor(ax[1, 0], Xmesh, Ymesh, np.loadtxt(fname+"_Sxx", delimiter=','), "Sxx")
    cust_pcolor(ax[1, 1], Xmesh, Ymesh, np.loadtxt(fname+"_Syy", delimiter=','), "Syy")
    cust_pcolor(ax[1, 2], Xmesh, Ymesh, np.loadtxt(fname+"_Sxy", delimiter=','), "Sxy")
    fig.subplots_adjust(left=0.1, right=0.9, bottom=0.05, top=0.9, wspace=0.3, hspace=0.2)
    plt.savefig("{}_Stress.png".format(output_file_name))
    
    #fig, ax = plt.subplots(2, 3, figsize=(11, 6), dpi=300)
    #plot_exx = rearrange(numx, numy, np.asarray(input_d.sel(field='NE11')))
    #plot_eyy = rearrange(numx, numy, np.asarray(input_d.sel(field='NE22')))
    #plot_exy = rearrange(numx, numy, np.asarray(input_d.sel(field='NE12')))
    #cust_pcolor(ax[0, 0], Xmesh, Ymesh, plot_exx, "Exx*")
    #cust_pcolor(ax[0, 1], Xmesh, Ymesh, plot_eyy, "Eyy*")
    #cust_pcolor(ax[0, 2], Xmesh, Ymesh, plot_exy, "Exy*")
    #cust_pcolor(ax[1, 0], Xmesh, Ymesh, np.loadtxt(fname+"_Exx", delimiter=','), "Exx")
    #cust_pcolor(ax[1, 1], Xmesh, Ymesh, np.loadtxt(fname+"_Eyy", delimiter=','), "Eyy")
    #cust_pcolor(ax[1, 2], Xmesh, Ymesh, np.loadtxt(fname+"_Exy", delimiter=','), "Exy")
    #fig.subplots_adjust(left=0.1, right=0.9, bottom=0.05, top=0.9, wspace=0.3, hspace=0.2)
    #plt.savefig("{}_Strain.png".format(output_file_name))

# %%
# Setting up cost function
#layers = 6
#neurons = 10

x = Variable("x", dtype='float64')
y = Variable("y", dtype='float64')
t = Variable("t", dtype='float64')

U = Functional("U", [x,y,t], layers, actf)
V = Functional("V", [x,y,t], layers, actf)
Sxx = Functional("Sxx", [x,y,t], layers, actf)
Syy = Functional("Syy", [x,y,t], layers, actf)
Sxy = Functional("Sxy", [x,y,t], layers, actf)

'''
Abaqus takes E and nu
The Navier form of equations takes mu and lambda

E = [mu*(3*lambda + 2*mu)] / [lambda + mu]
nu = lambda / [2*(lambda + mu)]

mu = E / [2*(1 + nu)]
lambda = [nu*E] / [(1 + nu)*(1 - 2*nu)]

Inputs values:
E  = 210 GPa -> 0.280
nu = 0.3     -> 0.333

Expected values:
mu     =  80.769231 GPa
lambda = 121.15438 GPa
'''

Emods = Parameter(0.9*np.random.rand()+0.1, inputs=[x,y,t], min_max=[0.1,1.0], name="Emods")
nus = Parameter(0.3*np.random.rand()+0.1, inputs=[x,y,t], min_max=[0.1,0.4], name="nus")

# Strains
Exx = diff(U, x)
Eyy = diff(V, y)
Exy = 0.5*(diff(U,y) + diff(V,x))

# define constraints
d1 = Data(U)
d2 = Data(V)
d3 = Data(Sxx)
d4 = Data(Syy)
d5 = Data(Sxy)

# some constants
C11 = Emods/(1-(nus**2))
C22 = C11*nus
C33 = Emods/(1*(1-nus))

# Equations
c1 = Tie(Sxx, C11*Exx + C22*Eyy)
c2 = Tie(Syy, C11*Eyy + C22*Exx)
c3 = Tie(Sxy, C33*Exy)

Lx = diff(Sxx, x) + diff(Sxy, y)
Ly = diff(Sxy, x) + diff(Syy, y)


if mode == 'train':
    
    # define output folder. 
    if not os.path.isdir(outputpath):
        os.mkdir(outputpath)
        
    output_file_name = os.path.join(outputpath, outputprefix)
    #fname = output_file_name + "_{}_".format(actf) + "x".join([str(x) for x in layers])
    fname = output_file_name + "_{}_".format(actf) 
    
    # Call in training data
    x_train, y_train, t_train, u_train, v_train, sxx_train, syy_train, sxy_train = PrepareData(set_in, nodal_coordinates, times, random=True)
    
    model = SciModel(
        inputs=[x, y, t],
        targets = [d1, d2, d3, d4, d5, c1, c2, c3, Lx, Ly],
        #targets = [d1, d2, c1, c2, c3],
        loss_func = "mse",
        #plot_to_file = "NS-Model.png"
    )
    
    input_data = [x_train, y_train, t_train]
    print(np.shape(input_data))

    # like an initial condition for c1, c2, c3, and c4
    data_d1 = u_train
    data_d2 = v_train
    data_d3 = sxx_train
    data_d4 = syy_train
    data_d5 = sxy_train
    data_c1 = sxx_train #'zeros'
    data_c2 = syy_train #'zeros'
    data_c3 = sxy_train #'zeros'
    data_Lx = 'zeros'
    data_Ly = 'zeros'
    
    target_data = [data_d1, data_d2, data_d3, data_d4, data_d5, 
                   data_c1, data_c2, data_c3,
                   data_Lx, data_Ly]
    #target_data = [data_d1, data_d2, data_d3, data_d4, data_d5, data_c1, data_c2, data_c3]
    #target_data = [data_d1, data_d2, data_c1, data_c2, data_c3]

    ## hyper parameter define

    #Epochs= 100
    #Batch_size=100
    #Learning_rate=0.001
    #Reduce_lr_after=1000
    
#log the data

    # Prepare training data 
    ## Training grid 
    XMIN, XMAX = -1.0, 1.0 # 0.0, 3000.0 #1.0
    YMIN, YMAX = -1.0, 1.0 # -1500., 1500. # 0.0, 1.0
    #YMIN, YMAX = 0.0, 3000.0 # 0.0, 1.0
    Xmesh = np.linspace(XMIN, XMAX, numx).reshape((-1, 1))
    Ymesh = np.linspace(YMIN, YMAX, numy).reshape((-1, 1))
    X, Y = np.meshgrid(Xmesh, Ymesh)
    
    
    
    #input_data = [grid[0],grid[1]]
    
    fname_out = fname +'_WEIGHTS'
    
    ##train PINN
    training_time = time.time()
    history = model.train(
        x_true=input_data,
        y_true=target_data,
        epochs= epochs,
        batch_size= batchsize,
        shuffle=shuffle,
        learning_rate= learningrate,
        #reduce_lr_after= Reduce_lr_after,
        stop_after = stopafter,
        #stop_loss_value=1e-8,
        verbose=verbose,
    )
    
    training_time = time.time() - training_time
    
    for loss in history.history:
        np.savetxt(fname+"_{}".format("_".join(loss.split("/"))), 
                    np.array(history.history[loss]).reshape(-1, 1))
    
    '''
    Old from Yang
    ## logs and plots
    model.save_weights('elasticity_train.hdf5')
    ## print iterated parameters value
    print("Emod: {},  lamb: {}".format(Emods.value, lamb.value))
    with open(f'../logs/log_layers{layers}_neurons{neurons}_epochs{Epochs}_batchsize{Batch_size}_learning_rate{Learning_rate}_reduce_lr_after{Reduce_lr_after}/parameters_{layers}_{neurons}.txt', 'w') as f:
        f.write(f"mu: {mu.value},  lamb: {lamb.value}")
    print("mu: {},  lamb: {}".format(mu.value, lamb.value))
    
    ## print loss function value
    print("loss: {}".format(history.history['loss']))
    with open(f'../logs/log_layers{layers}_neurons{neurons}_epochs{Epochs}_batchsize{Batch_size}_learning_rate{Learning_rate}_reduce_lr_after{Reduce_lr_after}/loss_{layers}_{neurons}.txt', 'w') as f:
        f.write(f"loss: {history.history['loss']}")
    ## plot loss function
    plt.figure(f'Train_Loss_{layers}_{neurons}')
    plt.semilogy(history.history['loss'])
    plt.xlabel('epochs')
    plt.ylabel('loss')
    plt.savefig(f'../logs/log_layers{layers}_neurons{neurons}_epochs{Epochs}_batchsize{Batch_size}_learning_rate{Learning_rate}_reduce_lr_after{Reduce_lr_after}/loss_{layers}_{neurons}.png')
    plt.semilogy(history.history['loss'])
    plt.xlabel('epochs')
    plt.ylabel('loss')
    '''
    
    time_steps = np.linspace(0, training_time, len(history.history["loss"]))
    np.savetxt(fname+"_Time", time_steps.reshape(-1,1))

    # Post process the trained model.
    
    Xmesh_plot = np.linspace(XMIN, XMAX, numxplot).reshape((-1, 1))
    Ymesh_plot = np.linspace(YMIN, YMAX, numyplot).reshape((-1, 1))
    X_plot, Y_plot = np.meshgrid(Xmesh_plot, Ymesh_plot)
    input_plot = [X_plot.reshape(-1, 1), Y_plot.reshape(-1, 1),t_train]

    Emods_pred = Emods.eval(model, input_plot)
    nus_pred = nus.eval(model, input_plot)
    U_pred = U.eval(model, input_plot)
    V_pred = V.eval(model, input_plot)
    Exx_pred = Exx.eval(model, input_plot)
    Eyy_pred = Eyy.eval(model, input_plot)
    Exy_pred = Exy.eval(model, input_plot)
    Sxx_pred = Sxx.eval(model, input_plot)
    Syy_pred = Syy.eval(model, input_plot)
    Sxy_pred = Sxy.eval(model, input_plot)
    
        
    np.savetxt(fname+"_Xmesh", X_plot, delimiter=', ')
    np.savetxt(fname+"_Ymesh", Y_plot, delimiter=', ')
    np.savetxt(fname+"_Emods", Emods_pred, delimiter=', ')
    np.savetxt(fname+"_nus", nus_pred, delimiter=', ')
    np.savetxt(fname+"_U", U_pred.reshape(X_plot.shape), delimiter=', ')
    np.savetxt(fname+"_V", V_pred.reshape(X_plot.shape), delimiter=', ')
    np.savetxt(fname+"_Exx", Exx_pred.reshape(X_plot.shape), delimiter=', ')
    np.savetxt(fname+"_Eyy", Eyy_pred.reshape(X_plot.shape), delimiter=', ')
    np.savetxt(fname+"_Exy", Exy_pred.reshape(X_plot.shape), delimiter=', ')
    np.savetxt(fname+"_Sxx", Sxx_pred.reshape(X_plot.shape), delimiter=', ')
    np.savetxt(fname+"_Syy", Syy_pred.reshape(X_plot.shape), delimiter=', ')
    np.savetxt(fname+"_Sxy", Sxy_pred.reshape(X_plot.shape), delimiter=', ')
# Out:
# (2760, 2)
# (2760, 2)
# (3, 2760, 1)
#
# Total samples: 2760
# Batch size: 50
# Total batches: 56
# 2022-04-25 15:50:31.637051: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/mnt/c/Windows/System32/xdmf/build/lib:/mnt/c/Windows/System32/yaml-cpp/build
# 2022-04-25 15:50:31.637141: W tensorflow/stream_executor/cuda/cuda_driver.cc:326] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-04-25 15:50:31.637221: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (DESKTOP-KVJB0RN): /proc/driver/nvidia/version does not exist
# 2022-04-25 15:50:31.637520: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-04-25 15:50:31.706545: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 1608000000 Hz
# Epoch 1/1000
# 56/56 - 2s - loss: 0.7981 - U_loss: 0.0807 - V_loss: 0.0575 - Sxx_loss: 0.1008 - Syy_loss: 0.1218 - Sxy_loss: 0.0997 - sub_loss: 0.0620 - sub_2_loss: 0.1042 - sub_3_loss: 0.0851 - add_4_loss: 0.0187 - add_5_loss: 0.0589 - lr: 0.0010 - time: 2.4679
# Epoch 2/1000
# 56/56 - 0s - loss: 0.0782 - U_loss: 0.0059 - V_loss: 0.0326 - Sxx_loss: 0.0019 - Syy_loss: 0.0107 - Sxy_loss: 0.0012 - sub_loss: 0.0023 - sub_2_loss: 0.0127 - sub_3_loss: 9.5805e-04 - add_4_loss: 0.0028 - add_5_loss: 0.0073 - lr: 0.0010 - time: 0.2608
# Epoch 3/1000
# 56/56 - 0s - loss: 0.0630 - U_loss: 0.0047 - V_loss: 0.0311 - Sxx_loss: 0.0013 - Syy_loss: 0.0085 - Sxy_loss: 4.2991e-04 - sub_loss: 0.0016 - sub_2_loss: 0.0101 - sub_3_loss: 4.0903e-04 - add_4_loss: 0.0015 - add_5_loss: 0.0037 - lr: 0.0010 - time: 0.2907
# Epoch 4/1000
# 56/56 - 0s - loss: 0.0549 - U_loss: 0.0035 - V_loss: 0.0288 - Sxx_loss: 0.0010 - Syy_loss: 0.0073 - Sxy_loss: 3.7014e-04 - sub_loss: 0.0014 - sub_2_loss: 0.0088 - sub_3_loss: 3.3239e-04 - add_4_loss: 0.0011 - add_5_loss: 0.0026 - lr: 0.0010 - time: 0.2924
# Epoch 5/1000
# 56/56 - 0s - loss: 0.0486 - U_loss: 0.0025 - V_loss: 0.0259 - Sxx_loss: 8.4150e-04 - Syy_loss: 0.0063 - Sxy_loss: 3.1160e-04 - sub_loss: 0.0013 - sub_2_loss: 0.0082 - sub_3_loss: 2.5749e-04 - add_4_loss: 8.0121e-04 - add_5_loss: 0.0019 - lr: 0.0010 - time: 0.3037
# Epoch 6/1000
# 56/56 - 0s - loss: 0.0422 - U_loss: 0.0018 - V_loss: 0.0228 - Sxx_loss: 6.9005e-04 - Syy_loss: 0.0055 - Sxy_loss: 2.6931e-04 - sub_loss: 0.0011 - sub_2_loss: 0.0077 - sub_3_loss: 2.1649e-04 - add_4_loss: 6.0369e-04 - add_5_loss: 0.0014 - lr: 0.0010 - time: 0.3127
# Epoch 7/1000
# 56/56 - 0s - loss: 0.0360 - U_loss: 0.0013 - V_loss: 0.0196 - Sxx_loss: 5.8947e-04 - Syy_loss: 0.0047 - Sxy_loss: 2.1799e-04 - sub_loss: 9.4765e-04 - sub_2_loss: 0.0067 - sub_3_loss: 1.8003e-04 - add_4_loss: 4.9246e-04 - add_5_loss: 0.0011 - lr: 0.0010 - time: 0.2985
# Epoch 8/1000
# 56/56 - 0s - loss: 0.0306 - U_loss: 0.0010 - V_loss: 0.0164 - Sxx_loss: 4.8510e-04 - Syy_loss: 0.0039 - Sxy_loss: 2.0399e-04 - sub_loss: 7.6974e-04 - sub_2_loss: 0.0062 - sub_3_loss: 2.0358e-04 - add_4_loss: 3.8236e-04 - add_5_loss: 9.8316e-04 - lr: 0.0010 - time: 0.3196
# Epoch 9/1000
# 56/56 - 0s - loss: 0.0241 - U_loss: 6.1493e-04 - V_loss: 0.0130 - Sxx_loss: 3.9544e-04 - Syy_loss: 0.0031 - Sxy_loss: 1.9465e-04 - sub_loss: 6.0519e-04 - sub_2_loss: 0.0047 - sub_3_loss: 1.9355e-04 - add_4_loss: 3.2474e-04 - add_5_loss: 9.1483e-04 - lr: 0.0010 - time: 0.3256
# Epoch 10/1000
# 56/56 - 0s - loss: 0.0204 - U_loss: 5.1720e-04 - V_loss: 0.0114 - Sxx_loss: 3.0662e-04 - Syy_loss: 0.0024 - Sxy_loss: 1.6370e-04 - sub_loss: 4.3906e-04 - sub_2_loss: 0.0041 - sub_3_loss: 1.7674e-04 - add_4_loss: 2.6547e-04 - add_5_loss: 6.3038e-04 - lr: 0.0010 - time: 0.3451
# Epoch 11/1000
# 56/56 - 0s - loss: 0.0142 - U_loss: 3.9629e-04 - V_loss: 0.0075 - Sxx_loss: 2.3351e-04 - Syy_loss: 0.0018 - Sxy_loss: 1.3672e-04 - sub_loss: 3.0924e-04 - sub_2_loss: 0.0029 - sub_3_loss: 1.5654e-04 - add_4_loss: 2.1652e-04 - add_5_loss: 4.9088e-04 - lr: 0.0010 - time: 0.2941
# Epoch 12/1000
# 56/56 - 0s - loss: 0.0110 - U_loss: 3.2710e-04 - V_loss: 0.0061 - Sxx_loss: 1.7991e-04 - Syy_loss: 0.0013 - Sxy_loss: 1.1291e-04 - sub_loss: 2.3149e-04 - sub_2_loss: 0.0020 - sub_3_loss: 1.3101e-04 - add_4_loss: 1.7306e-04 - add_5_loss: 4.2176e-04 - lr: 0.0010 - time: 0.3052
# Epoch 13/1000
# 56/56 - 0s - loss: 0.0090 - U_loss: 2.8064e-04 - V_loss: 0.0051 - Sxx_loss: 1.5732e-04 - Syy_loss: 0.0010 - Sxy_loss: 9.7561e-05 - sub_loss: 1.8150e-04 - sub_2_loss: 0.0015 - sub_3_loss: 1.0842e-04 - add_4_loss: 1.4597e-04 - add_5_loss: 3.3990e-04 - lr: 0.0010 - time: 0.2887
# Epoch 14/1000
# 56/56 - 0s - loss: 0.0083 - U_loss: 2.2940e-04 - V_loss: 0.0046 - Sxx_loss: 1.3887e-04 - Syy_loss: 0.0010 - Sxy_loss: 9.1600e-05 - sub_loss: 1.6033e-04 - sub_2_loss: 0.0015 - sub_3_loss: 1.0642e-04 - add_4_loss: 1.2707e-04 - add_5_loss: 3.3219e-04 - lr: 0.0010 - time: 0.2964
# Epoch 15/1000
# 56/56 - 0s - loss: 0.0073 - U_loss: 2.4482e-04 - V_loss: 0.0039 - Sxx_loss: 1.2438e-04 - Syy_loss: 9.3789e-04 - Sxy_loss: 9.4641e-05 - sub_loss: 1.4409e-04 - sub_2_loss: 0.0013 - sub_3_loss: 1.0883e-04 - add_4_loss: 9.3721e-05 - add_5_loss: 2.6940e-04 - lr: 0.0010 - time: 0.3012
# Epoch 16/1000
# 56/56 - 0s - loss: 0.0070 - U_loss: 2.1504e-04 - V_loss: 0.0039 - Sxx_loss: 1.1290e-04 - Syy_loss: 8.9006e-04 - Sxy_loss: 7.3234e-05 - sub_loss: 1.3230e-04 - sub_2_loss: 0.0013 - sub_3_loss: 9.0032e-05 - add_4_loss: 8.0495e-05 - add_5_loss: 2.2080e-04 - lr: 0.0010 - time: 0.3008
# Epoch 17/1000
# 56/56 - 0s - loss: 0.0066 - U_loss: 2.6008e-04 - V_loss: 0.0034 - Sxx_loss: 1.2579e-04 - Syy_loss: 9.0089e-04 - Sxy_loss: 7.4361e-05 - sub_loss: 1.4153e-04 - sub_2_loss: 0.0013 - sub_3_loss: 9.3967e-05 - add_4_loss: 8.7778e-05 - add_5_loss: 2.1371e-04 - lr: 0.0010 - time: 0.2929
# Epoch 18/1000
# 56/56 - 0s - loss: 0.0058 - U_loss: 2.0991e-04 - V_loss: 0.0028 - Sxx_loss: 1.1415e-04 - Syy_loss: 8.9476e-04 - Sxy_loss: 7.0137e-05 - sub_loss: 1.3029e-04 - sub_2_loss: 0.0012 - sub_3_loss: 8.6767e-05 - add_4_loss: 6.8028e-05 - add_5_loss: 2.0419e-04 - lr: 0.0010 - time: 0.2976
# Epoch 19/1000
# 56/56 - 0s - loss: 0.0055 - U_loss: 2.4892e-04 - V_loss: 0.0025 - Sxx_loss: 1.0870e-04 - Syy_loss: 8.8646e-04 - Sxy_loss: 6.4069e-05 - sub_loss: 1.2593e-04 - sub_2_loss: 0.0012 - sub_3_loss: 8.3034e-05 - add_4_loss: 5.6857e-05 - add_5_loss: 2.0002e-04 - lr: 0.0010 - time: 0.2910
# Epoch 20/1000
# 56/56 - 0s - loss: 0.0052 - U_loss: 1.8115e-04 - V_loss: 0.0023 - Sxx_loss: 9.9237e-05 - Syy_loss: 8.5800e-04 - Sxy_loss: 6.4893e-05 - sub_loss: 1.1470e-04 - sub_2_loss: 0.0012 - sub_3_loss: 8.0218e-05 - add_4_loss: 5.7735e-05 - add_5_loss: 2.0736e-04 - lr: 0.0010 - time: 0.3051
# Epoch 21/1000
# 56/56 - 0s - loss: 0.0052 - U_loss: 1.8027e-04 - V_loss: 0.0025 - Sxx_loss: 9.4657e-05 - Syy_loss: 8.4635e-04 - Sxy_loss: 5.2933e-05 - sub_loss: 1.0809e-04 - sub_2_loss: 0.0011 - sub_3_loss: 6.8149e-05 - add_4_loss: 4.6356e-05 - add_5_loss: 1.5770e-04 - lr: 0.0010 - time: 0.2994
# Epoch 22/1000
# 56/56 - 0s - loss: 0.0050 - U_loss: 1.7232e-04 - V_loss: 0.0024 - Sxx_loss: 9.4140e-05 - Syy_loss: 8.2149e-04 - Sxy_loss: 4.7735e-05 - sub_loss: 1.0672e-04 - sub_2_loss: 0.0011 - sub_3_loss: 6.3376e-05 - add_4_loss: 4.1890e-05 - add_5_loss: 1.4528e-04 - lr: 0.0010 - time: 0.3038
# Epoch 23/1000
# 56/56 - 0s - loss: 0.0045 - U_loss: 1.6000e-04 - V_loss: 0.0018 - Sxx_loss: 9.6962e-05 - Syy_loss: 8.3747e-04 - Sxy_loss: 5.4794e-05 - sub_loss: 1.1165e-04 - sub_2_loss: 0.0011 - sub_3_loss: 6.9868e-05 - add_4_loss: 4.7926e-05 - add_5_loss: 1.4769e-04 - lr: 0.0010 - time: 0.2999
# Epoch 24/1000
# 56/56 - 0s - loss: 0.0042 - U_loss: 1.7277e-04 - V_loss: 0.0017 - Sxx_loss: 8.9134e-05 - Syy_loss: 8.2511e-04 - Sxy_loss: 4.3515e-05 - sub_loss: 1.0174e-04 - sub_2_loss: 0.0010 - sub_3_loss: 5.6790e-05 - add_4_loss: 4.0721e-05 - add_5_loss: 1.2723e-04 - lr: 0.0010 - time: 0.2987
# Epoch 25/1000
# 56/56 - 0s - loss: 0.0043 - U_loss: 1.5399e-04 - V_loss: 0.0019 - Sxx_loss: 9.0039e-05 - Syy_loss: 7.9374e-04 - Sxy_loss: 4.0183e-05 - sub_loss: 1.0424e-04 - sub_2_loss: 0.0010 - sub_3_loss: 5.2638e-05 - add_4_loss: 3.4689e-05 - add_5_loss: 1.2688e-04 - lr: 0.0010 - time: 0.2981
# Epoch 26/1000
# 56/56 - 0s - loss: 0.0041 - U_loss: 1.9177e-04 - V_loss: 0.0016 - Sxx_loss: 9.8174e-05 - Syy_loss: 8.2333e-04 - Sxy_loss: 5.1678e-05 - sub_loss: 1.0634e-04 - sub_2_loss: 0.0010 - sub_3_loss: 6.5588e-05 - add_4_loss: 4.2795e-05 - add_5_loss: 1.3719e-04 - lr: 0.0010 - time: 0.2893
# Epoch 27/1000
# 56/56 - 0s - loss: 0.0037 - U_loss: 1.4558e-04 - V_loss: 0.0014 - Sxx_loss: 8.1279e-05 - Syy_loss: 7.7945e-04 - Sxy_loss: 3.4390e-05 - sub_loss: 9.4902e-05 - sub_2_loss: 9.7069e-04 - sub_3_loss: 4.4163e-05 - add_4_loss: 4.2269e-05 - add_5_loss: 1.1288e-04 - lr: 0.0010 - time: 0.2957
# Epoch 28/1000
# 56/56 - 0s - loss: 0.0038 - U_loss: 1.8399e-04 - V_loss: 0.0014 - Sxx_loss: 7.7092e-05 - Syy_loss: 7.7574e-04 - Sxy_loss: 4.1307e-05 - sub_loss: 9.0088e-05 - sub_2_loss: 9.7583e-04 - sub_3_loss: 5.3370e-05 - add_4_loss: 3.0866e-05 - add_5_loss: 1.1864e-04 - lr: 0.0010 - time: 0.2857
# Epoch 29/1000
# 56/56 - 0s - loss: 0.0035 - U_loss: 1.4583e-04 - V_loss: 0.0013 - Sxx_loss: 8.2093e-05 - Syy_loss: 7.8668e-04 - Sxy_loss: 3.3261e-05 - sub_loss: 9.2750e-05 - sub_2_loss: 9.4753e-04 - sub_3_loss: 4.2537e-05 - add_4_loss: 3.5986e-05 - add_5_loss: 1.0635e-04 - lr: 0.0010 - time: 0.3096
# Epoch 30/1000
# 56/56 - 0s - loss: 0.0035 - U_loss: 1.6030e-04 - V_loss: 0.0013 - Sxx_loss: 7.8600e-05 - Syy_loss: 7.5764e-04 - Sxy_loss: 3.0585e-05 - sub_loss: 9.1392e-05 - sub_2_loss: 9.4436e-04 - sub_3_loss: 3.7892e-05 - add_4_loss: 3.8747e-05 - add_5_loss: 8.9279e-05 - lr: 0.0010 - time: 0.2887
# Epoch 31/1000
# 56/56 - 0s - loss: 0.0037 - U_loss: 1.4755e-04 - V_loss: 0.0014 - Sxx_loss: 6.8668e-05 - Syy_loss: 8.0938e-04 - Sxy_loss: 2.6603e-05 - sub_loss: 8.1088e-05 - sub_2_loss: 9.4675e-04 - sub_3_loss: 3.5438e-05 - add_4_loss: 2.7408e-05 - add_5_loss: 8.8566e-05 - lr: 0.0010 - time: 0.2915
# Epoch 32/1000
# 56/56 - 0s - loss: 0.0037 - U_loss: 1.6020e-04 - V_loss: 0.0015 - Sxx_loss: 7.8990e-05 - Syy_loss: 7.7122e-04 - Sxy_loss: 3.3532e-05 - sub_loss: 9.2287e-05 - sub_2_loss: 9.2849e-04 - sub_3_loss: 4.1174e-05 - add_4_loss: 4.3109e-05 - add_5_loss: 9.2225e-05 - lr: 0.0010 - time: 0.2975
# Epoch 33/1000
# 56/56 - 0s - loss: 0.0034 - U_loss: 1.4095e-04 - V_loss: 0.0013 - Sxx_loss: 6.4278e-05 - Syy_loss: 7.8283e-04 - Sxy_loss: 2.9586e-05 - sub_loss: 7.7024e-05 - sub_2_loss: 9.0783e-04 - sub_3_loss: 3.6127e-05 - add_4_loss: 2.2010e-05 - add_5_loss: 8.4784e-05 - lr: 0.0010 - time: 0.2945
# Epoch 34/1000
# 56/56 - 0s - loss: 0.0034 - U_loss: 1.3218e-04 - V_loss: 0.0013 - Sxx_loss: 6.0093e-05 - Syy_loss: 7.4574e-04 - Sxy_loss: 2.2868e-05 - sub_loss: 7.1199e-05 - sub_2_loss: 8.9676e-04 - sub_3_loss: 2.9613e-05 - add_4_loss: 1.8042e-05 - add_5_loss: 6.5615e-05 - lr: 0.0010 - time: 0.2971
# Epoch 35/1000
# 56/56 - 0s - loss: 0.0033 - U_loss: 1.3574e-04 - V_loss: 0.0013 - Sxx_loss: 6.5068e-05 - Syy_loss: 7.4991e-04 - Sxy_loss: 2.3307e-05 - sub_loss: 7.5463e-05 - sub_2_loss: 8.8431e-04 - sub_3_loss: 2.8907e-05 - add_4_loss: 2.6583e-05 - add_5_loss: 6.6300e-05 - lr: 0.0010 - time: 0.2928
# Epoch 36/1000
# 56/56 - 0s - loss: 0.0030 - U_loss: 1.2859e-04 - V_loss: 0.0010 - Sxx_loss: 5.7848e-05 - Syy_loss: 7.3840e-04 - Sxy_loss: 1.9271e-05 - sub_loss: 7.2207e-05 - sub_2_loss: 8.5750e-04 - sub_3_loss: 2.5858e-05 - add_4_loss: 2.0235e-05 - add_5_loss: 6.4070e-05 - lr: 0.0010 - time: 0.2871
# Epoch 37/1000
# 56/56 - 0s - loss: 0.0029 - U_loss: 1.2732e-04 - V_loss: 9.0544e-04 - Sxx_loss: 5.4349e-05 - Syy_loss: 7.6110e-04 - Sxy_loss: 2.3063e-05 - sub_loss: 6.4088e-05 - sub_2_loss: 8.6929e-04 - sub_3_loss: 2.9282e-05 - add_4_loss: 1.8607e-05 - add_5_loss: 6.3349e-05 - lr: 0.0010 - time: 0.2878
# Epoch 38/1000
# 56/56 - 0s - loss: 0.0028 - U_loss: 1.4737e-04 - V_loss: 8.8033e-04 - Sxx_loss: 5.2683e-05 - Syy_loss: 7.1923e-04 - Sxy_loss: 1.5037e-05 - sub_loss: 6.5204e-05 - sub_2_loss: 8.4424e-04 - sub_3_loss: 1.9245e-05 - add_4_loss: 1.8736e-05 - add_5_loss: 5.0490e-05 - lr: 0.0010 - time: 0.2895
# Epoch 39/1000
# 56/56 - 0s - loss: 0.0027 - U_loss: 1.1416e-04 - V_loss: 8.2366e-04 - Sxx_loss: 5.2700e-05 - Syy_loss: 7.2485e-04 - Sxy_loss: 1.7006e-05 - sub_loss: 6.6253e-05 - sub_2_loss: 8.2804e-04 - sub_3_loss: 2.1605e-05 - add_4_loss: 1.8922e-05 - add_5_loss: 4.8975e-05 - lr: 0.0010 - time: 0.2976
# Epoch 40/1000
# 56/56 - 0s - loss: 0.0029 - U_loss: 1.4653e-04 - V_loss: 8.7924e-04 - Sxx_loss: 7.8010e-05 - Syy_loss: 7.3978e-04 - Sxy_loss: 2.5900e-05 - sub_loss: 9.0349e-05 - sub_2_loss: 8.4121e-04 - sub_3_loss: 2.9718e-05 - add_4_loss: 4.1538e-05 - add_5_loss: 5.0475e-05 - lr: 0.0010 - time: 0.3034
# Epoch 41/1000
# 56/56 - 0s - loss: 0.0028 - U_loss: 1.5357e-04 - V_loss: 8.0526e-04 - Sxx_loss: 4.7283e-05 - Syy_loss: 7.2622e-04 - Sxy_loss: 2.1616e-05 - sub_loss: 5.9561e-05 - sub_2_loss: 8.3186e-04 - sub_3_loss: 2.5145e-05 - add_4_loss: 1.4834e-05 - add_5_loss: 6.4444e-05 - lr: 0.0010 - time: 0.2905
# Epoch 42/1000
# 56/56 - 0s - loss: 0.0027 - U_loss: 1.0859e-04 - V_loss: 8.4826e-04 - Sxx_loss: 4.7375e-05 - Syy_loss: 7.4946e-04 - Sxy_loss: 1.4924e-05 - sub_loss: 5.7855e-05 - sub_2_loss: 8.3922e-04 - sub_3_loss: 1.7595e-05 - add_4_loss: 1.6488e-05 - add_5_loss: 4.8396e-05 - lr: 0.0010 - time: 0.2985
# Epoch 43/1000
# 56/56 - 0s - loss: 0.0026 - U_loss: 1.8808e-04 - V_loss: 6.4268e-04 - Sxx_loss: 5.3729e-05 - Syy_loss: 7.2371e-04 - Sxy_loss: 1.3397e-05 - sub_loss: 6.5618e-05 - sub_2_loss: 8.1453e-04 - sub_3_loss: 1.6489e-05 - add_4_loss: 2.6972e-05 - add_5_loss: 3.7937e-05 - lr: 0.0010 - time: 0.2908
# Epoch 44/1000
# 56/56 - 0s - loss: 0.0026 - U_loss: 1.1742e-04 - V_loss: 6.4852e-04 - Sxx_loss: 6.1446e-05 - Syy_loss: 7.3183e-04 - Sxy_loss: 2.1124e-05 - sub_loss: 7.2841e-05 - sub_2_loss: 8.1675e-04 - sub_3_loss: 2.3349e-05 - add_4_loss: 4.1191e-05 - add_5_loss: 5.6807e-05 - lr: 0.0010 - time: 0.2948
# Epoch 45/1000
# 56/56 - 0s - loss: 0.0026 - U_loss: 1.3335e-04 - V_loss: 6.7791e-04 - Sxx_loss: 6.4825e-05 - Syy_loss: 7.1755e-04 - Sxy_loss: 1.7457e-05 - sub_loss: 7.5687e-05 - sub_2_loss: 7.9693e-04 - sub_3_loss: 1.9908e-05 - add_4_loss: 4.2190e-05 - add_5_loss: 4.9865e-05 - lr: 0.0010 - time: 0.2918
# Epoch 46/1000
# 56/56 - 0s - loss: 0.0027 - U_loss: 1.3867e-04 - V_loss: 7.3484e-04 - Sxx_loss: 6.3000e-05 - Syy_loss: 7.2295e-04 - Sxy_loss: 1.5252e-05 - sub_loss: 7.4226e-05 - sub_2_loss: 8.0772e-04 - sub_3_loss: 1.7573e-05 - add_4_loss: 4.5724e-05 - add_5_loss: 3.6621e-05 - lr: 0.0010 - time: 0.2976
# Epoch 47/1000
# 56/56 - 0s - loss: 0.0024 - U_loss: 1.4462e-04 - V_loss: 5.6528e-04 - Sxx_loss: 3.8739e-05 - Syy_loss: 7.3121e-04 - Sxy_loss: 1.0702e-05 - sub_loss: 5.0057e-05 - sub_2_loss: 7.9552e-04 - sub_3_loss: 1.2693e-05 - add_4_loss: 1.0936e-05 - add_5_loss: 3.0284e-05 - lr: 0.0010 - time: 0.2943
# Epoch 48/1000
# 56/56 - 0s - loss: 0.0023 - U_loss: 1.6350e-04 - V_loss: 4.6431e-04 - Sxx_loss: 4.5224e-05 - Syy_loss: 7.1847e-04 - Sxy_loss: 1.5258e-05 - sub_loss: 5.8819e-05 - sub_2_loss: 8.0281e-04 - sub_3_loss: 1.8338e-05 - add_4_loss: 2.1364e-05 - add_5_loss: 3.8336e-05 - lr: 0.0010 - time: 0.2916
# Epoch 49/1000
# 56/56 - 0s - loss: 0.0023 - U_loss: 1.2281e-04 - V_loss: 4.4383e-04 - Sxx_loss: 5.8471e-05 - Syy_loss: 7.3183e-04 - Sxy_loss: 1.6427e-05 - sub_loss: 7.0835e-05 - sub_2_loss: 8.0651e-04 - sub_3_loss: 1.7814e-05 - add_4_loss: 3.9601e-05 - add_5_loss: 3.2885e-05 - lr: 0.0010 - time: 0.2963
# Epoch 50/1000
# 56/56 - 0s - loss: 0.0023 - U_loss: 9.6359e-05 - V_loss: 4.0783e-04 - Sxx_loss: 4.9782e-05 - Syy_loss: 7.7172e-04 - Sxy_loss: 1.3241e-05 - sub_loss: 6.1304e-05 - sub_2_loss: 8.3219e-04 - sub_3_loss: 1.4806e-05 - add_4_loss: 2.4355e-05 - add_5_loss: 3.2636e-05 - lr: 0.0010 - time: 0.2944
# Epoch 51/1000
# 56/56 - 0s - loss: 0.0023 - U_loss: 1.2844e-04 - V_loss: 4.3593e-04 - Sxx_loss: 4.6042e-05 - Syy_loss: 7.3147e-04 - Sxy_loss: 9.9252e-06 - sub_loss: 5.6994e-05 - sub_2_loss: 8.0150e-04 - sub_3_loss: 1.1809e-05 - add_4_loss: 1.8312e-05 - add_5_loss: 3.0642e-05 - lr: 0.0010 - time: 0.2920
# Epoch 52/1000
# 56/56 - 0s - loss: 0.0022 - U_loss: 1.3311e-04 - V_loss: 3.9793e-04 - Sxx_loss: 3.7017e-05 - Syy_loss: 7.3052e-04 - Sxy_loss: 1.0071e-05 - sub_loss: 4.8902e-05 - sub_2_loss: 7.9219e-04 - sub_3_loss: 1.2156e-05 - add_4_loss: 1.2082e-05 - add_5_loss: 3.1141e-05 - lr: 0.0010 - time: 0.2888
# Epoch 53/1000
# 56/56 - 0s - loss: 0.0022 - U_loss: 1.0932e-04 - V_loss: 3.8299e-04 - Sxx_loss: 3.8883e-05 - Syy_loss: 7.2299e-04 - Sxy_loss: 1.1037e-05 - sub_loss: 5.0984e-05 - sub_2_loss: 7.8573e-04 - sub_3_loss: 1.3657e-05 - add_4_loss: 2.1092e-05 - add_5_loss: 2.5310e-05 - lr: 0.0010 - time: 0.3098
# Epoch 54/1000
# 56/56 - 0s - loss: 0.0022 - U_loss: 1.3611e-04 - V_loss: 4.1011e-04 - Sxx_loss: 4.0103e-05 - Syy_loss: 7.2222e-04 - Sxy_loss: 8.9811e-06 - sub_loss: 5.1857e-05 - sub_2_loss: 7.8427e-04 - sub_3_loss: 9.9707e-06 - add_4_loss: 1.6809e-05 - add_5_loss: 2.8827e-05 - lr: 0.0010 - time: 0.2963
# Epoch 55/1000
# 56/56 - 0s - loss: 0.0024 - U_loss: 2.2422e-04 - V_loss: 3.8735e-04 - Sxx_loss: 5.0957e-05 - Syy_loss: 7.5244e-04 - Sxy_loss: 1.6096e-05 - sub_loss: 5.9554e-05 - sub_2_loss: 8.3416e-04 - sub_3_loss: 1.6243e-05 - add_4_loss: 3.6298e-05 - add_5_loss: 2.8620e-05 - lr: 0.0010 - time: 0.2993
# Epoch 56/1000
# 56/56 - 0s - loss: 0.0023 - U_loss: 1.0615e-04 - V_loss: 4.4021e-04 - Sxx_loss: 4.4210e-05 - Syy_loss: 7.6643e-04 - Sxy_loss: 1.2774e-05 - sub_loss: 5.3627e-05 - sub_2_loss: 8.1028e-04 - sub_3_loss: 1.4191e-05 - add_4_loss: 2.7709e-05 - add_5_loss: 3.1939e-05 - lr: 0.0010 - time: 0.3042
# Epoch 57/1000
# 56/56 - 0s - loss: 0.0025 - U_loss: 1.3816e-04 - V_loss: 4.1754e-04 - Sxx_loss: 7.0948e-05 - Syy_loss: 7.7661e-04 - Sxy_loss: 2.1655e-05 - sub_loss: 8.4179e-05 - sub_2_loss: 8.3758e-04 - sub_3_loss: 2.2788e-05 - add_4_loss: 7.1039e-05 - add_5_loss: 5.4203e-05 - lr: 0.0010 - time: 0.2994
# Epoch 58/1000
# 56/56 - 0s - loss: 0.0022 - U_loss: 1.0415e-04 - V_loss: 3.4550e-04 - Sxx_loss: 4.1331e-05 - Syy_loss: 7.4170e-04 - Sxy_loss: 1.2078e-05 - sub_loss: 5.1468e-05 - sub_2_loss: 8.0367e-04 - sub_3_loss: 1.3044e-05 - add_4_loss: 2.5953e-05 - add_5_loss: 3.4171e-05 - lr: 0.0010 - time: 0.2924
# Epoch 59/1000
# 56/56 - 0s - loss: 0.0023 - U_loss: 1.3935e-04 - V_loss: 4.3147e-04 - Sxx_loss: 4.2653e-05 - Syy_loss: 7.2774e-04 - Sxy_loss: 1.0831e-05 - sub_loss: 5.3493e-05 - sub_2_loss: 7.8459e-04 - sub_3_loss: 1.2252e-05 - add_4_loss: 2.6460e-05 - add_5_loss: 2.6513e-05 - lr: 0.0010 - time: 0.3110
# Epoch 60/1000
# 56/56 - 0s - loss: 0.0022 - U_loss: 1.1089e-04 - V_loss: 2.7862e-04 - Sxx_loss: 5.9709e-05 - Syy_loss: 7.3632e-04 - Sxy_loss: 1.9468e-05 - sub_loss: 6.9812e-05 - sub_2_loss: 7.7980e-04 - sub_3_loss: 2.0524e-05 - add_4_loss: 5.9795e-05 - add_5_loss: 4.5974e-05 - lr: 0.0010 - time: 0.3021
# Epoch 61/1000
# 56/56 - 0s - loss: 0.0023 - U_loss: 1.1188e-04 - V_loss: 4.0845e-04 - Sxx_loss: 5.8192e-05 - Syy_loss: 7.3855e-04 - Sxy_loss: 1.5595e-05 - sub_loss: 7.0137e-05 - sub_2_loss: 7.8107e-04 - sub_3_loss: 1.6401e-05 - add_4_loss: 4.9390e-05 - add_5_loss: 4.1278e-05 - lr: 0.0010 - time: 0.2888
# Epoch 62/1000
# 56/56 - 0s - loss: 0.0021 - U_loss: 1.1285e-04 - V_loss: 3.3669e-04 - Sxx_loss: 4.0436e-05 - Syy_loss: 7.3095e-04 - Sxy_loss: 1.1519e-05 - sub_loss: 4.8952e-05 - sub_2_loss: 7.8200e-04 - sub_3_loss: 1.2939e-05 - add_4_loss: 2.2055e-05 - add_5_loss: 2.9318e-05 - lr: 0.0010 - time: 0.3043
# Epoch 63/1000
# 56/56 - 0s - loss: 0.0022 - U_loss: 9.0238e-05 - V_loss: 3.7313e-04 - Sxx_loss: 4.1008e-05 - Syy_loss: 7.6993e-04 - Sxy_loss: 1.1377e-05 - sub_loss: 5.0461e-05 - sub_2_loss: 8.3456e-04 - sub_3_loss: 1.2424e-05 - add_4_loss: 1.9594e-05 - add_5_loss: 2.7075e-05 - lr: 0.0010 - time: 0.2916
# Epoch 64/1000
# 56/56 - 0s - loss: 0.0023 - U_loss: 1.7753e-04 - V_loss: 3.4468e-04 - Sxx_loss: 4.6307e-05 - Syy_loss: 7.6820e-04 - Sxy_loss: 1.7437e-05 - sub_loss: 5.5545e-05 - sub_2_loss: 8.1127e-04 - sub_3_loss: 1.8840e-05 - add_4_loss: 1.7339e-05 - add_5_loss: 2.4894e-05 - lr: 0.0010 - time: 0.2971
# Epoch 65/1000
# 56/56 - 0s - loss: 0.0022 - U_loss: 1.2887e-04 - V_loss: 3.1289e-04 - Sxx_loss: 4.4581e-05 - Syy_loss: 7.4790e-04 - Sxy_loss: 1.6465e-05 - sub_loss: 5.7666e-05 - sub_2_loss: 7.9682e-04 - sub_3_loss: 1.7387e-05 - add_4_loss: 2.7354e-05 - add_5_loss: 4.1175e-05 - lr: 0.0010 - time: 0.2948
# Epoch 66/1000
# 56/56 - 0s - loss: 0.0022 - U_loss: 1.4917e-04 - V_loss: 3.2578e-04 - Sxx_loss: 5.3199e-05 - Syy_loss: 7.3188e-04 - Sxy_loss: 1.1817e-05 - sub_loss: 6.1748e-05 - sub_2_loss: 7.7458e-04 - sub_3_loss: 1.2555e-05 - add_4_loss: 3.0847e-05 - add_5_loss: 3.2158e-05 - lr: 0.0010 - time: 0.2969
# Epoch 67/1000
# 56/56 - 0s - loss: 0.0021 - U_loss: 1.4862e-04 - V_loss: 3.2172e-04 - Sxx_loss: 3.8266e-05 - Syy_loss: 7.3704e-04 - Sxy_loss: 1.0633e-05 - sub_loss: 4.8283e-05 - sub_2_loss: 7.6861e-04 - sub_3_loss: 1.1710e-05 - add_4_loss: 1.9046e-05 - add_5_loss: 3.0322e-05 - lr: 0.0010 - time: 0.2997
# Epoch 68/1000
# 56/56 - 0s - loss: 0.0021 - U_loss: 1.0646e-04 - V_loss: 2.3899e-04 - Sxx_loss: 4.1638e-05 - Syy_loss: 7.4500e-04 - Sxy_loss: 1.7889e-05 - sub_loss: 5.2192e-05 - sub_2_loss: 7.9046e-04 - sub_3_loss: 1.8883e-05 - add_4_loss: 2.1340e-05 - add_5_loss: 5.0775e-05 - lr: 0.0010 - time: 0.2899
# Epoch 69/1000
# 56/56 - 0s - loss: 0.0020 - U_loss: 1.0186e-04 - V_loss: 2.5420e-04 - Sxx_loss: 3.6344e-05 - Syy_loss: 7.3647e-04 - Sxy_loss: 9.0403e-06 - sub_loss: 4.4024e-05 - sub_2_loss: 7.8033e-04 - sub_3_loss: 1.0187e-05 - add_4_loss: 2.0690e-05 - add_5_loss: 2.3420e-05 - lr: 0.0010 - time: 0.2929
# Epoch 70/1000
# 56/56 - 0s - loss: 0.0020 - U_loss: 8.6580e-05 - V_loss: 2.1243e-04 - Sxx_loss: 3.7271e-05 - Syy_loss: 7.2913e-04 - Sxy_loss: 1.1575e-05 - sub_loss: 4.6965e-05 - sub_2_loss: 7.6661e-04 - sub_3_loss: 1.2518e-05 - add_4_loss: 2.1823e-05 - add_5_loss: 3.7644e-05 - lr: 0.0010 - time: 0.2899
# Epoch 71/1000
# 56/56 - 0s - loss: 0.0020 - U_loss: 1.1038e-04 - V_loss: 2.5648e-04 - Sxx_loss: 4.1645e-05 - Syy_loss: 7.3195e-04 - Sxy_loss: 1.2487e-05 - sub_loss: 5.0585e-05 - sub_2_loss: 7.7014e-04 - sub_3_loss: 1.3714e-05 - add_4_loss: 2.2722e-05 - add_5_loss: 3.1582e-05 - lr: 0.0010 - time: 0.2998
# Epoch 72/1000
# 56/56 - 0s - loss: 0.0022 - U_loss: 1.6005e-04 - V_loss: 2.9275e-04 - Sxx_loss: 3.9299e-05 - Syy_loss: 7.2828e-04 - Sxy_loss: 1.5663e-05 - sub_loss: 4.7531e-05 - sub_2_loss: 7.7388e-04 - sub_3_loss: 1.6876e-05 - add_4_loss: 2.3848e-05 - add_5_loss: 6.0444e-05 - lr: 0.0010 - time: 0.2968
# Epoch 73/1000
# 56/56 - 0s - loss: 0.0020 - U_loss: 1.1106e-04 - V_loss: 2.5948e-04 - Sxx_loss: 3.0559e-05 - Syy_loss: 7.5588e-04 - Sxy_loss: 9.3224e-06 - sub_loss: 3.7608e-05 - sub_2_loss: 7.8390e-04 - sub_3_loss: 1.0573e-05 - add_4_loss: 1.3071e-05 - add_5_loss: 2.0861e-05 - lr: 0.0010 - time: 0.2977
# Epoch 74/1000
# 56/56 - 0s - loss: 0.0021 - U_loss: 9.9320e-05 - V_loss: 2.7975e-04 - Sxx_loss: 4.7748e-05 - Syy_loss: 7.4771e-04 - Sxy_loss: 1.6405e-05 - sub_loss: 5.7385e-05 - sub_2_loss: 7.8752e-04 - sub_3_loss: 1.7320e-05 - add_4_loss: 4.2876e-05 - add_5_loss: 3.6505e-05 - lr: 0.0010 - time: 0.3000
# Epoch 75/1000
# 56/56 - 0s - loss: 0.0021 - U_loss: 7.9324e-05 - V_loss: 3.0271e-04 - Sxx_loss: 3.4855e-05 - Syy_loss: 7.3971e-04 - Sxy_loss: 2.5170e-05 - sub_loss: 4.4272e-05 - sub_2_loss: 7.8153e-04 - sub_3_loss: 2.6743e-05 - add_4_loss: 2.4093e-05 - add_5_loss: 7.6864e-05 - lr: 0.0010 - time: 0.2954
# Epoch 76/1000
# 56/56 - 0s - loss: 0.0021 - U_loss: 9.6922e-05 - V_loss: 2.8569e-04 - Sxx_loss: 4.3633e-05 - Syy_loss: 7.3336e-04 - Sxy_loss: 1.7280e-05 - sub_loss: 5.1719e-05 - sub_2_loss: 7.6313e-04 - sub_3_loss: 1.8485e-05 - add_4_loss: 3.1241e-05 - add_5_loss: 3.9802e-05 - lr: 0.0010 - time: 0.3017
# Epoch 77/1000
# 56/56 - 0s - loss: 0.0023 - U_loss: 2.2369e-04 - V_loss: 3.7056e-04 - Sxx_loss: 3.8299e-05 - Syy_loss: 7.3669e-04 - Sxy_loss: 2.0536e-05 - sub_loss: 4.5325e-05 - sub_2_loss: 7.6651e-04 - sub_3_loss: 2.1431e-05 - add_4_loss: 2.6379e-05 - add_5_loss: 3.1741e-05 - lr: 0.0010 - time: 0.2981
# Epoch 78/1000
# 56/56 - 0s - loss: 0.0022 - U_loss: 1.6409e-04 - V_loss: 3.1142e-04 - Sxx_loss: 3.9453e-05 - Syy_loss: 7.5034e-04 - Sxy_loss: 1.5490e-05 - sub_loss: 4.9482e-05 - sub_2_loss: 7.9573e-04 - sub_3_loss: 1.6617e-05 - add_4_loss: 1.8320e-05 - add_5_loss: 3.0954e-05 - lr: 0.0010 - time: 0.2993
# Epoch 79/1000
# 56/56 - 0s - loss: 0.0019 - U_loss: 1.1436e-04 - V_loss: 2.1411e-04 - Sxx_loss: 2.9533e-05 - Syy_loss: 7.2462e-04 - Sxy_loss: 8.3359e-06 - sub_loss: 3.7396e-05 - sub_2_loss: 7.5739e-04 - sub_3_loss: 9.2190e-06 - add_4_loss: 1.1712e-05 - add_5_loss: 1.9472e-05 - lr: 0.0010 - time: 0.2935
# Epoch 80/1000
# 56/56 - 0s - loss: 0.0022 - U_loss: 1.0609e-04 - V_loss: 1.9087e-04 - Sxx_loss: 6.1150e-05 - Syy_loss: 7.3871e-04 - Sxy_loss: 3.0395e-05 - sub_loss: 6.8740e-05 - sub_2_loss: 7.8418e-04 - sub_3_loss: 3.1730e-05 - add_4_loss: 5.2514e-05 - add_5_loss: 7.5517e-05 - lr: 0.0010 - time: 0.2982
# Epoch 81/1000
# 56/56 - 0s - loss: 0.0020 - U_loss: 6.8796e-05 - V_loss: 2.0985e-04 - Sxx_loss: 3.5505e-05 - Syy_loss: 7.5216e-04 - Sxy_loss: 1.5674e-05 - sub_loss: 4.4229e-05 - sub_2_loss: 7.7240e-04 - sub_3_loss: 1.7074e-05 - add_4_loss: 1.9396e-05 - add_5_loss: 2.6623e-05 - lr: 0.0010 - time: 0.2939
# Epoch 82/1000
# 56/56 - 0s - loss: 0.0022 - U_loss: 1.0614e-04 - V_loss: 2.7013e-04 - Sxx_loss: 3.3513e-05 - Syy_loss: 8.0327e-04 - Sxy_loss: 2.2797e-05 - sub_loss: 4.0466e-05 - sub_2_loss: 8.3934e-04 - sub_3_loss: 2.3218e-05 - add_4_loss: 2.1625e-05 - add_5_loss: 5.0176e-05 - lr: 0.0010 - time: 0.3006
# Epoch 83/1000
# 56/56 - 0s - loss: 0.0020 - U_loss: 1.1494e-04 - V_loss: 2.9033e-04 - Sxx_loss: 3.8136e-05 - Syy_loss: 7.3021e-04 - Sxy_loss: 9.6224e-06 - sub_loss: 4.7469e-05 - sub_2_loss: 7.5381e-04 - sub_3_loss: 1.0548e-05 - add_4_loss: 1.8581e-05 - add_5_loss: 1.7267e-05 - lr: 0.0010 - time: 0.2889
# Epoch 84/1000
# 56/56 - 0s - loss: 0.0020 - U_loss: 6.5980e-05 - V_loss: 2.8307e-04 - Sxx_loss: 3.5885e-05 - Syy_loss: 7.1618e-04 - Sxy_loss: 1.5260e-05 - sub_loss: 4.3768e-05 - sub_2_loss: 7.5601e-04 - sub_3_loss: 1.6302e-05 - add_4_loss: 2.2255e-05 - add_5_loss: 4.4838e-05 - lr: 0.0010 - time: 0.3053
# Epoch 85/1000
# 56/56 - 0s - loss: 0.0020 - U_loss: 6.8679e-05 - V_loss: 2.6553e-04 - Sxx_loss: 3.6604e-05 - Syy_loss: 7.2330e-04 - Sxy_loss: 1.7857e-05 - sub_loss: 4.3210e-05 - sub_2_loss: 7.6221e-04 - sub_3_loss: 1.9432e-05 - add_4_loss: 1.9056e-05 - add_5_loss: 2.6630e-05 - lr: 0.0010 - time: 0.2910
# Epoch 86/1000
# 56/56 - 0s - loss: 0.0022 - U_loss: 1.1512e-04 - V_loss: 2.7020e-04 - Sxx_loss: 5.2682e-05 - Syy_loss: 7.4462e-04 - Sxy_loss: 3.9587e-05 - sub_loss: 6.0142e-05 - sub_2_loss: 7.7913e-04 - sub_3_loss: 4.1060e-05 - add_4_loss: 4.2547e-05 - add_5_loss: 7.4484e-05 - lr: 0.0010 - time: 0.3031
# Epoch 87/1000
# 56/56 - 0s - loss: 0.0020 - U_loss: 1.1715e-04 - V_loss: 2.8053e-04 - Sxx_loss: 3.2807e-05 - Syy_loss: 7.3419e-04 - Sxy_loss: 9.8613e-06 - sub_loss: 3.6722e-05 - sub_2_loss: 7.6245e-04 - sub_3_loss: 1.0265e-05 - add_4_loss: 1.8158e-05 - add_5_loss: 2.5295e-05 - lr: 0.0010 - time: 0.3010
# Epoch 88/1000
# 56/56 - 0s - loss: 0.0021 - U_loss: 1.0939e-04 - V_loss: 2.4961e-04 - Sxx_loss: 6.3210e-05 - Syy_loss: 7.4009e-04 - Sxy_loss: 1.4209e-05 - sub_loss: 7.0607e-05 - sub_2_loss: 7.6531e-04 - sub_3_loss: 1.4745e-05 - add_4_loss: 4.3074e-05 - add_5_loss: 3.5335e-05 - lr: 0.0010 - time: 0.2998
# Epoch 89/1000
# 56/56 - 0s - loss: 0.0020 - U_loss: 1.3565e-04 - V_loss: 2.0964e-04 - Sxx_loss: 3.7253e-05 - Syy_loss: 7.5491e-04 - Sxy_loss: 1.5030e-05 - sub_loss: 4.5437e-05 - sub_2_loss: 7.8467e-04 - sub_3_loss: 1.5850e-05 - add_4_loss: 1.6763e-05 - add_5_loss: 2.8114e-05 - lr: 0.0010 - time: 0.2949
# Epoch 90/1000
# 56/56 - 0s - loss: 0.0019 - U_loss: 9.9745e-05 - V_loss: 1.9291e-04 - Sxx_loss: 2.9672e-05 - Syy_loss: 7.2999e-04 - Sxy_loss: 9.3781e-06 - sub_loss: 3.5454e-05 - sub_2_loss: 7.7603e-04 - sub_3_loss: 1.0282e-05 - add_4_loss: 1.3147e-05 - add_5_loss: 2.3149e-05 - lr: 0.0010 - time: 0.2961
# Epoch 91/1000
# 56/56 - 0s - loss: 0.0021 - U_loss: 1.4055e-04 - V_loss: 1.7707e-04 - Sxx_loss: 4.4867e-05 - Syy_loss: 7.7382e-04 - Sxy_loss: 2.1435e-05 - sub_loss: 5.3841e-05 - sub_2_loss: 7.8690e-04 - sub_3_loss: 2.1976e-05 - add_4_loss: 2.9018e-05 - add_5_loss: 4.6239e-05 - lr: 0.0010 - time: 0.2896
# Epoch 92/1000
# 56/56 - 0s - loss: 0.0020 - U_loss: 1.1966e-04 - V_loss: 2.3297e-04 - Sxx_loss: 2.9622e-05 - Syy_loss: 7.2384e-04 - Sxy_loss: 1.0486e-05 - sub_loss: 3.5376e-05 - sub_2_loss: 7.6987e-04 - sub_3_loss: 1.1202e-05 - add_4_loss: 1.4220e-05 - add_5_loss: 1.4770e-05 - lr: 0.0010 - time: 0.3024
# Epoch 93/1000
# 56/56 - 0s - loss: 0.0022 - U_loss: 1.2096e-04 - V_loss: 3.3045e-04 - Sxx_loss: 4.2925e-05 - Syy_loss: 7.5888e-04 - Sxy_loss: 1.6656e-05 - sub_loss: 5.2177e-05 - sub_2_loss: 7.7113e-04 - sub_3_loss: 1.7303e-05 - add_4_loss: 1.8801e-05 - add_5_loss: 2.9152e-05 - lr: 0.0010 - time: 0.2954
# Epoch 94/1000
# 56/56 - 0s - loss: 0.0022 - U_loss: 1.2253e-04 - V_loss: 2.9751e-04 - Sxx_loss: 5.5686e-05 - Syy_loss: 7.3449e-04 - Sxy_loss: 1.9792e-05 - sub_loss: 6.0380e-05 - sub_2_loss: 7.7835e-04 - sub_3_loss: 1.9967e-05 - add_4_loss: 3.8580e-05 - add_5_loss: 5.5694e-05 - lr: 0.0010 - time: 0.2946
# Epoch 95/1000
# 56/56 - 0s - loss: 0.0019 - U_loss: 1.0925e-04 - V_loss: 1.9180e-04 - Sxx_loss: 2.9326e-05 - Syy_loss: 7.4130e-04 - Sxy_loss: 1.0918e-05 - sub_loss: 3.6072e-05 - sub_2_loss: 7.6080e-04 - sub_3_loss: 1.1992e-05 - add_4_loss: 1.2014e-05 - add_5_loss: 2.9884e-05 - lr: 0.0010 - time: 0.2973
# Epoch 96/1000
# 56/56 - 0s - loss: 0.0020 - U_loss: 1.0228e-04 - V_loss: 2.9349e-04 - Sxx_loss: 2.6555e-05 - Syy_loss: 7.4387e-04 - Sxy_loss: 7.1765e-06 - sub_loss: 3.3468e-05 - sub_2_loss: 7.7882e-04 - sub_3_loss: 7.8736e-06 - add_4_loss: 7.2341e-06 - add_5_loss: 1.6438e-05 - lr: 0.0010 - time: 0.2942
# Epoch 97/1000
# 56/56 - 0s - loss: 0.0019 - U_loss: 1.0746e-04 - V_loss: 1.6868e-04 - Sxx_loss: 2.8893e-05 - Syy_loss: 7.4108e-04 - Sxy_loss: 1.0680e-05 - sub_loss: 3.4121e-05 - sub_2_loss: 7.6654e-04 - sub_3_loss: 1.1269e-05 - add_4_loss: 1.3595e-05 - add_5_loss: 1.6193e-05 - lr: 0.0010 - time: 0.2922
# Epoch 98/1000
# 56/56 - 0s - loss: 0.0019 - U_loss: 1.2927e-04 - V_loss: 1.9660e-04 - Sxx_loss: 3.5106e-05 - Syy_loss: 7.2896e-04 - Sxy_loss: 1.2040e-05 - sub_loss: 4.1103e-05 - sub_2_loss: 7.5226e-04 - sub_3_loss: 1.2621e-05 - add_4_loss: 1.3785e-05 - add_5_loss: 2.2507e-05 - lr: 0.0010 - time: 0.2954
# Epoch 99/1000
# 56/56 - 0s - loss: 0.0019 - U_loss: 6.2298e-05 - V_loss: 2.3906e-04 - Sxx_loss: 3.4740e-05 - Syy_loss: 7.3483e-04 - Sxy_loss: 1.3965e-05 - sub_loss: 4.1398e-05 - sub_2_loss: 7.6956e-04 - sub_3_loss: 1.4777e-05 - add_4_loss: 1.4504e-05 - add_5_loss: 2.3683e-05 - lr: 0.0010 - time: 0.2987
# Epoch 100/1000
# 56/56 - 0s - loss: 0.0023 - U_loss: 6.8379e-05 - V_loss: 2.3834e-04 - Sxx_loss: 5.0815e-05 - Syy_loss: 7.6503e-04 - Sxy_loss: 6.0451e-05 - sub_loss: 5.7817e-05 - sub_2_loss: 7.9884e-04 - sub_3_loss: 6.2401e-05 - add_4_loss: 4.6105e-05 - add_5_loss: 1.1573e-04 - lr: 0.0010 - time: 0.2947
# Epoch 101/1000
# 56/56 - 0s - loss: 0.0021 - U_loss: 8.6150e-05 - V_loss: 3.6051e-04 - Sxx_loss: 3.6884e-05 - Syy_loss: 7.3938e-04 - Sxy_loss: 1.3713e-05 - sub_loss: 4.2653e-05 - sub_2_loss: 7.5268e-04 - sub_3_loss: 1.4412e-05 - add_4_loss: 1.1968e-05 - add_5_loss: 2.6673e-05 - lr: 0.0010 - time: 0.2948
# Epoch 102/1000
# 56/56 - 0s - loss: 0.0019 - U_loss: 7.4848e-05 - V_loss: 2.1720e-04 - Sxx_loss: 2.8924e-05 - Syy_loss: 7.2247e-04 - Sxy_loss: 7.1247e-06 - sub_loss: 3.4848e-05 - sub_2_loss: 7.6052e-04 - sub_3_loss: 7.5337e-06 - add_4_loss: 9.5551e-06 - add_5_loss: 1.3051e-05 - lr: 0.0010 - time: 0.2966
# Epoch 103/1000
# 56/56 - 0s - loss: 0.0018 - U_loss: 9.0630e-05 - V_loss: 1.6882e-04 - Sxx_loss: 2.5354e-05 - Syy_loss: 7.2333e-04 - Sxy_loss: 9.6091e-06 - sub_loss: 3.1446e-05 - sub_2_loss: 7.4628e-04 - sub_3_loss: 1.0684e-05 - add_4_loss: 8.5246e-06 - add_5_loss: 1.8574e-05 - lr: 0.0010 - time: 0.2913
# Epoch 104/1000
# 56/56 - 0s - loss: 0.0020 - U_loss: 1.3579e-04 - V_loss: 2.0312e-04 - Sxx_loss: 3.1554e-05 - Syy_loss: 7.4739e-04 - Sxy_loss: 1.6459e-05 - sub_loss: 3.6030e-05 - sub_2_loss: 7.8003e-04 - sub_3_loss: 1.7128e-05 - add_4_loss: 8.4231e-06 - add_5_loss: 2.5315e-05 - lr: 0.0010 - time: 0.3064
# Epoch 105/1000
# 56/56 - 0s - loss: 0.0020 - U_loss: 9.6001e-05 - V_loss: 2.3605e-04 - Sxx_loss: 3.8608e-05 - Syy_loss: 7.3438e-04 - Sxy_loss: 1.4103e-05 - sub_loss: 4.5063e-05 - sub_2_loss: 7.6450e-04 - sub_3_loss: 1.4993e-05 - add_4_loss: 1.9341e-05 - add_5_loss: 2.4468e-05 - lr: 0.0010 - time: 0.2987
# Epoch 106/1000
# 56/56 - 0s - loss: 0.0019 - U_loss: 7.1569e-05 - V_loss: 2.2989e-04 - Sxx_loss: 4.8877e-05 - Syy_loss: 7.2648e-04 - Sxy_loss: 9.6360e-06 - sub_loss: 5.3783e-05 - sub_2_loss: 7.5065e-04 - sub_3_loss: 1.0210e-05 - add_4_loss: 1.6859e-05 - add_5_loss: 2.3795e-05 - lr: 0.0010 - time: 0.3123
# Epoch 107/1000
# 56/56 - 0s - loss: 0.0026 - U_loss: 1.3186e-04 - V_loss: 2.2061e-04 - Sxx_loss: 1.8714e-04 - Syy_loss: 7.6605e-04 - Sxy_loss: 5.3670e-05 - sub_loss: 1.9713e-04 - sub_2_loss: 8.0232e-04 - sub_3_loss: 5.4536e-05 - add_4_loss: 1.0845e-04 - add_5_loss: 8.4734e-05 - lr: 0.0010 - time: 0.2890
# Epoch 108/1000
# 56/56 - 0s - loss: 0.0022 - U_loss: 1.4237e-04 - V_loss: 2.9528e-04 - Sxx_loss: 7.7690e-05 - Syy_loss: 7.3824e-04 - Sxy_loss: 2.2309e-05 - sub_loss: 8.1868e-05 - sub_2_loss: 7.5981e-04 - sub_3_loss: 2.3502e-05 - add_4_loss: 4.8926e-05 - add_5_loss: 3.6543e-05 - lr: 0.0010 - time: 0.2972
# Epoch 109/1000
# 56/56 - 0s - loss: 0.0024 - U_loss: 2.8649e-04 - V_loss: 4.7590e-04 - Sxx_loss: 2.7592e-05 - Syy_loss: 7.2093e-04 - Sxy_loss: 1.6126e-05 - sub_loss: 3.1832e-05 - sub_2_loss: 7.5560e-04 - sub_3_loss: 1.6556e-05 - add_4_loss: 9.3209e-06 - add_5_loss: 3.0398e-05 - lr: 0.0010 - time: 0.2992
# Epoch 110/1000
# 56/56 - 0s - loss: 0.0019 - U_loss: 1.2864e-04 - V_loss: 2.1820e-04 - Sxx_loss: 2.8344e-05 - Syy_loss: 7.2560e-04 - Sxy_loss: 7.0831e-06 - sub_loss: 3.5314e-05 - sub_2_loss: 7.4628e-04 - sub_3_loss: 7.6870e-06 - add_4_loss: 1.4282e-05 - add_5_loss: 1.1088e-05 - lr: 0.0010 - time: 0.2984
# Epoch 111/1000
# 56/56 - 0s - loss: 0.0019 - U_loss: 5.8926e-05 - V_loss: 2.4042e-04 - Sxx_loss: 2.4636e-05 - Syy_loss: 7.2485e-04 - Sxy_loss: 5.3163e-06 - sub_loss: 3.0223e-05 - sub_2_loss: 7.4612e-04 - sub_3_loss: 5.9502e-06 - add_4_loss: 6.3978e-06 - add_5_loss: 1.3090e-05 - lr: 0.0010 - time: 0.3001
# Epoch 112/1000
# 56/56 - 0s - loss: 0.0018 - U_loss: 5.3344e-05 - V_loss: 1.6376e-04 - Sxx_loss: 2.5259e-05 - Syy_loss: 7.4129e-04 - Sxy_loss: 8.1213e-06 - sub_loss: 3.0151e-05 - sub_2_loss: 7.6338e-04 - sub_3_loss: 8.9742e-06 - add_4_loss: 4.9296e-06 - add_5_loss: 1.6068e-05 - lr: 0.0010 - time: 0.2930
# Epoch 113/1000
# 56/56 - 0s - loss: 0.0018 - U_loss: 5.4501e-05 - V_loss: 1.6877e-04 - Sxx_loss: 2.3268e-05 - Syy_loss: 7.2257e-04 - Sxy_loss: 5.3006e-06 - sub_loss: 2.8255e-05 - sub_2_loss: 7.6175e-04 - sub_3_loss: 5.7950e-06 - add_4_loss: 3.7468e-06 - add_5_loss: 1.1706e-05 - lr: 0.0010 - time: 0.2912
# Epoch 114/1000
# 56/56 - 0s - loss: 0.0018 - U_loss: 5.6365e-05 - V_loss: 1.6432e-04 - Sxx_loss: 2.5366e-05 - Syy_loss: 7.2084e-04 - Sxy_loss: 7.3364e-06 - sub_loss: 3.0791e-05 - sub_2_loss: 7.4127e-04 - sub_3_loss: 8.2620e-06 - add_4_loss: 6.6552e-06 - add_5_loss: 1.4649e-05 - lr: 0.0010 - time: 0.2929
# Epoch 115/1000
# 56/56 - 0s - loss: 0.0019 - U_loss: 6.8254e-05 - V_loss: 1.6764e-04 - Sxx_loss: 2.7386e-05 - Syy_loss: 7.6126e-04 - Sxy_loss: 1.5594e-05 - sub_loss: 3.3328e-05 - sub_2_loss: 7.8756e-04 - sub_3_loss: 1.6412e-05 - add_4_loss: 9.0815e-06 - add_5_loss: 3.4497e-05 - lr: 0.0010 - time: 0.2895
# Epoch 116/1000
# 56/56 - 0s - loss: 0.0018 - U_loss: 7.3362e-05 - V_loss: 1.8088e-04 - Sxx_loss: 2.5757e-05 - Syy_loss: 7.1511e-04 - Sxy_loss: 6.8458e-06 - sub_loss: 3.1974e-05 - sub_2_loss: 7.4186e-04 - sub_3_loss: 7.3406e-06 - add_4_loss: 5.1666e-06 - add_5_loss: 1.8436e-05 - lr: 0.0010 - time: 0.2929
# Epoch 117/1000
# 56/56 - 0s - loss: 0.0018 - U_loss: 4.8645e-05 - V_loss: 2.3311e-04 - Sxx_loss: 2.5208e-05 - Syy_loss: 7.2148e-04 - Sxy_loss: 6.7246e-06 - sub_loss: 2.9896e-05 - sub_2_loss: 7.4602e-04 - sub_3_loss: 7.2474e-06 - add_4_loss: 6.9891e-06 - add_5_loss: 1.7281e-05 - lr: 0.0010 - time: 0.2954
# Epoch 118/1000
# 56/56 - 0s - loss: 0.0021 - U_loss: 3.1174e-04 - V_loss: 1.8662e-04 - Sxx_loss: 2.9803e-05 - Syy_loss: 7.1063e-04 - Sxy_loss: 9.3095e-06 - sub_loss: 3.2664e-05 - sub_2_loss: 7.4317e-04 - sub_3_loss: 9.7208e-06 - add_4_loss: 1.1439e-05 - add_5_loss: 2.7112e-05 - lr: 0.0010 - time: 0.3008
# Epoch 119/1000
# 56/56 - 0s - loss: 0.0020 - U_loss: 1.4462e-04 - V_loss: 2.4536e-04 - Sxx_loss: 2.7894e-05 - Syy_loss: 7.3337e-04 - Sxy_loss: 2.5297e-05 - sub_loss: 3.2291e-05 - sub_2_loss: 7.5569e-04 - sub_3_loss: 2.5807e-05 - add_4_loss: 7.5304e-06 - add_5_loss: 2.5704e-05 - lr: 0.0010 - time: 0.3059
# Epoch 120/1000
# 56/56 - 0s - loss: 0.0019 - U_loss: 5.1937e-05 - V_loss: 2.1399e-04 - Sxx_loss: 3.4773e-05 - Syy_loss: 7.3607e-04 - Sxy_loss: 2.7362e-05 - sub_loss: 4.1704e-05 - sub_2_loss: 7.6247e-04 - sub_3_loss: 2.8164e-05 - add_4_loss: 1.5611e-05 - add_5_loss: 2.0700e-05 - lr: 0.0010 - time: 0.3058
# Epoch 121/1000
# 56/56 - 0s - loss: 0.0019 - U_loss: 5.1312e-05 - V_loss: 1.7206e-04 - Sxx_loss: 4.4002e-05 - Syy_loss: 7.1652e-04 - Sxy_loss: 1.0871e-05 - sub_loss: 4.9620e-05 - sub_2_loss: 7.3930e-04 - sub_3_loss: 1.1386e-05 - add_4_loss: 2.2065e-05 - add_5_loss: 2.9838e-05 - lr: 0.0010 - time: 0.3094
# Epoch 122/1000
# 56/56 - 0s - loss: 0.0018 - U_loss: 6.9208e-05 - V_loss: 1.7746e-04 - Sxx_loss: 2.4518e-05 - Syy_loss: 7.2290e-04 - Sxy_loss: 1.0809e-05 - sub_loss: 2.9489e-05 - sub_2_loss: 7.4554e-04 - sub_3_loss: 1.1340e-05 - add_4_loss: 5.7934e-06 - add_5_loss: 1.5511e-05 - lr: 0.0010 - time: 0.3009
# Epoch 123/1000
# 56/56 - 0s - loss: 0.0018 - U_loss: 6.1857e-05 - V_loss: 1.5744e-04 - Sxx_loss: 2.5653e-05 - Syy_loss: 7.3501e-04 - Sxy_loss: 1.0973e-05 - sub_loss: 3.1384e-05 - sub_2_loss: 7.5972e-04 - sub_3_loss: 1.1684e-05 - add_4_loss: 6.3232e-06 - add_5_loss: 1.6081e-05 - lr: 0.0010 - time: 0.2970
# Epoch 124/1000
# 56/56 - 0s - loss: 0.0020 - U_loss: 6.9367e-05 - V_loss: 1.6254e-04 - Sxx_loss: 3.5357e-05 - Syy_loss: 7.7892e-04 - Sxy_loss: 2.5270e-05 - sub_loss: 3.8548e-05 - sub_2_loss: 7.9810e-04 - sub_3_loss: 2.6477e-05 - add_4_loss: 1.1276e-05 - add_5_loss: 3.4246e-05 - lr: 0.0010 - time: 0.2981
# Epoch 125/1000
# 56/56 - 0s - loss: 0.0019 - U_loss: 8.4808e-05 - V_loss: 1.8698e-04 - Sxx_loss: 2.9561e-05 - Syy_loss: 7.3015e-04 - Sxy_loss: 1.5211e-05 - sub_loss: 3.4833e-05 - sub_2_loss: 7.7451e-04 - sub_3_loss: 1.5837e-05 - add_4_loss: 8.8869e-06 - add_5_loss: 2.0191e-05 - lr: 0.0010 - time: 0.2975
# Epoch 126/1000
# 56/56 - 0s - loss: 0.0018 - U_loss: 3.8538e-05 - V_loss: 1.7381e-04 - Sxx_loss: 2.4585e-05 - Syy_loss: 7.3097e-04 - Sxy_loss: 6.9458e-06 - sub_loss: 2.9746e-05 - sub_2_loss: 7.5660e-04 - sub_3_loss: 7.4545e-06 - add_4_loss: 5.8789e-06 - add_5_loss: 1.0870e-05 - lr: 0.0010 - time: 0.3002
# Epoch 127/1000
# 56/56 - 0s - loss: 0.0018 - U_loss: 6.4923e-05 - V_loss: 1.3974e-04 - Sxx_loss: 2.6322e-05 - Syy_loss: 7.3841e-04 - Sxy_loss: 1.0538e-05 - sub_loss: 3.1581e-05 - sub_2_loss: 7.5585e-04 - sub_3_loss: 1.1004e-05 - add_4_loss: 6.9186e-06 - add_5_loss: 1.2568e-05 - lr: 0.0010 - time: 0.2983
# Epoch 128/1000
# 56/56 - 0s - loss: 0.0019 - U_loss: 1.1413e-04 - V_loss: 1.8369e-04 - Sxx_loss: 2.6406e-05 - Syy_loss: 7.4875e-04 - Sxy_loss: 1.1030e-05 - sub_loss: 3.1074e-05 - sub_2_loss: 7.6787e-04 - sub_3_loss: 1.1570e-05 - add_4_loss: 6.8120e-06 - add_5_loss: 1.7321e-05 - lr: 0.0010 - time: 0.2934
# Epoch 129/1000
# 56/56 - 0s - loss: 0.0018 - U_loss: 5.4810e-05 - V_loss: 1.7973e-04 - Sxx_loss: 3.2185e-05 - Syy_loss: 7.2790e-04 - Sxy_loss: 1.0203e-05 - sub_loss: 3.8550e-05 - sub_2_loss: 7.5963e-04 - sub_3_loss: 1.0880e-05 - add_4_loss: 8.0986e-06 - add_5_loss: 1.4563e-05 - lr: 0.0010 - time: 0.3026
# Epoch 130/1000
# 56/56 - 0s - loss: 0.0019 - U_loss: 6.2164e-05 - V_loss: 2.1220e-04 - Sxx_loss: 2.9628e-05 - Syy_loss: 7.5446e-04 - Sxy_loss: 1.4977e-05 - sub_loss: 3.3774e-05 - sub_2_loss: 7.8423e-04 - sub_3_loss: 1.5492e-05 - add_4_loss: 1.0942e-05 - add_5_loss: 2.8161e-05 - lr: 0.0010 - time: 0.2865
# Epoch 131/1000
# 56/56 - 0s - loss: 0.0019 - U_loss: 5.7372e-05 - V_loss: 1.2273e-04 - Sxx_loss: 2.6727e-05 - Syy_loss: 7.6552e-04 - Sxy_loss: 1.7645e-05 - sub_loss: 3.1016e-05 - sub_2_loss: 7.9010e-04 - sub_3_loss: 1.8624e-05 - add_4_loss: 6.2411e-06 - add_5_loss: 1.8673e-05 - lr: 0.0010 - time: 0.2851
# Epoch 132/1000
# 56/56 - 0s - loss: 0.0019 - U_loss: 6.3637e-05 - V_loss: 2.1044e-04 - Sxx_loss: 2.9172e-05 - Syy_loss: 7.2797e-04 - Sxy_loss: 2.0428e-05 - sub_loss: 3.5263e-05 - sub_2_loss: 7.5005e-04 - sub_3_loss: 2.0921e-05 - add_4_loss: 8.3287e-06 - add_5_loss: 3.4118e-05 - lr: 0.0010 - time: 0.2919
# Epoch 133/1000
# 56/56 - 0s - loss: 0.0019 - U_loss: 5.3482e-05 - V_loss: 2.0315e-04 - Sxx_loss: 6.5531e-05 - Syy_loss: 7.1738e-04 - Sxy_loss: 1.4804e-05 - sub_loss: 7.0086e-05 - sub_2_loss: 7.4406e-04 - sub_3_loss: 1.5304e-05 - add_4_loss: 2.4744e-05 - add_5_loss: 2.5619e-05 - lr: 0.0010 - time: 0.2889
# Epoch 134/1000
# 56/56 - 0s - loss: 0.0018 - U_loss: 6.4149e-05 - V_loss: 1.6176e-04 - Sxx_loss: 2.3082e-05 - Syy_loss: 7.1377e-04 - Sxy_loss: 4.9700e-06 - sub_loss: 2.8325e-05 - sub_2_loss: 7.3825e-04 - sub_3_loss: 5.2736e-06 - add_4_loss: 4.0643e-06 - add_5_loss: 1.3135e-05 - lr: 0.0010 - time: 0.2852
# Epoch 135/1000
# 56/56 - 0s - loss: 0.0018 - U_loss: 7.1444e-05 - V_loss: 1.6819e-04 - Sxx_loss: 2.7688e-05 - Syy_loss: 7.1040e-04 - Sxy_loss: 4.3814e-06 - sub_loss: 3.1340e-05 - sub_2_loss: 7.3673e-04 - sub_3_loss: 4.8586e-06 - add_4_loss: 6.5090e-06 - add_5_loss: 1.3018e-05 - lr: 0.0010 - time: 0.2960
# Epoch 136/1000
# 56/56 - 0s - loss: 0.0020 - U_loss: 2.8428e-04 - V_loss: 1.4595e-04 - Sxx_loss: 2.5746e-05 - Syy_loss: 7.1827e-04 - Sxy_loss: 7.7405e-06 - sub_loss: 2.9715e-05 - sub_2_loss: 7.3370e-04 - sub_3_loss: 7.9953e-06 - add_4_loss: 5.8372e-06 - add_5_loss: 1.1556e-05 - lr: 0.0010 - time: 0.2978
# Epoch 137/1000
# 56/56 - 0s - loss: 0.0018 - U_loss: 8.9926e-05 - V_loss: 1.5387e-04 - Sxx_loss: 2.6819e-05 - Syy_loss: 7.2078e-04 - Sxy_loss: 5.9760e-06 - sub_loss: 3.1310e-05 - sub_2_loss: 7.4055e-04 - sub_3_loss: 6.3409e-06 - add_4_loss: 6.7133e-06 - add_5_loss: 1.1954e-05 - lr: 0.0010 - time: 0.3059
# Epoch 138/1000
# 56/56 - 0s - loss: 0.0018 - U_loss: 5.9093e-05 - V_loss: 1.3651e-04 - Sxx_loss: 2.4688e-05 - Syy_loss: 7.2807e-04 - Sxy_loss: 1.2012e-05 - sub_loss: 2.9197e-05 - sub_2_loss: 7.5598e-04 - sub_3_loss: 1.2562e-05 - add_4_loss: 4.5053e-06 - add_5_loss: 1.7189e-05 - lr: 0.0010 - time: 0.2876
# Epoch 139/1000
# 56/56 - 0s - loss: 0.0018 - U_loss: 6.8929e-05 - V_loss: 1.5248e-04 - Sxx_loss: 2.2889e-05 - Syy_loss: 7.1909e-04 - Sxy_loss: 6.0834e-06 - sub_loss: 2.7075e-05 - sub_2_loss: 7.4084e-04 - sub_3_loss: 6.6691e-06 - add_4_loss: 3.1928e-06 - add_5_loss: 1.6683e-05 - lr: 0.0010 - time: 0.2995
# Epoch 140/1000
# 56/56 - 0s - loss: 0.0018 - U_loss: 5.5187e-05 - V_loss: 1.9295e-04 - Sxx_loss: 2.6231e-05 - Syy_loss: 7.1926e-04 - Sxy_loss: 7.0617e-06 - sub_loss: 3.0357e-05 - sub_2_loss: 7.3623e-04 - sub_3_loss: 7.5286e-06 - add_4_loss: 6.0188e-06 - add_5_loss: 8.0407e-06 - lr: 0.0010 - time: 0.2912
# Epoch 141/1000
# 56/56 - 0s - loss: 0.0018 - U_loss: 7.5499e-05 - V_loss: 1.3404e-04 - Sxx_loss: 3.5622e-05 - Syy_loss: 7.1753e-04 - Sxy_loss: 5.7323e-06 - sub_loss: 3.9982e-05 - sub_2_loss: 7.4388e-04 - sub_3_loss: 6.2289e-06 - add_4_loss: 9.1699e-06 - add_5_loss: 7.8813e-06 - lr: 0.0010 - time: 0.2964
# Epoch 142/1000
# 56/56 - 0s - loss: 0.0018 - U_loss: 6.8988e-05 - V_loss: 1.8294e-04 - Sxx_loss: 3.4247e-05 - Syy_loss: 7.1269e-04 - Sxy_loss: 8.5252e-06 - sub_loss: 3.8634e-05 - sub_2_loss: 7.4523e-04 - sub_3_loss: 9.0615e-06 - add_4_loss: 1.0224e-05 - add_5_loss: 1.2262e-05 - lr: 0.0010 - time: 0.3002
# Epoch 143/1000
# 56/56 - 0s - loss: 0.0018 - U_loss: 5.7677e-05 - V_loss: 1.6078e-04 - Sxx_loss: 2.4759e-05 - Syy_loss: 7.2558e-04 - Sxy_loss: 9.9755e-06 - sub_loss: 2.8293e-05 - sub_2_loss: 7.3828e-04 - sub_3_loss: 1.0444e-05 - add_4_loss: 4.5235e-06 - add_5_loss: 1.4809e-05 - lr: 0.0010 - time: 0.2908
# Epoch 144/1000
# 56/56 - 0s - loss: 0.0019 - U_loss: 1.0287e-04 - V_loss: 1.4157e-04 - Sxx_loss: 3.8597e-05 - Syy_loss: 7.4389e-04 - Sxy_loss: 1.5803e-05 - sub_loss: 4.2994e-05 - sub_2_loss: 7.7658e-04 - sub_3_loss: 1.6227e-05 - add_4_loss: 1.4795e-05 - add_5_loss: 1.7969e-05 - lr: 0.0010 - time: 0.3057
# Epoch 145/1000
# 56/56 - 0s - loss: 0.0021 - U_loss: 2.1914e-04 - V_loss: 1.6006e-04 - Sxx_loss: 3.7338e-05 - Syy_loss: 7.8290e-04 - Sxy_loss: 1.6069e-05 - sub_loss: 4.0780e-05 - sub_2_loss: 8.2238e-04 - sub_3_loss: 1.6184e-05 - add_4_loss: 1.4044e-05 - add_5_loss: 2.0993e-05 - lr: 0.0010 - time: 0.3006
# Epoch 146/1000
# 56/56 - 0s - loss: 0.0020 - U_loss: 1.6360e-04 - V_loss: 1.6425e-04 - Sxx_loss: 2.8361e-05 - Syy_loss: 7.6855e-04 - Sxy_loss: 1.6756e-05 - sub_loss: 3.3341e-05 - sub_2_loss: 7.8702e-04 - sub_3_loss: 1.6928e-05 - add_4_loss: 9.2155e-06 - add_5_loss: 1.6247e-05 - lr: 0.0010 - time: 0.3032
# Epoch 147/1000
# 56/56 - 0s - loss: 0.0018 - U_loss: 5.5044e-05 - V_loss: 1.7582e-04 - Sxx_loss: 2.3149e-05 - Syy_loss: 7.2316e-04 - Sxy_loss: 9.4025e-06 - sub_loss: 2.7781e-05 - sub_2_loss: 7.5349e-04 - sub_3_loss: 9.7286e-06 - add_4_loss: 4.1234e-06 - add_5_loss: 1.4489e-05 - lr: 0.0010 - time: 0.2932
# Epoch 148/1000
# 56/56 - 0s - loss: 0.0018 - U_loss: 5.3663e-05 - V_loss: 1.5369e-04 - Sxx_loss: 2.7212e-05 - Syy_loss: 7.4107e-04 - Sxy_loss: 6.5148e-06 - sub_loss: 3.1406e-05 - sub_2_loss: 7.5880e-04 - sub_3_loss: 6.8755e-06 - add_4_loss: 6.3926e-06 - add_5_loss: 9.5005e-06 - lr: 0.0010 - time: 0.2887
# Epoch 149/1000
# 56/56 - 0s - loss: 0.0018 - U_loss: 5.3629e-05 - V_loss: 1.3402e-04 - Sxx_loss: 2.9963e-05 - Syy_loss: 7.3193e-04 - Sxy_loss: 9.6760e-06 - sub_loss: 3.4709e-05 - sub_2_loss: 7.5814e-04 - sub_3_loss: 9.8479e-06 - add_4_loss: 6.1303e-06 - add_5_loss: 1.3917e-05 - lr: 0.0010 - time: 0.2968
# Epoch 150/1000
# 56/56 - 0s - loss: 0.0018 - U_loss: 5.6484e-05 - V_loss: 2.1118e-04 - Sxx_loss: 3.1272e-05 - Syy_loss: 7.1516e-04 - Sxy_loss: 9.5094e-06 - sub_loss: 3.5756e-05 - sub_2_loss: 7.3678e-04 - sub_3_loss: 9.8465e-06 - add_4_loss: 6.4126e-06 - add_5_loss: 1.4673e-05 - lr: 0.0010 - time: 0.2976
# Epoch 151/1000
# 56/56 - 0s - loss: 0.0018 - U_loss: 7.0454e-05 - V_loss: 1.5253e-04 - Sxx_loss: 2.5286e-05 - Syy_loss: 7.1744e-04 - Sxy_loss: 6.5751e-06 - sub_loss: 2.8756e-05 - sub_2_loss: 7.3853e-04 - sub_3_loss: 6.9312e-06 - add_4_loss: 3.5675e-06 - add_5_loss: 1.3323e-05 - lr: 0.0010 - time: 0.3016
# Epoch 152/1000
# 56/56 - 0s - loss: 0.0018 - U_loss: 7.1509e-05 - V_loss: 1.5922e-04 - Sxx_loss: 4.4798e-05 - Syy_loss: 7.2032e-04 - Sxy_loss: 8.0622e-06 - sub_loss: 4.9912e-05 - sub_2_loss: 7.3549e-04 - sub_3_loss: 8.5486e-06 - add_4_loss: 9.5007e-06 - add_5_loss: 1.1239e-05 - lr: 0.0010 - time: 0.3230
# Epoch 153/1000
# 56/56 - 0s - loss: 0.0018 - U_loss: 4.9522e-05 - V_loss: 1.6354e-04 - Sxx_loss: 2.6900e-05 - Syy_loss: 7.2281e-04 - Sxy_loss: 1.7628e-05 - sub_loss: 3.0610e-05 - sub_2_loss: 7.5097e-04 - sub_3_loss: 1.8143e-05 - add_4_loss: 8.2667e-06 - add_5_loss: 2.7267e-05 - lr: 0.0010 - time: 0.2900
# Epoch 154/1000
# 56/56 - 0s - loss: 0.0018 - U_loss: 4.2676e-05 - V_loss: 1.5465e-04 - Sxx_loss: 2.7536e-05 - Syy_loss: 7.2723e-04 - Sxy_loss: 7.6655e-06 - sub_loss: 3.1096e-05 - sub_2_loss: 7.5152e-04 - sub_3_loss: 8.3059e-06 - add_4_loss: 7.7655e-06 - add_5_loss: 9.0236e-06 - lr: 0.0010 - time: 0.2999
# Epoch 155/1000
# 56/56 - 0s - loss: 0.0017 - U_loss: 4.3136e-05 - V_loss: 1.2955e-04 - Sxx_loss: 2.3264e-05 - Syy_loss: 7.1280e-04 - Sxy_loss: 4.4556e-06 - sub_loss: 2.7572e-05 - sub_2_loss: 7.3354e-04 - sub_3_loss: 4.7613e-06 - add_4_loss: 2.9674e-06 - add_5_loss: 6.1420e-06 - lr: 0.0010 - time: 0.2928
# Epoch 156/1000
# 56/56 - 0s - loss: 0.0018 - U_loss: 3.9380e-05 - V_loss: 1.6440e-04 - Sxx_loss: 4.0324e-05 - Syy_loss: 7.2863e-04 - Sxy_loss: 1.7594e-05 - sub_loss: 4.4515e-05 - sub_2_loss: 7.5618e-04 - sub_3_loss: 1.7827e-05 - add_4_loss: 9.0530e-06 - add_5_loss: 1.8244e-05 - lr: 0.0010 - time: 0.2934
# Epoch 157/1000
# ...
# Epoch 950/1000
# 56/56 - 0s - loss: 0.0015 - U_loss: 5.5580e-06 - V_loss: 6.6868e-05 - Sxx_loss: 2.0174e-05 - Syy_loss: 7.0337e-04 - Sxy_loss: 7.1567e-07 - sub_loss: 2.1396e-05 - sub_2_loss: 7.2367e-04 - sub_3_loss: 6.4677e-07 - add_4_loss: 2.5251e-08 - add_5_loss: 1.0295e-06 - lr: 5.0000e-04 - time: 0.3983
# Epoch 951/1000
# 56/56 - 0s - loss: 0.0015 - U_loss: 5.8345e-06 - V_loss: 6.0547e-05 - Sxx_loss: 2.0364e-05 - Syy_loss: 6.9942e-04 - Sxy_loss: 6.0841e-07 - sub_loss: 2.1307e-05 - sub_2_loss: 7.2283e-04 - sub_3_loss: 5.4157e-07 - add_4_loss: 3.2195e-08 - add_5_loss: 1.2951e-06 - lr: 5.0000e-04 - time: 0.3886
# Epoch 952/1000
# 56/56 - 0s - loss: 0.0015 - U_loss: 7.8193e-06 - V_loss: 7.2087e-05 - Sxx_loss: 2.0408e-05 - Syy_loss: 6.9908e-04 - Sxy_loss: 6.2613e-07 - sub_loss: 2.1494e-05 - sub_2_loss: 7.2565e-04 - sub_3_loss: 5.4834e-07 - add_4_loss: 3.2148e-08 - add_5_loss: 1.1506e-06 - lr: 5.0000e-04 - time: 0.3732
# Epoch 953/1000
# 56/56 - 0s - loss: 0.0015 - U_loss: 6.7940e-06 - V_loss: 6.7055e-05 - Sxx_loss: 2.0068e-05 - Syy_loss: 7.0478e-04 - Sxy_loss: 6.5843e-07 - sub_loss: 2.1198e-05 - sub_2_loss: 7.1907e-04 - sub_3_loss: 5.8923e-07 - add_4_loss: 2.0550e-08 - add_5_loss: 1.4433e-06 - lr: 5.0000e-04 - time: 0.3849
# Epoch 954/1000
# 56/56 - 0s - loss: 0.0015 - U_loss: 6.1097e-06 - V_loss: 6.4632e-05 - Sxx_loss: 2.0581e-05 - Syy_loss: 7.0022e-04 - Sxy_loss: 8.8680e-07 - sub_loss: 2.1473e-05 - sub_2_loss: 7.3068e-04 - sub_3_loss: 8.1685e-07 - add_4_loss: 2.1339e-08 - add_5_loss: 1.0043e-06 - lr: 5.0000e-04 - time: 0.3855
# Epoch 955/1000
# 56/56 - 0s - loss: 0.0015 - U_loss: 3.4189e-06 - V_loss: 6.4211e-05 - Sxx_loss: 2.0191e-05 - Syy_loss: 6.9927e-04 - Sxy_loss: 6.2787e-07 - sub_loss: 2.1262e-05 - sub_2_loss: 7.2037e-04 - sub_3_loss: 5.5513e-07 - add_4_loss: 2.2213e-08 - add_5_loss: 1.0904e-06 - lr: 5.0000e-04 - time: 0.3832
# Epoch 956/1000
# 56/56 - 0s - loss: 0.0015 - U_loss: 3.6615e-06 - V_loss: 6.3291e-05 - Sxx_loss: 2.0458e-05 - Syy_loss: 6.9726e-04 - Sxy_loss: 7.5628e-07 - sub_loss: 2.1554e-05 - sub_2_loss: 7.2193e-04 - sub_3_loss: 6.8946e-07 - add_4_loss: 2.2273e-08 - add_5_loss: 1.1927e-06 - lr: 5.0000e-04 - time: 0.3935
# Epoch 957/1000
# 56/56 - 0s - loss: 0.0015 - U_loss: 8.0350e-06 - V_loss: 5.8572e-05 - Sxx_loss: 2.0264e-05 - Syy_loss: 6.9683e-04 - Sxy_loss: 6.8344e-07 - sub_loss: 2.1304e-05 - sub_2_loss: 7.1354e-04 - sub_3_loss: 6.1764e-07 - add_4_loss: 2.5986e-08 - add_5_loss: 1.2337e-06 - lr: 5.0000e-04 - time: 0.4127
# Epoch 958/1000
# 56/56 - 0s - loss: 0.0015 - U_loss: 7.9673e-06 - V_loss: 6.4596e-05 - Sxx_loss: 2.0226e-05 - Syy_loss: 6.9359e-04 - Sxy_loss: 5.6906e-07 - sub_loss: 2.1222e-05 - sub_2_loss: 7.1728e-04 - sub_3_loss: 4.8894e-07 - add_4_loss: 4.4662e-08 - add_5_loss: 2.0422e-06 - lr: 5.0000e-04 - time: 0.3854
# Epoch 959/1000
# 56/56 - 0s - loss: 0.0015 - U_loss: 5.9797e-06 - V_loss: 7.0334e-05 - Sxx_loss: 2.0197e-05 - Syy_loss: 6.9051e-04 - Sxy_loss: 5.5691e-07 - sub_loss: 2.1283e-05 - sub_2_loss: 7.1660e-04 - sub_3_loss: 4.8451e-07 - add_4_loss: 3.0389e-08 - add_5_loss: 8.7297e-07 - lr: 5.0000e-04 - time: 0.3805
# Epoch 960/1000
# 56/56 - 0s - loss: 0.0015 - U_loss: 7.6589e-06 - V_loss: 7.3515e-05 - Sxx_loss: 2.0291e-05 - Syy_loss: 6.9855e-04 - Sxy_loss: 5.1272e-07 - sub_loss: 2.1359e-05 - sub_2_loss: 7.2621e-04 - sub_3_loss: 4.4088e-07 - add_4_loss: 1.7177e-08 - add_5_loss: 1.2515e-06 - lr: 5.0000e-04 - time: 0.3749
# Epoch 961/1000
# 56/56 - 0s - loss: 0.0015 - U_loss: 6.4306e-06 - V_loss: 6.2957e-05 - Sxx_loss: 2.0245e-05 - Syy_loss: 6.9657e-04 - Sxy_loss: 8.8838e-07 - sub_loss: 2.1424e-05 - sub_2_loss: 7.1936e-04 - sub_3_loss: 8.2405e-07 - add_4_loss: 3.8677e-08 - add_5_loss: 1.5364e-06 - lr: 5.0000e-04 - time: 0.3712
# Epoch 962/1000
# 56/56 - 0s - loss: 0.0015 - U_loss: 3.2982e-06 - V_loss: 7.2547e-05 - Sxx_loss: 2.0522e-05 - Syy_loss: 7.0377e-04 - Sxy_loss: 5.3729e-07 - sub_loss: 2.1369e-05 - sub_2_loss: 7.2314e-04 - sub_3_loss: 4.6346e-07 - add_4_loss: 4.5935e-08 - add_5_loss: 1.2895e-06 - lr: 5.0000e-04 - time: 0.3703
# Epoch 963/1000
# 56/56 - 0s - loss: 0.0015 - U_loss: 3.2421e-06 - V_loss: 6.1163e-05 - Sxx_loss: 2.0130e-05 - Syy_loss: 6.9955e-04 - Sxy_loss: 8.5212e-07 - sub_loss: 2.1256e-05 - sub_2_loss: 7.1890e-04 - sub_3_loss: 7.8734e-07 - add_4_loss: 2.4340e-08 - add_5_loss: 1.1459e-06 - lr: 5.0000e-04 - time: 0.3904
# Epoch 964/1000
# 56/56 - 0s - loss: 0.0016 - U_loss: 5.1426e-06 - V_loss: 7.5682e-05 - Sxx_loss: 2.0529e-05 - Syy_loss: 7.0214e-04 - Sxy_loss: 5.2040e-07 - sub_loss: 2.1478e-05 - sub_2_loss: 7.3454e-04 - sub_3_loss: 4.3878e-07 - add_4_loss: 2.1126e-08 - add_5_loss: 1.0102e-06 - lr: 5.0000e-04 - time: 0.3715
# Epoch 965/1000
# 56/56 - 0s - loss: 0.0016 - U_loss: 5.1395e-06 - V_loss: 6.4554e-05 - Sxx_loss: 2.0275e-05 - Syy_loss: 7.0046e-04 - Sxy_loss: 5.2107e-07 - sub_loss: 2.1298e-05 - sub_2_loss: 7.2387e-04 - sub_3_loss: 4.5170e-07 - add_4_loss: 1.8394e-08 - add_5_loss: 1.1039e-06 - lr: 5.0000e-04 - time: 0.3772
# Epoch 966/1000
# 56/56 - 0s - loss: 0.0015 - U_loss: 5.6354e-06 - V_loss: 5.7036e-05 - Sxx_loss: 2.0140e-05 - Syy_loss: 6.9963e-04 - Sxy_loss: 5.6005e-07 - sub_loss: 2.1353e-05 - sub_2_loss: 7.1615e-04 - sub_3_loss: 4.8998e-07 - add_4_loss: 2.2632e-08 - add_5_loss: 1.0136e-06 - lr: 5.0000e-04 - time: 0.3753
# Epoch 967/1000
# 56/56 - 0s - loss: 0.0015 - U_loss: 4.3847e-06 - V_loss: 6.9092e-05 - Sxx_loss: 2.0195e-05 - Syy_loss: 6.9893e-04 - Sxy_loss: 6.8769e-07 - sub_loss: 2.1085e-05 - sub_2_loss: 7.2590e-04 - sub_3_loss: 6.3059e-07 - add_4_loss: 4.0248e-08 - add_5_loss: 1.4659e-06 - lr: 5.0000e-04 - time: 0.3791
# Epoch 968/1000
# 56/56 - 0s - loss: 0.0015 - U_loss: 5.2753e-06 - V_loss: 6.3242e-05 - Sxx_loss: 2.0495e-05 - Syy_loss: 7.0105e-04 - Sxy_loss: 5.6201e-07 - sub_loss: 2.1472e-05 - sub_2_loss: 7.2370e-04 - sub_3_loss: 5.0366e-07 - add_4_loss: 2.6594e-08 - add_5_loss: 1.4142e-06 - lr: 5.0000e-04 - time: 0.4099
# Epoch 969/1000
# 56/56 - 0s - loss: 0.0015 - U_loss: 3.7792e-06 - V_loss: 6.5120e-05 - Sxx_loss: 2.0245e-05 - Syy_loss: 7.0586e-04 - Sxy_loss: 5.4309e-07 - sub_loss: 2.1404e-05 - sub_2_loss: 7.2404e-04 - sub_3_loss: 4.6393e-07 - add_4_loss: 2.4745e-08 - add_5_loss: 1.2848e-06 - lr: 5.0000e-04 - time: 0.4178
# Epoch 970/1000
# 56/56 - 0s - loss: 0.0015 - U_loss: 5.9777e-06 - V_loss: 7.2722e-05 - Sxx_loss: 2.0182e-05 - Syy_loss: 6.9469e-04 - Sxy_loss: 5.7033e-07 - sub_loss: 2.1290e-05 - sub_2_loss: 7.2210e-04 - sub_3_loss: 4.9390e-07 - add_4_loss: 2.4444e-08 - add_5_loss: 1.1864e-06 - lr: 5.0000e-04 - time: 0.4157
# Epoch 971/1000
# 56/56 - 0s - loss: 0.0015 - U_loss: 4.4185e-06 - V_loss: 6.0363e-05 - Sxx_loss: 2.0339e-05 - Syy_loss: 7.0060e-04 - Sxy_loss: 6.5428e-07 - sub_loss: 2.1098e-05 - sub_2_loss: 7.2098e-04 - sub_3_loss: 5.8049e-07 - add_4_loss: 2.5893e-08 - add_5_loss: 1.0613e-06 - lr: 5.0000e-04 - time: 0.4122
# Epoch 972/1000
# 56/56 - 0s - loss: 0.0015 - U_loss: 4.3275e-06 - V_loss: 6.2232e-05 - Sxx_loss: 2.0299e-05 - Syy_loss: 6.9844e-04 - Sxy_loss: 5.9963e-07 - sub_loss: 2.1461e-05 - sub_2_loss: 7.2623e-04 - sub_3_loss: 5.2437e-07 - add_4_loss: 1.2464e-08 - add_5_loss: 1.4429e-06 - lr: 5.0000e-04 - time: 0.4246
# Epoch 973/1000
# 56/56 - 0s - loss: 0.0015 - U_loss: 4.6487e-06 - V_loss: 6.9570e-05 - Sxx_loss: 2.0395e-05 - Syy_loss: 6.9954e-04 - Sxy_loss: 7.3473e-07 - sub_loss: 2.1503e-05 - sub_2_loss: 7.2030e-04 - sub_3_loss: 6.7004e-07 - add_4_loss: 3.5888e-08 - add_5_loss: 1.5663e-06 - lr: 5.0000e-04 - time: 0.4245
# Epoch 974/1000
# 56/56 - 0s - loss: 0.0015 - U_loss: 3.5676e-06 - V_loss: 6.5487e-05 - Sxx_loss: 2.0687e-05 - Syy_loss: 7.0039e-04 - Sxy_loss: 6.5794e-07 - sub_loss: 2.1947e-05 - sub_2_loss: 7.2211e-04 - sub_3_loss: 5.8319e-07 - add_4_loss: 4.2592e-08 - add_5_loss: 1.1129e-06 - lr: 5.0000e-04 - time: 0.4218
# Epoch 975/1000
# 56/56 - 0s - loss: 0.0016 - U_loss: 7.7142e-06 - V_loss: 7.0978e-05 - Sxx_loss: 2.0208e-05 - Syy_loss: 7.0481e-04 - Sxy_loss: 5.9008e-07 - sub_loss: 2.1278e-05 - sub_2_loss: 7.2774e-04 - sub_3_loss: 5.0945e-07 - add_4_loss: 3.0136e-08 - add_5_loss: 1.0125e-06 - lr: 5.0000e-04 - time: 0.4442
# Epoch 976/1000
# 56/56 - 0s - loss: 0.0015 - U_loss: 8.7927e-06 - V_loss: 7.4991e-05 - Sxx_loss: 2.0360e-05 - Syy_loss: 6.9566e-04 - Sxy_loss: 5.6720e-07 - sub_loss: 2.1277e-05 - sub_2_loss: 7.2186e-04 - sub_3_loss: 4.8566e-07 - add_4_loss: 3.0999e-08 - add_5_loss: 9.0515e-07 - lr: 5.0000e-04 - time: 0.4730
# Epoch 977/1000
# 56/56 - 0s - loss: 0.0015 - U_loss: 4.6616e-06 - V_loss: 6.5094e-05 - Sxx_loss: 2.0110e-05 - Syy_loss: 6.9579e-04 - Sxy_loss: 5.4975e-07 - sub_loss: 2.1001e-05 - sub_2_loss: 7.1924e-04 - sub_3_loss: 4.8003e-07 - add_4_loss: 1.8279e-08 - add_5_loss: 1.1754e-06 - lr: 5.0000e-04 - time: 0.4888
# Epoch 978/1000
# 56/56 - 0s - loss: 0.0015 - U_loss: 3.7650e-06 - V_loss: 7.0606e-05 - Sxx_loss: 2.0311e-05 - Syy_loss: 7.0019e-04 - Sxy_loss: 6.9857e-07 - sub_loss: 2.1644e-05 - sub_2_loss: 7.2190e-04 - sub_3_loss: 6.1884e-07 - add_4_loss: 2.5801e-08 - add_5_loss: 1.5087e-06 - lr: 5.0000e-04 - time: 0.4464
# Epoch 979/1000
# 56/56 - 1s - loss: 0.0015 - U_loss: 5.5202e-06 - V_loss: 6.9490e-05 - Sxx_loss: 2.0147e-05 - Syy_loss: 6.9695e-04 - Sxy_loss: 6.2201e-07 - sub_loss: 2.1192e-05 - sub_2_loss: 7.1727e-04 - sub_3_loss: 5.5482e-07 - add_4_loss: 1.7221e-08 - add_5_loss: 1.0005e-06 - lr: 5.0000e-04 - time: 0.5754
# Epoch 980/1000
# 56/56 - 0s - loss: 0.0016 - U_loss: 3.6969e-06 - V_loss: 8.1639e-05 - Sxx_loss: 2.0458e-05 - Syy_loss: 7.0006e-04 - Sxy_loss: 7.3905e-07 - sub_loss: 2.1427e-05 - sub_2_loss: 7.2081e-04 - sub_3_loss: 6.6797e-07 - add_4_loss: 2.3578e-08 - add_5_loss: 1.0092e-06 - lr: 5.0000e-04 - time: 0.4704
# Epoch 981/1000
# 56/56 - 1s - loss: 0.0015 - U_loss: 5.7919e-06 - V_loss: 6.2002e-05 - Sxx_loss: 2.0184e-05 - Syy_loss: 6.9844e-04 - Sxy_loss: 9.6823e-07 - sub_loss: 2.1586e-05 - sub_2_loss: 7.2759e-04 - sub_3_loss: 9.0814e-07 - add_4_loss: 2.3068e-08 - add_5_loss: 1.1720e-06 - lr: 5.0000e-04 - time: 0.5371
# Epoch 982/1000
# 56/56 - 0s - loss: 0.0016 - U_loss: 4.0271e-06 - V_loss: 6.7388e-05 - Sxx_loss: 2.1526e-05 - Syy_loss: 7.0705e-04 - Sxy_loss: 7.5378e-07 - sub_loss: 2.2371e-05 - sub_2_loss: 7.3538e-04 - sub_3_loss: 7.0355e-07 - add_4_loss: 4.5623e-08 - add_5_loss: 1.5838e-06 - lr: 5.0000e-04 - time: 0.4639
# Epoch 983/1000
# 56/56 - 0s - loss: 0.0015 - U_loss: 3.5299e-06 - V_loss: 6.2064e-05 - Sxx_loss: 2.0445e-05 - Syy_loss: 7.0535e-04 - Sxy_loss: 1.0088e-06 - sub_loss: 2.2154e-05 - sub_2_loss: 7.2605e-04 - sub_3_loss: 9.3972e-07 - add_4_loss: 4.9032e-08 - add_5_loss: 1.2689e-06 - lr: 5.0000e-04 - time: 0.4548
# Epoch 984/1000
# 56/56 - 0s - loss: 0.0015 - U_loss: 4.3910e-06 - V_loss: 6.4094e-05 - Sxx_loss: 2.0369e-05 - Syy_loss: 7.0159e-04 - Sxy_loss: 5.7969e-07 - sub_loss: 2.1245e-05 - sub_2_loss: 7.2307e-04 - sub_3_loss: 5.0486e-07 - add_4_loss: 1.8583e-08 - add_5_loss: 1.0300e-06 - lr: 5.0000e-04 - time: 0.4478
# Epoch 985/1000
# 56/56 - 1s - loss: 0.0015 - U_loss: 5.0620e-06 - V_loss: 5.9627e-05 - Sxx_loss: 2.0411e-05 - Syy_loss: 7.0217e-04 - Sxy_loss: 5.7158e-07 - sub_loss: 2.1471e-05 - sub_2_loss: 7.2546e-04 - sub_3_loss: 4.8413e-07 - add_4_loss: 3.1988e-08 - add_5_loss: 1.3092e-06 - lr: 5.0000e-04 - time: 0.5852
# Epoch 986/1000
# 56/56 - 0s - loss: 0.0015 - U_loss: 4.2496e-06 - V_loss: 6.7444e-05 - Sxx_loss: 2.0140e-05 - Syy_loss: 7.0064e-04 - Sxy_loss: 6.0301e-07 - sub_loss: 2.1028e-05 - sub_2_loss: 7.2514e-04 - sub_3_loss: 5.2421e-07 - add_4_loss: 1.7258e-08 - add_5_loss: 1.0355e-06 - lr: 5.0000e-04 - time: 0.4383
# Epoch 987/1000
# 56/56 - 1s - loss: 0.0016 - U_loss: 5.3138e-06 - V_loss: 9.1595e-05 - Sxx_loss: 2.0353e-05 - Syy_loss: 6.9669e-04 - Sxy_loss: 5.5728e-07 - sub_loss: 2.1440e-05 - sub_2_loss: 7.2084e-04 - sub_3_loss: 5.0176e-07 - add_4_loss: 1.8085e-08 - add_5_loss: 9.9626e-07 - lr: 5.0000e-04 - time: 0.5136
# Epoch 988/1000
# 56/56 - 0s - loss: 0.0015 - U_loss: 5.0605e-06 - V_loss: 6.4939e-05 - Sxx_loss: 2.0416e-05 - Syy_loss: 7.0279e-04 - Sxy_loss: 5.7786e-07 - sub_loss: 2.1871e-05 - sub_2_loss: 7.2448e-04 - sub_3_loss: 5.1924e-07 - add_4_loss: 3.0494e-08 - add_5_loss: 1.2054e-06 - lr: 5.0000e-04 - time: 0.4587
# Epoch 989/1000
# 56/56 - 0s - loss: 0.0016 - U_loss: 4.7301e-06 - V_loss: 7.9023e-05 - Sxx_loss: 2.1036e-05 - Syy_loss: 6.9873e-04 - Sxy_loss: 6.0685e-07 - sub_loss: 2.2029e-05 - sub_2_loss: 7.2356e-04 - sub_3_loss: 5.3916e-07 - add_4_loss: 3.0562e-08 - add_5_loss: 1.9795e-06 - lr: 5.0000e-04 - time: 0.4433
# Epoch 990/1000
# 56/56 - 1s - loss: 0.0015 - U_loss: 3.5000e-06 - V_loss: 5.8617e-05 - Sxx_loss: 1.9971e-05 - Syy_loss: 6.9446e-04 - Sxy_loss: 5.3551e-07 - sub_loss: 2.1025e-05 - sub_2_loss: 7.1899e-04 - sub_3_loss: 4.7261e-07 - add_4_loss: 2.1009e-08 - add_5_loss: 1.3462e-06 - lr: 5.0000e-04 - time: 0.5750
# Epoch 991/1000
# 56/56 - 0s - loss: 0.0015 - U_loss: 3.5792e-06 - V_loss: 5.7541e-05 - Sxx_loss: 2.0774e-05 - Syy_loss: 7.0521e-04 - Sxy_loss: 6.0120e-07 - sub_loss: 2.1890e-05 - sub_2_loss: 7.2846e-04 - sub_3_loss: 5.3555e-07 - add_4_loss: 2.0039e-08 - add_5_loss: 1.4957e-06 - lr: 5.0000e-04 - time: 0.4374
# Epoch 992/1000
# 56/56 - 0s - loss: 0.0015 - U_loss: 4.2147e-06 - V_loss: 6.3512e-05 - Sxx_loss: 2.0194e-05 - Syy_loss: 6.9526e-04 - Sxy_loss: 6.3192e-07 - sub_loss: 2.1189e-05 - sub_2_loss: 7.1742e-04 - sub_3_loss: 5.6479e-07 - add_4_loss: 1.6135e-08 - add_5_loss: 1.1408e-06 - lr: 5.0000e-04 - time: 0.4701
# Epoch 993/1000
# 56/56 - 0s - loss: 0.0015 - U_loss: 3.8349e-06 - V_loss: 7.2187e-05 - Sxx_loss: 2.0514e-05 - Syy_loss: 7.0225e-04 - Sxy_loss: 5.2922e-07 - sub_loss: 2.1442e-05 - sub_2_loss: 7.2627e-04 - sub_3_loss: 4.5809e-07 - add_4_loss: 2.5224e-08 - add_5_loss: 1.1940e-06 - lr: 5.0000e-04 - time: 0.4149
# Epoch 994/1000
# 56/56 - 0s - loss: 0.0016 - U_loss: 7.1968e-06 - V_loss: 7.9501e-05 - Sxx_loss: 2.0360e-05 - Syy_loss: 6.9924e-04 - Sxy_loss: 5.5352e-07 - sub_loss: 2.1523e-05 - sub_2_loss: 7.1708e-04 - sub_3_loss: 4.7841e-07 - add_4_loss: 1.9837e-08 - add_5_loss: 9.5215e-07 - lr: 5.0000e-04 - time: 0.3908
# Epoch 995/1000
# 56/56 - 0s - loss: 0.0015 - U_loss: 9.3576e-06 - V_loss: 7.2687e-05 - Sxx_loss: 2.0758e-05 - Syy_loss: 7.0039e-04 - Sxy_loss: 5.7615e-07 - sub_loss: 2.1927e-05 - sub_2_loss: 7.3024e-04 - sub_3_loss: 4.9762e-07 - add_4_loss: 1.8908e-08 - add_5_loss: 1.4035e-06 - lr: 5.0000e-04 - time: 0.3795
# Epoch 996/1000
# 56/56 - 0s - loss: 0.0015 - U_loss: 4.8712e-06 - V_loss: 5.7550e-05 - Sxx_loss: 2.0358e-05 - Syy_loss: 6.9576e-04 - Sxy_loss: 5.9239e-07 - sub_loss: 2.1350e-05 - sub_2_loss: 7.2063e-04 - sub_3_loss: 5.1816e-07 - add_4_loss: 2.7544e-08 - add_5_loss: 1.0456e-06 - lr: 5.0000e-04 - time: 0.4042
# Epoch 997/1000
# 56/56 - 0s - loss: 0.0015 - U_loss: 4.5881e-06 - V_loss: 6.0835e-05 - Sxx_loss: 2.0217e-05 - Syy_loss: 6.9916e-04 - Sxy_loss: 6.4819e-07 - sub_loss: 2.1139e-05 - sub_2_loss: 7.2018e-04 - sub_3_loss: 5.6054e-07 - add_4_loss: 2.5307e-08 - add_5_loss: 1.1366e-06 - lr: 5.0000e-04 - time: 0.4072
# Epoch 998/1000
# 56/56 - 0s - loss: 0.0015 - U_loss: 4.0447e-06 - V_loss: 6.8720e-05 - Sxx_loss: 2.0438e-05 - Syy_loss: 7.0039e-04 - Sxy_loss: 5.6744e-07 - sub_loss: 2.1652e-05 - sub_2_loss: 7.2289e-04 - sub_3_loss: 4.9179e-07 - add_4_loss: 2.2064e-08 - add_5_loss: 1.5375e-06 - lr: 5.0000e-04 - time: 0.4091
# Epoch 999/1000
# 56/56 - 0s - loss: 0.0016 - U_loss: 3.5727e-06 - V_loss: 7.9585e-05 - Sxx_loss: 2.0413e-05 - Syy_loss: 6.9871e-04 - Sxy_loss: 7.3634e-07 - sub_loss: 2.1468e-05 - sub_2_loss: 7.2812e-04 - sub_3_loss: 6.6880e-07 - add_4_loss: 1.9003e-08 - add_5_loss: 1.3729e-06 - lr: 5.0000e-04 - time: 0.3861
# Epoch 1000/1000
# 56/56 - 0s - loss: 0.0015 - U_loss: 5.4441e-06 - V_loss: 6.4759e-05 - Sxx_loss: 2.0417e-05 - Syy_loss: 6.9967e-04 - Sxy_loss: 7.3057e-07 - sub_loss: 2.1271e-05 - sub_2_loss: 7.2153e-04 - sub_3_loss: 6.6697e-07 - add_4_loss: 2.3832e-08 - add_5_loss: 1.1756e-06 - lr: 5.0000e-04 - time: 0.3711
# Input and output dimensions need re-adjustment for post-processing.
# Input and output dimensions need re-adjustment for post-processing.

# %%
plot(Emod,nu)
# Out:
# /tmp/ipykernel_26036/3587175452.py:34: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   im = AX.pcolor(X, Y, C, cmap="jet")
# (60, 46)

# %%
# Plot "exact" pressure field
#plt.imshow(P_exact, interpolation='nearest', cmap='rainbow', 
#                  extent=[x_star.min(), x_star.max(), y_star.min(), y_star.max()], 
#                  origin='lower', aspect='auto')

plt.imshow(P_exact, cmap='rainbow', 
                  extent=[x_star.min(), x_star.max(), y_star.min(), y_star.max()], 
                  origin='lower', aspect='auto')
plt.colorbar()

# %%
set_in.step_080.sel(field='S22')
