# %% [markdown]
# # Example
# from: https://github.com/sciann/sciann-applications/tree/master/SciANN-SolidMechanics

# %%
""" SciANN-SolidMechanics.py
Description:
    SciANN code for solution and discovery of solid mechanics from data.
    For additional details, please check our paper at: https://arxiv.org/abs/2003.02751
    
Created by Ehsan Haghighat on 2/14/20.
"""

import os, sys, time
import numpy as np
from sciann.utils.math import diff
from sciann import SciModel, Functional, Parameter
from sciann import Data, Tie
from sciann import Variable, Field

import matplotlib.pyplot as plt
import argparse
pi = np.pi

# %% [markdown]
# ## Parameters

# %%
# current file name. 
#current_file_name = os.path.basename(__file__).split(".")[0]
current_file_name = 'SciANN-SolidMechanics.ipynb'

# Lame paramters used in the paper. 
lmbd = 12.0
mu = 8.0
qload = 4.0

# %%
'''
# Input interface for python. 
parser = argparse.ArgumentParser(description=
        #SciANN code for solution and discovery of solid mechanics from data. \n 
        #For additional details, please check our paper at: https://arxiv.org/submit/3042511
)

# Define number of data points.
parser.add_argument('-l', '--layers', help='Num layers and neurons (default 4 layers each 40 neurons [40, 40, 40, 40])', type=int, nargs='+', default=[40]*4)
parser.add_argument('-af', '--actf', help='Activation function (default tanh)', type=str, nargs=1, default=['tanh'])
parser.add_argument('-nx', '--numx', help='Num Node in X (default 40)', type=int, nargs=1, default=[20])
parser.add_argument('-ny', '--numy', help='Num Node in Y (default 40)', type=int, nargs=1, default=[20])
parser.add_argument('-bs', '--batchsize', help='Batch size for Adam optimizer (default 32)', type=int, nargs=1, default=[32])
parser.add_argument('-e', '--epochs', help='Maximum number of epochs (default 2000)', type=int, nargs=1, default=[5000])
parser.add_argument('-lr', '--learningrate', help='Initial learning rate (default 0.001)', type=float, nargs=1, default=[0.001])
parser.add_argument('-in', '--independent_networks', help='Use independent networks for each var (default True)', type=bool, nargs=1, default=[True])
parser.add_argument('-v', '--verbose', help='Show training progress (default 2) (check Keras.fit)', type=int, nargs=1, default=[2])

parser.add_argument('--shuffle', help='Shuffle data for training (default True)', type=bool, nargs=1, default=[True])
parser.add_argument('--stopafter', help='Patience argument from Keras (default 500)', type=int, nargs=1, default=[500])
parser.add_argument('--savefreq', help='Frequency to save weights (each n-epoch)', type=int, nargs=1, default=[100000])
parser.add_argument('--dtype', help='Data type for weights and biases (default float64)', type=str, nargs=1, default=['float64'])
parser.add_argument('--gpu', help='Use GPU if available (default False)', type=bool, nargs=1, default=[False])
parser.add_argument('-op', '--outputpath', help='Output path (default ./file_name)', type=str, nargs=1, default=['output'])
parser.add_argument('-of', '--outputprefix', help='Output path (default res**)', type=str, nargs=1, default=['res'])

parser.add_argument('-nxp', '--numxplot', help='Num Node in X for ploting final results (default 200)', type=int, nargs=1, default=[200])
parser.add_argument('-nyp', '--numyplot', help='Num Node in Y for ploting final results (default 200)', type=int, nargs=1, default=[200])
parser.add_argument('--plot', help='Plot the model', nargs='?', default=False)

args = parser.parse_args()
'''
        
        
layers = [40]*4
actf = 'tanh'
numx = 20
numy = 20
batchsize = 32
epochs = 5000
learningrate = 0.001
independent_networks = True
verbose = 2
shuffle = True
stopafter = 500
savefreq = 100000
dtype = 'float64'
gpu = False
outputpath = 'output'
outputprefix = 'res'
numxplot = 200
numyplot = 200
plot = False

set = xr.open_dataset(data_file)

# %% [markdown]
# ## Functions

# %%
'''
def load(xx):
    x, y = xx[0], xx[1]
    Q = qload
    return Q * np.sin(pi*x)


def bodyfx(xx):
    x, y = xx[0], xx[1]
    Q = qload
    frc = - lmbd*(4*pi**2*np.cos(2*pi*x)*np.sin(pi*y) - Q*y**3*pi*np.cos(pi*x)) \
          - mu*(pi**2*np.cos(2*pi*x)*np.sin(pi*y) - Q*y**3*pi*np.cos(pi*x)) \
          - 8*mu*pi**2*np.cos(2*pi*x)*np.sin(pi*y)
    return frc


def bodyfy(xx):
    x, y = xx[0], xx[1]
    Q = qload
    frc = lmbd*(3*Q*y**2*np.sin(pi*x) - 2*pi**2*np.cos(pi*y)*np.sin(2*pi*x)) \
          - mu*(2*pi**2*np.cos(pi*y)*np.sin(2*pi*x) + (Q*y**4*pi**2*np.sin(pi*x))/4) \
          + 6*Q*mu*y**2*np.sin(pi*x)
    return frc
'''

def dispx(set): # xx
    #x, y = xx[0], xx[1]
    disp_x=set.sel(field='ux').to_array()
    return disp_x #np.cos(2*pi*x) * np.sin(pi*y)


def dispy(set): # xx
    #x, y = xx[0], xx[1]
    #Q = qload
    disp_y=set.sel(field='uy').to_array()
    return disp_y #np.sin(pi*x) * Q * y**4/4

'''
def strainxx(xx):
    x, y = xx[0], xx[1]
    Q = qload
    return -2*pi*np.sin(2*pi*x)*np.sin(pi*y)

def strainyy(xx):
    x, y = xx[0], xx[1]
    Q = qload
    return np.sin(pi*x)*Q*y**3


def strainxy(xx):
    x, y = xx[0], xx[1]
    Q = qload
    return 0.5*(pi*np.cos(2*pi*x)*np.cos(pi*y) + pi*np.cos(pi*x)*Q*y**4/4)
'''

def stressxx(set): # xx
    return set.sel(field='S11').to_array() #(lmbd+2*mu)*strainxx(xx) + lmbd*strainyy(xx)

def stressyy(set): # xx
    return set.sel(field='S22').to_array() #(lmbd+2*mu)*strainyy(xx) + lmbd*strainxx(xx)

def stressxy(set): # xx
    return set.sel(field='S21').to_array() #2.0*mu*strainxy(xx)

def cust_pcolor(AX, X, Y, C, title):
    im = AX.pcolor(X, Y, C, cmap="jet")
    AX.axis("equal")
    AX.axis("off")
    AX.set_title(title, fontsize=14)
    plt.colorbar(im, ax=AX)

def cust_semilogx(AX, X, Y, xlabel, ylabel):
    if X is None:
        im = AX.semilogy(Y)
    else:
        im = AX.semilogy(X, Y)
    if xlabel is not None: AX.set_xlabel(xlabel)
    if ylabel is not None: AX.set_ylabel(ylabel)

# %% [markdown]
# ## Training model

# %%
def train():
    # define output folder. 
    if not os.path.isdir(outputpath):
        os.mkdir(outputpath)
        
    output_file_name = os.path.join(outputpath, outputprefix)
    fname = output_file_name + "_{}_".format(actf) + "x".join([str(x) for x in layers])
    
    # Neural Network Setup.
    x = Variable("x", dtype=dtype)
    y = Variable("y", dtype=dtype)

    if independent_networks:
        Uxy = Functional("Uxy", [x, y], layers, actf)
        Vxy = Functional("Vxy", [x, y], layers, actf)
        Sxx = Functional("Sxx", [x, y], layers, actf)
        Syy = Functional("Syy", [x, y], layers, actf)
        Sxy = Functional("Sxy", [x, y], layers, actf)

    else:
        Uxy, Vxy, Sxx, Syy, Sxy = Functional(
            ["Uxy", "Vxy", "Sxx", "Syy", "Sxy"],
            [x, y],
            layers, act).split()
    
    lame1 = Parameter(2.0, inputs=[x,y], name="lame1")
    lame2 = Parameter(2.0, inputs=[x,y], name="lame2")

    C11 = (2*lame2 + lame1)
    C12 = lame1
    C33 = 2*lame2

    Exx = diff(Uxy, x)
    Eyy = diff(Vxy, y)
    Exy = (diff(Uxy, y) + diff(Vxy, x))*0.5

    # Define constraints 
    d1 = Data(Uxy)
    d2 = Data(Vxy)
    d3 = Data(Sxx)
    d4 = Data(Syy)
    d5 = Data(Sxy)
    
    c1 = Tie(Sxx, Exx*C11 + Eyy*C12)
    c2 = Tie(Syy, Eyy*C11 + Exx*C12)
    c3 = Tie(Sxy, Exy*C33)
    
    Lx = diff(Sxx, x) + diff(Sxy, y)
    Ly = diff(Sxy, x) + diff(Syy, y)
    
    # Define the optimization model (set of inputs and constraints)
    model = SciModel(
        inputs=[x, y],
        targets=[d1, d2, d3, d4, d5, c1, c2, c3, Lx, Ly],
        loss_func="mse"
    )
    with open("{}_summary".format(fname), "w") as fobj:
        model.summary(print_fn=lambda x: fobj.write(x + '\n'))
        
    # Prepare training data 
    ## Training grid 
    XMIN, XMAX = 0.0, 1.0
    YMIN, YMAX = 0.0, 1.0
    Xmesh = np.linspace(XMIN, XMAX, numx).reshape((-1, 1))
    Ymesh = np.linspace(YMIN, YMAX, numy).reshape((-1, 1))
    X, Y = np.meshgrid(Xmesh, Ymesh)

    input_data = [X.reshape(-1, 1), Y.reshape(-1, 1)]

    ## data associated to constrains defined earlier 
    # Define constraints 
    data_d1 = dispx(input_data)
    data_d2 = dispy(input_data)
    data_d3 = stressxx(input_data)
    data_d4 = stressyy(input_data)
    data_d5 = stressxy(input_data)
    data_c1 = 'zeros'
    data_c2 = 'zeros'
    data_c3 = 'zeros'
    data_Lx = bodyfx(input_data)
    data_Ly = bodyfy(input_data)
    
    target_data = [data_d1, data_d2, data_d3, data_d4, data_d5, 
                   data_c1, data_c2, data_c3,
                   data_Lx, data_Ly]

    fname_out = fname +'_WEIGHTS'
    # Train the model 
    training_time = time.time()
    history = model.train(
        x_true=input_data,
        y_true=target_data,
        epochs=epochs,
        batch_size=batchsize,
        shuffle=shuffle,
        learning_rate=learningrate,
        stop_after=stopafter,
        verbose=verbose,
        #save_weights_to=fname_out,
        #save_weights_freq=savefreq
    )
    training_time = time.time() - training_time

    for loss in history.history:
        np.savetxt(fname+"_{}".format("_".join(loss.split("/"))), 
                    np.array(history.history[loss]).reshape(-1, 1))
    
    time_steps = np.linspace(0, training_time, len(history.history["loss"]))
    np.savetxt(fname+"_Time", time_steps.reshape(-1,1))

    # Post process the trained model.
    Xmesh_plot = np.linspace(XMIN, XMAX, numxplot).reshape((-1, 1))
    Ymesh_plot = np.linspace(YMIN, YMAX, numyplot).reshape((-1, 1))
    X_plot, Y_plot = np.meshgrid(Xmesh_plot, Ymesh_plot)
    input_plot = [X_plot.reshape(-1, 1), Y_plot.reshape(-1, 1)]

    lame1_pred = lame1.eval(model, input_plot)
    lame2_pred = lame2.eval(model, input_plot)
    Uxy_pred = Uxy.eval(model, input_plot)
    Vxy_pred = Vxy.eval(model, input_plot)
    Exx_pred = Exx.eval(model, input_plot)
    Eyy_pred = Eyy.eval(model, input_plot)
    Exy_pred = Exy.eval(model, input_plot)
    Sxx_pred = Sxx.eval(model, input_plot)
    Syy_pred = Syy.eval(model, input_plot)
    Sxy_pred = Sxy.eval(model, input_plot)
        
    np.savetxt(fname+"_Xmesh", X_plot, delimiter=', ')
    np.savetxt(fname+"_Ymesh", Y_plot, delimiter=', ')
    np.savetxt(fname+"_lame1", lame1_pred, delimiter=', ')
    np.savetxt(fname+"_lame2", lame2_pred, delimiter=', ')
    np.savetxt(fname+"_Uxy", Uxy_pred.reshape(X_plot.shape), delimiter=', ')
    np.savetxt(fname+"_Vxy", Vxy_pred.reshape(X_plot.shape), delimiter=', ')
    np.savetxt(fname+"_Exx", Exx_pred.reshape(X_plot.shape), delimiter=', ')
    np.savetxt(fname+"_Eyy", Eyy_pred.reshape(X_plot.shape), delimiter=', ')
    np.savetxt(fname+"_Exy", Exy_pred.reshape(X_plot.shape), delimiter=', ')
    np.savetxt(fname+"_Sxx", Sxx_pred.reshape(X_plot.shape), delimiter=', ')
    np.savetxt(fname+"_Syy", Syy_pred.reshape(X_plot.shape), delimiter=', ')
    np.savetxt(fname+"_Sxy", Sxy_pred.reshape(X_plot.shape), delimiter=', ')

# %%
def plot():
    output_file_name = os.path.join(outputpath, outputprefix)
    fname = output_file_name + "_{}_".format(actf) + "x".join([str(x) for x in layers])
    
    loss = np.loadtxt(fname+"_loss")
    time = np.loadtxt(fname+"_Time")
    fig, ax = plt.subplots(1, 2, figsize=(7, 3), dpi=300)
    cust_semilogx(ax[0], None, loss/loss[0], "epochs", "L/L0")
    cust_semilogx(ax[1], time, loss/loss[0], "time(s)", None)
    fig.subplots_adjust(left=0.1, right=0.9, bottom=0.15, top=0.9, wspace=0.3, hspace=0.2)
    plt.savefig("{}_loss.png".format(output_file_name))
    
    Xmesh = np.loadtxt(fname+"_Xmesh", delimiter=',')
    Ymesh = np.loadtxt(fname+"_Ymesh", delimiter=',')
    
    fig, ax = plt.subplots(2, 2, figsize=(8, 6), dpi=300)
    cust_pcolor(ax[0, 0], Xmesh, Ymesh, np.ones_like(Xmesh)*lmbd, "L*={:.3f}".format(lmbd))
    cust_pcolor(ax[0, 1], Xmesh, Ymesh, np.ones_like(Xmesh)*mu, "G*={:.3f}".format(mu))
    lmbd_pred = np.loadtxt(fname+"_lame1", delimiter=',')
    mu_pred = np.loadtxt(fname+"_lame2", delimiter=',')
    cust_pcolor(ax[1, 0], Xmesh, Ymesh, np.ones_like(Xmesh)*lmbd_pred, "L={:.3f}".format(lmbd_pred.mean()))
    cust_pcolor(ax[1, 1], Xmesh, Ymesh, np.ones_like(Xmesh)*mu_pred, "G={:.3f}".format(mu_pred.mean()))
    plt.savefig("{}_Parameters.png".format(output_file_name))
    
    fig, ax = plt.subplots(2, 2, figsize=(8, 6), dpi=300)
    cust_pcolor(ax[0, 0], Xmesh, Ymesh, dispx([Xmesh, Ymesh]), "Ux*")
    cust_pcolor(ax[0, 1], Xmesh, Ymesh, dispy([Xmesh, Ymesh]), "Uy*")
    cust_pcolor(ax[1, 0], Xmesh, Ymesh, np.loadtxt(fname+"_Uxy", delimiter=','), "Ux")
    cust_pcolor(ax[1, 1], Xmesh, Ymesh, np.loadtxt(fname+"_Vxy", delimiter=','), "Uy")
    plt.savefig("{}_Displacement.png".format(output_file_name))
    
    fig, ax = plt.subplots(2, 3, figsize=(11, 6), dpi=300)
    cust_pcolor(ax[0, 0], Xmesh, Ymesh, stressxx([Xmesh, Ymesh]), "Sxx*")
    cust_pcolor(ax[0, 1], Xmesh, Ymesh, stressyy([Xmesh, Ymesh]), "Syy*")
    cust_pcolor(ax[0, 2], Xmesh, Ymesh, stressxy([Xmesh, Ymesh]), "Sxy*")
    cust_pcolor(ax[1, 0], Xmesh, Ymesh, np.loadtxt(fname+"_Sxx", delimiter=','), "Sxx")
    cust_pcolor(ax[1, 1], Xmesh, Ymesh, np.loadtxt(fname+"_Syy", delimiter=','), "Syy")
    cust_pcolor(ax[1, 2], Xmesh, Ymesh, np.loadtxt(fname+"_Sxy", delimiter=','), "Sxy")
    fig.subplots_adjust(left=0.1, right=0.9, bottom=0.05, top=0.9, wspace=0.3, hspace=0.2)
    plt.savefig("{}_Stress.png".format(output_file_name))
    
    fig, ax = plt.subplots(2, 3, figsize=(11, 6), dpi=300)
    cust_pcolor(ax[0, 0], Xmesh, Ymesh, strainxx([Xmesh, Ymesh]), "Exx*")
    cust_pcolor(ax[0, 1], Xmesh, Ymesh, strainyy([Xmesh, Ymesh]), "Eyy*")
    cust_pcolor(ax[0, 2], Xmesh, Ymesh, strainxy([Xmesh, Ymesh]), "Exy*")
    cust_pcolor(ax[1, 0], Xmesh, Ymesh, np.loadtxt(fname+"_Exx", delimiter=','), "Exx")
    cust_pcolor(ax[1, 1], Xmesh, Ymesh, np.loadtxt(fname+"_Eyy", delimiter=','), "Eyy")
    cust_pcolor(ax[1, 2], Xmesh, Ymesh, np.loadtxt(fname+"_Exy", delimiter=','), "Exy")
    fig.subplots_adjust(left=0.1, right=0.9, bottom=0.05, top=0.9, wspace=0.3, hspace=0.2)
    plt.savefig("{}_Strain.png".format(output_file_name))

# %% [markdown]
# ## Run it

# %%
train()
plot()
# Out:
# Total samples: 400
# Batch size: 32
# Total batches: 13
# 2022-04-23 17:11:02.366229: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/mnt/c/Windows/System32/xdmf/build/lib:/mnt/c/Windows/System32/yaml-cpp/build
# 2022-04-23 17:11:02.366316: W tensorflow/stream_executor/cuda/cuda_driver.cc:326] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-04-23 17:11:02.366392: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (DESKTOP-KVJB0RN): /proc/driver/nvidia/version does not exist
# 2022-04-23 17:11:02.367006: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-04-23 17:11:02.423939: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 1608000000 Hz
# Epoch 1/5000
# 13/13 - 2s - loss: 411182.0844 - Uxy_loss: 0.2620 - Vxy_loss: 0.0733 - Sxx_loss: 7133.4614 - Syy_loss: 2245.9230 - Sxy_loss: 221.2768 - sub_loss: 0.5385 - sub_2_loss: 0.7218 - sub_3_loss: 0.3160 - add_5_loss: 350018.3239 - add_6_loss: 46682.2312 - lr: 0.0010 - time: 2.2292
# Epoch 2/5000
# 13/13 - 0s - loss: 410205.0832 - Uxy_loss: 0.2452 - Vxy_loss: 0.1087 - Sxx_loss: 7097.1798 - Syy_loss: 2183.5855 - Sxy_loss: 219.7591 - sub_loss: 0.2335 - sub_2_loss: 0.3993 - sub_3_loss: 0.2873 - add_5_loss: 352443.9709 - add_6_loss: 48447.8406 - lr: 0.0010 - time: 0.0884
# Epoch 3/5000
# 13/13 - 0s - loss: 408370.6829 - Uxy_loss: 0.2630 - Vxy_loss: 0.2172 - Sxx_loss: 7161.5092 - Syy_loss: 2143.1565 - Sxy_loss: 220.5816 - sub_loss: 0.1800 - sub_2_loss: 0.4409 - sub_3_loss: 0.2893 - add_5_loss: 354559.7880 - add_6_loss: 45557.1166 - lr: 0.0010 - time: 0.1118
# Epoch 4/5000
# 13/13 - 0s - loss: 405104.9841 - Uxy_loss: 0.2686 - Vxy_loss: 0.2536 - Sxx_loss: 7141.2334 - Syy_loss: 2089.9623 - Sxy_loss: 221.1965 - sub_loss: 0.3649 - sub_2_loss: 0.4049 - sub_3_loss: 0.2714 - add_5_loss: 347628.6614 - add_6_loss: 45877.9637 - lr: 0.0010 - time: 0.1218
# Epoch 5/5000
# 13/13 - 0s - loss: 400300.2742 - Uxy_loss: 0.3149 - Vxy_loss: 0.3260 - Sxx_loss: 7118.0638 - Syy_loss: 2077.6339 - Sxy_loss: 225.1985 - sub_loss: 0.8891 - sub_2_loss: 0.8547 - sub_3_loss: 0.4527 - add_5_loss: 351277.6623 - add_6_loss: 44058.3967 - lr: 0.0010 - time: 0.1136
# Epoch 6/5000
# 13/13 - 0s - loss: 394863.6113 - Uxy_loss: 0.3171 - Vxy_loss: 0.3959 - Sxx_loss: 7034.8761 - Syy_loss: 1963.4235 - Sxy_loss: 223.6530 - sub_loss: 1.4795 - sub_2_loss: 2.6887 - sub_3_loss: 1.1098 - add_5_loss: 341988.6647 - add_6_loss: 42929.3173 - lr: 0.0010 - time: 0.1177
# Epoch 7/5000
# 13/13 - 0s - loss: 387351.3842 - Uxy_loss: 0.5096 - Vxy_loss: 0.5188 - Sxx_loss: 6993.9716 - Syy_loss: 1813.7082 - Sxy_loss: 216.5210 - sub_loss: 3.7180 - sub_2_loss: 8.1014 - sub_3_loss: 2.1605 - add_5_loss: 335687.1247 - add_6_loss: 40717.1894 - lr: 0.0010 - time: 0.1145
# Epoch 8/5000
# 13/13 - 0s - loss: 380079.4943 - Uxy_loss: 0.7543 - Vxy_loss: 0.8108 - Sxx_loss: 6919.1592 - Syy_loss: 1715.7759 - Sxy_loss: 220.6766 - sub_loss: 5.3833 - sub_2_loss: 12.9376 - sub_3_loss: 4.4867 - add_5_loss: 328229.6957 - add_6_loss: 37828.8652 - lr: 0.0010 - time: 0.1308
# Epoch 9/5000
# 13/13 - 0s - loss: 372839.7110 - Uxy_loss: 0.6750 - Vxy_loss: 1.2165 - Sxx_loss: 6869.4445 - Syy_loss: 1671.4988 - Sxy_loss: 207.9475 - sub_loss: 9.0567 - sub_2_loss: 18.8149 - sub_3_loss: 8.1061 - add_5_loss: 327679.9938 - add_6_loss: 34794.6127 - lr: 0.0010 - time: 0.1170
# Epoch 10/5000
# 13/13 - 0s - loss: 365164.4825 - Uxy_loss: 0.9319 - Vxy_loss: 1.4300 - Sxx_loss: 6927.9184 - Syy_loss: 1574.4113 - Sxy_loss: 209.5787 - sub_loss: 10.6405 - sub_2_loss: 20.1067 - sub_3_loss: 12.6948 - add_5_loss: 320134.1802 - add_6_loss: 31837.3859 - lr: 0.0010 - time: 0.1168
# Epoch 11/5000
# 13/13 - 0s - loss: 357825.3781 - Uxy_loss: 1.0172 - Vxy_loss: 1.7764 - Sxx_loss: 6814.1926 - Syy_loss: 1554.7653 - Sxy_loss: 216.4337 - sub_loss: 9.2577 - sub_2_loss: 26.0961 - sub_3_loss: 21.8769 - add_5_loss: 319899.9251 - add_6_loss: 29176.1183 - lr: 0.0010 - time: 0.1157
# Epoch 12/5000
# 13/13 - 0s - loss: 350310.3071 - Uxy_loss: 1.1644 - Vxy_loss: 1.5969 - Sxx_loss: 6671.8327 - Syy_loss: 1514.4828 - Sxy_loss: 226.8388 - sub_loss: 13.5232 - sub_2_loss: 29.7509 - sub_3_loss: 26.9575 - add_5_loss: 315779.3904 - add_6_loss: 27923.6427 - lr: 0.0010 - time: 0.1376
# Epoch 13/5000
# 13/13 - 0s - loss: 345964.7452 - Uxy_loss: 1.2868 - Vxy_loss: 1.2977 - Sxx_loss: 6839.0684 - Syy_loss: 1490.4814 - Sxy_loss: 238.1431 - sub_loss: 17.6238 - sub_2_loss: 23.7504 - sub_3_loss: 33.1623 - add_5_loss: 311312.6114 - add_6_loss: 25311.9432 - lr: 0.0010 - time: 0.1111
# Epoch 14/5000
# 13/13 - 0s - loss: 338210.7050 - Uxy_loss: 1.2381 - Vxy_loss: 2.0783 - Sxx_loss: 6597.5030 - Syy_loss: 1450.0975 - Sxy_loss: 261.3731 - sub_loss: 19.8904 - sub_2_loss: 31.5015 - sub_3_loss: 35.7655 - add_5_loss: 307099.3559 - add_6_loss: 25322.7887 - lr: 0.0010 - time: 0.1325
# Epoch 15/5000
# 13/13 - 0s - loss: 330327.7553 - Uxy_loss: 1.2986 - Vxy_loss: 1.8528 - Sxx_loss: 6553.8155 - Syy_loss: 1605.2884 - Sxy_loss: 268.8461 - sub_loss: 18.0895 - sub_2_loss: 30.7984 - sub_3_loss: 52.7254 - add_5_loss: 305173.7254 - add_6_loss: 22557.7459 - lr: 0.0010 - time: 0.1189
# Epoch 16/5000
# 13/13 - 0s - loss: 325402.1875 - Uxy_loss: 1.2493 - Vxy_loss: 0.9357 - Sxx_loss: 6589.5450 - Syy_loss: 1480.6662 - Sxy_loss: 293.4529 - sub_loss: 17.8148 - sub_2_loss: 22.4763 - sub_3_loss: 54.5169 - add_5_loss: 292821.3754 - add_6_loss: 21524.6805 - lr: 0.0010 - time: 0.1211
# Epoch 17/5000
# 13/13 - 0s - loss: 322914.4702 - Uxy_loss: 0.9999 - Vxy_loss: 2.6414 - Sxx_loss: 6404.7410 - Syy_loss: 1525.1841 - Sxy_loss: 325.8875 - sub_loss: 19.3173 - sub_2_loss: 24.0914 - sub_3_loss: 76.2293 - add_5_loss: 291338.1404 - add_6_loss: 21934.3180 - lr: 0.0010 - time: 0.1297
# Epoch 18/5000
# 13/13 - 0s - loss: 317225.1452 - Uxy_loss: 1.3297 - Vxy_loss: 1.0315 - Sxx_loss: 6401.4739 - Syy_loss: 1534.7022 - Sxy_loss: 316.4798 - sub_loss: 23.1393 - sub_2_loss: 27.5877 - sub_3_loss: 77.0939 - add_5_loss: 289156.6937 - add_6_loss: 19621.6008 - lr: 0.0010 - time: 0.1155
# Epoch 19/5000
# 13/13 - 0s - loss: 315534.9663 - Uxy_loss: 1.0511 - Vxy_loss: 1.6008 - Sxx_loss: 6443.3534 - Syy_loss: 1466.8847 - Sxy_loss: 348.0889 - sub_loss: 21.8566 - sub_2_loss: 36.2400 - sub_3_loss: 68.9603 - add_5_loss: 291524.2378 - add_6_loss: 19143.8097 - lr: 0.0010 - time: 0.1124
# Epoch 20/5000
# 13/13 - 0s - loss: 311179.6737 - Uxy_loss: 0.7911 - Vxy_loss: 1.2995 - Sxx_loss: 6286.1306 - Syy_loss: 1562.6684 - Sxy_loss: 364.5686 - sub_loss: 21.1661 - sub_2_loss: 28.0858 - sub_3_loss: 94.7507 - add_5_loss: 285014.5006 - add_6_loss: 18802.4951 - lr: 0.0010 - time: 0.1191
# Epoch 21/5000
# 13/13 - 0s - loss: 307734.8844 - Uxy_loss: 1.1458 - Vxy_loss: 1.2685 - Sxx_loss: 6262.4916 - Syy_loss: 1456.7692 - Sxy_loss: 377.6021 - sub_loss: 22.9048 - sub_2_loss: 30.9215 - sub_3_loss: 90.4635 - add_5_loss: 284893.4232 - add_6_loss: 18032.6860 - lr: 0.0010 - time: 0.1095
# Epoch 22/5000
# 13/13 - 0s - loss: 304483.1441 - Uxy_loss: 0.9420 - Vxy_loss: 1.8373 - Sxx_loss: 6118.0899 - Syy_loss: 1701.8403 - Sxy_loss: 382.1732 - sub_loss: 20.6614 - sub_2_loss: 32.8691 - sub_3_loss: 95.7449 - add_5_loss: 275949.2924 - add_6_loss: 19489.2506 - lr: 0.0010 - time: 0.1187
# Epoch 23/5000
# 13/13 - 0s - loss: 302100.0083 - Uxy_loss: 1.1352 - Vxy_loss: 1.7612 - Sxx_loss: 6184.1436 - Syy_loss: 1376.9271 - Sxy_loss: 407.6875 - sub_loss: 26.1303 - sub_2_loss: 34.8090 - sub_3_loss: 119.7841 - add_5_loss: 280850.1273 - add_6_loss: 17445.2872 - lr: 0.0010 - time: 0.1231
# Epoch 24/5000
# 13/13 - 0s - loss: 298068.0264 - Uxy_loss: 0.9490 - Vxy_loss: 4.0497 - Sxx_loss: 6053.0583 - Syy_loss: 1391.1760 - Sxy_loss: 436.8535 - sub_loss: 29.3976 - sub_2_loss: 45.0839 - sub_3_loss: 100.1653 - add_5_loss: 270485.8687 - add_6_loss: 16665.3711 - lr: 0.0010 - time: 0.1250
# Epoch 25/5000
# 13/13 - 0s - loss: 296282.6466 - Uxy_loss: 1.2364 - Vxy_loss: 1.8108 - Sxx_loss: 6106.5769 - Syy_loss: 1603.2554 - Sxy_loss: 421.9998 - sub_loss: 32.5665 - sub_2_loss: 47.7007 - sub_3_loss: 106.7535 - add_5_loss: 268550.3545 - add_6_loss: 16650.7855 - lr: 0.0010 - time: 0.1112
# Epoch 26/5000
# 13/13 - 0s - loss: 291655.5760 - Uxy_loss: 1.0070 - Vxy_loss: 2.8039 - Sxx_loss: 6048.5008 - Syy_loss: 1366.6260 - Sxy_loss: 455.7594 - sub_loss: 29.9572 - sub_2_loss: 36.1834 - sub_3_loss: 111.2192 - add_5_loss: 265435.5510 - add_6_loss: 16028.0205 - lr: 0.0010 - time: 0.1181
# Epoch 27/5000
# 13/13 - 0s - loss: 288166.5762 - Uxy_loss: 0.8839 - Vxy_loss: 2.4081 - Sxx_loss: 6177.2657 - Syy_loss: 1521.3502 - Sxy_loss: 451.1710 - sub_loss: 26.9980 - sub_2_loss: 40.6481 - sub_3_loss: 97.4792 - add_5_loss: 262395.1787 - add_6_loss: 15426.2080 - lr: 0.0010 - time: 0.1201
# Epoch 28/5000
# 13/13 - 0s - loss: 287920.5433 - Uxy_loss: 0.8801 - Vxy_loss: 2.3829 - Sxx_loss: 6067.0104 - Syy_loss: 1600.5328 - Sxy_loss: 452.4843 - sub_loss: 27.4772 - sub_2_loss: 37.0411 - sub_3_loss: 117.5301 - add_5_loss: 263287.7493 - add_6_loss: 15383.9303 - lr: 0.0010 - time: 0.1197
# Epoch 29/5000
# 13/13 - 0s - loss: 286230.7155 - Uxy_loss: 0.9826 - Vxy_loss: 2.2092 - Sxx_loss: 5852.3766 - Syy_loss: 1442.3392 - Sxy_loss: 482.0728 - sub_loss: 32.1148 - sub_2_loss: 39.4849 - sub_3_loss: 109.3506 - add_5_loss: 261771.7487 - add_6_loss: 14662.2628 - lr: 0.0010 - time: 0.1059
# Epoch 30/5000
# 13/13 - 0s - loss: 282851.5320 - Uxy_loss: 0.7585 - Vxy_loss: 2.2025 - Sxx_loss: 5983.5929 - Syy_loss: 1516.5924 - Sxy_loss: 522.3686 - sub_loss: 28.3872 - sub_2_loss: 34.5568 - sub_3_loss: 107.0163 - add_5_loss: 259106.7697 - add_6_loss: 14263.1052 - lr: 0.0010 - time: 0.1346
# Epoch 31/5000
# 13/13 - 0s - loss: 284744.6030 - Uxy_loss: 0.9412 - Vxy_loss: 2.9183 - Sxx_loss: 5966.6151 - Syy_loss: 1462.6167 - Sxy_loss: 504.5576 - sub_loss: 28.0968 - sub_2_loss: 64.6059 - sub_3_loss: 123.9680 - add_5_loss: 260392.9705 - add_6_loss: 15031.9900 - lr: 0.0010 - time: 0.1176
# Epoch 32/5000
# 13/13 - 0s - loss: 284064.5609 - Uxy_loss: 1.1016 - Vxy_loss: 2.6634 - Sxx_loss: 5891.4289 - Syy_loss: 1639.8447 - Sxy_loss: 564.9717 - sub_loss: 34.7662 - sub_2_loss: 41.0953 - sub_3_loss: 168.3204 - add_5_loss: 261477.5380 - add_6_loss: 15207.6644 - lr: 0.0010 - time: 0.1139
# Epoch 33/5000
# 13/13 - 0s - loss: 276755.4327 - Uxy_loss: 0.8262 - Vxy_loss: 2.3553 - Sxx_loss: 5768.5759 - Syy_loss: 1325.6888 - Sxy_loss: 519.4097 - sub_loss: 39.1132 - sub_2_loss: 71.6118 - sub_3_loss: 134.2983 - add_5_loss: 253057.9138 - add_6_loss: 13893.2204 - lr: 0.0010 - time: 0.1140
# Epoch 34/5000
# 13/13 - 0s - loss: 274157.4101 - Uxy_loss: 0.9463 - Vxy_loss: 1.6502 - Sxx_loss: 5784.8053 - Syy_loss: 1519.3181 - Sxy_loss: 549.3412 - sub_loss: 33.5558 - sub_2_loss: 39.2044 - sub_3_loss: 137.5734 - add_5_loss: 255459.1705 - add_6_loss: 12872.2779 - lr: 0.0010 - time: 0.1228
# Epoch 35/5000
# 13/13 - 0s - loss: 271702.1829 - Uxy_loss: 0.9560 - Vxy_loss: 3.0121 - Sxx_loss: 5746.7057 - Syy_loss: 1333.9325 - Sxy_loss: 558.9191 - sub_loss: 31.1438 - sub_2_loss: 56.7567 - sub_3_loss: 143.1997 - add_5_loss: 250491.4322 - add_6_loss: 12825.6573 - lr: 0.0010 - time: 0.1162
# Epoch 36/5000
# 13/13 - 0s - loss: 269642.5901 - Uxy_loss: 0.8222 - Vxy_loss: 2.4047 - Sxx_loss: 5579.2771 - Syy_loss: 1353.8684 - Sxy_loss: 566.2117 - sub_loss: 31.6679 - sub_2_loss: 53.1596 - sub_3_loss: 123.6695 - add_5_loss: 247830.8577 - add_6_loss: 12989.2724 - lr: 0.0010 - time: 0.1138
# Epoch 37/5000
# 13/13 - 0s - loss: 268109.9320 - Uxy_loss: 0.7164 - Vxy_loss: 2.5333 - Sxx_loss: 5670.8973 - Syy_loss: 1354.8995 - Sxy_loss: 599.6835 - sub_loss: 40.4745 - sub_2_loss: 54.4141 - sub_3_loss: 119.4667 - add_5_loss: 245997.7216 - add_6_loss: 12498.2454 - lr: 0.0010 - time: 0.1082
# Epoch 38/5000
# 13/13 - 0s - loss: 264810.2869 - Uxy_loss: 1.0080 - Vxy_loss: 2.9639 - Sxx_loss: 5586.7594 - Syy_loss: 1549.1429 - Sxy_loss: 623.1386 - sub_loss: 47.1074 - sub_2_loss: 61.7248 - sub_3_loss: 113.6799 - add_5_loss: 249385.4128 - add_6_loss: 12196.1797 - lr: 0.0010 - time: 0.1190
# Epoch 39/5000
# 13/13 - 0s - loss: 263177.1008 - Uxy_loss: 0.7826 - Vxy_loss: 2.9269 - Sxx_loss: 5645.0205 - Syy_loss: 1439.5043 - Sxy_loss: 640.3806 - sub_loss: 46.1579 - sub_2_loss: 47.4826 - sub_3_loss: 114.2167 - add_5_loss: 242946.5491 - add_6_loss: 11501.2349 - lr: 0.0010 - time: 0.1089
# Epoch 40/5000
# 13/13 - 0s - loss: 260309.9265 - Uxy_loss: 1.0790 - Vxy_loss: 2.3108 - Sxx_loss: 5697.7414 - Syy_loss: 1374.7425 - Sxy_loss: 601.4219 - sub_loss: 41.1973 - sub_2_loss: 48.2216 - sub_3_loss: 105.6086 - add_5_loss: 239552.5504 - add_6_loss: 11585.1323 - lr: 0.0010 - time: 0.1059
# Epoch 41/5000
# 13/13 - 0s - loss: 257625.4383 - Uxy_loss: 0.8319 - Vxy_loss: 2.1115 - Sxx_loss: 5479.5258 - Syy_loss: 1317.9570 - Sxy_loss: 636.4630 - sub_loss: 44.5262 - sub_2_loss: 49.8962 - sub_3_loss: 110.2422 - add_5_loss: 241194.8096 - add_6_loss: 11549.1034 - lr: 0.0010 - time: 0.1137
# Epoch 42/5000
# 13/13 - 0s - loss: 256917.8685 - Uxy_loss: 0.8163 - Vxy_loss: 2.5554 - Sxx_loss: 5665.6760 - Syy_loss: 1481.4634 - Sxy_loss: 658.0444 - sub_loss: 40.8207 - sub_2_loss: 67.1739 - sub_3_loss: 120.4921 - add_5_loss: 236666.4235 - add_6_loss: 11920.5175 - lr: 0.0010 - time: 0.1142
# Epoch 43/5000
# 13/13 - 0s - loss: 252283.0095 - Uxy_loss: 0.9998 - Vxy_loss: 2.2388 - Sxx_loss: 5719.7668 - Syy_loss: 1307.9624 - Sxy_loss: 689.1947 - sub_loss: 45.9044 - sub_2_loss: 61.8030 - sub_3_loss: 154.6940 - add_5_loss: 231813.1334 - add_6_loss: 11618.6442 - lr: 0.0010 - time: 0.1180
# Epoch 44/5000
# 13/13 - 0s - loss: 246442.5737 - Uxy_loss: 0.9056 - Vxy_loss: 2.3109 - Sxx_loss: 5719.2786 - Syy_loss: 1258.8789 - Sxy_loss: 684.5332 - sub_loss: 52.5719 - sub_2_loss: 68.4830 - sub_3_loss: 116.2819 - add_5_loss: 227231.1749 - add_6_loss: 11195.5530 - lr: 0.0010 - time: 0.1135
# Epoch 45/5000
# 13/13 - 0s - loss: 241781.1293 - Uxy_loss: 1.0420 - Vxy_loss: 1.7978 - Sxx_loss: 5775.4939 - Syy_loss: 1228.0902 - Sxy_loss: 682.1152 - sub_loss: 55.0021 - sub_2_loss: 55.0327 - sub_3_loss: 105.0230 - add_5_loss: 219823.6798 - add_6_loss: 10858.9034 - lr: 0.0010 - time: 0.1119
# Epoch 46/5000
# 13/13 - 0s - loss: 238977.2442 - Uxy_loss: 0.9116 - Vxy_loss: 2.5197 - Sxx_loss: 5697.3265 - Syy_loss: 1264.8200 - Sxy_loss: 727.6067 - sub_loss: 59.7646 - sub_2_loss: 73.2685 - sub_3_loss: 102.5717 - add_5_loss: 219983.4985 - add_6_loss: 10677.7509 - lr: 0.0010 - time: 0.1154
# Epoch 47/5000
# 13/13 - 0s - loss: 234342.2072 - Uxy_loss: 1.1627 - Vxy_loss: 2.4358 - Sxx_loss: 5712.4092 - Syy_loss: 1324.5064 - Sxy_loss: 700.8320 - sub_loss: 63.1408 - sub_2_loss: 73.2240 - sub_3_loss: 91.3108 - add_5_loss: 215675.6914 - add_6_loss: 11119.7657 - lr: 0.0010 - time: 0.1202
# Epoch 48/5000
# 13/13 - 0s - loss: 230606.9831 - Uxy_loss: 1.0038 - Vxy_loss: 2.1029 - Sxx_loss: 5600.0415 - Syy_loss: 1129.4701 - Sxy_loss: 751.0895 - sub_loss: 71.3282 - sub_2_loss: 57.9469 - sub_3_loss: 138.9928 - add_5_loss: 221012.0056 - add_6_loss: 10015.8122 - lr: 0.0010 - time: 0.1090
# Epoch 49/5000
# 13/13 - 0s - loss: 226903.5430 - Uxy_loss: 0.9701 - Vxy_loss: 2.9104 - Sxx_loss: 5566.4975 - Syy_loss: 1332.5041 - Sxy_loss: 776.5049 - sub_loss: 63.2983 - sub_2_loss: 83.5629 - sub_3_loss: 102.4323 - add_5_loss: 211105.4215 - add_6_loss: 10307.9738 - lr: 0.0010 - time: 0.1323
# Epoch 50/5000
# 13/13 - 0s - loss: 224200.1085 - Uxy_loss: 0.9354 - Vxy_loss: 1.9891 - Sxx_loss: 5726.1949 - Syy_loss: 1107.7692 - Sxy_loss: 786.5757 - sub_loss: 85.8071 - sub_2_loss: 76.3280 - sub_3_loss: 116.5403 - add_5_loss: 205345.9684 - add_6_loss: 10345.4017 - lr: 0.0010 - time: 0.1177
# Epoch 51/5000
# 13/13 - 0s - loss: 222832.9713 - Uxy_loss: 1.0713 - Vxy_loss: 2.3276 - Sxx_loss: 5689.0522 - Syy_loss: 1356.5723 - Sxy_loss: 767.7947 - sub_loss: 88.2433 - sub_2_loss: 87.3294 - sub_3_loss: 111.3265 - add_5_loss: 206523.4515 - add_6_loss: 9430.8886 - lr: 0.0010 - time: 0.1301
# Epoch 52/5000
# 13/13 - 0s - loss: 215495.5640 - Uxy_loss: 1.1329 - Vxy_loss: 2.2702 - Sxx_loss: 5557.2431 - Syy_loss: 1174.0115 - Sxy_loss: 761.7127 - sub_loss: 80.7081 - sub_2_loss: 83.4139 - sub_3_loss: 81.2605 - add_5_loss: 199943.9748 - add_6_loss: 9150.2589 - lr: 0.0010 - time: 0.1181
# Epoch 53/5000
# 13/13 - 0s - loss: 211367.3756 - Uxy_loss: 0.9686 - Vxy_loss: 2.3021 - Sxx_loss: 5438.7848 - Syy_loss: 1201.9685 - Sxy_loss: 790.6950 - sub_loss: 84.9946 - sub_2_loss: 85.5776 - sub_3_loss: 103.7692 - add_5_loss: 192368.0140 - add_6_loss: 9102.1168 - lr: 0.0010 - time: 0.1198
# Epoch 54/5000
# 13/13 - 0s - loss: 208552.2134 - Uxy_loss: 1.0643 - Vxy_loss: 2.5314 - Sxx_loss: 5453.4647 - Syy_loss: 1242.3850 - Sxy_loss: 806.2071 - sub_loss: 82.2555 - sub_2_loss: 96.9728 - sub_3_loss: 92.2403 - add_5_loss: 187961.3351 - add_6_loss: 9928.1747 - lr: 0.0010 - time: 0.1167
# Epoch 55/5000
# 13/13 - 0s - loss: 206137.5368 - Uxy_loss: 1.2450 - Vxy_loss: 2.4169 - Sxx_loss: 5395.9016 - Syy_loss: 1235.5805 - Sxy_loss: 830.0312 - sub_loss: 99.5396 - sub_2_loss: 94.1343 - sub_3_loss: 113.0481 - add_5_loss: 188063.5923 - add_6_loss: 9617.7061 - lr: 0.0010 - time: 0.1182
# Epoch 56/5000
# 13/13 - 0s - loss: 201009.7766 - Uxy_loss: 0.9487 - Vxy_loss: 2.6586 - Sxx_loss: 5305.6121 - Syy_loss: 1192.0060 - Sxy_loss: 834.6106 - sub_loss: 83.1605 - sub_2_loss: 89.9566 - sub_3_loss: 82.3242 - add_5_loss: 183570.4162 - add_6_loss: 9418.1645 - lr: 0.0010 - time: 0.1087
# Epoch 57/5000
# 13/13 - 0s - loss: 201097.0809 - Uxy_loss: 1.0749 - Vxy_loss: 2.0473 - Sxx_loss: 5218.5954 - Syy_loss: 1169.6094 - Sxy_loss: 854.9226 - sub_loss: 85.5591 - sub_2_loss: 70.1088 - sub_3_loss: 114.7550 - add_5_loss: 184823.4548 - add_6_loss: 8644.4289 - lr: 0.0010 - time: 0.1122
# Epoch 58/5000
# 13/13 - 0s - loss: 204791.3999 - Uxy_loss: 0.8650 - Vxy_loss: 2.8036 - Sxx_loss: 5351.6480 - Syy_loss: 1176.5118 - Sxy_loss: 912.5650 - sub_loss: 127.4229 - sub_2_loss: 96.0460 - sub_3_loss: 86.3536 - add_5_loss: 189864.2633 - add_6_loss: 9340.7689 - lr: 0.0010 - time: 0.1181
# Epoch 59/5000
# 13/13 - 0s - loss: 198188.7002 - Uxy_loss: 1.0163 - Vxy_loss: 2.2533 - Sxx_loss: 5049.0145 - Syy_loss: 1191.8773 - Sxy_loss: 882.5087 - sub_loss: 89.7371 - sub_2_loss: 76.3053 - sub_3_loss: 102.0182 - add_5_loss: 181443.1953 - add_6_loss: 8370.9956 - lr: 0.0010 - time: 0.1151
# Epoch 60/5000
# 13/13 - 0s - loss: 193360.0518 - Uxy_loss: 1.0301 - Vxy_loss: 2.5348 - Sxx_loss: 5221.3245 - Syy_loss: 1177.6512 - Sxy_loss: 907.1404 - sub_loss: 105.5339 - sub_2_loss: 90.7658 - sub_3_loss: 97.2340 - add_5_loss: 175986.8110 - add_6_loss: 8660.2026 - lr: 0.0010 - time: 0.1070
# Epoch 61/5000
# 13/13 - 0s - loss: 190048.7203 - Uxy_loss: 0.9520 - Vxy_loss: 2.6934 - Sxx_loss: 5010.8897 - Syy_loss: 1168.8884 - Sxy_loss: 884.4457 - sub_loss: 91.4151 - sub_2_loss: 95.4455 - sub_3_loss: 93.9280 - add_5_loss: 172452.5443 - add_6_loss: 8117.7465 - lr: 0.0010 - time: 0.1174
# Epoch 62/5000
# 13/13 - 0s - loss: 188660.4929 - Uxy_loss: 1.0959 - Vxy_loss: 2.3105 - Sxx_loss: 5021.9954 - Syy_loss: 1195.7890 - Sxy_loss: 936.3085 - sub_loss: 95.3733 - sub_2_loss: 76.6412 - sub_3_loss: 98.1634 - add_5_loss: 173194.6307 - add_6_loss: 8262.4092 - lr: 0.0010 - time: 0.1145
# Epoch 63/5000
# 13/13 - 0s - loss: 184484.1984 - Uxy_loss: 0.7940 - Vxy_loss: 2.9026 - Sxx_loss: 4949.2177 - Syy_loss: 1109.3583 - Sxy_loss: 940.5754 - sub_loss: 97.6681 - sub_2_loss: 83.1442 - sub_3_loss: 81.8796 - add_5_loss: 168792.8943 - add_6_loss: 7713.6742 - lr: 0.0010 - time: 0.1113
# Epoch 64/5000
# 13/13 - 0s - loss: 181384.9808 - Uxy_loss: 1.0321 - Vxy_loss: 2.4592 - Sxx_loss: 4968.2136 - Syy_loss: 1203.2704 - Sxy_loss: 954.8180 - sub_loss: 88.3655 - sub_2_loss: 82.5375 - sub_3_loss: 95.4333 - add_5_loss: 166370.1782 - add_6_loss: 8070.1680 - lr: 0.0010 - time: 0.1120
# Epoch 65/5000
# 13/13 - 0s - loss: 180509.0918 - Uxy_loss: 0.9259 - Vxy_loss: 2.7178 - Sxx_loss: 5026.0197 - Syy_loss: 1188.7978 - Sxy_loss: 967.7726 - sub_loss: 82.0034 - sub_2_loss: 83.9049 - sub_3_loss: 85.3101 - add_5_loss: 166096.9030 - add_6_loss: 7528.5038 - lr: 0.0010 - time: 0.1137
# Epoch 66/5000
# 13/13 - 0s - loss: 179771.8944 - Uxy_loss: 1.0143 - Vxy_loss: 2.4974 - Sxx_loss: 4857.8492 - Syy_loss: 1178.0711 - Sxy_loss: 996.1517 - sub_loss: 86.7052 - sub_2_loss: 100.6527 - sub_3_loss: 98.4594 - add_5_loss: 166431.5521 - add_6_loss: 7660.5419 - lr: 0.0010 - time: 0.1169
# Epoch 67/5000
# 13/13 - 0s - loss: 175305.4933 - Uxy_loss: 1.0248 - Vxy_loss: 2.7554 - Sxx_loss: 4896.0509 - Syy_loss: 1125.5874 - Sxy_loss: 1004.3468 - sub_loss: 114.2979 - sub_2_loss: 89.4163 - sub_3_loss: 102.3982 - add_5_loss: 159723.0119 - add_6_loss: 7467.6819 - lr: 0.0010 - time: 0.1254
# Epoch 68/5000
# 13/13 - 0s - loss: 174581.9843 - Uxy_loss: 0.7510 - Vxy_loss: 2.9494 - Sxx_loss: 4870.8845 - Syy_loss: 1107.9023 - Sxy_loss: 997.0431 - sub_loss: 92.7606 - sub_2_loss: 87.8396 - sub_3_loss: 100.4632 - add_5_loss: 158334.8275 - add_6_loss: 7264.8249 - lr: 0.0010 - time: 0.1197
# Epoch 69/5000
# 13/13 - 0s - loss: 170838.8605 - Uxy_loss: 1.1235 - Vxy_loss: 2.6386 - Sxx_loss: 4782.4805 - Syy_loss: 1283.0267 - Sxy_loss: 1021.4198 - sub_loss: 84.8143 - sub_2_loss: 104.4627 - sub_3_loss: 95.8576 - add_5_loss: 156901.3575 - add_6_loss: 7288.3222 - lr: 0.0010 - time: 0.1167
# Epoch 70/5000
# 13/13 - 0s - loss: 173308.0594 - Uxy_loss: 0.7448 - Vxy_loss: 2.9139 - Sxx_loss: 4816.5578 - Syy_loss: 1183.7841 - Sxy_loss: 1036.5004 - sub_loss: 110.2229 - sub_2_loss: 106.0012 - sub_3_loss: 114.9079 - add_5_loss: 155812.4492 - add_6_loss: 7637.5337 - lr: 0.0010 - time: 0.1195
# Epoch 71/5000
# 13/13 - 0s - loss: 167011.8177 - Uxy_loss: 0.8021 - Vxy_loss: 3.2558 - Sxx_loss: 4781.5888 - Syy_loss: 1133.4932 - Sxy_loss: 1040.4388 - sub_loss: 87.0664 - sub_2_loss: 92.7258 - sub_3_loss: 129.4606 - add_5_loss: 149353.6167 - add_6_loss: 7655.0192 - lr: 0.0010 - time: 0.1119
# Epoch 72/5000
# 13/13 - 0s - loss: 170241.3877 - Uxy_loss: 0.7122 - Vxy_loss: 2.6928 - Sxx_loss: 5009.3875 - Syy_loss: 1201.8028 - Sxy_loss: 1066.4809 - sub_loss: 125.7558 - sub_2_loss: 95.4911 - sub_3_loss: 120.1726 - add_5_loss: 153377.2431 - add_6_loss: 6568.1911 - lr: 0.0010 - time: 0.1174
# Epoch 73/5000
# 13/13 - 0s - loss: 170142.5580 - Uxy_loss: 1.0870 - Vxy_loss: 3.1358 - Sxx_loss: 4745.1470 - Syy_loss: 1164.9448 - Sxy_loss: 1069.7595 - sub_loss: 98.2888 - sub_2_loss: 105.8458 - sub_3_loss: 76.0121 - add_5_loss: 154257.3081 - add_6_loss: 6810.6046 - lr: 0.0010 - time: 0.1115
# Epoch 74/5000
# 13/13 - 0s - loss: 174427.9483 - Uxy_loss: 0.7136 - Vxy_loss: 2.8293 - Sxx_loss: 4890.2469 - Syy_loss: 1191.5258 - Sxy_loss: 1095.0654 - sub_loss: 135.0568 - sub_2_loss: 83.9961 - sub_3_loss: 110.2895 - add_5_loss: 158366.8942 - add_6_loss: 7286.8141 - lr: 0.0010 - time: 0.1144
# Epoch 75/5000
# 13/13 - 0s - loss: 167294.4845 - Uxy_loss: 1.1087 - Vxy_loss: 3.1618 - Sxx_loss: 4605.4987 - Syy_loss: 1161.6971 - Sxy_loss: 1091.5616 - sub_loss: 65.3247 - sub_2_loss: 101.0533 - sub_3_loss: 97.4258 - add_5_loss: 149325.8471 - add_6_loss: 7155.0677 - lr: 0.0010 - time: 0.1144
# Epoch 76/5000
# 13/13 - 0s - loss: 177629.8479 - Uxy_loss: 0.6937 - Vxy_loss: 2.9368 - Sxx_loss: 5108.8800 - Syy_loss: 1148.0051 - Sxy_loss: 1110.6878 - sub_loss: 155.8526 - sub_2_loss: 105.3228 - sub_3_loss: 87.7630 - add_5_loss: 160381.0024 - add_6_loss: 6525.1198 - lr: 0.0010 - time: 0.1179
# Epoch 77/5000
# 13/13 - 0s - loss: 160625.0432 - Uxy_loss: 0.9671 - Vxy_loss: 2.8785 - Sxx_loss: 4631.6822 - Syy_loss: 1131.1269 - Sxy_loss: 1106.9937 - sub_loss: 94.2976 - sub_2_loss: 121.7221 - sub_3_loss: 83.5548 - add_5_loss: 145810.7462 - add_6_loss: 6465.4646 - lr: 0.0010 - time: 0.1093
# Epoch 78/5000
# 13/13 - 0s - loss: 162611.5181 - Uxy_loss: 0.8201 - Vxy_loss: 3.1649 - Sxx_loss: 4907.0249 - Syy_loss: 1190.9254 - Sxy_loss: 1143.4201 - sub_loss: 110.9843 - sub_2_loss: 111.7581 - sub_3_loss: 109.7637 - add_5_loss: 146753.8970 - add_6_loss: 6825.3796 - lr: 0.0010 - time: 0.1161
# Epoch 79/5000
# 13/13 - 0s - loss: 164365.3207 - Uxy_loss: 1.0249 - Vxy_loss: 3.2214 - Sxx_loss: 4458.9234 - Syy_loss: 1143.2620 - Sxy_loss: 1166.8973 - sub_loss: 73.2643 - sub_2_loss: 126.6591 - sub_3_loss: 102.6412 - add_5_loss: 150820.0024 - add_6_loss: 7764.2222 - lr: 0.0010 - time: 0.1139
# Epoch 80/5000
# 13/13 - 0s - loss: 162941.8620 - Uxy_loss: 0.6572 - Vxy_loss: 3.0404 - Sxx_loss: 4980.6782 - Syy_loss: 1235.0300 - Sxy_loss: 1148.4507 - sub_loss: 133.1959 - sub_2_loss: 162.2814 - sub_3_loss: 145.3680 - add_5_loss: 147112.8451 - add_6_loss: 6764.9457 - lr: 0.0010 - time: 0.1100
# Epoch 81/5000
# 13/13 - 0s - loss: 156299.3222 - Uxy_loss: 1.1726 - Vxy_loss: 3.3139 - Sxx_loss: 4443.4240 - Syy_loss: 1116.0474 - Sxy_loss: 1179.3384 - sub_loss: 98.1077 - sub_2_loss: 153.2268 - sub_3_loss: 103.9694 - add_5_loss: 142089.9387 - add_6_loss: 7209.7961 - lr: 0.0010 - time: 0.1178
# Epoch 82/5000
# 13/13 - 0s - loss: 165628.0252 - Uxy_loss: 0.8524 - Vxy_loss: 3.2042 - Sxx_loss: 4944.6455 - Syy_loss: 1079.0995 - Sxy_loss: 1188.7332 - sub_loss: 206.2261 - sub_2_loss: 132.2947 - sub_3_loss: 103.3818 - add_5_loss: 150531.9400 - add_6_loss: 6518.7054 - lr: 0.0010 - time: 0.1171
# Epoch 83/5000
# 13/13 - 0s - loss: 150265.2392 - Uxy_loss: 1.3567 - Vxy_loss: 3.8228 - Sxx_loss: 4455.3558 - Syy_loss: 1155.4930 - Sxy_loss: 1172.0416 - sub_loss: 108.3712 - sub_2_loss: 158.1090 - sub_3_loss: 91.5568 - add_5_loss: 135525.7022 - add_6_loss: 6822.8876 - lr: 0.0010 - time: 0.1098
# Epoch 84/5000
# 13/13 - 0s - loss: 150137.0721 - Uxy_loss: 1.0578 - Vxy_loss: 3.3297 - Sxx_loss: 4438.3345 - Syy_loss: 1161.9563 - Sxy_loss: 1202.6987 - sub_loss: 64.3848 - sub_2_loss: 148.4932 - sub_3_loss: 83.5084 - add_5_loss: 134293.0543 - add_6_loss: 6799.9490 - lr: 0.0010 - time: 0.1140
# Epoch 85/5000
# 13/13 - 0s - loss: 158694.1372 - Uxy_loss: 0.9254 - Vxy_loss: 3.3060 - Sxx_loss: 4608.3584 - Syy_loss: 1132.6862 - Sxy_loss: 1198.0682 - sub_loss: 118.1991 - sub_2_loss: 112.8316 - sub_3_loss: 85.8957 - add_5_loss: 149745.5798 - add_6_loss: 6720.7287 - lr: 0.0010 - time: 0.1145
# Epoch 86/5000
# 13/13 - 0s - loss: 149258.4895 - Uxy_loss: 1.0670 - Vxy_loss: 3.4802 - Sxx_loss: 4702.9536 - Syy_loss: 1340.5352 - Sxy_loss: 1206.3014 - sub_loss: 116.6870 - sub_2_loss: 144.2711 - sub_3_loss: 79.8254 - add_5_loss: 133631.1864 - add_6_loss: 7061.9511 - lr: 0.0010 - time: 0.1132
# Epoch 87/5000
# 13/13 - 0s - loss: 151367.1073 - Uxy_loss: 0.8576 - Vxy_loss: 3.2508 - Sxx_loss: 4452.8141 - Syy_loss: 1073.2779 - Sxy_loss: 1229.5060 - sub_loss: 104.7970 - sub_2_loss: 153.9659 - sub_3_loss: 115.9281 - add_5_loss: 140030.1648 - add_6_loss: 6883.1177 - lr: 0.0010 - time: 0.1208
# Epoch 88/5000
# 13/13 - 0s - loss: 147858.0841 - Uxy_loss: 1.0245 - Vxy_loss: 3.9053 - Sxx_loss: 4791.6060 - Syy_loss: 1133.7746 - Sxy_loss: 1211.2271 - sub_loss: 118.3660 - sub_2_loss: 102.0197 - sub_3_loss: 130.4374 - add_5_loss: 135633.6615 - add_6_loss: 6487.1688 - lr: 0.0010 - time: 0.1096
# Epoch 89/5000
# 13/13 - 0s - loss: 145692.3182 - Uxy_loss: 0.8680 - Vxy_loss: 3.4112 - Sxx_loss: 4469.0809 - Syy_loss: 1202.9897 - Sxy_loss: 1248.3463 - sub_loss: 75.0004 - sub_2_loss: 93.3958 - sub_3_loss: 119.2745 - add_5_loss: 133482.9879 - add_6_loss: 6298.0297 - lr: 0.0010 - time: 0.1271
# Epoch 90/5000
# 13/13 - 0s - loss: 152635.7065 - Uxy_loss: 0.8023 - Vxy_loss: 3.4973 - Sxx_loss: 4733.3280 - Syy_loss: 1131.2145 - Sxy_loss: 1222.4156 - sub_loss: 133.5266 - sub_2_loss: 105.6618 - sub_3_loss: 87.5371 - add_5_loss: 135775.7240 - add_6_loss: 6270.5098 - lr: 0.0010 - time: 0.1113
# Epoch 91/5000
# 13/13 - 0s - loss: 146692.7991 - Uxy_loss: 0.9777 - Vxy_loss: 3.0930 - Sxx_loss: 4463.6478 - Syy_loss: 1118.1062 - Sxy_loss: 1231.5349 - sub_loss: 96.0251 - sub_2_loss: 99.6584 - sub_3_loss: 80.0792 - add_5_loss: 133359.5044 - add_6_loss: 6122.4090 - lr: 0.0010 - time: 0.1089
# Epoch 92/5000
# 13/13 - 0s - loss: 141174.0420 - Uxy_loss: 0.9117 - Vxy_loss: 3.3996 - Sxx_loss: 4454.8723 - Syy_loss: 1203.6142 - Sxy_loss: 1252.1949 - sub_loss: 94.6798 - sub_2_loss: 98.8979 - sub_3_loss: 86.8918 - add_5_loss: 126553.4110 - add_6_loss: 6358.7513 - lr: 0.0010 - time: 0.1155
# Epoch 93/5000
# 13/13 - 0s - loss: 138982.0445 - Uxy_loss: 0.9085 - Vxy_loss: 3.5445 - Sxx_loss: 4297.5636 - Syy_loss: 1103.8834 - Sxy_loss: 1247.8599 - sub_loss: 68.9675 - sub_2_loss: 122.3506 - sub_3_loss: 71.0233 - add_5_loss: 125937.7888 - add_6_loss: 6157.2775 - lr: 0.0010 - time: 0.1128
# Epoch 94/5000
# 13/13 - 0s - loss: 137508.2963 - Uxy_loss: 0.7941 - Vxy_loss: 3.2510 - Sxx_loss: 4294.1685 - Syy_loss: 1086.4679 - Sxy_loss: 1298.2501 - sub_loss: 68.8997 - sub_2_loss: 105.3509 - sub_3_loss: 84.3706 - add_5_loss: 125829.1915 - add_6_loss: 6454.6819 - lr: 0.0010 - time: 0.1156
# Epoch 95/5000
# 13/13 - 0s - loss: 139385.8651 - Uxy_loss: 0.9208 - Vxy_loss: 3.2934 - Sxx_loss: 4370.5534 - Syy_loss: 1287.5010 - Sxy_loss: 1232.8441 - sub_loss: 65.7051 - sub_2_loss: 147.1898 - sub_3_loss: 100.4106 - add_5_loss: 124665.5592 - add_6_loss: 6422.4201 - lr: 0.0010 - time: 0.1129
# Epoch 96/5000
# 13/13 - 0s - loss: 137304.9053 - Uxy_loss: 0.7734 - Vxy_loss: 3.7009 - Sxx_loss: 4266.3884 - Syy_loss: 1111.8419 - Sxy_loss: 1297.7129 - sub_loss: 75.7429 - sub_2_loss: 122.4342 - sub_3_loss: 91.4612 - add_5_loss: 122266.4421 - add_6_loss: 6407.8319 - lr: 0.0010 - time: 0.1101
# Epoch 97/5000
# 13/13 - 0s - loss: 135073.5097 - Uxy_loss: 0.9332 - Vxy_loss: 3.1853 - Sxx_loss: 4461.6838 - Syy_loss: 1164.9763 - Sxy_loss: 1308.5671 - sub_loss: 97.7621 - sub_2_loss: 100.3730 - sub_3_loss: 90.4631 - add_5_loss: 124160.1163 - add_6_loss: 6305.0752 - lr: 0.0010 - time: 0.1248
# Epoch 98/5000
# 13/13 - 0s - loss: 137327.3819 - Uxy_loss: 0.9253 - Vxy_loss: 3.5922 - Sxx_loss: 4317.7883 - Syy_loss: 1137.6500 - Sxy_loss: 1299.8900 - sub_loss: 99.1279 - sub_2_loss: 104.5532 - sub_3_loss: 72.9574 - add_5_loss: 126284.2755 - add_6_loss: 6108.6297 - lr: 0.0010 - time: 0.1063
# Epoch 99/5000
# 13/13 - 0s - loss: 137176.1096 - Uxy_loss: 0.8709 - Vxy_loss: 3.3209 - Sxx_loss: 4305.2057 - Syy_loss: 1260.6124 - Sxy_loss: 1270.3413 - sub_loss: 94.1971 - sub_2_loss: 97.4597 - sub_3_loss: 83.7599 - add_5_loss: 125038.0069 - add_6_loss: 5435.8812 - lr: 0.0010 - time: 0.1155
# Epoch 100/5000
# 13/13 - 0s - loss: 131623.2040 - Uxy_loss: 0.8706 - Vxy_loss: 3.5730 - Sxx_loss: 4300.0975 - Syy_loss: 1184.4099 - Sxy_loss: 1311.1685 - sub_loss: 77.5429 - sub_2_loss: 102.4230 - sub_3_loss: 87.4330 - add_5_loss: 117536.3644 - add_6_loss: 6214.7457 - lr: 0.0010 - time: 0.1091
# Epoch 101/5000
# 13/13 - 0s - loss: 137065.9405 - Uxy_loss: 0.8408 - Vxy_loss: 3.2980 - Sxx_loss: 4182.2178 - Syy_loss: 1189.1367 - Sxy_loss: 1314.1119 - sub_loss: 85.5773 - sub_2_loss: 99.8951 - sub_3_loss: 118.0409 - add_5_loss: 124224.5530 - add_6_loss: 5641.2427 - lr: 0.0010 - time: 0.1368
# Epoch 102/5000
# 13/13 - 0s - loss: 132879.4006 - Uxy_loss: 0.7253 - Vxy_loss: 3.4425 - Sxx_loss: 4173.0539 - Syy_loss: 1229.4995 - Sxy_loss: 1313.0469 - sub_loss: 67.4922 - sub_2_loss: 100.1460 - sub_3_loss: 93.5558 - add_5_loss: 119504.0425 - add_6_loss: 5790.8616 - lr: 0.0010 - time: 0.1138
# Epoch 103/5000
# 13/13 - 0s - loss: 129853.9233 - Uxy_loss: 1.0322 - Vxy_loss: 3.0622 - Sxx_loss: 4320.3002 - Syy_loss: 1238.9109 - Sxy_loss: 1297.9747 - sub_loss: 70.1937 - sub_2_loss: 100.3762 - sub_3_loss: 95.2727 - add_5_loss: 117325.6835 - add_6_loss: 5786.4279 - lr: 0.0010 - time: 0.1162
# Epoch 104/5000
# 13/13 - 0s - loss: 129871.7324 - Uxy_loss: 0.8156 - Vxy_loss: 3.7117 - Sxx_loss: 4213.3909 - Syy_loss: 1240.3266 - Sxy_loss: 1368.7273 - sub_loss: 77.9036 - sub_2_loss: 106.7390 - sub_3_loss: 82.0118 - add_5_loss: 119695.6946 - add_6_loss: 5678.1883 - lr: 0.0010 - time: 0.1107
# Epoch 105/5000
# 13/13 - 0s - loss: 128413.8326 - Uxy_loss: 0.8371 - Vxy_loss: 3.3646 - Sxx_loss: 4165.5995 - Syy_loss: 1319.6275 - Sxy_loss: 1330.8488 - sub_loss: 71.8747 - sub_2_loss: 106.6374 - sub_3_loss: 123.6426 - add_5_loss: 115621.6836 - add_6_loss: 5316.2459 - lr: 0.0010 - time: 0.1208
# Epoch 106/5000
# 13/13 - 0s - loss: 130486.3517 - Uxy_loss: 0.7603 - Vxy_loss: 3.7769 - Sxx_loss: 4261.2075 - Syy_loss: 1287.6764 - Sxy_loss: 1315.3643 - sub_loss: 90.2140 - sub_2_loss: 114.3726 - sub_3_loss: 98.0423 - add_5_loss: 117533.9352 - add_6_loss: 5790.2541 - lr: 0.0010 - time: 0.1081
# Epoch 107/5000
# 13/13 - 0s - loss: 127104.8668 - Uxy_loss: 0.8504 - Vxy_loss: 3.0213 - Sxx_loss: 4213.6800 - Syy_loss: 1204.4015 - Sxy_loss: 1356.3371 - sub_loss: 63.3619 - sub_2_loss: 115.1482 - sub_3_loss: 129.7620 - add_5_loss: 115136.7137 - add_6_loss: 5851.9455 - lr: 0.0010 - time: 0.1131
# Epoch 108/5000
# 13/13 - 0s - loss: 128989.4237 - Uxy_loss: 0.7584 - Vxy_loss: 3.3520 - Sxx_loss: 4259.6264 - Syy_loss: 1324.1201 - Sxy_loss: 1345.7472 - sub_loss: 86.3722 - sub_2_loss: 121.8238 - sub_3_loss: 128.3945 - add_5_loss: 115371.4145 - add_6_loss: 5516.6802 - lr: 0.0010 - time: 0.1115
# Epoch 109/5000
# 13/13 - 0s - loss: 124965.3572 - Uxy_loss: 1.3206 - Vxy_loss: 3.3931 - Sxx_loss: 4065.6675 - Syy_loss: 1292.0356 - Sxy_loss: 1376.0441 - sub_loss: 79.1857 - sub_2_loss: 99.2432 - sub_3_loss: 132.8868 - add_5_loss: 112390.9067 - add_6_loss: 6156.8281 - lr: 0.0010 - time: 0.1151
# Epoch 110/5000
# 13/13 - 0s - loss: 126153.5624 - Uxy_loss: 0.6924 - Vxy_loss: 3.3637 - Sxx_loss: 4112.8597 - Syy_loss: 1284.3107 - Sxy_loss: 1324.6204 - sub_loss: 129.5942 - sub_2_loss: 100.3923 - sub_3_loss: 99.2051 - add_5_loss: 116759.5479 - add_6_loss: 4832.7399 - lr: 0.0010 - time: 0.1139
# Epoch 111/5000
# 13/13 - 0s - loss: 126421.2985 - Uxy_loss: 1.4016 - Vxy_loss: 3.2846 - Sxx_loss: 4133.0146 - Syy_loss: 1264.1439 - Sxy_loss: 1320.7475 - sub_loss: 103.4221 - sub_2_loss: 83.6047 - sub_3_loss: 86.5131 - add_5_loss: 113117.6563 - add_6_loss: 5033.3317 - lr: 0.0010 - time: 0.1177
# Epoch 112/5000
# 13/13 - 0s - loss: 124231.0296 - Uxy_loss: 0.8522 - Vxy_loss: 3.1210 - Sxx_loss: 4406.0653 - Syy_loss: 1332.1133 - Sxy_loss: 1326.9224 - sub_loss: 116.0904 - sub_2_loss: 90.8885 - sub_3_loss: 127.2403 - add_5_loss: 111919.7690 - add_6_loss: 5298.0410 - lr: 0.0010 - time: 0.1109
# Epoch 113/5000
# 13/13 - 0s - loss: 120475.1038 - Uxy_loss: 1.4603 - Vxy_loss: 3.7276 - Sxx_loss: 4139.6737 - Syy_loss: 1270.8349 - Sxy_loss: 1349.0564 - sub_loss: 81.5317 - sub_2_loss: 95.8256 - sub_3_loss: 113.5340 - add_5_loss: 106360.0101 - add_6_loss: 5904.2970 - lr: 0.0010 - time: 0.1167
# Epoch 114/5000
# 13/13 - 0s - loss: 118410.4538 - Uxy_loss: 0.8710 - Vxy_loss: 3.0513 - Sxx_loss: 4057.6700 - Syy_loss: 1578.2498 - Sxy_loss: 1372.2502 - sub_loss: 87.9170 - sub_2_loss: 147.6852 - sub_3_loss: 121.7466 - add_5_loss: 106641.3711 - add_6_loss: 5055.3571 - lr: 0.0010 - time: 0.1156
# Epoch 115/5000
# 13/13 - 0s - loss: 117372.0753 - Uxy_loss: 1.2508 - Vxy_loss: 4.0836 - Sxx_loss: 4118.7885 - Syy_loss: 1303.4098 - Sxy_loss: 1353.3533 - sub_loss: 69.5056 - sub_2_loss: 130.4587 - sub_3_loss: 76.5668 - add_5_loss: 104454.1256 - add_6_loss: 4883.3754 - lr: 0.0010 - time: 0.1127
# Epoch 116/5000
# 13/13 - 0s - loss: 115507.8990 - Uxy_loss: 0.8555 - Vxy_loss: 3.0641 - Sxx_loss: 4046.9487 - Syy_loss: 1290.3534 - Sxy_loss: 1341.6357 - sub_loss: 56.0326 - sub_2_loss: 108.4364 - sub_3_loss: 100.1901 - add_5_loss: 103891.3833 - add_6_loss: 4928.8093 - lr: 0.0010 - time: 0.1147
# Epoch 117/5000
# 13/13 - 0s - loss: 114372.3208 - Uxy_loss: 1.0442 - Vxy_loss: 3.6153 - Sxx_loss: 4085.1637 - Syy_loss: 1476.0759 - Sxy_loss: 1382.1332 - sub_loss: 56.3788 - sub_2_loss: 120.5743 - sub_3_loss: 67.4864 - add_5_loss: 101342.8645 - add_6_loss: 5250.6051 - lr: 0.0010 - time: 0.1137
# Epoch 118/5000
# 13/13 - 0s - loss: 113431.5552 - Uxy_loss: 0.8308 - Vxy_loss: 3.2144 - Sxx_loss: 4104.2369 - Syy_loss: 1363.3316 - Sxy_loss: 1254.1433 - sub_loss: 55.0445 - sub_2_loss: 102.5495 - sub_3_loss: 84.6426 - add_5_loss: 101627.1238 - add_6_loss: 4148.2995 - lr: 0.0010 - time: 0.1104
# Epoch 119/5000
# 13/13 - 0s - loss: 112494.7355 - Uxy_loss: 1.0324 - Vxy_loss: 3.7367 - Sxx_loss: 3954.7284 - Syy_loss: 1296.1708 - Sxy_loss: 1309.1969 - sub_loss: 46.5459 - sub_2_loss: 109.4880 - sub_3_loss: 79.6526 - add_5_loss: 99346.4503 - add_6_loss: 4493.4895 - lr: 0.0010 - time: 0.1169
# Epoch 120/5000
# 13/13 - 0s - loss: 110894.0525 - Uxy_loss: 0.7893 - Vxy_loss: 3.2719 - Sxx_loss: 4035.7177 - Syy_loss: 1352.4386 - Sxy_loss: 1291.0281 - sub_loss: 45.3789 - sub_2_loss: 90.8455 - sub_3_loss: 87.1133 - add_5_loss: 101155.2348 - add_6_loss: 3876.2734 - lr: 0.0010 - time: 0.1117
# Epoch 121/5000
# 13/13 - 0s - loss: 108011.0251 - Uxy_loss: 0.8403 - Vxy_loss: 3.5116 - Sxx_loss: 4035.4437 - Syy_loss: 1311.6366 - Sxy_loss: 1282.6762 - sub_loss: 49.5315 - sub_2_loss: 88.3356 - sub_3_loss: 80.4334 - add_5_loss: 98079.8035 - add_6_loss: 4343.5342 - lr: 0.0010 - time: 0.1196
# Epoch 122/5000
# 13/13 - 0s - loss: 110977.0623 - Uxy_loss: 1.0385 - Vxy_loss: 3.3824 - Sxx_loss: 3936.9303 - Syy_loss: 1490.3886 - Sxy_loss: 1332.4432 - sub_loss: 59.3622 - sub_2_loss: 94.7573 - sub_3_loss: 96.8549 - add_5_loss: 99069.2975 - add_6_loss: 4785.3880 - lr: 0.0010 - time: 0.1143
# Epoch 123/5000
# 13/13 - 0s - loss: 108120.4408 - Uxy_loss: 0.7829 - Vxy_loss: 3.4622 - Sxx_loss: 3959.8256 - Syy_loss: 1412.0301 - Sxy_loss: 1273.8145 - sub_loss: 46.9595 - sub_2_loss: 102.4146 - sub_3_loss: 70.2595 - add_5_loss: 94913.9678 - add_6_loss: 4138.3442 - lr: 0.0010 - time: 0.1138
# Epoch 124/5000
# 13/13 - 0s - loss: 109433.4360 - Uxy_loss: 0.7935 - Vxy_loss: 3.6692 - Sxx_loss: 3864.4023 - Syy_loss: 1289.9929 - Sxy_loss: 1324.5001 - sub_loss: 48.9735 - sub_2_loss: 95.6739 - sub_3_loss: 75.6757 - add_5_loss: 98355.6635 - add_6_loss: 4735.2342 - lr: 0.0010 - time: 0.1140
# Epoch 125/5000
# 13/13 - 0s - loss: 107857.5843 - Uxy_loss: 0.6739 - Vxy_loss: 3.6412 - Sxx_loss: 3922.2121 - Syy_loss: 1450.0690 - Sxy_loss: 1306.3699 - sub_loss: 62.0262 - sub_2_loss: 102.9335 - sub_3_loss: 108.8821 - add_5_loss: 97111.9879 - add_6_loss: 4080.5853 - lr: 0.0010 - time: 0.1130
# Epoch 126/5000
# 13/13 - 0s - loss: 106501.7322 - Uxy_loss: 1.1403 - Vxy_loss: 3.7201 - Sxx_loss: 3928.2472 - Syy_loss: 1308.3847 - Sxy_loss: 1291.6114 - sub_loss: 59.3305 - sub_2_loss: 111.8537 - sub_3_loss: 83.7098 - add_5_loss: 92407.1862 - add_6_loss: 4611.4529 - lr: 0.0010 - time: 0.1132
# Epoch 127/5000
# 13/13 - 0s - loss: 103664.5458 - Uxy_loss: 0.7405 - Vxy_loss: 3.2658 - Sxx_loss: 3881.9157 - Syy_loss: 1407.9091 - Sxy_loss: 1314.9290 - sub_loss: 40.7426 - sub_2_loss: 90.7635 - sub_3_loss: 86.7030 - add_5_loss: 93353.7280 - add_6_loss: 3934.2277 - lr: 0.0010 - time: 0.1212
# Epoch 128/5000
# 13/13 - 0s - loss: 103857.4626 - Uxy_loss: 0.7480 - Vxy_loss: 3.4121 - Sxx_loss: 3916.8390 - Syy_loss: 1373.3527 - Sxy_loss: 1325.5794 - sub_loss: 34.9890 - sub_2_loss: 101.2138 - sub_3_loss: 96.7984 - add_5_loss: 94124.8838 - add_6_loss: 4311.9679 - lr: 0.0010 - time: 0.1168
# Epoch 129/5000
# 13/13 - 0s - loss: 102233.9030 - Uxy_loss: 0.8524 - Vxy_loss: 3.7428 - Sxx_loss: 3958.2663 - Syy_loss: 1426.8188 - Sxy_loss: 1266.2976 - sub_loss: 33.0226 - sub_2_loss: 105.3809 - sub_3_loss: 88.1157 - add_5_loss: 90281.2215 - add_6_loss: 4149.9205 - lr: 0.0010 - time: 0.1138
# Epoch 130/5000
# 13/13 - 0s - loss: 100734.9037 - Uxy_loss: 0.6647 - Vxy_loss: 3.3864 - Sxx_loss: 3847.8921 - Syy_loss: 1428.5793 - Sxy_loss: 1301.4505 - sub_loss: 33.5918 - sub_2_loss: 96.7463 - sub_3_loss: 79.1420 - add_5_loss: 89484.5003 - add_6_loss: 4045.0577 - lr: 0.0010 - time: 0.1149
# Epoch 131/5000
# 13/13 - 0s - loss: 100684.3405 - Uxy_loss: 0.9381 - Vxy_loss: 3.6158 - Sxx_loss: 3866.8814 - Syy_loss: 1366.7129 - Sxy_loss: 1356.7252 - sub_loss: 34.6206 - sub_2_loss: 108.9433 - sub_3_loss: 78.3468 - add_5_loss: 87502.4693 - add_6_loss: 4622.0551 - lr: 0.0010 - time: 0.1208
# Epoch 132/5000
# 13/13 - 0s - loss: 99669.9652 - Uxy_loss: 0.7648 - Vxy_loss: 3.4009 - Sxx_loss: 3795.1600 - Syy_loss: 1486.7648 - Sxy_loss: 1271.7802 - sub_loss: 24.9855 - sub_2_loss: 119.9555 - sub_3_loss: 78.6504 - add_5_loss: 88864.5107 - add_6_loss: 4064.5095 - lr: 0.0010 - time: 0.1153
# Epoch 133/5000
# 13/13 - 0s - loss: 99589.5260 - Uxy_loss: 0.7856 - Vxy_loss: 3.6441 - Sxx_loss: 3834.4970 - Syy_loss: 1411.0275 - Sxy_loss: 1259.9316 - sub_loss: 24.9920 - sub_2_loss: 129.8106 - sub_3_loss: 70.9874 - add_5_loss: 86893.0312 - add_6_loss: 4589.2073 - lr: 0.0010 - time: 0.1204
# Epoch 134/5000
# 13/13 - 0s - loss: 99280.7485 - Uxy_loss: 0.8581 - Vxy_loss: 3.3218 - Sxx_loss: 3821.5866 - Syy_loss: 1427.7782 - Sxy_loss: 1297.2800 - sub_loss: 32.9824 - sub_2_loss: 92.4746 - sub_3_loss: 91.6265 - add_5_loss: 89566.2561 - add_6_loss: 3799.3871 - lr: 0.0010 - time: 0.1105
# Epoch 135/5000
# 13/13 - 0s - loss: 102847.4964 - Uxy_loss: 0.9055 - Vxy_loss: 3.6119 - Sxx_loss: 4108.0803 - Syy_loss: 1455.6223 - Sxy_loss: 1321.3695 - sub_loss: 55.9431 - sub_2_loss: 120.7631 - sub_3_loss: 68.6238 - add_5_loss: 91349.2922 - add_6_loss: 4184.2766 - lr: 0.0010 - time: 0.1144
# Epoch 136/5000
# 13/13 - 0s - loss: 104505.1798 - Uxy_loss: 0.9970 - Vxy_loss: 3.5584 - Sxx_loss: 3832.6766 - Syy_loss: 1373.2864 - Sxy_loss: 1341.1170 - sub_loss: 74.3155 - sub_2_loss: 111.9143 - sub_3_loss: 78.3744 - add_5_loss: 92017.8403 - add_6_loss: 4261.8792 - lr: 0.0010 - time: 0.1158
# Epoch 137/5000
# 13/13 - 0s - loss: 97779.6109 - Uxy_loss: 1.1363 - Vxy_loss: 3.6174 - Sxx_loss: 3937.3235 - Syy_loss: 1475.2178 - Sxy_loss: 1349.1249 - sub_loss: 75.4771 - sub_2_loss: 111.5558 - sub_3_loss: 104.3513 - add_5_loss: 83918.1266 - add_6_loss: 5591.4350 - lr: 0.0010 - time: 0.1329
# Epoch 138/5000
# 13/13 - 0s - loss: 97435.7135 - Uxy_loss: 0.7406 - Vxy_loss: 3.5595 - Sxx_loss: 3687.0803 - Syy_loss: 1583.4041 - Sxy_loss: 1244.4641 - sub_loss: 55.0256 - sub_2_loss: 104.6067 - sub_3_loss: 133.2383 - add_5_loss: 85389.8062 - add_6_loss: 4099.7641 - lr: 0.0010 - time: 0.1008
# Epoch 139/5000
# 13/13 - 0s - loss: 98720.9191 - Uxy_loss: 0.9548 - Vxy_loss: 4.2889 - Sxx_loss: 3796.0786 - Syy_loss: 1261.0233 - Sxy_loss: 1273.4406 - sub_loss: 40.7658 - sub_2_loss: 100.1630 - sub_3_loss: 125.3202 - add_5_loss: 87022.7334 - add_6_loss: 4516.0820 - lr: 0.0010 - time: 0.1133
# Epoch 140/5000
# 13/13 - 0s - loss: 99399.3452 - Uxy_loss: 0.8440 - Vxy_loss: 3.5051 - Sxx_loss: 3825.0509 - Syy_loss: 1583.8377 - Sxy_loss: 1311.1572 - sub_loss: 46.6142 - sub_2_loss: 114.9706 - sub_3_loss: 107.1221 - add_5_loss: 88044.8079 - add_6_loss: 4260.1687 - lr: 0.0010 - time: 0.1174
# Epoch 141/5000
# 13/13 - 0s - loss: 94834.4874 - Uxy_loss: 0.8110 - Vxy_loss: 3.7086 - Sxx_loss: 3897.1384 - Syy_loss: 1403.4945 - Sxy_loss: 1372.8721 - sub_loss: 61.0354 - sub_2_loss: 101.7355 - sub_3_loss: 92.2305 - add_5_loss: 83841.2863 - add_6_loss: 4552.9643 - lr: 0.0010 - time: 0.1103
# Epoch 142/5000
# 13/13 - 0s - loss: 93547.9841 - Uxy_loss: 0.8732 - Vxy_loss: 3.5172 - Sxx_loss: 3689.1892 - Syy_loss: 1521.7663 - Sxy_loss: 1277.8069 - sub_loss: 37.6752 - sub_2_loss: 88.0160 - sub_3_loss: 111.1406 - add_5_loss: 82527.5526 - add_6_loss: 3915.9268 - lr: 0.0010 - time: 0.1153
# Epoch 143/5000
# 13/13 - 0s - loss: 92905.8379 - Uxy_loss: 0.8306 - Vxy_loss: 3.6639 - Sxx_loss: 3853.2945 - Syy_loss: 1389.9562 - Sxy_loss: 1301.2199 - sub_loss: 38.4257 - sub_2_loss: 115.7286 - sub_3_loss: 82.1266 - add_5_loss: 82218.7435 - add_6_loss: 3834.6045 - lr: 0.0010 - time: 0.1119
# Epoch 144/5000
# 13/13 - 0s - loss: 93216.4088 - Uxy_loss: 0.7055 - Vxy_loss: 3.5016 - Sxx_loss: 3690.8237 - Syy_loss: 1553.7541 - Sxy_loss: 1303.3539 - sub_loss: 36.4975 - sub_2_loss: 98.2055 - sub_3_loss: 122.8152 - add_5_loss: 81281.7289 - add_6_loss: 4177.5872 - lr: 0.0010 - time: 0.1124
# Epoch 145/5000
# 13/13 - 0s - loss: 92218.0410 - Uxy_loss: 0.9282 - Vxy_loss: 4.0842 - Sxx_loss: 3643.9006 - Syy_loss: 1486.8831 - Sxy_loss: 1302.5347 - sub_loss: 42.8382 - sub_2_loss: 129.4558 - sub_3_loss: 88.6116 - add_5_loss: 81514.8205 - add_6_loss: 3598.4476 - lr: 0.0010 - time: 0.1155
# Epoch 146/5000
# 13/13 - 0s - loss: 89968.8905 - Uxy_loss: 1.0131 - Vxy_loss: 3.6623 - Sxx_loss: 3779.6979 - Syy_loss: 1475.5039 - Sxy_loss: 1391.9771 - sub_loss: 42.5853 - sub_2_loss: 90.2631 - sub_3_loss: 104.4487 - add_5_loss: 80060.5268 - add_6_loss: 4092.0891 - lr: 0.0010 - time: 0.1118
# Epoch 147/5000
# 13/13 - 0s - loss: 90371.6385 - Uxy_loss: 0.9273 - Vxy_loss: 3.8038 - Sxx_loss: 3687.1057 - Syy_loss: 1546.3092 - Sxy_loss: 1333.7571 - sub_loss: 31.9776 - sub_2_loss: 92.6752 - sub_3_loss: 100.1668 - add_5_loss: 79344.6789 - add_6_loss: 3950.8081 - lr: 0.0010 - time: 0.1146
# Epoch 148/5000
# 13/13 - 0s - loss: 90079.5787 - Uxy_loss: 0.8039 - Vxy_loss: 3.7429 - Sxx_loss: 3599.6809 - Syy_loss: 1428.6638 - Sxy_loss: 1263.7594 - sub_loss: 53.8586 - sub_2_loss: 109.6587 - sub_3_loss: 79.9883 - add_5_loss: 79924.9295 - add_6_loss: 3617.2652 - lr: 0.0010 - time: 0.1151
# Epoch 149/5000
# 13/13 - 0s - loss: 88791.5030 - Uxy_loss: 0.9101 - Vxy_loss: 3.8141 - Sxx_loss: 3627.6052 - Syy_loss: 1511.0884 - Sxy_loss: 1309.6763 - sub_loss: 49.9201 - sub_2_loss: 97.3751 - sub_3_loss: 84.5816 - add_5_loss: 79252.5146 - add_6_loss: 3578.2380 - lr: 0.0010 - time: 0.1129
# Epoch 150/5000
# 13/13 - 0s - loss: 86753.5563 - Uxy_loss: 0.8582 - Vxy_loss: 3.7509 - Sxx_loss: 3699.7332 - Syy_loss: 1463.5350 - Sxy_loss: 1326.3531 - sub_loss: 44.6572 - sub_2_loss: 90.9810 - sub_3_loss: 82.5906 - add_5_loss: 74639.0542 - add_6_loss: 4042.0393 - lr: 0.0010 - time: 0.1173
# Epoch 151/5000
# 13/13 - 0s - loss: 85688.5307 - Uxy_loss: 0.7062 - Vxy_loss: 3.5364 - Sxx_loss: 3646.8458 - Syy_loss: 1571.9318 - Sxy_loss: 1263.2295 - sub_loss: 34.3425 - sub_2_loss: 94.2081 - sub_3_loss: 84.4478 - add_5_loss: 76064.0649 - add_6_loss: 3386.1511 - lr: 0.0010 - time: 0.1085
# Epoch 152/5000
# 13/13 - 0s - loss: 86888.3748 - Uxy_loss: 0.9411 - Vxy_loss: 3.7473 - Sxx_loss: 3644.4460 - Syy_loss: 1442.3006 - Sxy_loss: 1378.2309 - sub_loss: 30.8808 - sub_2_loss: 102.7060 - sub_3_loss: 64.6850 - add_5_loss: 77254.5849 - add_6_loss: 3795.0309 - lr: 0.0010 - time: 0.1103
# Epoch 153/5000
# 13/13 - 0s - loss: 89655.7319 - Uxy_loss: 0.9649 - Vxy_loss: 3.6823 - Sxx_loss: 3718.7961 - Syy_loss: 1478.5651 - Sxy_loss: 1355.2888 - sub_loss: 42.8044 - sub_2_loss: 88.8325 - sub_3_loss: 98.0215 - add_5_loss: 78607.0851 - add_6_loss: 3650.9422 - lr: 0.0010 - time: 0.1099
# Epoch 154/5000
# 13/13 - 0s - loss: 85351.1551 - Uxy_loss: 0.8244 - Vxy_loss: 3.7975 - Sxx_loss: 3589.7603 - Syy_loss: 1567.4956 - Sxy_loss: 1360.0150 - sub_loss: 56.3120 - sub_2_loss: 114.4362 - sub_3_loss: 84.4327 - add_5_loss: 73650.6566 - add_6_loss: 3722.1916 - lr: 0.0010 - time: 0.1206
# Epoch 155/5000
# 13/13 - 0s - loss: 87981.0824 - Uxy_loss: 0.9225 - Vxy_loss: 3.6173 - Sxx_loss: 3945.8369 - Syy_loss: 1535.7297 - Sxy_loss: 1302.6694 - sub_loss: 54.6286 - sub_2_loss: 86.2891 - sub_3_loss: 102.2216 - add_5_loss: 75844.1525 - add_6_loss: 3529.0525 - lr: 0.0010 - time: 0.1094
# Epoch 156/5000
# 13/13 - 0s - loss: 87152.8116 - Uxy_loss: 0.8868 - Vxy_loss: 3.7677 - Sxx_loss: 3555.2095 - Syy_loss: 1455.9994 - Sxy_loss: 1351.8835 - sub_loss: 56.1705 - sub_2_loss: 104.2620 - sub_3_loss: 83.9718 - add_5_loss: 76102.7908 - add_6_loss: 3884.7774 - lr: 0.0010 - time: 0.1096
# Epoch 157/5000
# 13/13 - 0s - loss: 84759.4728 - Uxy_loss: 0.8892 - Vxy_loss: 3.6100 - Sxx_loss: 3573.4558 - Syy_loss: 1574.5995 - Sxy_loss: 1316.2100 - sub_loss: 56.2958 - sub_2_loss: 101.6273 - sub_3_loss: 92.0407 - add_5_loss: 74297.9677 - add_6_loss: 3837.9190 - lr: 0.0010 - time: 0.1105
# Epoch 158/5000
# 13/13 - 0s - loss: 82252.2372 - Uxy_loss: 0.8502 - Vxy_loss: 3.7444 - Sxx_loss: 3583.4617 - Syy_loss: 1605.3898 - Sxy_loss: 1294.6218 - sub_loss: 48.8812 - sub_2_loss: 130.6261 - sub_3_loss: 89.1239 - add_5_loss: 69874.1923 - add_6_loss: 4496.9005 - lr: 0.0010 - time: 0.1131
# Epoch 159/5000
# 13/13 - 0s - loss: 87815.4996 - Uxy_loss: 0.9401 - Vxy_loss: 3.8016 - Sxx_loss: 3532.6689 - Syy_loss: 1469.0185 - Sxy_loss: 1300.4857 - sub_loss: 98.2386 - sub_2_loss: 121.0444 - sub_3_loss: 108.7300 - add_5_loss: 77830.6419 - add_6_loss: 3540.6473 - lr: 0.0010 - time: 0.1159
# Epoch 160/5000
# 13/13 - 0s - loss: 79471.6483 - Uxy_loss: 0.9212 - Vxy_loss: 3.6253 - Sxx_loss: 3583.4302 - Syy_loss: 1557.0609 - Sxy_loss: 1320.0565 - sub_loss: 48.5435 - sub_2_loss: 102.0788 - sub_3_loss: 103.4907 - add_5_loss: 69330.4313 - add_6_loss: 3768.1543 - lr: 0.0010 - time: 0.1112
# Epoch 161/5000
# ...
# Epoch 4691/5000
# 13/13 - 0s - loss: 18.9460 - Uxy_loss: 0.9930 - Vxy_loss: 0.1785 - Sxx_loss: 4.5197 - Syy_loss: 0.5292 - Sxy_loss: 0.5702 - sub_loss: 0.6621 - sub_2_loss: 0.4194 - sub_3_loss: 0.5249 - add_5_loss: 8.5199 - add_6_loss: 2.4079 - lr: 0.0010 - time: 0.1172
# Epoch 4692/5000
# 13/13 - 0s - loss: 19.9367 - Uxy_loss: 0.9847 - Vxy_loss: 0.1779 - Sxx_loss: 4.3801 - Syy_loss: 0.4359 - Sxy_loss: 0.5530 - sub_loss: 0.7995 - sub_2_loss: 0.3476 - sub_3_loss: 0.5320 - add_5_loss: 9.2597 - add_6_loss: 2.3325 - lr: 0.0010 - time: 0.1156
# Epoch 4693/5000
# 13/13 - 0s - loss: 18.0834 - Uxy_loss: 0.9874 - Vxy_loss: 0.1799 - Sxx_loss: 4.5329 - Syy_loss: 0.5297 - Sxy_loss: 0.5322 - sub_loss: 0.7760 - sub_2_loss: 0.3118 - sub_3_loss: 0.5045 - add_5_loss: 6.9958 - add_6_loss: 2.7463 - lr: 0.0010 - time: 0.1194
# Epoch 4694/5000
# 13/13 - 0s - loss: 20.7514 - Uxy_loss: 0.9903 - Vxy_loss: 0.1800 - Sxx_loss: 4.2262 - Syy_loss: 0.4473 - Sxy_loss: 0.5570 - sub_loss: 1.1348 - sub_2_loss: 0.4532 - sub_3_loss: 0.5541 - add_5_loss: 9.9734 - add_6_loss: 2.0018 - lr: 0.0010 - time: 0.1149
# Epoch 4695/5000
# 13/13 - 0s - loss: 23.8282 - Uxy_loss: 0.9825 - Vxy_loss: 0.1825 - Sxx_loss: 4.4515 - Syy_loss: 0.4818 - Sxy_loss: 0.5599 - sub_loss: 0.9577 - sub_2_loss: 0.4253 - sub_3_loss: 0.5812 - add_5_loss: 11.9855 - add_6_loss: 2.9601 - lr: 0.0010 - time: 0.1177
# Epoch 4696/5000
# 13/13 - 0s - loss: 19.8908 - Uxy_loss: 0.9903 - Vxy_loss: 0.1845 - Sxx_loss: 4.2867 - Syy_loss: 0.5317 - Sxy_loss: 0.5466 - sub_loss: 1.0377 - sub_2_loss: 0.6546 - sub_3_loss: 0.5496 - add_5_loss: 8.0088 - add_6_loss: 3.2737 - lr: 0.0010 - time: 0.1182
# Epoch 4697/5000
# 13/13 - 0s - loss: 19.7839 - Uxy_loss: 0.9957 - Vxy_loss: 0.1783 - Sxx_loss: 4.3947 - Syy_loss: 0.4976 - Sxy_loss: 0.5220 - sub_loss: 1.0301 - sub_2_loss: 0.6119 - sub_3_loss: 0.5703 - add_5_loss: 8.6406 - add_6_loss: 2.5887 - lr: 0.0010 - time: 0.1173
# Epoch 4698/5000
# 13/13 - 0s - loss: 17.4125 - Uxy_loss: 0.9694 - Vxy_loss: 0.1846 - Sxx_loss: 4.1422 - Syy_loss: 0.4744 - Sxy_loss: 0.5573 - sub_loss: 0.9547 - sub_2_loss: 0.5863 - sub_3_loss: 0.5597 - add_5_loss: 7.0428 - add_6_loss: 1.6791 - lr: 0.0010 - time: 0.1183
# Epoch 4699/5000
# 13/13 - 0s - loss: 17.5152 - Uxy_loss: 0.9923 - Vxy_loss: 0.1791 - Sxx_loss: 4.1822 - Syy_loss: 0.4590 - Sxy_loss: 0.5203 - sub_loss: 0.8904 - sub_2_loss: 0.3599 - sub_3_loss: 0.5426 - add_5_loss: 7.3614 - add_6_loss: 1.8758 - lr: 0.0010 - time: 0.1152
# Epoch 4700/5000
# 13/13 - 0s - loss: 16.7008 - Uxy_loss: 0.9823 - Vxy_loss: 0.1837 - Sxx_loss: 4.2006 - Syy_loss: 0.4826 - Sxy_loss: 0.5375 - sub_loss: 0.6800 - sub_2_loss: 0.4741 - sub_3_loss: 0.5131 - add_5_loss: 6.6797 - add_6_loss: 1.9289 - lr: 0.0010 - time: 0.1164
# Epoch 4701/5000
# 13/13 - 0s - loss: 21.8159 - Uxy_loss: 0.9970 - Vxy_loss: 0.1818 - Sxx_loss: 4.2453 - Syy_loss: 0.4649 - Sxy_loss: 0.5406 - sub_loss: 0.8658 - sub_2_loss: 0.4395 - sub_3_loss: 0.5303 - add_5_loss: 11.3588 - add_6_loss: 2.6428 - lr: 0.0010 - time: 0.1168
# Epoch 4702/5000
# 13/13 - 0s - loss: 30.3064 - Uxy_loss: 0.9883 - Vxy_loss: 0.1865 - Sxx_loss: 4.3453 - Syy_loss: 0.5253 - Sxy_loss: 0.5483 - sub_loss: 1.8630 - sub_2_loss: 0.9991 - sub_3_loss: 0.6043 - add_5_loss: 17.0212 - add_6_loss: 2.9085 - lr: 0.0010 - time: 0.1153
# Epoch 4703/5000
# 13/13 - 0s - loss: 30.4029 - Uxy_loss: 0.9836 - Vxy_loss: 0.1826 - Sxx_loss: 4.0395 - Syy_loss: 0.6601 - Sxy_loss: 0.5421 - sub_loss: 1.2912 - sub_2_loss: 0.8078 - sub_3_loss: 0.5990 - add_5_loss: 16.2432 - add_6_loss: 4.6658 - lr: 0.0010 - time: 0.1194
# Epoch 4704/5000
# 13/13 - 0s - loss: 27.9844 - Uxy_loss: 0.9741 - Vxy_loss: 0.1883 - Sxx_loss: 4.4252 - Syy_loss: 0.5338 - Sxy_loss: 0.5298 - sub_loss: 1.3940 - sub_2_loss: 0.4801 - sub_3_loss: 0.5807 - add_5_loss: 13.3975 - add_6_loss: 5.4607 - lr: 0.0010 - time: 0.1174
# Epoch 4705/5000
# 13/13 - 0s - loss: 31.6944 - Uxy_loss: 0.9886 - Vxy_loss: 0.1937 - Sxx_loss: 4.2199 - Syy_loss: 0.5863 - Sxy_loss: 0.5118 - sub_loss: 1.0831 - sub_2_loss: 0.6628 - sub_3_loss: 0.6046 - add_5_loss: 17.1628 - add_6_loss: 5.6476 - lr: 0.0010 - time: 0.1172
# Epoch 4706/5000
# 13/13 - 0s - loss: 32.4498 - Uxy_loss: 0.9644 - Vxy_loss: 0.1815 - Sxx_loss: 4.4585 - Syy_loss: 0.6640 - Sxy_loss: 0.5463 - sub_loss: 1.0619 - sub_2_loss: 0.6312 - sub_3_loss: 0.6043 - add_5_loss: 18.0242 - add_6_loss: 5.5952 - lr: 0.0010 - time: 0.1151
# Epoch 4707/5000
# 13/13 - 0s - loss: 59.3419 - Uxy_loss: 0.9632 - Vxy_loss: 0.1873 - Sxx_loss: 4.3852 - Syy_loss: 1.1826 - Sxy_loss: 0.5760 - sub_loss: 2.7168 - sub_2_loss: 3.1123 - sub_3_loss: 0.6209 - add_5_loss: 31.4976 - add_6_loss: 13.4497 - lr: 0.0010 - time: 0.1165
# Epoch 4708/5000
# 13/13 - 0s - loss: 92.5463 - Uxy_loss: 0.9943 - Vxy_loss: 0.1718 - Sxx_loss: 4.9689 - Syy_loss: 0.8020 - Sxy_loss: 0.6151 - sub_loss: 6.1227 - sub_2_loss: 2.5497 - sub_3_loss: 0.8779 - add_5_loss: 57.9558 - add_6_loss: 15.9176 - lr: 0.0010 - time: 0.1190
# Epoch 4709/5000
# 13/13 - 0s - loss: 82.7783 - Uxy_loss: 0.9855 - Vxy_loss: 0.1909 - Sxx_loss: 4.5117 - Syy_loss: 0.9588 - Sxy_loss: 0.5875 - sub_loss: 4.2754 - sub_2_loss: 2.3733 - sub_3_loss: 0.9632 - add_5_loss: 46.7811 - add_6_loss: 19.6183 - lr: 0.0010 - time: 0.1159
# Epoch 4710/5000
# 13/13 - 0s - loss: 115.8608 - Uxy_loss: 0.9924 - Vxy_loss: 0.1705 - Sxx_loss: 4.8366 - Syy_loss: 1.4225 - Sxy_loss: 0.8790 - sub_loss: 7.7751 - sub_2_loss: 3.9106 - sub_3_loss: 1.2871 - add_5_loss: 62.9980 - add_6_loss: 31.2907 - lr: 0.0010 - time: 0.1165
# Epoch 4711/5000
# 13/13 - 0s - loss: 140.4469 - Uxy_loss: 0.9949 - Vxy_loss: 0.1703 - Sxx_loss: 5.2311 - Syy_loss: 2.0558 - Sxy_loss: 0.8763 - sub_loss: 7.6456 - sub_2_loss: 4.6784 - sub_3_loss: 1.2376 - add_5_loss: 86.8411 - add_6_loss: 28.1543 - lr: 0.0010 - time: 0.1160
# Epoch 4712/5000
# 13/13 - 0s - loss: 170.0468 - Uxy_loss: 0.9694 - Vxy_loss: 0.1755 - Sxx_loss: 5.9571 - Syy_loss: 2.0329 - Sxy_loss: 0.8456 - sub_loss: 7.7304 - sub_2_loss: 6.0681 - sub_3_loss: 1.3620 - add_5_loss: 112.3311 - add_6_loss: 33.1868 - lr: 0.0010 - time: 0.1159
# Epoch 4713/5000
# 13/13 - 0s - loss: 168.3735 - Uxy_loss: 0.9634 - Vxy_loss: 0.1741 - Sxx_loss: 6.3378 - Syy_loss: 1.6116 - Sxy_loss: 0.8834 - sub_loss: 9.3677 - sub_2_loss: 2.8098 - sub_3_loss: 1.6241 - add_5_loss: 110.1679 - add_6_loss: 32.4916 - lr: 0.0010 - time: 0.1183
# Epoch 4714/5000
# 13/13 - 0s - loss: 141.8175 - Uxy_loss: 0.9821 - Vxy_loss: 0.1715 - Sxx_loss: 5.3187 - Syy_loss: 1.6221 - Sxy_loss: 0.7020 - sub_loss: 7.6903 - sub_2_loss: 3.8713 - sub_3_loss: 1.4444 - add_5_loss: 88.0038 - add_6_loss: 31.3705 - lr: 0.0010 - time: 0.1159
# Epoch 4715/5000
# 13/13 - 0s - loss: 120.6378 - Uxy_loss: 0.9584 - Vxy_loss: 0.1741 - Sxx_loss: 6.0570 - Syy_loss: 1.3634 - Sxy_loss: 0.6483 - sub_loss: 6.2729 - sub_2_loss: 3.5861 - sub_3_loss: 1.2390 - add_5_loss: 84.1597 - add_6_loss: 15.5500 - lr: 0.0010 - time: 0.1164
# Epoch 4716/5000
# 13/13 - 0s - loss: 123.6033 - Uxy_loss: 0.9819 - Vxy_loss: 0.1918 - Sxx_loss: 6.1379 - Syy_loss: 1.2097 - Sxy_loss: 0.7390 - sub_loss: 5.6248 - sub_2_loss: 3.9932 - sub_3_loss: 1.0881 - add_5_loss: 85.0227 - add_6_loss: 17.0748 - lr: 0.0010 - time: 0.1156
# Epoch 4717/5000
# 13/13 - 0s - loss: 121.4614 - Uxy_loss: 1.0047 - Vxy_loss: 0.1847 - Sxx_loss: 5.0068 - Syy_loss: 0.9193 - Sxy_loss: 0.8501 - sub_loss: 5.0213 - sub_2_loss: 3.5793 - sub_3_loss: 0.8233 - add_5_loss: 88.3811 - add_6_loss: 14.9818 - lr: 0.0010 - time: 0.1153
# Epoch 4718/5000
# 13/13 - 0s - loss: 124.7648 - Uxy_loss: 0.9764 - Vxy_loss: 0.1799 - Sxx_loss: 5.3193 - Syy_loss: 0.6804 - Sxy_loss: 0.5907 - sub_loss: 5.3830 - sub_2_loss: 2.3428 - sub_3_loss: 1.1405 - add_5_loss: 97.2700 - add_6_loss: 9.2644 - lr: 0.0010 - time: 0.1176
# Epoch 4719/5000
# 13/13 - 0s - loss: 119.0580 - Uxy_loss: 0.9748 - Vxy_loss: 0.1805 - Sxx_loss: 6.0033 - Syy_loss: 0.6515 - Sxy_loss: 0.6970 - sub_loss: 6.0135 - sub_2_loss: 2.9398 - sub_3_loss: 0.9673 - add_5_loss: 90.0232 - add_6_loss: 8.0046 - lr: 0.0010 - time: 0.1143
# Epoch 4720/5000
# 13/13 - 0s - loss: 129.8083 - Uxy_loss: 0.9746 - Vxy_loss: 0.1764 - Sxx_loss: 5.4424 - Syy_loss: 0.8184 - Sxy_loss: 0.8117 - sub_loss: 6.4026 - sub_2_loss: 1.9280 - sub_3_loss: 0.8180 - add_5_loss: 102.5497 - add_6_loss: 9.6499 - lr: 0.0010 - time: 0.1188
# Epoch 4721/5000
# 13/13 - 0s - loss: 121.2845 - Uxy_loss: 0.9883 - Vxy_loss: 0.1774 - Sxx_loss: 5.5848 - Syy_loss: 0.9159 - Sxy_loss: 0.6876 - sub_loss: 3.7623 - sub_2_loss: 1.6513 - sub_3_loss: 0.8035 - add_5_loss: 93.8876 - add_6_loss: 10.8578 - lr: 0.0010 - time: 0.1149
# Epoch 4722/5000
# 13/13 - 0s - loss: 111.7548 - Uxy_loss: 0.9691 - Vxy_loss: 0.1767 - Sxx_loss: 5.7379 - Syy_loss: 0.8375 - Sxy_loss: 0.7702 - sub_loss: 3.6083 - sub_2_loss: 1.5336 - sub_3_loss: 1.0114 - add_5_loss: 85.9899 - add_6_loss: 8.9315 - lr: 0.0010 - time: 0.1119
# Epoch 4723/5000
# 13/13 - 0s - loss: 111.8314 - Uxy_loss: 0.9736 - Vxy_loss: 0.1799 - Sxx_loss: 5.9881 - Syy_loss: 0.6132 - Sxy_loss: 0.7410 - sub_loss: 5.3147 - sub_2_loss: 2.5540 - sub_3_loss: 1.1873 - add_5_loss: 86.0257 - add_6_loss: 7.3489 - lr: 0.0010 - time: 0.1167
# Epoch 4724/5000
# 13/13 - 0s - loss: 81.4847 - Uxy_loss: 0.9649 - Vxy_loss: 0.1834 - Sxx_loss: 5.1131 - Syy_loss: 0.6971 - Sxy_loss: 0.6453 - sub_loss: 5.1065 - sub_2_loss: 1.3212 - sub_3_loss: 1.0824 - add_5_loss: 56.6645 - add_6_loss: 9.8685 - lr: 0.0010 - time: 0.1168
# Epoch 4725/5000
# 13/13 - 0s - loss: 131.9158 - Uxy_loss: 0.9714 - Vxy_loss: 0.1809 - Sxx_loss: 6.4050 - Syy_loss: 1.1297 - Sxy_loss: 0.5898 - sub_loss: 6.7883 - sub_2_loss: 2.3347 - sub_3_loss: 1.0017 - add_5_loss: 91.7401 - add_6_loss: 18.9644 - lr: 0.0010 - time: 0.1223
# Epoch 4726/5000
# 13/13 - 0s - loss: 146.8565 - Uxy_loss: 0.9788 - Vxy_loss: 0.1837 - Sxx_loss: 6.1812 - Syy_loss: 0.9042 - Sxy_loss: 0.5789 - sub_loss: 7.8617 - sub_2_loss: 3.5563 - sub_3_loss: 1.2439 - add_5_loss: 109.0427 - add_6_loss: 17.6485 - lr: 0.0010 - time: 0.1122
# Epoch 4727/5000
# 13/13 - 0s - loss: 147.9613 - Uxy_loss: 0.9846 - Vxy_loss: 0.1927 - Sxx_loss: 6.1284 - Syy_loss: 0.8568 - Sxy_loss: 0.7718 - sub_loss: 8.1260 - sub_2_loss: 3.7482 - sub_3_loss: 1.1122 - add_5_loss: 114.8406 - add_6_loss: 12.5761 - lr: 0.0010 - time: 0.1154
# Epoch 4728/5000
# 13/13 - 0s - loss: 86.5352 - Uxy_loss: 0.9546 - Vxy_loss: 0.1780 - Sxx_loss: 5.5390 - Syy_loss: 0.8807 - Sxy_loss: 0.7205 - sub_loss: 4.9599 - sub_2_loss: 3.2224 - sub_3_loss: 0.8906 - add_5_loss: 57.9157 - add_6_loss: 10.7138 - lr: 0.0010 - time: 0.1137
# Epoch 4729/5000
# 13/13 - 0s - loss: 95.9546 - Uxy_loss: 0.9881 - Vxy_loss: 0.1782 - Sxx_loss: 4.9777 - Syy_loss: 0.6589 - Sxy_loss: 0.6835 - sub_loss: 3.8709 - sub_2_loss: 1.4478 - sub_3_loss: 1.0192 - add_5_loss: 68.6364 - add_6_loss: 14.0334 - lr: 0.0010 - time: 0.1176
# Epoch 4730/5000
# 13/13 - 0s - loss: 65.4361 - Uxy_loss: 0.9808 - Vxy_loss: 0.1794 - Sxx_loss: 5.0006 - Syy_loss: 0.9419 - Sxy_loss: 0.8081 - sub_loss: 3.0220 - sub_2_loss: 2.7435 - sub_3_loss: 1.0994 - add_5_loss: 37.8075 - add_6_loss: 12.1995 - lr: 0.0010 - time: 0.1189
# Epoch 4731/5000
# 13/13 - 0s - loss: 69.9150 - Uxy_loss: 0.9833 - Vxy_loss: 0.1800 - Sxx_loss: 4.7830 - Syy_loss: 1.7357 - Sxy_loss: 0.7322 - sub_loss: 3.0716 - sub_2_loss: 3.1106 - sub_3_loss: 0.8135 - add_5_loss: 38.0890 - add_6_loss: 16.2922 - lr: 0.0010 - time: 0.1145
# Epoch 4732/5000
# 13/13 - 0s - loss: 68.2380 - Uxy_loss: 0.9796 - Vxy_loss: 0.1854 - Sxx_loss: 4.9876 - Syy_loss: 0.7819 - Sxy_loss: 0.6832 - sub_loss: 2.3946 - sub_2_loss: 1.0826 - sub_3_loss: 0.6940 - add_5_loss: 43.5945 - add_6_loss: 12.5937 - lr: 0.0010 - time: 0.1180
# Epoch 4733/5000
# 13/13 - 0s - loss: 77.6830 - Uxy_loss: 1.0071 - Vxy_loss: 0.1749 - Sxx_loss: 4.8186 - Syy_loss: 1.0589 - Sxy_loss: 0.5381 - sub_loss: 2.8207 - sub_2_loss: 1.4464 - sub_3_loss: 0.6430 - add_5_loss: 50.9824 - add_6_loss: 15.5253 - lr: 0.0010 - time: 0.1169
# Epoch 4734/5000
# 13/13 - 0s - loss: 77.8690 - Uxy_loss: 0.9638 - Vxy_loss: 0.1723 - Sxx_loss: 5.6421 - Syy_loss: 0.7613 - Sxy_loss: 0.5842 - sub_loss: 2.9154 - sub_2_loss: 3.0610 - sub_3_loss: 0.8264 - add_5_loss: 51.7544 - add_6_loss: 12.0788 - lr: 0.0010 - time: 0.1156
# Epoch 4735/5000
# 13/13 - 0s - loss: 83.2826 - Uxy_loss: 1.0005 - Vxy_loss: 0.1802 - Sxx_loss: 4.6173 - Syy_loss: 1.3176 - Sxy_loss: 0.7056 - sub_loss: 4.6775 - sub_2_loss: 3.3008 - sub_3_loss: 0.8529 - add_5_loss: 46.3170 - add_6_loss: 20.5119 - lr: 0.0010 - time: 0.1240
# Epoch 4736/5000
# 13/13 - 0s - loss: 76.7286 - Uxy_loss: 0.9674 - Vxy_loss: 0.1752 - Sxx_loss: 4.6137 - Syy_loss: 1.2100 - Sxy_loss: 0.6368 - sub_loss: 3.6250 - sub_2_loss: 1.4075 - sub_3_loss: 0.8271 - add_5_loss: 42.4251 - add_6_loss: 20.8170 - lr: 0.0010 - time: 0.1114
# Epoch 4737/5000
# 13/13 - 0s - loss: 70.7824 - Uxy_loss: 0.9843 - Vxy_loss: 0.1835 - Sxx_loss: 4.8586 - Syy_loss: 0.7331 - Sxy_loss: 0.6921 - sub_loss: 3.2504 - sub_2_loss: 1.7448 - sub_3_loss: 0.7148 - add_5_loss: 44.2298 - add_6_loss: 12.8571 - lr: 0.0010 - time: 0.1176
# Epoch 4738/5000
# 13/13 - 0s - loss: 120.8242 - Uxy_loss: 0.9542 - Vxy_loss: 0.1800 - Sxx_loss: 6.0225 - Syy_loss: 0.7992 - Sxy_loss: 0.6991 - sub_loss: 4.2976 - sub_2_loss: 1.2090 - sub_3_loss: 0.7137 - add_5_loss: 90.8960 - add_6_loss: 14.7047 - lr: 0.0010 - time: 0.1140
# Epoch 4739/5000
# 13/13 - 0s - loss: 228.1113 - Uxy_loss: 0.9548 - Vxy_loss: 0.1826 - Sxx_loss: 7.2827 - Syy_loss: 1.0409 - Sxy_loss: 0.7104 - sub_loss: 9.8643 - sub_2_loss: 2.0722 - sub_3_loss: 0.9757 - add_5_loss: 188.7053 - add_6_loss: 20.7091 - lr: 0.0010 - time: 0.1151
# Epoch 4740/5000
# 13/13 - 0s - loss: 190.1811 - Uxy_loss: 0.9786 - Vxy_loss: 0.1828 - Sxx_loss: 7.4936 - Syy_loss: 1.0903 - Sxy_loss: 0.7732 - sub_loss: 9.4973 - sub_2_loss: 2.3219 - sub_3_loss: 0.9467 - add_5_loss: 151.9288 - add_6_loss: 22.8960 - lr: 0.0010 - time: 0.1217
# Epoch 4741/5000
# 13/13 - 0s - loss: 247.4495 - Uxy_loss: 0.9877 - Vxy_loss: 0.1828 - Sxx_loss: 7.6732 - Syy_loss: 1.0629 - Sxy_loss: 1.0523 - sub_loss: 8.5444 - sub_2_loss: 3.1333 - sub_3_loss: 1.2098 - add_5_loss: 194.9484 - add_6_loss: 27.3277 - lr: 0.0010 - time: 0.1145
# Epoch 4742/5000
# 13/13 - 0s - loss: 217.4748 - Uxy_loss: 0.9507 - Vxy_loss: 0.1691 - Sxx_loss: 7.6883 - Syy_loss: 1.1029 - Sxy_loss: 0.7251 - sub_loss: 7.9679 - sub_2_loss: 3.0211 - sub_3_loss: 1.2483 - add_5_loss: 167.0369 - add_6_loss: 22.5883 - lr: 0.0010 - time: 0.1141
# Epoch 4743/5000
# 13/13 - 0s - loss: 242.7501 - Uxy_loss: 0.9677 - Vxy_loss: 0.1786 - Sxx_loss: 7.9014 - Syy_loss: 1.2994 - Sxy_loss: 0.7197 - sub_loss: 10.6983 - sub_2_loss: 4.0681 - sub_3_loss: 1.3964 - add_5_loss: 186.5501 - add_6_loss: 25.3251 - lr: 0.0010 - time: 0.1189
# Epoch 4744/5000
# 13/13 - 0s - loss: 319.2397 - Uxy_loss: 0.9854 - Vxy_loss: 0.1784 - Sxx_loss: 9.1543 - Syy_loss: 1.8576 - Sxy_loss: 0.8517 - sub_loss: 18.8722 - sub_2_loss: 7.7222 - sub_3_loss: 1.5863 - add_5_loss: 237.8889 - add_6_loss: 40.8633 - lr: 0.0010 - time: 0.1131
# Epoch 4745/5000
# 13/13 - 0s - loss: 334.2470 - Uxy_loss: 0.9801 - Vxy_loss: 0.1752 - Sxx_loss: 6.3853 - Syy_loss: 2.1375 - Sxy_loss: 1.0033 - sub_loss: 15.1676 - sub_2_loss: 9.3524 - sub_3_loss: 2.2380 - add_5_loss: 257.3192 - add_6_loss: 35.9667 - lr: 0.0010 - time: 0.1207
# Epoch 4746/5000
#
# Epoch 04746: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 13/13 - 0s - loss: 365.2809 - Uxy_loss: 0.9673 - Vxy_loss: 0.1835 - Sxx_loss: 9.1949 - Syy_loss: 1.2293 - Sxy_loss: 1.0361 - sub_loss: 12.9667 - sub_2_loss: 2.8538 - sub_3_loss: 1.4559 - add_5_loss: 303.6619 - add_6_loss: 31.2694 - lr: 0.0010 - time: 0.1139
# Epoch 04746: early stopping
# Input and output dimensions need re-adjustment for post-processing.
# Input and output dimensions need re-adjustment for post-processing.
# /tmp/ipykernel_7868/3618268720.py:61: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   im = AX.pcolor(X, Y, C, cmap="jet")
