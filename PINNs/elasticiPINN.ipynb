# %% [markdown]
# # Uniaxial Tension - Elasticity, Physics Informed Neural Network

# %% [markdown]
# Thomas Allard and Samantha Walker

# %%
#Imports
import os, sys, time
import numpy as np 
from sciann.utils.math import diff
from sciann import SciModel, Functional, Parameter
from sciann import Data, Tie
from sciann import Variable, Field
import matplotlib.pyplot as plt
import scipy.io
import netCDF4
import xarray as xr

import os
pi = np.pi

# %%
# Specify parameters and things
mode = 'train'   # 'test' to load PINN weights from previously trained model
                # 'train' to train a new model

current_file_name = 'elasticity_Yang3000_norm.ipynb'
    
#trained_file = 'trained-navier-stokes.hdf5'
data_file = '../abaqus/final_elastic/elastic_cdf.nc'

# file with nodal coordinates
node_file = '../abaqus/final_elastic/nodes.txt'

#layers = [40]*4
layers = [10, 40, 80, 100]
actf = 'tanh'
numx = 46
numy = 60
batchsize = 50
#batchsize = 16
epochs = 100
learningrate = 0.001
independent_networks = True
verbose = 2
shuffle = True
stopafter = 500
savefreq = 100000
dtype = 'float64'
gpu = False
outputpath = 'output_norm'
outputprefix = 'res'
numxplot = 46
numyplot = 60
plot = True


Emod = 210.0
nu = 0.3

E_range = [50, 300]
nu_range = [0.1, 0.4]
x_range = [0.0, 3000.0]
y_range = [-1500.0,1500.0]
disp_range = [-1.0, 1.0]
s_range = [0.0, 200.0]

# %%
# Functions
def dispx(input_d): # xx
    #x, y = xx[0], xx[1]
    disp_x = np.asarray(input_d.sel(field='ux'))
    disp_x = np.expand_dims(disp_x, axis=0).T
    return disp_x #np.cos(2*pi*x) * np.sin(pi*y)

def dispy(input_d): # xx
    #x, y = xx[0], xx[1]
    #Q = qload
    disp_y= np.asarray(input_d.sel(field='uy'))
    disp_y = np.expand_dims(disp_y, axis=0).T
    return disp_y #np.sin(pi*x) * Q * y**4/4

def stressxx(input_d): # xx
    stress_xx = np.asarray(input_d.sel(field='S11'))
    stress_xx = np.expand_dims(stress_xx, axis=0).T
    return stress_xx
    #set.sel(field='S11').to_array() #(lmbd+2*mu)*strainxx(xx) + lmbd*strainyy(xx)

def stressyy(input_d): # xx
    stress_yy = np.asarray(input_d.sel(field='S22'))
    stress_yy = np.expand_dims(stress_yy, axis=0).T
    return stress_yy
    #return set.sel(field='S22').to_array() #(lmbd+2*mu)*strainyy(xx) + lmbd*strainxx(xx)

def stressxy(input_d): # xx
    stress_xy = np.asarray(input_d.sel(field='S12'))
    stress_xy = np.expand_dims(stress_xy, axis=0).T
    return stress_xy
    #return set.sel(field='S21').to_array() #2.0*mu*strainxy(xx)

def cust_pcolor(AX, X, Y, C, title):
    im = AX.pcolor(X, Y, C, cmap="jet")
    AX.axis("equal")
    AX.axis("off")
    AX.set_title(title, fontsize=14)
    plt.colorbar(im, ax=AX)

def cust_semilogx(AX, X, Y, xlabel, ylabel):
    if X is None:
        im = AX.semilogy(Y)
    else:
        im = AX.semilogy(X, Y)
    if xlabel is not None: AX.set_xlabel(xlabel)
    if ylabel is not None: AX.set_ylabel(ylabel)

# Create function to read text files in as np array
def file2array(file):
    # load in each line of data as array
    with open(file, 'r') as f:
        line_string = f.read().splitlines()
    
    # loop through the lines from the file, split, and append to list
    list = []
    timestamp = 0 # default 
    for i, line in enumerate(line_string):
        list.append(line.split())

    # convert list to an array of type float64
    array = np.asarray(list, dtype=np.float64)

    return(array)

def rearrange(numx, numy, field):
    stuff = np.zeros([numx,numy])
    for k,f in enumerate(field):
        i = int(k % numx)
        j = int(np.floor(k/numx))
        stuff[i,j] = f
        
    stuff = stuff.T
    return(stuff)

def normalize(value, min, max,a=-1,b=1): # min max normalization from -1 to 1
    norm = (b-a)*((value-min)/(max-min))+a
    return(norm)

def denormalize(norm, min, max, a=-1, b=1):
    value = (max-min)*((norm-a)/(b-a))+min
    return(value)

def eval_mu_sig(X):
    return(X.mean(), X.std())

def std_normalize(X, mu, sig):
    return((X-mu)/sig)

def std_denormalize(X, mu, sig):
    return(X*sig + mu)

# %%
# load in data_file as xarray DataSet
set_in = xr.open_dataset(data_file)

# %%
# Load in displacements and create an ndarray
disp_x=set_in.sel(field='ux').to_array()
disp_y=set_in.sel(field='uy').to_array()
disps=np.dstack([disp_x,disp_y])

# %%
# Extract time and put in an array
times = [] # will be shape (81,)
for DataArray in set_in.values():
    times.append(DataArray.attrs['time'])
print(np.shape(times))
# Out:
# (81,)

# %%
# read in node file and save as grid
nodal_coordinates = file2array(node_file)
grid = nodal_coordinates[:,1:3]
#grid = np.array([grid[:,0],grid[:,1]+1500.])
grid = np.array([grid[:,0],grid[:,1]])
grid = np.expand_dims(grid, axis=0)
grid = np.moveaxis(grid, 0, -1)
print(np.shape(grid))
#print(grid)
# Out:
# (2, 2760, 1)

# %%
# Check that data loaded in correctly by plotting disp_y for node 1 (bottom left) and node 2715 (top left)
plt.plot(times,set_in.sel(field='uy',node='1').to_array(),   color='red',label='node_1')
plt.plot(times,set_in.sel(field='uy',node='2715').to_array(),color='blue',label='node_2715')
plt.xlabel('time (s)')
plt.ylabel('displacement (mm)')
plt.legend()
plt.show()

# %%
# Check that stress normalization is working

stresses=normalize(set_in.sel(field='S22',node='1').to_array(),s_range[0],s_range[1],-1,1)
stresses_mu,stresses_sig=eval_mu_sig(np.asarray(set_in.sel(field='S22',node='1').to_array()))
stresses_2=std_normalize(np.asarray(set_in.sel(field='S22',node='1').to_array()), stresses_mu, stresses_sig)
plt.plot(times,stresses,color='blue',label='node_2715, min-max normalization')
plt.plot(times,stresses_2,color='red',label='node_2715, z-score normalization')
plt.xlabel('time (s)')
plt.ylabel('normalized stress (MPa)')
plt.legend()
plt.show()

# %%
# check some shapes
disp_x=np.array(set_in.sel(field='ux').to_array())
np.shape(np.array(set_in.sel(field='ux').to_array()))
# Out:
# (81, 2760)

# %%
# define function for subsampling data
def PrepareData(set_in, nodal_coordinates, times, random=True): # num_data, data_file
    
    # Load data
    #data = scipy.io.loadmat('/content/' + data_file)
    #data = scipy.io.loadmat(data_file)
    
    # will want to change these to correspond to our input variables
    #U_star = data['U_star'] # N x 2 x T
    ## displacements -> U_star
    #disp_x=normalize(set_in.sel(field='ux').to_array(),disp_range[0],disp_range[1],-1,1) # T x N # (81, 2760)
    #disp_y=normalize(set_in.sel(field='uy').to_array(),disp_range[0],disp_range[1],-1,1) # T x N # (81, 2760)
    disp_x=np.array(set_in.sel(field='ux').to_array()) # T x N # (81, 2760)
    disp_y=np.array(set_in.sel(field='uy').to_array()) # T x N # (81, 2760)
    u_mu, u_sig = eval_mu_sig(disp_x)
    v_mu, v_sig = eval_mu_sig(disp_y)
    dispx = std_normalize(disp_x, u_mu, u_sig) # normalize(disp_x, disp_range[0],disp_range[1],-1,1)
    dispy = std_normalize(disp_y, v_mu, v_sig) # normalize(disp_y, disp_range[0],disp_range[1],-1,1)
    U_star=np.dstack([dispx,dispy])     # T x N x 2 (81, 2760, 2)
    
    # time
    times = [] # will be shape (81,)
    for DataArray in set_in.values():
        times.append(DataArray.attrs['time'])
        
    
    # Solution S22 -> P_star
    sxx_mu, sxx_sig = eval_mu_sig(np.asarray(set_in.sel(field='S11').to_array()))
    syy_mu, syy_sig = eval_mu_sig(np.asarray(set_in.sel(field='S22').to_array()))
    sxy_mu, sxy_sig = eval_mu_sig(np.asarray(set_in.sel(field='S12').to_array()))
    sxx_star = std_normalize(np.asarray(set_in.sel(field='S11').to_array()),sxx_mu,sxx_sig) #normalize(np.asarray(set_in.sel(field='S11').to_array()),s_range[0],s_range[1],0,1) # T x N
    ## change this?
    syy_star = std_normalize(np.asarray(set_in.sel(field='S12').to_array()),syy_mu,syy_sig) #normalize(np.asarray(set_in.sel(field='S22').to_array()),s_range[0],s_range[1],0,1) # T x N
    sxy_star = std_normalize(np.asarray(set_in.sel(field='S12').to_array()),sxy_mu,sxy_sig) #normalize(np.asarray(set_in.sel(field='S12').to_array()),s_range[0],s_range[1],0,1) # T x N

    # time -> t_star
    t_star = times #data['t'] # T x 1 # (81,)
    
    # grid -> X_star
    gridd = nodal_coordinates[:,1:3]
    #print(np.shape(gridd))
    #gridd = np.array([gridd[:,0],gridd[:,1]+1500.]).T
    #gridd = np.array([normalize(,x_range[0],x_range[1],-1,1),normalize(,y_range[0],y_range[1],-1,1)]).T
    #print(np.shape(gridd))
    grid_x = gridd[:,0]
    grid_y = gridd[:,1]
    x_mu, x_sig = eval_mu_sig(grid_x)
    y_mu, y_sig = eval_mu_sig(grid_y)
    gridx = std_normalize(grid_x, x_mu, x_sig).T #normalize(grid_x,x_range[0],x_range[1],-1,1) #min_max_normalize(grid_x, np.amin(grid_x), np.amax(grid_x)).T # std_normalize(grid_x, x_mu, x_sig).T
    gridy = std_normalize(grid_y, y_mu, y_sig).T #normalize(grid_y,y_range[0],y_range[1],-1,1) #min_max_normalize(grid_y, np.amin(grid_y), np.amax(grid_y)).T # std_normalize(grid_y, y_mu, y_sig).T
    gridd = np.array([gridx, gridy]).T
    #X_star = np.array([gridx, gridy]) # grid is N x 2 or shape (2760, 2)
    X_star = gridd
    
    N = np.shape(X_star)[0] #X_star.shape[0]
    T = np.shape(t_star)[0] #t_star.shape[0]
    
    # Rearrange Data 
    XX = np.tile(X_star[:,0:1], (1,T)) # N x T # (2760, 81)
    YY = np.tile(X_star[:,1:2], (1,T)) # N x T # (2760, 81)
    TT = np.tile(t_star, (1,N)).T # NT x 1 # (223560, 1)
    
    UU = U_star[:,:,0].T # N x T
    VV = U_star[:,:,1].T # N x T
    SSxx = sxx_star.T # N x T
    SSyy = syy_star.T # N x T
    SSxy = sxy_star.T # N x T

    
    # Pick random data.
    if random:
        idx = np.random.choice(N*T, N, replace=False) # num_data
    else:
        idx = np.arange(0, N*T)
    
    x = XX
    y = YY
    t = t_star
    
    x = XX.flatten()[idx,None] # NT x 1
    y = YY.flatten()[idx,None] # NT x 1
    t = TT.flatten()[idx,None] # NT x 1
 
    
    u = UU # T x N # (81, 2760)
    v = VV # T x N # (81, 2760)
    
    u = UU.flatten()[idx,None] # NT x 1
    v = VV.flatten()[idx,None] # NT x 1
    sxx = SSxx.flatten()[idx,None] # NT x 1
    syy = SSyy.flatten()[idx,None] # NT x 1
    sxy = SSxy.flatten()[idx,None] # NT x 1
    
        

    return (x,y,t,u,v,sxx,syy,sxy,[u_mu, v_mu, x_mu, y_mu, sxx_mu, syy_mu, sxy_mu], [u_sig, v_sig, x_sig, y_sig, sxx_sig, syy_sig, sxy_sig])

# %%
x,y,t,u,v,sxx, syy, sxy, mus, sigs = PrepareData(set_in, nodal_coordinates, times, random=True)

# check shapes
print(f'shape of x = {np.shape(x)}')     # N x 1
print(f'shape of y = {np.shape(y)}')     # N x 1
print(f'shape of t = {np.shape(t)}')     # N x 1
print(f'shape of u = {np.shape(u)}')     # N x 1
print(f'shape of v = {np.shape(v)}')     # N x 1
print(f'shape of sxx = {np.shape(sxx)}') # N x 1
print(f'shape of syy = {np.shape(syy)}') # N x 1
print(f'shape of sxy = {np.shape(sxy)}') # N x 1
# Out:
# shape of x = (2760, 1)
# shape of y = (2760, 1)
# shape of t = (2760, 1)
# shape of u = (2760, 1)
# shape of v = (2760, 1)
# shape of sxx = (2760, 1)
# shape of syy = (2760, 1)
# shape of sxy = (2760, 1)

# %%
# as a quick check
input_d = set_in.step_080
ux_mu,ux_sig=eval_mu_sig(np.asarray(input_d.sel(field='ux')))
ux_2=std_normalize(np.asarray(input_d.sel(field='ux')), ux_mu, ux_sig)
ux_2
# Out:
# array([ 1.69479811,  1.61947373,  1.54414936, ..., -1.54414942,
#        -1.61947359, -1.69479804])

# %%
s22_mu,s22_sig=eval_mu_sig(np.asarray(input_d.sel(field='S22')))

#rearrange(numx,numy,std_normalize(np.asarray(input_d.sel(field='S22')), s22_mu, s22_sig)) # doesn't work correctly, just nans
#rearrange(numx, numy, normalize(np.asarray(input_d.sel(field='S22')),s_range[0],s_range[1],-1,1))

# %%
def plot(Emod, nu):
    output_file_name = os.path.join(outputpath, outputprefix)
    #fname = output_file_name + "_{}_".format(actf) + "x".join([str(x) for x in layers])
    fname = output_file_name + "_{}_".format(actf)
    
    loss = np.loadtxt(fname+"_loss")
    times = np.loadtxt(fname+"_Time")
    fig, ax = plt.subplots(1, 2, figsize=(7, 3), dpi=300)
    cust_semilogx(ax[0], None, loss/loss[0], "epochs", "L/L0")
    cust_semilogx(ax[1], times, loss/loss[0], "time(s)", None)
    fig.subplots_adjust(left=0.1, right=0.9, bottom=0.15, top=0.9, wspace=0.3, hspace=0.2)
    plt.savefig("{}_loss.png".format(output_file_name))
    
    Xmesh = np.loadtxt(fname+"_Xmesh", delimiter=',')
    Ymesh = np.loadtxt(fname+"_Ymesh", delimiter=',')
    
    input_d = set_in.step_080
    ux_mu,ux_sig=eval_mu_sig(np.asarray(input_d.sel(field='ux')))
    uy_mu,uy_sig=eval_mu_sig(np.asarray(input_d.sel(field='uy')))
    s11_mu,s11_sig=eval_mu_sig(np.asarray(input_d.sel(field='S11')))
    s22_mu,s22_sig=eval_mu_sig(np.asarray(input_d.sel(field='S22')))
    s12_mu,s12_sig=eval_mu_sig(np.asarray(input_d.sel(field='S12')))
    #data_d1 = std_normalize(np.asarray(input_d.sel(field='ux')), ux_mu, ux_sig) #normalize(np.asarray(input_d.sel(field='ux')),disp_range[0],disp_range[1],-1,1)
    #data_d2 = std_normalize(np.asarray(input_d.sel(field='uy')), uy_mu, uy_sig) #normalize(np.asarray(input_d.sel(field='uy')),disp_range[0],disp_range[1],-1,1)
    #data_d3 = std_normalize(np.asarray(input_d.sel(field='S11')), s11_mu, s11_sig) #normalize(np.asarray(input_d.sel(field='S11')),s_range[0],s_range[1],-1,1)
    #data_d4 = std_normalize(np.asarray(input_d.sel(field='S22')), s22_mu, s22_sig) #normalize(np.asarray(input_d.sel(field='S22')),s_range[0],s_range[1],-1,1)
    #data_d5 = std_normalize(np.asarray(input_d.sel(field='S12')), s12_mu, s12_sig) #normalize(np.asarray(input_d.sel(field='S12')),s_range[0],s_range[1],-1,1)
    data_d1 = np.asarray(input_d.sel(field='ux')) 
    data_d2 = np.asarray(input_d.sel(field='uy'))
    data_d3 = np.asarray(input_d.sel(field='S11'))
    data_d4 = np.asarray(input_d.sel(field='S22'))
    data_d5 = np.asarray(input_d.sel(field='S12'))
    
    
    #Emods = normalize(Emod,E_range[0],E_range[1],0.1,1)
    #nus = normalize(nu,nu_range[0],nu_range[1],0.1,1)
    Emods = Emod
    nus = nu
    
    fig, ax = plt.subplots(2, 2, figsize=(8, 6), dpi=300)
    cust_pcolor(ax[0, 0], Xmesh, Ymesh, np.ones_like(Xmesh)*Emods, "E*={:.3f}".format(Emods))
    cust_pcolor(ax[0, 1], Xmesh, Ymesh, np.ones_like(Xmesh)*nu, "nu*={:.3f}".format(nus))
    Emods_pred = np.loadtxt(fname+"_Emods", delimiter=',')
    nus_pred = np.loadtxt(fname+"_nus", delimiter=',')
    cust_pcolor(ax[1, 0], Xmesh, Ymesh, np.ones_like(Xmesh)*Emods_pred, "E={:.3f}".format(Emods_pred.mean()))
    cust_pcolor(ax[1, 1], Xmesh, Ymesh, np.ones_like(Xmesh)*nus_pred, "nu={:.3f}".format(nus_pred.mean()))
    plt.savefig("{}_Parameters.png".format(output_file_name))
    
    fig, ax = plt.subplots(2, 2, figsize=(8, 6), dpi=300)
    plot_ux = rearrange(numx, numy, data_d1)
    plot_uy = rearrange(numx, numy, data_d2)
    sol_u = np.loadtxt(fname+"_U", delimiter=',')
    sol_v = np.loadtxt(fname+"_V", delimiter=',')
    mu_u, sig_u = eval_mu_sig(sol_u)
    mu_v, sig_v = eval_mu_sig(sol_v)
    #print(np.shape(np.loadtxt(fname+"_U", delimiter=',')))
    cust_pcolor(ax[0, 0], Xmesh, Ymesh, plot_ux, "Ux*")
    cust_pcolor(ax[0, 1], Xmesh, Ymesh, plot_uy, "Uy*")
    cust_pcolor(ax[1, 0], Xmesh, Ymesh, std_denormalize(sol_u, mu_u, sig_u), "Ux")
    cust_pcolor(ax[1, 1], Xmesh, Ymesh, std_denormalize(sol_v, mu_v, sig_v), "Uy")
    plt.savefig("{}_Displacement.png".format(output_file_name))
    
    fig, ax = plt.subplots(2, 3, figsize=(11, 6), dpi=300)
    plot_s11 = rearrange(numx, numy, data_d3)
    plot_s22 = rearrange(numx, numy, data_d4)
    plot_s12 = rearrange(numx, numy, data_d5)
    sol_s11 = np.loadtxt(fname+"_Sxx", delimiter=',')
    sol_s22 = np.loadtxt(fname+"_Syy", delimiter=',')
    sol_s12 = np.loadtxt(fname+"_Sxy", delimiter=',')
    #mu_s11, sig_s11 = eval_mu_sig(np.asarray(set_in.sel(field='S11').to_array()))
    #mu_s22, sig_s22 = eval_mu_sig(np.asarray(set_in.sel(field='S22').to_array()))
    #mu_s12, sig_s12 = eval_mu_sig(np.asarray(set_in.sel(field='S12').to_array()))
    mu_s11, sig_s11 = eval_mu_sig(sol_s11)
    mu_s22, sig_s22 = eval_mu_sig(sol_s22)
    mu_s12, sig_s12 = eval_mu_sig(sol_s12)
    #plot_s11 = rearrange(numx, numy, np.asarray(input_d.sel(field='S11')))
    #plot_s22 = rearrange(numx, numy, normalize(np.asarray(input_d.sel(field='S22')),s_range[0],s_range[1],-1,1))
    #plot_s12 = rearrange(numx, numy, np.asarray(input_d.sel(field='S12')))
    #plot_s11 = np.zeros([numy,numx])
    #plot_s22 = np.zeros([numx*numy,1])
    #plot_s12 = np.zeros([numy,numx])
    cust_pcolor(ax[0, 0], Xmesh, Ymesh, plot_s11, "Sxx*")
    cust_pcolor(ax[0, 1], Xmesh, Ymesh, plot_s22, "Syy*")
    cust_pcolor(ax[0, 2], Xmesh, Ymesh, plot_s12, "Sxy*")
    cust_pcolor(ax[1, 0], Xmesh, Ymesh, std_denormalize(sol_s11, mu_s11, sig_s11), "Sxx")
    cust_pcolor(ax[1, 1], Xmesh, Ymesh, std_denormalize(sol_s22, mu_s22, sig_s22), "Syy")
    cust_pcolor(ax[1, 2], Xmesh, Ymesh, std_denormalize(sol_s12, mu_s12, sig_s12), "Sxy")
    fig.subplots_adjust(left=0.1, right=0.9, bottom=0.05, top=0.9, wspace=0.3, hspace=0.2)
    plt.savefig("{}_Stress.png".format(output_file_name))
    
    #fig, ax = plt.subplots(2, 3, figsize=(11, 6), dpi=300)
    #plot_exx = rearrange(numx, numy, np.asarray(input_d.sel(field='NE11')))
    #plot_eyy = rearrange(numx, numy, np.asarray(input_d.sel(field='NE22')))
    #plot_exy = rearrange(numx, numy, np.asarray(input_d.sel(field='NE12')))
    #cust_pcolor(ax[0, 0], Xmesh, Ymesh, plot_exx, "Exx*")
    #cust_pcolor(ax[0, 1], Xmesh, Ymesh, plot_eyy, "Eyy*")
    #cust_pcolor(ax[0, 2], Xmesh, Ymesh, plot_exy, "Exy*")
    #cust_pcolor(ax[1, 0], Xmesh, Ymesh, np.loadtxt(fname+"_Exx", delimiter=','), "Exx")
    #cust_pcolor(ax[1, 1], Xmesh, Ymesh, np.loadtxt(fname+"_Eyy", delimiter=','), "Eyy")
    #cust_pcolor(ax[1, 2], Xmesh, Ymesh, np.loadtxt(fname+"_Exy", delimiter=','), "Exy")
    #fig.subplots_adjust(left=0.1, right=0.9, bottom=0.05, top=0.9, wspace=0.3, hspace=0.2)
    #plt.savefig("{}_Strain.png".format(output_file_name))

# %%
# Setting up cost function
#layers = 6
#neurons = 10

x = Variable("x", dtype='float64')
y = Variable("y", dtype='float64')
t = Variable("t", dtype='float64')

U = Functional("U", [x,y,t], layers, actf)
V = Functional("V", [x,y,t], layers, actf)
Sxx = Functional("Sxx", [x,y,t], layers, actf)
Syy = Functional("Syy", [x,y,t], layers, actf)
Sxy = Functional("Sxy", [x,y,t], layers, actf)

'''
Abaqus takes E and nu
The Navier form of equations takes mu and lambda

E = [mu*(3*lambda + 2*mu)] / [lambda + mu]
nu = lambda / [2*(lambda + mu)]

mu = E / [2*(1 + nu)]
lambda = [nu*E] / [(1 + nu)*(1 - 2*nu)]

Inputs values:
E  = 210 GPa -> 0.280
nu = 0.3     -> 0.333

Expected values:
mu     =  80.769231 GPa
lambda = 121.15438 GPa
'''

#Emods = Parameter(0.9*np.random.rand()+0.1, inputs=[x,y,t], min_max=[0.1,1.0], name="Emods")
#nus = Parameter(0.3*np.random.rand()+0.1, inputs=[x,y,t], min_max=[0.1,0.4], name="nus")
Emods = Parameter(np.random.rand(), inputs=[x,y,t], name="Emods")*Emod
nus = Parameter(np.random.rand(), inputs=[x,y,t], name="nus")*nu

# Call in training data
x_train, y_train, t_train, u_train, v_train, sxx_train, syy_train, sxy_train, mus, sigs = PrepareData(set_in, nodal_coordinates, times, random=True)
u_mu, u_sig = mus[0], sigs[0]
v_mu, v_sig = mus[1], sigs[1]
x_mu, x_sig = mus[2], sigs[2]
y_mu, y_sig = mus[3], sigs[3]
sxx_mu, sxx_sig = mus[4], sigs[4]
syy_mu, syy_sig = mus[5], sigs[5]
sxy_mu, sxy_sig = mus[6], sigs[6]
sig_sig = syy_sig # 100.0

# Strains
Exx = diff(U, x)
Eyy = diff(V, y)
Exy = 0.5*(diff(U,y) + diff(V,x))

# define constraints
d1 = Data(U)
d2 = Data(V)
d3 = Data(Sxx)
d4 = Data(Syy)
d5 = Data(Sxy)

# some constants
C11 = Emods/(1-(nus**2))
C22 = C11*nus
C33 = Emods/(1*(1-nus))

# Equations
c1 = Tie(Sxx/sig_sig, (C11*Exx + C22*Eyy)/sig_sig)
c2 = Tie(Syy/sig_sig, (C11*Eyy + C22*Exx)/sig_sig)    # can we weight this equation more than c1 and c3
c3 = Tie(Sxy/sig_sig, (C33*Exy)/sig_sig)

# Momentum relations
Lx = diff(Sxx, x) + diff(Sxy, y)
Ly = diff(Sxy, x) + diff(Syy, y)
d_Lx = Data(Lx/sig_sig)
d_Ly = Data(Ly/sig_sig)

if mode == 'train':
    
    # define output folder. 
    if not os.path.isdir(outputpath):
        os.mkdir(outputpath)
        
    output_file_name = os.path.join(outputpath, outputprefix)
    #fname = output_file_name + "_{}_".format(actf) + "x".join([str(x) for x in layers])
    fname = output_file_name + "_{}_".format(actf) 
    

    model = SciModel(
        inputs=[x, y, t],
        targets = [d1, d2, d3, d4, d5, c1, c2, c3, d_Lx, d_Ly],
        #targets = [d1, d2, c1, c2, c3],
        loss_func = "mse",
        #plot_to_file = "NS-Model.png"
    )
    
    input_data = [x_train, y_train, t_train]
    #print(np.shape(input_data))

    # like an initial condition for c1, c2, c3, and c4
    data_d1 = u_train
    data_d2 = v_train
    data_d3 = sxx_train
    data_d4 = syy_train
    data_d5 = sxy_train
    ## flop back to zeros ?
    data_c1 = sxx_train #'zeros' <-- !!
    data_c2 = syy_train #'zeros'
    data_c3 = sxy_train #'zeros' <-- !!
    data_Lx = 'zeros'
    data_Ly = 'zeros'
    
    target_data = [data_d1, data_d2, data_d3, data_d4, data_d5, 
                   data_c1, data_c2, data_c3,
                   data_Lx, data_Ly]
    #target_data = [data_d1, data_d2, data_d3, data_d4, data_d5, data_c1, data_c2, data_c3]
    #target_data = [data_d1, data_d2, data_c1, data_c2, data_c3]

    ## hyper parameter define

    #Epochs= 100
    #Batch_size=100
    #Learning_rate=0.001
    #Reduce_lr_after=1000
    
#log the data

    # Prepare training data 
    ## Training grid 
    XMIN, XMAX = -1.0, 1.0 # 0.0, 3000.0 #1.0
    YMIN, YMAX = -1.0, 1.0 # -1500., 1500. # 0.0, 1.0
    #YMIN, YMAX = 0.0, 3000.0 # 0.0, 1.0
    Xmesh = np.linspace(XMIN, XMAX, numx).reshape((-1, 1))
    Ymesh = np.linspace(YMIN, YMAX, numy).reshape((-1, 1))
    X, Y = np.meshgrid(Xmesh, Ymesh)
    
    
    
    #input_data = [grid[0],grid[1]]
    
    fname_out = fname +'_WEIGHTS'
    
    ##train PINN
    training_time = time.time()
    history = model.train(
        x_true=input_data,
        y_true=target_data,
        epochs= epochs,
        batch_size= batchsize,
        shuffle=shuffle,
        learning_rate= learningrate,
        #reduce_lr_after= Reduce_lr_after,
        stop_after = stopafter,
        #stop_loss_value=1e-8,
        verbose=verbose,
    )
    
    training_time = time.time() - training_time
    
    for loss in history.history:
        np.savetxt(fname+"_{}".format("_".join(loss.split("/"))), 
                    np.array(history.history[loss]).reshape(-1, 1))
    
    '''
    Old from Yang
    ## logs and plots
    model.save_weights('elasticity_train.hdf5')
    ## print iterated parameters value
    print("Emod: {},  lamb: {}".format(Emods.value, lamb.value))
    with open(f'../logs/log_layers{layers}_neurons{neurons}_epochs{Epochs}_batchsize{Batch_size}_learning_rate{Learning_rate}_reduce_lr_after{Reduce_lr_after}/parameters_{layers}_{neurons}.txt', 'w') as f:
        f.write(f"mu: {mu.value},  lamb: {lamb.value}")
    print("mu: {},  lamb: {}".format(mu.value, lamb.value))
    
    ## print loss function value
    print("loss: {}".format(history.history['loss']))
    with open(f'../logs/log_layers{layers}_neurons{neurons}_epochs{Epochs}_batchsize{Batch_size}_learning_rate{Learning_rate}_reduce_lr_after{Reduce_lr_after}/loss_{layers}_{neurons}.txt', 'w') as f:
        f.write(f"loss: {history.history['loss']}")
    ## plot loss function
    plt.figure(f'Train_Loss_{layers}_{neurons}')
    plt.semilogy(history.history['loss'])
    plt.xlabel('epochs')
    plt.ylabel('loss')
    plt.savefig(f'../logs/log_layers{layers}_neurons{neurons}_epochs{Epochs}_batchsize{Batch_size}_learning_rate{Learning_rate}_reduce_lr_after{Reduce_lr_after}/loss_{layers}_{neurons}.png')
    plt.semilogy(history.history['loss'])
    plt.xlabel('epochs')
    plt.ylabel('loss')
    '''
    
    time_steps = np.linspace(0, training_time, len(history.history["loss"]))
    np.savetxt(fname+"_Time", time_steps.reshape(-1,1))

    # Post process the trained model.
    
    Xmesh_plot = np.linspace(XMIN, XMAX, numxplot).reshape((-1, 1))
    Ymesh_plot = np.linspace(YMIN, YMAX, numyplot).reshape((-1, 1))
    X_plot, Y_plot = np.meshgrid(Xmesh_plot, Ymesh_plot)
    input_plot = [X_plot.reshape(-1, 1), Y_plot.reshape(-1, 1),t_train]

    Emods_pred = Emods.eval(model, input_plot)
    nus_pred = nus.eval(model, input_plot)
    U_pred = U.eval(model, input_plot)
    V_pred = V.eval(model, input_plot)
    Exx_pred = Exx.eval(model, input_plot)
    Eyy_pred = Eyy.eval(model, input_plot)
    Exy_pred = Exy.eval(model, input_plot)
    Sxx_pred = Sxx.eval(model, input_plot)
    Syy_pred = Syy.eval(model, input_plot)
    Sxy_pred = Sxy.eval(model, input_plot)
    
        
    np.savetxt(fname+"_Xmesh", X_plot, delimiter=', ')
    np.savetxt(fname+"_Ymesh", Y_plot, delimiter=', ')
    np.savetxt(fname+"_Emods", Emods_pred, delimiter=', ')
    np.savetxt(fname+"_nus", nus_pred, delimiter=', ')
    np.savetxt(fname+"_U", U_pred.reshape(X_plot.shape), delimiter=', ')
    np.savetxt(fname+"_V", V_pred.reshape(X_plot.shape), delimiter=', ')
    np.savetxt(fname+"_Exx", Exx_pred.reshape(X_plot.shape), delimiter=', ')
    np.savetxt(fname+"_Eyy", Eyy_pred.reshape(X_plot.shape), delimiter=', ')
    np.savetxt(fname+"_Exy", Exy_pred.reshape(X_plot.shape), delimiter=', ')
    np.savetxt(fname+"_Sxx", Sxx_pred.reshape(X_plot.shape), delimiter=', ')
    np.savetxt(fname+"_Syy", Syy_pred.reshape(X_plot.shape), delimiter=', ')
    np.savetxt(fname+"_Sxy", Sxy_pred.reshape(X_plot.shape), delimiter=', ')
# Out:
# Total samples: 2760
# Batch size: 50
# Total batches: 56
#
# Epoch 1/100
# 56/56 - 3s - loss: 4.7431 - U_loss: 0.8281 - V_loss: 0.5302 - Sxx_loss: 1.0079 - Syy_loss: 0.5380 - Sxy_loss: 1.0395 - sub_7_loss: 0.1209 - sub_8_loss: 0.4382 - sub_9_loss: 0.2366 - div_29_loss: 1.3299e-05 - div_30_loss: 3.6191e-05 - lr: 0.0010 - time: 3.3556
# Epoch 2/100
# 56/56 - 0s - loss: 3.3202 - U_loss: 0.6502 - V_loss: 0.4621 - Sxx_loss: 0.9903 - Syy_loss: 0.0221 - Sxy_loss: 1.0299 - sub_7_loss: 0.0420 - sub_8_loss: 0.0872 - sub_9_loss: 0.0344 - div_29_loss: 1.9501e-05 - div_30_loss: 2.3060e-05 - lr: 0.0010 - time: 0.2533
# Epoch 3/100
# 56/56 - 0s - loss: 3.1117 - U_loss: 0.5108 - V_loss: 0.4436 - Sxx_loss: 0.9794 - Syy_loss: 0.0027 - Sxy_loss: 1.0146 - sub_7_loss: 0.0459 - sub_8_loss: 0.0625 - sub_9_loss: 0.0314 - div_29_loss: 1.9931e-05 - div_30_loss: 2.0620e-05 - lr: 0.0010 - time: 0.3165
# Epoch 4/100
# 56/56 - 0s - loss: 3.0237 - U_loss: 0.4763 - V_loss: 0.4346 - Sxx_loss: 0.9881 - Syy_loss: 0.0018 - Sxy_loss: 1.0370 - sub_7_loss: 0.0398 - sub_8_loss: 0.0442 - sub_9_loss: 0.0239 - div_29_loss: 2.1069e-05 - div_30_loss: 2.0687e-05 - lr: 0.0010 - time: 0.3225
# Epoch 5/100
# 56/56 - 0s - loss: 2.9554 - U_loss: 0.4491 - V_loss: 0.4165 - Sxx_loss: 0.9688 - Syy_loss: 0.0015 - Sxy_loss: 1.0038 - sub_7_loss: 0.0380 - sub_8_loss: 0.0356 - sub_9_loss: 0.0229 - div_29_loss: 2.0479e-05 - div_30_loss: 1.6828e-05 - lr: 0.0010 - time: 0.3142
# Epoch 6/100
# 56/56 - 0s - loss: 2.8944 - U_loss: 0.4262 - V_loss: 0.3949 - Sxx_loss: 0.9749 - Syy_loss: 0.0011 - Sxy_loss: 1.0022 - sub_7_loss: 0.0358 - sub_8_loss: 0.0295 - sub_9_loss: 0.0113 - div_29_loss: 2.6675e-05 - div_30_loss: 1.9946e-05 - lr: 0.0010 - time: 0.3247
# Epoch 7/100
# 56/56 - 0s - loss: 2.8651 - U_loss: 0.4157 - V_loss: 0.3714 - Sxx_loss: 1.0103 - Syy_loss: 9.9677e-04 - Sxy_loss: 1.0861 - sub_7_loss: 0.0401 - sub_8_loss: 0.0244 - sub_9_loss: 0.0096 - div_29_loss: 2.7224e-05 - div_30_loss: 2.1389e-05 - lr: 0.0010 - time: 0.3383
# Epoch 8/100
# 56/56 - 0s - loss: 2.8005 - U_loss: 0.3895 - V_loss: 0.3532 - Sxx_loss: 0.9687 - Syy_loss: 8.2847e-04 - Sxy_loss: 1.0233 - sub_7_loss: 0.0422 - sub_8_loss: 0.0241 - sub_9_loss: 0.0087 - div_29_loss: 2.8149e-05 - div_30_loss: 2.3573e-05 - lr: 0.0010 - time: 0.3415
# Epoch 9/100
# 56/56 - 0s - loss: 2.7477 - U_loss: 0.3639 - V_loss: 0.3253 - Sxx_loss: 0.9496 - Syy_loss: 8.7483e-04 - Sxy_loss: 1.0075 - sub_7_loss: 0.0441 - sub_8_loss: 0.0245 - sub_9_loss: 0.0069 - div_29_loss: 4.2890e-05 - div_30_loss: 1.6818e-05 - lr: 0.0010 - time: 0.3179
# Epoch 10/100
# 56/56 - 0s - loss: 2.6994 - U_loss: 0.3393 - V_loss: 0.3010 - Sxx_loss: 0.9618 - Syy_loss: 7.1307e-04 - Sxy_loss: 0.9952 - sub_7_loss: 0.0462 - sub_8_loss: 0.0245 - sub_9_loss: 0.0082 - div_29_loss: 3.9407e-05 - div_30_loss: 1.8882e-05 - lr: 0.0010 - time: 0.3238
# Epoch 11/100
# 56/56 - 0s - loss: 2.6364 - U_loss: 0.3177 - V_loss: 0.2746 - Sxx_loss: 0.9643 - Syy_loss: 5.3895e-04 - Sxy_loss: 1.0052 - sub_7_loss: 0.0465 - sub_8_loss: 0.0230 - sub_9_loss: 0.0073 - div_29_loss: 5.0244e-05 - div_30_loss: 3.1495e-05 - lr: 0.0010 - time: 0.3374
# Epoch 12/100
# 56/56 - 0s - loss: 2.5795 - U_loss: 0.2880 - V_loss: 0.2460 - Sxx_loss: 0.9574 - Syy_loss: 5.1695e-04 - Sxy_loss: 1.0062 - sub_7_loss: 0.0483 - sub_8_loss: 0.0233 - sub_9_loss: 0.0069 - div_29_loss: 5.7594e-05 - div_30_loss: 1.7793e-05 - lr: 0.0010 - time: 0.3361
# Epoch 13/100
# 56/56 - 0s - loss: 2.5314 - U_loss: 0.2532 - V_loss: 0.2192 - Sxx_loss: 0.9510 - Syy_loss: 5.1645e-04 - Sxy_loss: 1.0115 - sub_7_loss: 0.0520 - sub_8_loss: 0.0260 - sub_9_loss: 0.0061 - div_29_loss: 6.1603e-05 - div_30_loss: 2.6552e-05 - lr: 0.0010 - time: 0.3381
# Epoch 14/100
# 56/56 - 0s - loss: 2.4758 - U_loss: 0.2281 - V_loss: 0.2060 - Sxx_loss: 0.9610 - Syy_loss: 4.4557e-04 - Sxy_loss: 0.9989 - sub_7_loss: 0.0490 - sub_8_loss: 0.0223 - sub_9_loss: 0.0058 - div_29_loss: 6.1782e-05 - div_30_loss: 2.6827e-05 - lr: 0.0010 - time: 0.3240
# Epoch 15/100
# 56/56 - 0s - loss: 2.4434 - U_loss: 0.1968 - V_loss: 0.1904 - Sxx_loss: 0.9503 - Syy_loss: 4.2787e-04 - Sxy_loss: 1.0032 - sub_7_loss: 0.0474 - sub_8_loss: 0.0246 - sub_9_loss: 0.0075 - div_29_loss: 6.4599e-05 - div_30_loss: 1.6002e-05 - lr: 0.0010 - time: 0.3126
# Epoch 16/100
# 56/56 - 0s - loss: 2.4049 - U_loss: 0.1807 - V_loss: 0.1785 - Sxx_loss: 1.0106 - Syy_loss: 3.4124e-04 - Sxy_loss: 1.0131 - sub_7_loss: 0.0485 - sub_8_loss: 0.0303 - sub_9_loss: 0.0075 - div_29_loss: 6.9580e-05 - div_30_loss: 2.5541e-05 - lr: 0.0010 - time: 0.3230
# Epoch 17/100
# 56/56 - 0s - loss: 2.3929 - U_loss: 0.1584 - V_loss: 0.1737 - Sxx_loss: 0.9671 - Syy_loss: 3.1452e-04 - Sxy_loss: 1.0094 - sub_7_loss: 0.0465 - sub_8_loss: 0.0371 - sub_9_loss: 0.0102 - div_29_loss: 7.9226e-05 - div_30_loss: 2.3553e-05 - lr: 0.0010 - time: 0.3318
# Epoch 18/100
# 56/56 - 0s - loss: 2.3775 - U_loss: 0.1432 - V_loss: 0.1717 - Sxx_loss: 0.9492 - Syy_loss: 3.3451e-04 - Sxy_loss: 0.9951 - sub_7_loss: 0.0456 - sub_8_loss: 0.0428 - sub_9_loss: 0.0110 - div_29_loss: 8.9161e-05 - div_30_loss: 1.8613e-05 - lr: 0.0010 - time: 0.3291
# Epoch 19/100
# 56/56 - 0s - loss: 2.3638 - U_loss: 0.1331 - V_loss: 0.1651 - Sxx_loss: 0.9560 - Syy_loss: 3.2401e-04 - Sxy_loss: 1.0071 - sub_7_loss: 0.0495 - sub_8_loss: 0.0458 - sub_9_loss: 0.0082 - div_29_loss: 8.8951e-05 - div_30_loss: 3.5134e-05 - lr: 0.0010 - time: 0.3338
# Epoch 20/100
# 56/56 - 0s - loss: 2.3344 - U_loss: 0.1269 - V_loss: 0.1611 - Sxx_loss: 0.9543 - Syy_loss: 3.2737e-04 - Sxy_loss: 1.0646 - sub_7_loss: 0.0442 - sub_8_loss: 0.0479 - sub_9_loss: 0.0072 - div_29_loss: 1.0647e-04 - div_30_loss: 3.4666e-05 - lr: 0.0010 - time: 0.3217
# Epoch 21/100
# 56/56 - 0s - loss: 2.3243 - U_loss: 0.1163 - V_loss: 0.1576 - Sxx_loss: 0.9513 - Syy_loss: 2.5989e-04 - Sxy_loss: 1.0040 - sub_7_loss: 0.0479 - sub_8_loss: 0.0484 - sub_9_loss: 0.0065 - div_29_loss: 9.4073e-05 - div_30_loss: 2.7396e-05 - lr: 0.0010 - time: 0.3513
# Epoch 22/100
# 56/56 - 0s - loss: 2.3225 - U_loss: 0.1101 - V_loss: 0.1517 - Sxx_loss: 0.9590 - Syy_loss: 3.2701e-04 - Sxy_loss: 1.0347 - sub_7_loss: 0.0437 - sub_8_loss: 0.0537 - sub_9_loss: 0.0071 - div_29_loss: 8.4226e-05 - div_30_loss: 3.2849e-05 - lr: 0.0010 - time: 0.3275
# Epoch 23/100
# 56/56 - 0s - loss: 2.3114 - U_loss: 0.1064 - V_loss: 0.1512 - Sxx_loss: 0.9436 - Syy_loss: 2.7058e-04 - Sxy_loss: 1.0039 - sub_7_loss: 0.0441 - sub_8_loss: 0.0518 - sub_9_loss: 0.0074 - div_29_loss: 8.3030e-05 - div_30_loss: 2.9705e-05 - lr: 0.0010 - time: 0.3193
# Epoch 24/100
# 56/56 - 0s - loss: 2.2988 - U_loss: 0.0972 - V_loss: 0.1481 - Sxx_loss: 0.9556 - Syy_loss: 2.3866e-04 - Sxy_loss: 0.9954 - sub_7_loss: 0.0450 - sub_8_loss: 0.0524 - sub_9_loss: 0.0076 - div_29_loss: 9.2593e-05 - div_30_loss: 3.2608e-05 - lr: 0.0010 - time: 0.3370
# Epoch 25/100
# 56/56 - 0s - loss: 2.2897 - U_loss: 0.0945 - V_loss: 0.1464 - Sxx_loss: 0.9450 - Syy_loss: 2.3173e-04 - Sxy_loss: 1.0075 - sub_7_loss: 0.0431 - sub_8_loss: 0.0543 - sub_9_loss: 0.0066 - div_29_loss: 1.1807e-04 - div_30_loss: 2.7037e-05 - lr: 0.0010 - time: 0.3655
# Epoch 26/100
# 56/56 - 0s - loss: 2.2796 - U_loss: 0.0877 - V_loss: 0.1388 - Sxx_loss: 0.9434 - Syy_loss: 2.0193e-04 - Sxy_loss: 1.0043 - sub_7_loss: 0.0446 - sub_8_loss: 0.0546 - sub_9_loss: 0.0063 - div_29_loss: 1.1671e-04 - div_30_loss: 2.7078e-05 - lr: 0.0010 - time: 0.3272
# Epoch 27/100
# 56/56 - 0s - loss: 2.2704 - U_loss: 0.0850 - V_loss: 0.1367 - Sxx_loss: 0.9350 - Syy_loss: 1.8741e-04 - Sxy_loss: 1.0226 - sub_7_loss: 0.0432 - sub_8_loss: 0.0561 - sub_9_loss: 0.0080 - div_29_loss: 9.7628e-05 - div_30_loss: 2.3553e-05 - lr: 0.0010 - time: 0.3288
# Epoch 28/100
# 56/56 - 0s - loss: 2.2756 - U_loss: 0.0810 - V_loss: 0.1406 - Sxx_loss: 0.9465 - Syy_loss: 2.2723e-04 - Sxy_loss: 1.0196 - sub_7_loss: 0.0432 - sub_8_loss: 0.0540 - sub_9_loss: 0.0081 - div_29_loss: 1.4028e-04 - div_30_loss: 4.4273e-05 - lr: 0.0010 - time: 0.3514
# Epoch 29/100
# 56/56 - 0s - loss: 2.2630 - U_loss: 0.0780 - V_loss: 0.1350 - Sxx_loss: 0.9215 - Syy_loss: 1.8594e-04 - Sxy_loss: 0.9973 - sub_7_loss: 0.0451 - sub_8_loss: 0.0600 - sub_9_loss: 0.0079 - div_29_loss: 8.6683e-05 - div_30_loss: 2.2884e-05 - lr: 0.0010 - time: 0.3338
# Epoch 30/100
# 56/56 - 0s - loss: 2.2500 - U_loss: 0.0735 - V_loss: 0.1333 - Sxx_loss: 0.9262 - Syy_loss: 2.3415e-04 - Sxy_loss: 0.9918 - sub_7_loss: 0.0461 - sub_8_loss: 0.0591 - sub_9_loss: 0.0077 - div_29_loss: 1.4411e-04 - div_30_loss: 4.6483e-05 - lr: 0.0010 - time: 0.3247
# Epoch 31/100
# 56/56 - 0s - loss: 2.2501 - U_loss: 0.0722 - V_loss: 0.1349 - Sxx_loss: 0.9278 - Syy_loss: 2.3351e-04 - Sxy_loss: 0.9921 - sub_7_loss: 0.0450 - sub_8_loss: 0.0565 - sub_9_loss: 0.0081 - div_29_loss: 1.0864e-04 - div_30_loss: 3.6818e-05 - lr: 0.0010 - time: 0.3354
# Epoch 32/100
# 56/56 - 0s - loss: 2.2373 - U_loss: 0.0679 - V_loss: 0.1271 - Sxx_loss: 0.9262 - Syy_loss: 1.4583e-04 - Sxy_loss: 1.0176 - sub_7_loss: 0.0412 - sub_8_loss: 0.0573 - sub_9_loss: 0.0069 - div_29_loss: 1.2782e-04 - div_30_loss: 3.6094e-05 - lr: 0.0010 - time: 0.3084
# Epoch 33/100
# 56/56 - 0s - loss: 2.2354 - U_loss: 0.0626 - V_loss: 0.1247 - Sxx_loss: 0.9339 - Syy_loss: 1.6752e-04 - Sxy_loss: 1.0283 - sub_7_loss: 0.0429 - sub_8_loss: 0.0567 - sub_9_loss: 0.0056 - div_29_loss: 1.3477e-04 - div_30_loss: 3.1357e-05 - lr: 0.0010 - time: 0.3349
# Epoch 34/100
# 56/56 - 0s - loss: 2.2228 - U_loss: 0.0623 - V_loss: 0.1254 - Sxx_loss: 0.9169 - Syy_loss: 1.6164e-04 - Sxy_loss: 0.9907 - sub_7_loss: 0.0428 - sub_8_loss: 0.0568 - sub_9_loss: 0.0074 - div_29_loss: 1.1917e-04 - div_30_loss: 3.2471e-05 - lr: 0.0010 - time: 0.3392
# Epoch 35/100
# 56/56 - 0s - loss: 2.2249 - U_loss: 0.0605 - V_loss: 0.1225 - Sxx_loss: 0.9457 - Syy_loss: 1.2956e-04 - Sxy_loss: 0.9915 - sub_7_loss: 0.0415 - sub_8_loss: 0.0553 - sub_9_loss: 0.0070 - div_29_loss: 1.7097e-04 - div_30_loss: 3.3695e-05 - lr: 0.0010 - time: 0.3245
# Epoch 36/100
# 56/56 - 0s - loss: 2.2110 - U_loss: 0.0546 - V_loss: 0.1213 - Sxx_loss: 0.9160 - Syy_loss: 1.4793e-04 - Sxy_loss: 0.9911 - sub_7_loss: 0.0431 - sub_8_loss: 0.0602 - sub_9_loss: 0.0072 - div_29_loss: 1.5865e-04 - div_30_loss: 4.3042e-05 - lr: 0.0010 - time: 0.3271
# Epoch 37/100
# 56/56 - 0s - loss: 2.2087 - U_loss: 0.0545 - V_loss: 0.1211 - Sxx_loss: 0.9228 - Syy_loss: 1.5783e-04 - Sxy_loss: 0.9957 - sub_7_loss: 0.0432 - sub_8_loss: 0.0583 - sub_9_loss: 0.0062 - div_29_loss: 1.5304e-04 - div_30_loss: 3.9838e-05 - lr: 0.0010 - time: 0.3285
# Epoch 38/100
# 56/56 - 0s - loss: 2.2072 - U_loss: 0.0551 - V_loss: 0.1228 - Sxx_loss: 0.9152 - Syy_loss: 1.2096e-04 - Sxy_loss: 1.0019 - sub_7_loss: 0.0432 - sub_8_loss: 0.0576 - sub_9_loss: 0.0101 - div_29_loss: 1.5750e-04 - div_30_loss: 2.6563e-05 - lr: 0.0010 - time: 0.3215
# Epoch 39/100
# 56/56 - 0s - loss: 2.1948 - U_loss: 0.0528 - V_loss: 0.1169 - Sxx_loss: 0.9137 - Syy_loss: 1.4000e-04 - Sxy_loss: 1.0092 - sub_7_loss: 0.0404 - sub_8_loss: 0.0552 - sub_9_loss: 0.0075 - div_29_loss: 1.8569e-04 - div_30_loss: 3.7993e-05 - lr: 0.0010 - time: 0.3262
# Epoch 40/100
# 56/56 - 0s - loss: 2.1969 - U_loss: 0.0494 - V_loss: 0.1141 - Sxx_loss: 0.9121 - Syy_loss: 1.5799e-04 - Sxy_loss: 0.9929 - sub_7_loss: 0.0426 - sub_8_loss: 0.0573 - sub_9_loss: 0.0082 - div_29_loss: 2.0448e-04 - div_30_loss: 4.8593e-05 - lr: 0.0010 - time: 0.3473
# Epoch 41/100
# 56/56 - 0s - loss: 2.1856 - U_loss: 0.0495 - V_loss: 0.1144 - Sxx_loss: 0.9024 - Syy_loss: 1.8280e-04 - Sxy_loss: 1.0035 - sub_7_loss: 0.0435 - sub_8_loss: 0.0571 - sub_9_loss: 0.0073 - div_29_loss: 1.9834e-04 - div_30_loss: 3.2908e-05 - lr: 0.0010 - time: 0.3211
# Epoch 42/100
# 56/56 - 0s - loss: 2.1848 - U_loss: 0.0467 - V_loss: 0.1104 - Sxx_loss: 0.9147 - Syy_loss: 1.1016e-04 - Sxy_loss: 0.9893 - sub_7_loss: 0.0427 - sub_8_loss: 0.0605 - sub_9_loss: 0.0070 - div_29_loss: 2.0639e-04 - div_30_loss: 3.9214e-05 - lr: 0.0010 - time: 0.3348
# Epoch 43/100
# 56/56 - 0s - loss: 2.1822 - U_loss: 0.0447 - V_loss: 0.1132 - Sxx_loss: 0.9044 - Syy_loss: 1.1626e-04 - Sxy_loss: 1.0282 - sub_7_loss: 0.0426 - sub_8_loss: 0.0580 - sub_9_loss: 0.0073 - div_29_loss: 2.1046e-04 - div_30_loss: 5.2403e-05 - lr: 0.0010 - time: 0.3263
# Epoch 44/100
# 56/56 - 0s - loss: 2.1667 - U_loss: 0.0440 - V_loss: 0.1131 - Sxx_loss: 0.8945 - Syy_loss: 1.1436e-04 - Sxy_loss: 1.0017 - sub_7_loss: 0.0423 - sub_8_loss: 0.0562 - sub_9_loss: 0.0082 - div_29_loss: 2.5980e-04 - div_30_loss: 3.4684e-05 - lr: 0.0010 - time: 0.3314
# Epoch 45/100
# 56/56 - 0s - loss: 2.1967 - U_loss: 0.0424 - V_loss: 0.1067 - Sxx_loss: 1.0576 - Syy_loss: 1.0673e-04 - Sxy_loss: 1.0140 - sub_7_loss: 0.0421 - sub_8_loss: 0.0579 - sub_9_loss: 0.0062 - div_29_loss: 2.6204e-04 - div_30_loss: 3.2934e-05 - lr: 0.0010 - time: 0.3126
# Epoch 46/100
# 56/56 - 0s - loss: 2.1563 - U_loss: 0.0407 - V_loss: 0.1071 - Sxx_loss: 0.9355 - Syy_loss: 1.2397e-04 - Sxy_loss: 0.9946 - sub_7_loss: 0.0429 - sub_8_loss: 0.0582 - sub_9_loss: 0.0055 - div_29_loss: 2.6563e-04 - div_30_loss: 3.9567e-05 - lr: 0.0010 - time: 0.3275
# Epoch 47/100
# 56/56 - 0s - loss: 2.1578 - U_loss: 0.0401 - V_loss: 0.1059 - Sxx_loss: 0.8957 - Syy_loss: 8.5451e-05 - Sxy_loss: 0.9883 - sub_7_loss: 0.0431 - sub_8_loss: 0.0567 - sub_9_loss: 0.0055 - div_29_loss: 3.1295e-04 - div_30_loss: 4.3681e-05 - lr: 0.0010 - time: 0.3148
# Epoch 48/100
# 56/56 - 0s - loss: 2.1546 - U_loss: 0.0408 - V_loss: 0.1047 - Sxx_loss: 0.8968 - Syy_loss: 9.2262e-05 - Sxy_loss: 0.9979 - sub_7_loss: 0.0426 - sub_8_loss: 0.0588 - sub_9_loss: 0.0056 - div_29_loss: 2.8746e-04 - div_30_loss: 4.3099e-05 - lr: 0.0010 - time: 0.3356
# Epoch 49/100
# 56/56 - 0s - loss: 2.1663 - U_loss: 0.0377 - V_loss: 0.1072 - Sxx_loss: 0.9200 - Syy_loss: 1.4755e-04 - Sxy_loss: 1.0032 - sub_7_loss: 0.0441 - sub_8_loss: 0.0598 - sub_9_loss: 0.0068 - div_29_loss: 3.7155e-04 - div_30_loss: 5.2977e-05 - lr: 0.0010 - time: 0.3385
# Epoch 50/100
# 56/56 - 0s - loss: 2.1474 - U_loss: 0.0385 - V_loss: 0.1032 - Sxx_loss: 0.8918 - Syy_loss: 9.1719e-05 - Sxy_loss: 0.9910 - sub_7_loss: 0.0436 - sub_8_loss: 0.0573 - sub_9_loss: 0.0072 - div_29_loss: 3.7947e-04 - div_30_loss: 4.5575e-05 - lr: 0.0010 - time: 0.3194
# Epoch 51/100
# 56/56 - 0s - loss: 2.1537 - U_loss: 0.0371 - V_loss: 0.1024 - Sxx_loss: 0.9120 - Syy_loss: 8.9915e-05 - Sxy_loss: 0.9872 - sub_7_loss: 0.0436 - sub_8_loss: 0.0582 - sub_9_loss: 0.0076 - div_29_loss: 3.7084e-04 - div_30_loss: 4.5437e-05 - lr: 0.0010 - time: 0.3360
# Epoch 52/100
# 56/56 - 0s - loss: 2.1396 - U_loss: 0.0376 - V_loss: 0.1010 - Sxx_loss: 0.8862 - Syy_loss: 2.5478e-04 - Sxy_loss: 0.9865 - sub_7_loss: 0.0457 - sub_8_loss: 0.0595 - sub_9_loss: 0.0052 - div_29_loss: 3.4549e-04 - div_30_loss: 6.1622e-05 - lr: 0.0010 - time: 0.3252
# Epoch 53/100
# 56/56 - 0s - loss: 2.1436 - U_loss: 0.0358 - V_loss: 0.1021 - Sxx_loss: 0.8821 - Syy_loss: 2.0697e-04 - Sxy_loss: 0.9910 - sub_7_loss: 0.0430 - sub_8_loss: 0.0565 - sub_9_loss: 0.0081 - div_29_loss: 4.5302e-04 - div_30_loss: 4.2956e-05 - lr: 0.0010 - time: 0.3237
# Epoch 54/100
# 56/56 - 0s - loss: 2.1311 - U_loss: 0.0343 - V_loss: 0.1013 - Sxx_loss: 0.8707 - Syy_loss: 1.5188e-04 - Sxy_loss: 0.9924 - sub_7_loss: 0.0452 - sub_8_loss: 0.0595 - sub_9_loss: 0.0063 - div_29_loss: 4.6494e-04 - div_30_loss: 4.7228e-05 - lr: 0.0010 - time: 0.3368
# Epoch 55/100
# 56/56 - 0s - loss: 2.1221 - U_loss: 0.0349 - V_loss: 0.1004 - Sxx_loss: 0.8819 - Syy_loss: 1.8960e-04 - Sxy_loss: 1.0504 - sub_7_loss: 0.0441 - sub_8_loss: 0.0593 - sub_9_loss: 0.0072 - div_29_loss: 5.0834e-04 - div_30_loss: 6.4278e-05 - lr: 0.0010 - time: 0.3411
# Epoch 56/100
# 56/56 - 0s - loss: 2.1493 - U_loss: 0.0341 - V_loss: 0.1008 - Sxx_loss: 0.8922 - Syy_loss: 1.9391e-04 - Sxy_loss: 0.9931 - sub_7_loss: 0.0459 - sub_8_loss: 0.0605 - sub_9_loss: 0.0061 - div_29_loss: 6.8280e-04 - div_30_loss: 5.7010e-05 - lr: 0.0010 - time: 0.3300
# Epoch 57/100
# 56/56 - 0s - loss: 2.1204 - U_loss: 0.0335 - V_loss: 0.0970 - Sxx_loss: 0.8775 - Syy_loss: 1.2533e-04 - Sxy_loss: 1.0027 - sub_7_loss: 0.0446 - sub_8_loss: 0.0589 - sub_9_loss: 0.0046 - div_29_loss: 6.9519e-04 - div_30_loss: 5.9107e-05 - lr: 0.0010 - time: 0.3176
# Epoch 58/100
# 56/56 - 0s - loss: 2.1112 - U_loss: 0.0331 - V_loss: 0.0997 - Sxx_loss: 0.8819 - Syy_loss: 6.2799e-05 - Sxy_loss: 1.0126 - sub_7_loss: 0.0443 - sub_8_loss: 0.0569 - sub_9_loss: 0.0041 - div_29_loss: 6.9969e-04 - div_30_loss: 6.3435e-05 - lr: 0.0010 - time: 0.3302
# Epoch 59/100
# 56/56 - 0s - loss: 2.1074 - U_loss: 0.0333 - V_loss: 0.0970 - Sxx_loss: 0.8699 - Syy_loss: 1.0685e-04 - Sxy_loss: 1.0085 - sub_7_loss: 0.0445 - sub_8_loss: 0.0591 - sub_9_loss: 0.0042 - div_29_loss: 6.9711e-04 - div_30_loss: 5.0014e-05 - lr: 0.0010 - time: 0.3437
# Epoch 60/100
# 56/56 - 0s - loss: 2.1313 - U_loss: 0.0318 - V_loss: 0.0956 - Sxx_loss: 0.8976 - Syy_loss: 1.9782e-04 - Sxy_loss: 0.9816 - sub_7_loss: 0.0466 - sub_8_loss: 0.0596 - sub_9_loss: 0.0071 - div_29_loss: 5.7441e-04 - div_30_loss: 5.8285e-05 - lr: 0.0010 - time: 0.3244
# Epoch 61/100
# 56/56 - 0s - loss: 2.1203 - U_loss: 0.0330 - V_loss: 0.0964 - Sxx_loss: 0.8931 - Syy_loss: 1.8250e-04 - Sxy_loss: 1.0178 - sub_7_loss: 0.0444 - sub_8_loss: 0.0588 - sub_9_loss: 0.0074 - div_29_loss: 9.0485e-04 - div_30_loss: 6.6828e-05 - lr: 0.0010 - time: 0.3181
# Epoch 62/100
# 56/56 - 0s - loss: 2.1486 - U_loss: 0.0305 - V_loss: 0.0955 - Sxx_loss: 0.9006 - Syy_loss: 1.3786e-04 - Sxy_loss: 0.9875 - sub_7_loss: 0.0457 - sub_8_loss: 0.0599 - sub_9_loss: 0.0062 - div_29_loss: 5.7390e-04 - div_30_loss: 5.4546e-05 - lr: 0.0010 - time: 0.3491
# Epoch 63/100
# 56/56 - 0s - loss: 2.1031 - U_loss: 0.0303 - V_loss: 0.0939 - Sxx_loss: 0.8621 - Syy_loss: 8.5319e-05 - Sxy_loss: 0.9843 - sub_7_loss: 0.0461 - sub_8_loss: 0.0586 - sub_9_loss: 0.0047 - div_29_loss: 8.1504e-04 - div_30_loss: 5.4948e-05 - lr: 0.0010 - time: 0.3083
# Epoch 64/100
# 56/56 - 0s - loss: 2.1122 - U_loss: 0.0306 - V_loss: 0.0941 - Sxx_loss: 0.8703 - Syy_loss: 7.6578e-05 - Sxy_loss: 1.0458 - sub_7_loss: 0.0449 - sub_8_loss: 0.0586 - sub_9_loss: 0.0044 - div_29_loss: 8.7560e-04 - div_30_loss: 6.8267e-05 - lr: 0.0010 - time: 0.3292
# Epoch 65/100
# 56/56 - 0s - loss: 2.1100 - U_loss: 0.0303 - V_loss: 0.0948 - Sxx_loss: 0.9054 - Syy_loss: 9.1114e-05 - Sxy_loss: 1.0547 - sub_7_loss: 0.0452 - sub_8_loss: 0.0572 - sub_9_loss: 0.0056 - div_29_loss: 9.9650e-04 - div_30_loss: 4.8013e-05 - lr: 0.0010 - time: 0.3358
# Epoch 66/100
# 56/56 - 0s - loss: 2.1099 - U_loss: 0.0301 - V_loss: 0.0917 - Sxx_loss: 0.8784 - Syy_loss: 7.1079e-05 - Sxy_loss: 1.0050 - sub_7_loss: 0.0459 - sub_8_loss: 0.0585 - sub_9_loss: 0.0057 - div_29_loss: 9.0654e-04 - div_30_loss: 8.6643e-05 - lr: 0.0010 - time: 0.3221
# Epoch 67/100
# 56/56 - 0s - loss: 2.0881 - U_loss: 0.0304 - V_loss: 0.0926 - Sxx_loss: 0.8558 - Syy_loss: 1.8206e-04 - Sxy_loss: 1.0174 - sub_7_loss: 0.0452 - sub_8_loss: 0.0582 - sub_9_loss: 0.0046 - div_29_loss: 0.0011 - div_30_loss: 6.0286e-05 - lr: 0.0010 - time: 0.3143
# Epoch 68/100
# 56/56 - 0s - loss: 2.0721 - U_loss: 0.0298 - V_loss: 0.0903 - Sxx_loss: 0.8503 - Syy_loss: 1.0253e-04 - Sxy_loss: 0.9833 - sub_7_loss: 0.0458 - sub_8_loss: 0.0593 - sub_9_loss: 0.0047 - div_29_loss: 0.0012 - div_30_loss: 6.5989e-05 - lr: 0.0010 - time: 0.3350
# Epoch 69/100
# 56/56 - 0s - loss: 2.0938 - U_loss: 0.0305 - V_loss: 0.0913 - Sxx_loss: 0.8587 - Syy_loss: 7.7738e-05 - Sxy_loss: 0.9848 - sub_7_loss: 0.0478 - sub_8_loss: 0.0592 - sub_9_loss: 0.0042 - div_29_loss: 0.0014 - div_30_loss: 7.5340e-05 - lr: 0.0010 - time: 0.3297
# Epoch 70/100
# 56/56 - 0s - loss: 2.0927 - U_loss: 0.0293 - V_loss: 0.0922 - Sxx_loss: 0.8612 - Syy_loss: 8.7435e-05 - Sxy_loss: 0.9802 - sub_7_loss: 0.0452 - sub_8_loss: 0.0581 - sub_9_loss: 0.0043 - div_29_loss: 0.0014 - div_30_loss: 9.3476e-05 - lr: 0.0010 - time: 0.3220
# Epoch 71/100
# 56/56 - 0s - loss: 2.0843 - U_loss: 0.0294 - V_loss: 0.0897 - Sxx_loss: 0.8527 - Syy_loss: 9.9767e-05 - Sxy_loss: 0.9797 - sub_7_loss: 0.0470 - sub_8_loss: 0.0602 - sub_9_loss: 0.0049 - div_29_loss: 0.0014 - div_30_loss: 6.3635e-05 - lr: 0.0010 - time: 0.3260
# Epoch 72/100
# 56/56 - 0s - loss: 2.0777 - U_loss: 0.0288 - V_loss: 0.0898 - Sxx_loss: 0.8461 - Syy_loss: 1.2429e-04 - Sxy_loss: 0.9923 - sub_7_loss: 0.0468 - sub_8_loss: 0.0582 - sub_9_loss: 0.0050 - div_29_loss: 0.0014 - div_30_loss: 8.3219e-05 - lr: 0.0010 - time: 0.3314
# Epoch 73/100
# 56/56 - 0s - loss: 2.0884 - U_loss: 0.0293 - V_loss: 0.0923 - Sxx_loss: 0.8630 - Syy_loss: 9.4695e-05 - Sxy_loss: 1.0087 - sub_7_loss: 0.0454 - sub_8_loss: 0.0580 - sub_9_loss: 0.0062 - div_29_loss: 0.0014 - div_30_loss: 9.5451e-05 - lr: 0.0010 - time: 0.3090
# Epoch 74/100
# 56/56 - 0s - loss: 2.0818 - U_loss: 0.0290 - V_loss: 0.0911 - Sxx_loss: 0.8619 - Syy_loss: 1.2451e-04 - Sxy_loss: 1.0021 - sub_7_loss: 0.0473 - sub_8_loss: 0.0590 - sub_9_loss: 0.0047 - div_29_loss: 0.0014 - div_30_loss: 6.4014e-05 - lr: 0.0010 - time: 0.3300
# Epoch 75/100
# 56/56 - 0s - loss: 2.0723 - U_loss: 0.0286 - V_loss: 0.0898 - Sxx_loss: 0.8474 - Syy_loss: 5.7112e-05 - Sxy_loss: 0.9862 - sub_7_loss: 0.0453 - sub_8_loss: 0.0579 - sub_9_loss: 0.0054 - div_29_loss: 0.0017 - div_30_loss: 9.7053e-05 - lr: 0.0010 - time: 0.3313
# Epoch 76/100
# 56/56 - 0s - loss: 2.0609 - U_loss: 0.0288 - V_loss: 0.0897 - Sxx_loss: 0.8411 - Syy_loss: 1.1989e-04 - Sxy_loss: 0.9770 - sub_7_loss: 0.0466 - sub_8_loss: 0.0592 - sub_9_loss: 0.0037 - div_29_loss: 0.0017 - div_30_loss: 9.6618e-05 - lr: 0.0010 - time: 0.3252
# Epoch 77/100
# 56/56 - 0s - loss: 2.0718 - U_loss: 0.0286 - V_loss: 0.0886 - Sxx_loss: 0.8415 - Syy_loss: 3.2001e-04 - Sxy_loss: 0.9787 - sub_7_loss: 0.0489 - sub_8_loss: 0.0620 - sub_9_loss: 0.0051 - div_29_loss: 0.0017 - div_30_loss: 7.5963e-05 - lr: 0.0010 - time: 0.3506
# Epoch 78/100
# 56/56 - 0s - loss: 2.0999 - U_loss: 0.0300 - V_loss: 0.0899 - Sxx_loss: 0.8734 - Syy_loss: 2.6632e-04 - Sxy_loss: 1.0418 - sub_7_loss: 0.0459 - sub_8_loss: 0.0567 - sub_9_loss: 0.0044 - div_29_loss: 0.0017 - div_30_loss: 1.2718e-04 - lr: 0.0010 - time: 0.3288
# Epoch 79/100
# 56/56 - 0s - loss: 2.0726 - U_loss: 0.0273 - V_loss: 0.0892 - Sxx_loss: 0.8455 - Syy_loss: 1.5614e-04 - Sxy_loss: 0.9893 - sub_7_loss: 0.0471 - sub_8_loss: 0.0586 - sub_9_loss: 0.0044 - div_29_loss: 0.0013 - div_30_loss: 8.6032e-05 - lr: 0.0010 - time: 0.3201
# Epoch 80/100
# 56/56 - 0s - loss: 2.0847 - U_loss: 0.0283 - V_loss: 0.0896 - Sxx_loss: 0.8468 - Syy_loss: 6.5236e-05 - Sxy_loss: 0.9991 - sub_7_loss: 0.0470 - sub_8_loss: 0.0604 - sub_9_loss: 0.0048 - div_29_loss: 0.0013 - div_30_loss: 9.8787e-05 - lr: 0.0010 - time: 0.3294
# Epoch 81/100
# 56/56 - 0s - loss: 2.0656 - U_loss: 0.0283 - V_loss: 0.0878 - Sxx_loss: 0.8647 - Syy_loss: 8.0622e-05 - Sxy_loss: 1.0051 - sub_7_loss: 0.0475 - sub_8_loss: 0.0588 - sub_9_loss: 0.0045 - div_29_loss: 0.0018 - div_30_loss: 8.1705e-05 - lr: 0.0010 - time: 0.3349
# Epoch 82/100
# 56/56 - 0s - loss: 2.0736 - U_loss: 0.0281 - V_loss: 0.0883 - Sxx_loss: 0.8510 - Syy_loss: 7.0879e-05 - Sxy_loss: 0.9877 - sub_7_loss: 0.0470 - sub_8_loss: 0.0588 - sub_9_loss: 0.0046 - div_29_loss: 0.0019 - div_30_loss: 7.8090e-05 - lr: 0.0010 - time: 0.3197
# Epoch 83/100
# 56/56 - 0s - loss: 2.0722 - U_loss: 0.0277 - V_loss: 0.0874 - Sxx_loss: 0.8368 - Syy_loss: 8.4819e-05 - Sxy_loss: 0.9883 - sub_7_loss: 0.0470 - sub_8_loss: 0.0588 - sub_9_loss: 0.0035 - div_29_loss: 0.0022 - div_30_loss: 7.9620e-05 - lr: 0.0010 - time: 0.3356
# Epoch 84/100
# 56/56 - 0s - loss: 2.0919 - U_loss: 0.0276 - V_loss: 0.0863 - Sxx_loss: 0.8698 - Syy_loss: 6.0311e-05 - Sxy_loss: 0.9910 - sub_7_loss: 0.0470 - sub_8_loss: 0.0591 - sub_9_loss: 0.0041 - div_29_loss: 0.0022 - div_30_loss: 8.8033e-05 - lr: 0.0010 - time: 0.3255
# Epoch 85/100
# 56/56 - 0s - loss: 2.0677 - U_loss: 0.0279 - V_loss: 0.0906 - Sxx_loss: 0.8467 - Syy_loss: 9.9490e-05 - Sxy_loss: 0.9804 - sub_7_loss: 0.0467 - sub_8_loss: 0.0580 - sub_9_loss: 0.0075 - div_29_loss: 0.0023 - div_30_loss: 8.0335e-05 - lr: 0.0010 - time: 0.3444
# Epoch 86/100
#
# Epoch 00086: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 56/56 - 0s - loss: 2.0683 - U_loss: 0.0273 - V_loss: 0.0888 - Sxx_loss: 0.8401 - Syy_loss: 9.9218e-05 - Sxy_loss: 0.9833 - sub_7_loss: 0.0486 - sub_8_loss: 0.0616 - sub_9_loss: 0.0052 - div_29_loss: 0.0021 - div_30_loss: 8.2608e-05 - lr: 0.0010 - time: 0.3353
# Epoch 87/100
# 56/56 - 0s - loss: 2.0424 - U_loss: 0.0277 - V_loss: 0.0880 - Sxx_loss: 0.8283 - Syy_loss: 4.2601e-05 - Sxy_loss: 0.9919 - sub_7_loss: 0.0465 - sub_8_loss: 0.0568 - sub_9_loss: 0.0030 - div_29_loss: 0.0022 - div_30_loss: 7.7746e-05 - lr: 5.0000e-04 - time: 0.3284
# Epoch 88/100
# 56/56 - 0s - loss: 2.0358 - U_loss: 0.0265 - V_loss: 0.0856 - Sxx_loss: 0.8350 - Syy_loss: 3.6677e-05 - Sxy_loss: 1.0068 - sub_7_loss: 0.0465 - sub_8_loss: 0.0582 - sub_9_loss: 0.0028 - div_29_loss: 0.0021 - div_30_loss: 9.1061e-05 - lr: 5.0000e-04 - time: 0.3333
# Epoch 89/100
# 56/56 - 0s - loss: 2.0480 - U_loss: 0.0264 - V_loss: 0.0850 - Sxx_loss: 0.8333 - Syy_loss: 4.7399e-05 - Sxy_loss: 0.9826 - sub_7_loss: 0.0468 - sub_8_loss: 0.0593 - sub_9_loss: 0.0026 - div_29_loss: 0.0021 - div_30_loss: 9.3831e-05 - lr: 5.0000e-04 - time: 0.3263
# Epoch 90/100
# 56/56 - 0s - loss: 2.0489 - U_loss: 0.0263 - V_loss: 0.0846 - Sxx_loss: 0.8295 - Syy_loss: 5.5701e-05 - Sxy_loss: 0.9907 - sub_7_loss: 0.0468 - sub_8_loss: 0.0588 - sub_9_loss: 0.0027 - div_29_loss: 0.0022 - div_30_loss: 8.7670e-05 - lr: 5.0000e-04 - time: 0.3094
# Epoch 91/100
# 56/56 - 0s - loss: 2.0564 - U_loss: 0.0268 - V_loss: 0.0858 - Sxx_loss: 0.8474 - Syy_loss: 4.6549e-05 - Sxy_loss: 1.0081 - sub_7_loss: 0.0466 - sub_8_loss: 0.0573 - sub_9_loss: 0.0024 - div_29_loss: 0.0024 - div_30_loss: 1.1153e-04 - lr: 5.0000e-04 - time: 0.3310
# Epoch 92/100
# 56/56 - 0s - loss: 2.0450 - U_loss: 0.0262 - V_loss: 0.0850 - Sxx_loss: 0.8285 - Syy_loss: 5.9159e-05 - Sxy_loss: 0.9813 - sub_7_loss: 0.0473 - sub_8_loss: 0.0599 - sub_9_loss: 0.0026 - div_29_loss: 0.0023 - div_30_loss: 9.0267e-05 - lr: 5.0000e-04 - time: 0.3337
# Epoch 93/100
# 56/56 - 0s - loss: 2.0343 - U_loss: 0.0268 - V_loss: 0.0838 - Sxx_loss: 0.8200 - Syy_loss: 3.8024e-05 - Sxy_loss: 0.9876 - sub_7_loss: 0.0470 - sub_8_loss: 0.0575 - sub_9_loss: 0.0024 - div_29_loss: 0.0025 - div_30_loss: 1.0838e-04 - lr: 5.0000e-04 - time: 0.3327
# Epoch 94/100
# 56/56 - 0s - loss: 2.0374 - U_loss: 0.0267 - V_loss: 0.0855 - Sxx_loss: 0.8286 - Syy_loss: 5.6082e-05 - Sxy_loss: 1.0274 - sub_7_loss: 0.0470 - sub_8_loss: 0.0581 - sub_9_loss: 0.0028 - div_29_loss: 0.0026 - div_30_loss: 1.0702e-04 - lr: 5.0000e-04 - time: 0.3328
# Epoch 95/100
# 56/56 - 0s - loss: 2.0389 - U_loss: 0.0268 - V_loss: 0.0862 - Sxx_loss: 0.8175 - Syy_loss: 7.3630e-05 - Sxy_loss: 0.9778 - sub_7_loss: 0.0479 - sub_8_loss: 0.0597 - sub_9_loss: 0.0035 - div_29_loss: 0.0025 - div_30_loss: 1.0221e-04 - lr: 5.0000e-04 - time: 0.3293
# Epoch 96/100
# 56/56 - 0s - loss: 2.0380 - U_loss: 0.0266 - V_loss: 0.0847 - Sxx_loss: 0.8287 - Syy_loss: 4.6484e-05 - Sxy_loss: 0.9740 - sub_7_loss: 0.0472 - sub_8_loss: 0.0587 - sub_9_loss: 0.0030 - div_29_loss: 0.0025 - div_30_loss: 1.1739e-04 - lr: 5.0000e-04 - time: 0.3205
# Epoch 97/100
# 56/56 - 0s - loss: 2.0436 - U_loss: 0.0267 - V_loss: 0.0844 - Sxx_loss: 0.8395 - Syy_loss: 5.0530e-05 - Sxy_loss: 0.9737 - sub_7_loss: 0.0468 - sub_8_loss: 0.0575 - sub_9_loss: 0.0031 - div_29_loss: 0.0026 - div_30_loss: 7.8744e-05 - lr: 5.0000e-04 - time: 0.3487
# Epoch 98/100
# 56/56 - 0s - loss: 2.0353 - U_loss: 0.0261 - V_loss: 0.0845 - Sxx_loss: 0.8228 - Syy_loss: 5.6240e-05 - Sxy_loss: 0.9914 - sub_7_loss: 0.0466 - sub_8_loss: 0.0580 - sub_9_loss: 0.0018 - div_29_loss: 0.0029 - div_30_loss: 1.2083e-04 - lr: 5.0000e-04 - time: 0.3337
# Epoch 99/100
# 56/56 - 0s - loss: 2.0451 - U_loss: 0.0255 - V_loss: 0.0839 - Sxx_loss: 0.8424 - Syy_loss: 3.7087e-05 - Sxy_loss: 0.9953 - sub_7_loss: 0.0484 - sub_8_loss: 0.0590 - sub_9_loss: 0.0030 - div_29_loss: 0.0027 - div_30_loss: 1.1113e-04 - lr: 5.0000e-04 - time: 0.3411
# Epoch 100/100
# 56/56 - 0s - loss: 2.0309 - U_loss: 0.0267 - V_loss: 0.0847 - Sxx_loss: 0.8294 - Syy_loss: 5.2381e-05 - Sxy_loss: 0.9754 - sub_7_loss: 0.0463 - sub_8_loss: 0.0577 - sub_9_loss: 0.0021 - div_29_loss: 0.0029 - div_30_loss: 1.2102e-04 - lr: 5.0000e-04 - time: 0.3645
# Input and output dimensions need re-adjustment for post-processing.
# Input and output dimensions need re-adjustment for post-processing.

# %%
plot(Emod,nu)
# Out:
# /tmp/ipykernel_4288/2335051956.py:34: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   im = AX.pcolor(X, Y, C, cmap="jet")

# %%
# Plot "exact" pressure field
#plt.imshow(P_exact, interpolation='nearest', cmap='rainbow', 
#                  extent=[x_star.min(), x_star.max(), y_star.min(), y_star.max()], 
#                  origin='lower', aspect='auto')

plt.imshow(P_exact, cmap='rainbow', 
                  extent=[x_star.min(), x_star.max(), y_star.min(), y_star.max()], 
                  origin='lower', aspect='auto')
plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2967/1597334697.py in <module>
#       4 #                  origin='lower', aspect='auto')
#       5
# ----> 6 plt.imshow(P_exact, cmap='rainbow',
#       7                   extent=[x_star.min(), x_star.max(), y_star.min(), y_star.max()],
#       8                   origin='lower', aspect='auto')
#
# NameError: name 'P_exact' is not defined

# %%
set_in.step_080.sel(field='S22')
