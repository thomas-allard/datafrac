# %% [markdown]
# # Uniaxial Tension - Elasticity, Physics Informed Neural Network

# %% [markdown]
# Thomas Allard and Samantha Walker

# %%
#Imports
import os, sys, time
import numpy as np 
from sciann.utils.math import diff
from sciann import SciModel, Functional, Parameter
from sciann import Data, Tie
from sciann import Variable, Field
import matplotlib.pyplot as plt
import scipy.io
import netCDF4
import xarray as xr

import os
pi = np.pi
# Out:
# 2022-04-24 20:11:33.350151: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/mnt/c/Windows/System32/xdmf/build/lib:/mnt/c/Windows/System32/yaml-cpp/build
# 2022-04-24 20:11:33.350237: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# ---------------------- SCIANN 0.6.6.1 ----------------------
# For details, check out our review paper and the documentation at:
#  +  "https://www.sciencedirect.com/science/article/pii/S0045782520307374",
#  +  "https://arxiv.org/abs/2005.08803",
#  +  "https://www.sciann.com".
#
#  Need support or would like to contribute, please join sciann`s slack group:
#  +  "https://join.slack.com/t/sciann/shared_invite/zt-ne1f5jlx-k_dY8RGo3ZreDXwz0f~CeA"
#
# TensorFlow Version: 2.5.3
# Python Version: 3.8.12 | packaged by conda-forge | (default, Jan 30 2022, 23:53:36)
# [GCC 9.4.0]

# %%
# Specify parameters and things
mode = 'train'   # 'test' to load PINN weights from previously trained model
                # 'train' to train a new model

current_file_name = 'elasticity_Yang3000.ipynb'
    
#trained_file = 'trained-navier-stokes.hdf5'
data_file = '../abaqus/final_elastic/elastic_cdf.nc'

# file with nodal coordinates
node_file = '../abaqus/final_elastic/nodes.txt'

#layers = [40]*4
layers = [10, 40, 80, 100]
actf = 'tanh'
numx = 46
numy = 60
batchsize = 100
#batchsize = 16
epochs = 1000
learningrate = 0.001
independent_networks = True
verbose = 2
shuffle = True
stopafter = 500
savefreq = 100000
dtype = 'float64'
gpu = False
outputpath = 'output3'
outputprefix = 'res'
numxplot = 46
numyplot = 60
plot = True


Emod = 210.0
nu = 0.3

# %%
# Functions
def dispx(input_d): # xx
    #x, y = xx[0], xx[1]
    disp_x = np.asarray(input_d.sel(field='ux'))
    disp_x = np.expand_dims(disp_x, axis=0).T
    return disp_x #np.cos(2*pi*x) * np.sin(pi*y)

def dispy(input_d): # xx
    #x, y = xx[0], xx[1]
    #Q = qload
    disp_y= np.asarray(input_d.sel(field='uy'))
    disp_y = np.expand_dims(disp_y, axis=0).T
    return disp_y #np.sin(pi*x) * Q * y**4/4

def stressxx(input_d): # xx
    stress_xx = np.asarray(input_d.sel(field='S11'))
    stress_xx = np.expand_dims(stress_xx, axis=0).T
    return stress_xx
    #set.sel(field='S11').to_array() #(lmbd+2*mu)*strainxx(xx) + lmbd*strainyy(xx)

def stressyy(input_d): # xx
    stress_yy = np.asarray(input_d.sel(field='S22'))
    stress_yy = np.expand_dims(stress_yy, axis=0).T
    return stress_yy
    #return set.sel(field='S22').to_array() #(lmbd+2*mu)*strainyy(xx) + lmbd*strainxx(xx)

def stressxy(input_d): # xx
    stress_xy = np.asarray(input_d.sel(field='S12'))
    stress_xy = np.expand_dims(stress_xy, axis=0).T
    return stress_xy
    #return set.sel(field='S21').to_array() #2.0*mu*strainxy(xx)

def cust_pcolor(AX, X, Y, C, title):
    im = AX.pcolor(X, Y, C, cmap="jet")
    AX.axis("equal")
    AX.axis("off")
    AX.set_title(title, fontsize=14)
    plt.colorbar(im, ax=AX)

def cust_semilogx(AX, X, Y, xlabel, ylabel):
    if X is None:
        im = AX.semilogy(Y)
    else:
        im = AX.semilogy(X, Y)
    if xlabel is not None: AX.set_xlabel(xlabel)
    if ylabel is not None: AX.set_ylabel(ylabel)

# Create function to read text files in as np array
def file2array(file):
    # load in each line of data as array
    with open(file, 'r') as f:
        line_string = f.read().splitlines()
    
    # loop through the lines from the file, split, and append to list
    list = []
    timestamp = 0 # default 
    for i, line in enumerate(line_string):
        list.append(line.split())

    # convert list to an array of type float64
    array = np.asarray(list, dtype=np.float64)

    return(array)

def rearrange(numx, numy, field):
    stuff = np.zeros([numx,numy])
    for k,f in enumerate(field):
        i = int(k % numx)
        j = int(np.floor(k/numx))
        stuff[i,j] = f
        
    stuff = stuff.T
    return(stuff)

# %%
# load in data_file as xarray DataSet
set_in = xr.open_dataset(data_file)

# %%
# Load in displacements and create an ndarray
disp_x=set_in.sel(field='ux').to_array()
disp_y=set_in.sel(field='uy').to_array()
disps=np.dstack([disp_x,disp_y])

# %%
# Extract time and put in an array
times = [] # will be shape (81,)
for DataArray in set_in.values():
    times.append(DataArray.attrs['time'])
print(np.shape(times))
# Out:
# (81,)

# %%
# read in node file and save as grid
nodal_coordinates = file2array(node_file)
grid = nodal_coordinates[:,1:3].T
grid = np.expand_dims(grid, axis=0)
grid = np.moveaxis(grid, 0, -1)
print(np.shape(grid))
# Out:
# (2, 2760, 1)

# %%
# Check that data loaded in correctly by plotting disp_y for node 1 (bottom left) and node 2715 (top left)
plt.plot(times,set_in.sel(field='uy',node='1').to_array(),   color='red',label='node_1')
plt.plot(times,set_in.sel(field='uy',node='2715').to_array(),color='blue',label='node_2715')
plt.xlabel('time (s)')
plt.ylabel('displacement (mm)')
plt.legend()
plt.show()

# %%
# define function for subsampling data
def PrepareData(set_in, nodal_coordinates, times, random=True): # num_data, data_file
    
    # Load data
    #data = scipy.io.loadmat('/content/' + data_file)
    #data = scipy.io.loadmat(data_file)
    
    # will want to change these to correspond to our input variables
    #U_star = data['U_star'] # N x 2 x T
    ## displacements -> U_star
    disp_x=set_in.sel(field='ux').to_array() # T x N # (81, 2760)
    disp_y=set_in.sel(field='uy').to_array() # T x N # (81, 2760)
    U_star=np.dstack([disp_x,disp_y])     # T x N x 2 (81, 2760, 2)
    
    # time
    times = [] # will be shape (81,)
    for DataArray in set_in.values():
        times.append(DataArray.attrs['time'])
        

    
    # Solution S22 -> P_star
    sxx_star = np.asarray(set_in.sel(field='S11').to_array()) # T x N
    syy_star = np.asarray(set_in.sel(field='S22').to_array()) # T x N
    sxy_star = np.asarray(set_in.sel(field='S12').to_array()) # T x N

    # time -> t_star
    t_star = times #data['t'] # T x 1 # (81,)
    
    # grid -> X_star
    gridd = nodal_coordinates[:,1:3]
    X_star = gridd # grid is N x 2 or shape (2760, 2)
    
    N = np.shape(X_star)[0] #X_star.shape[0]
    T = np.shape(t_star)[0] #t_star.shape[0]
    
    # Rearrange Data 
    XX = np.tile(X_star[:,0:1], (1,T)) # N x T # (2760, 81)
    YY = np.tile(X_star[:,1:2], (1,T)) # N x T # (2760, 81)
    TT = np.tile(t_star, (1,N)).T # NT x 1 # (223560, 1)
    
    UU = U_star[:,:,0].T # N x T
    VV = U_star[:,:,1].T # N x T
    SSxx = sxx_star.T # N x T
    SSyy = syy_star.T # N x T
    SSxy = sxy_star.T # N x T

    
    # Pick random data.
    if random:
        idx = np.random.choice(N*T, N, replace=False) # num_data
    else:
        idx = np.arange(0, N*T)
    
    x = XX
    y = YY
    t = t_star
    
    x = XX.flatten()[idx,None] # NT x 1
    y = YY.flatten()[idx,None] # NT x 1
    t = TT.flatten()[idx,None] # NT x 1
 
    
    u = UU # T x N # (81, 2760)
    v = VV # T x N # (81, 2760)
    
    u = UU.flatten()[idx,None] # NT x 1
    v = VV.flatten()[idx,None] # NT x 1
    sxx = SSxx.flatten()[idx,None] # NT x 1
    syy = SSyy.flatten()[idx,None] # NT x 1
    sxy = SSxy.flatten()[idx,None] # NT x 1
    
        

    return (x,y,t,u,v,sxx,syy,sxy)

# %%
x,y,t,u,v,sxx, syy, sxy = PrepareData(set_in, nodal_coordinates, times, random=True)

# check shapes
print(f'shape of x = {np.shape(x)}')
print(f'shape of y = {np.shape(y)}')
print(f'shape of t = {np.shape(t)}')
print(f'shape of u = {np.shape(u)}')
print(f'shape of v = {np.shape(v)}')
print(f'shape of sxx = {np.shape(sxx)}')
print(f'shape of syy = {np.shape(syy)}')
print(f'shape of sxy = {np.shape(sxy)}')
# Out:
# shape of x = (2760, 1)
# shape of y = (2760, 1)
# shape of t = (2760, 1)
# shape of u = (2760, 1)
# shape of v = (2760, 1)
# shape of sxx = (2760, 1)
# shape of syy = (2760, 1)
# shape of sxy = (2760, 1)

# %%
def plot():
    output_file_name = os.path.join(outputpath, outputprefix)
    #fname = output_file_name + "_{}_".format(actf) + "x".join([str(x) for x in layers])
    fname = output_file_name + "_{}_".format(actf)
    
    loss = np.loadtxt(fname+"_loss")
    times = np.loadtxt(fname+"_Time")
    fig, ax = plt.subplots(1, 2, figsize=(7, 3), dpi=300)
    cust_semilogx(ax[0], None, loss/loss[0], "epochs", "L/L0")
    cust_semilogx(ax[1], times, loss/loss[0], "time(s)", None)
    fig.subplots_adjust(left=0.1, right=0.9, bottom=0.15, top=0.9, wspace=0.3, hspace=0.2)
    plt.savefig("{}_loss.png".format(output_file_name))
    
    Xmesh = np.loadtxt(fname+"_Xmesh", delimiter=',')
    Ymesh = np.loadtxt(fname+"_Ymesh", delimiter=',')
    
    input_d = set_in.step_080
    data_d1 = np.asarray(input_d.sel(field='ux'))
    data_d2 = np.asarray(input_d.sel(field='uy'))
    data_d3 = np.asarray(input_d.sel(field='S11'))
    data_d4 = np.asarray(input_d.sel(field='S22'))
    data_d5 = np.asarray(input_d.sel(field='S12'))
    
    fig, ax = plt.subplots(2, 2, figsize=(8, 6), dpi=300)
    cust_pcolor(ax[0, 0], Xmesh, Ymesh, np.ones_like(Xmesh)*Emod, "E*={:.3f}".format(Emod))
    cust_pcolor(ax[0, 1], Xmesh, Ymesh, np.ones_like(Xmesh)*nu, "nu*={:.3f}".format(nu))
    Emods_pred = np.loadtxt(fname+"_Emods", delimiter=',')
    nus_pred = np.loadtxt(fname+"_nus", delimiter=',')
    cust_pcolor(ax[1, 0], Xmesh, Ymesh, np.ones_like(Xmesh)*Emods_pred, "E={:.3f}".format(Emods_pred.mean()))
    cust_pcolor(ax[1, 1], Xmesh, Ymesh, np.ones_like(Xmesh)*nus_pred, "nu={:.3f}".format(nus_pred.mean()))
    plt.savefig("{}_Parameters.png".format(output_file_name))
    
    fig, ax = plt.subplots(2, 2, figsize=(8, 6), dpi=300)
    plot_ux = rearrange(numx, numy, np.asarray(input_d.sel(field='ux')))
    plot_uy = rearrange(numx, numy, np.asarray(input_d.sel(field='uy')))
    print(np.shape(np.loadtxt(fname+"_U", delimiter=',')))
    cust_pcolor(ax[0, 0], Xmesh, Ymesh, plot_ux, "Ux*")
    cust_pcolor(ax[0, 1], Xmesh, Ymesh, plot_uy, "Uy*")
    cust_pcolor(ax[1, 0], Xmesh, Ymesh, np.loadtxt(fname+"_U", delimiter=','), "Ux")
    cust_pcolor(ax[1, 1], Xmesh, Ymesh, np.loadtxt(fname+"_V", delimiter=','), "Uy")
    plt.savefig("{}_Displacement.png".format(output_file_name))
    
    fig, ax = plt.subplots(2, 3, figsize=(11, 6), dpi=300)
    #plot_s11 = rearrange(numx, numy, np.asarray(input_d.sel(field='S11')))
    plot_s22 = rearrange(numx, numy, np.asarray(input_d.sel(field='S22')))
    #plot_s12 = rearrange(numx, numy, np.asarray(input_d.sel(field='S12')))
    plot_s11 = np.zeros([numy,numx])
    #plot_s22 = np.zeros([numx*numy,1])
    plot_s12 = np.zeros([numy,numx])
    cust_pcolor(ax[0, 0], Xmesh, Ymesh, plot_s11, "Sxx*")
    cust_pcolor(ax[0, 1], Xmesh, Ymesh, plot_s22, "Syy*")
    cust_pcolor(ax[0, 2], Xmesh, Ymesh, plot_s12, "Sxy*")
    cust_pcolor(ax[1, 0], Xmesh, Ymesh, np.loadtxt(fname+"_Sxx", delimiter=','), "Sxx")
    cust_pcolor(ax[1, 1], Xmesh, Ymesh, np.loadtxt(fname+"_Syy", delimiter=','), "Syy")
    cust_pcolor(ax[1, 2], Xmesh, Ymesh, np.loadtxt(fname+"_Sxy", delimiter=','), "Sxy")
    fig.subplots_adjust(left=0.1, right=0.9, bottom=0.05, top=0.9, wspace=0.3, hspace=0.2)
    plt.savefig("{}_Stress.png".format(output_file_name))
    
    #fig, ax = plt.subplots(2, 3, figsize=(11, 6), dpi=300)
    #cust_pcolor(ax[0, 0], Xmesh, Ymesh, strainxx([Xmesh, Ymesh]), "Exx*")
    #cust_pcolor(ax[0, 1], Xmesh, Ymesh, strainyy([Xmesh, Ymesh]), "Eyy*")
    #cust_pcolor(ax[0, 2], Xmesh, Ymesh, strainxy([Xmesh, Ymesh]), "Exy*")
    #cust_pcolor(ax[1, 0], Xmesh, Ymesh, np.loadtxt(fname+"_Exx", delimiter=','), "Exx")
    #cust_pcolor(ax[1, 1], Xmesh, Ymesh, np.loadtxt(fname+"_Eyy", delimiter=','), "Eyy")
    #cust_pcolor(ax[1, 2], Xmesh, Ymesh, np.loadtxt(fname+"_Exy", delimiter=','), "Exy")
    #fig.subplots_adjust(left=0.1, right=0.9, bottom=0.05, top=0.9, wspace=0.3, hspace=0.2)
    #plt.savefig("{}_Strain.png".format(output_file_name))

# %%
# Setting up cost function
#layers = 6
#neurons = 10

x = Variable("x", dtype='float64')
y = Variable("y", dtype='float64')
t = Variable("t", dtype='float64')

U = Functional("U", [x,y,t], layers, actf)
V = Functional("V", [x,y,t], layers, actf)
Sxx = Functional("Sxx", [x,y,t], layers, actf)
Syy = Functional("Syy", [x,y,t], layers, actf)
Sxy = Functional("Sxy", [x,y,t], layers, actf)

'''
Abaqus takes E and nu
The Navier form of equations takes mu and lambda

E = [mu*(3*lambda + 2*mu)] / [lambda + mu]
nu = lambda / [2*(lambda + mu)]

mu = E / [2*(1 + nu)]
lambda = [nu*E] / [(1 + nu)*(1 - 2*nu)]

Inputs values:
E  = 210 GPa
nu = 0.3

Expected values:
mu     =  80.769231 GPa
lambda = 121.15438 GPa
'''

Emods = Parameter(209.0, inputs=[x,y,t], name="Emods")
nus = Parameter(0.28, inputs=[x,y,t], name="nus")

# Strains
Exx = diff(U, x)
Eyy = diff(V, y)
Exy = 0.5*(diff(U,y) + diff(V,x))

# define constraints
d1 = Data(U)
d2 = Data(V)
d3 = Data(Sxx)
d4 = Data(Syy)
d5 = Data(Sxy)

# some constants
C11 = Emods/(1-(nus**2))
C22 = C11*nus
C33 = Emods/(1*(1-nus))

# Equations
c1 = Tie(Sxx, C11*Exx + C22*Eyy)
c2 = Tie(Syy, C11*Eyy + C22*Exx)
c3 = Tie(Sxy, C33*Exy)


if mode == 'train':
    
    # define output folder. 
    if not os.path.isdir(outputpath):
        os.mkdir(outputpath)
        
    output_file_name = os.path.join(outputpath, outputprefix)
    #fname = output_file_name + "_{}_".format(actf) + "x".join([str(x) for x in layers])
    fname = output_file_name + "_{}_".format(actf) 
    
    # Call in training data
    x_train, y_train, t_train, u_train, v_train, sxx_train, syy_train, sxy_train = PrepareData(set_in, nodal_coordinates, times, random=True)
    
    model = SciModel(
        inputs=[x, y, t],
        targets = [d1, d2, d3, d4, d5, c1, c2, c3],
        loss_func = "mse",
        #plot_to_file = "NS-Model.png"
    )
    
    input_data = [x_train, y_train, t_train]
    print(np.shape(input_data))

    # like an initial condition for c1, c2, c3, and c4
    data_d1 = u_train
    data_d2 = v_train
    data_d3 = sxx_train
    data_d4 = syy_train
    data_d5 = sxy_train
    data_c1 = 'zeros'
    data_c2 = 'zeros'
    data_c3 = 'zeros'
    target_data = [data_d1, data_d2, data_d3, data_d4, data_d5, data_c1, data_c2, data_c3]

    ## hyper parameter define

    #Epochs= 100
    #Batch_size=100
    #Learning_rate=0.001
    #Reduce_lr_after=1000
    
#log the data

    # Prepare training data 
    ## Training grid 
    XMIN, XMAX = 0.0, 3000.0 #1.0
    YMIN, YMAX = -1500., 1500. # 0.0, 1.0
    Xmesh = np.linspace(XMIN, XMAX, numx).reshape((-1, 1))
    Ymesh = np.linspace(YMIN, YMAX, numy).reshape((-1, 1))
    X, Y = np.meshgrid(Xmesh, Ymesh)
    
    
    
    #input_data = [grid[0],grid[1]]
    
    fname_out = fname +'_WEIGHTS'
    
    ##train PINN
    training_time = time.time()
    history = model.train(
        x_true=input_data,
        y_true=target_data,
        epochs= epochs,
        batch_size= batchsize,
        shuffle=shuffle,
        learning_rate= learningrate,
        #reduce_lr_after= Reduce_lr_after,
        stop_after = stopafter,
        #stop_loss_value=1e-8,
        verbose=verbose,
    )
    
    training_time = time.time() - training_time
    
    for loss in history.history:
        np.savetxt(fname+"_{}".format("_".join(loss.split("/"))), 
                    np.array(history.history[loss]).reshape(-1, 1))
    
    '''
    Old from Yang
    ## logs and plots
    model.save_weights('elasticity_train.hdf5')
    ## print iterated parameters value
    print("Emod: {},  lamb: {}".format(Emods.value, lamb.value))
    with open(f'../logs/log_layers{layers}_neurons{neurons}_epochs{Epochs}_batchsize{Batch_size}_learning_rate{Learning_rate}_reduce_lr_after{Reduce_lr_after}/parameters_{layers}_{neurons}.txt', 'w') as f:
        f.write(f"mu: {mu.value},  lamb: {lamb.value}")
    print("mu: {},  lamb: {}".format(mu.value, lamb.value))
    
    ## print loss function value
    print("loss: {}".format(history.history['loss']))
    with open(f'../logs/log_layers{layers}_neurons{neurons}_epochs{Epochs}_batchsize{Batch_size}_learning_rate{Learning_rate}_reduce_lr_after{Reduce_lr_after}/loss_{layers}_{neurons}.txt', 'w') as f:
        f.write(f"loss: {history.history['loss']}")
    ## plot loss function
    plt.figure(f'Train_Loss_{layers}_{neurons}')
    plt.semilogy(history.history['loss'])
    plt.xlabel('epochs')
    plt.ylabel('loss')
    plt.savefig(f'../logs/log_layers{layers}_neurons{neurons}_epochs{Epochs}_batchsize{Batch_size}_learning_rate{Learning_rate}_reduce_lr_after{Reduce_lr_after}/loss_{layers}_{neurons}.png')
    plt.semilogy(history.history['loss'])
    plt.xlabel('epochs')
    plt.ylabel('loss')
    '''
    
    time_steps = np.linspace(0, training_time, len(history.history["loss"]))
    np.savetxt(fname+"_Time", time_steps.reshape(-1,1))

    # Post process the trained model.
    
    Xmesh_plot = np.linspace(XMIN, XMAX, numxplot).reshape((-1, 1))
    Ymesh_plot = np.linspace(YMIN, YMAX, numyplot).reshape((-1, 1))
    X_plot, Y_plot = np.meshgrid(Xmesh_plot, Ymesh_plot)
    input_plot = [X_plot.reshape(-1, 1), Y_plot.reshape(-1, 1),t_train]

    Emods_pred = Emods.eval(model, input_plot)
    nus_pred = nus.eval(model, input_plot)
    U_pred = U.eval(model, input_plot)
    V_pred = V.eval(model, input_plot)
    Exx_pred = Exx.eval(model, input_plot)
    Eyy_pred = Eyy.eval(model, input_plot)
    Exy_pred = Exy.eval(model, input_plot)
    Sxx_pred = Sxx.eval(model, input_plot)
    Syy_pred = Syy.eval(model, input_plot)
    Sxy_pred = Sxy.eval(model, input_plot)
    
        
    np.savetxt(fname+"_Xmesh", X_plot, delimiter=', ')
    np.savetxt(fname+"_Ymesh", Y_plot, delimiter=', ')
    np.savetxt(fname+"_Emods", Emods_pred, delimiter=', ')
    np.savetxt(fname+"_nus", nus_pred, delimiter=', ')
    np.savetxt(fname+"_U", U_pred.reshape(X_plot.shape), delimiter=', ')
    np.savetxt(fname+"_V", V_pred.reshape(X_plot.shape), delimiter=', ')
    np.savetxt(fname+"_Exx", Exx_pred.reshape(X_plot.shape), delimiter=', ')
    np.savetxt(fname+"_Eyy", Eyy_pred.reshape(X_plot.shape), delimiter=', ')
    np.savetxt(fname+"_Exy", Exy_pred.reshape(X_plot.shape), delimiter=', ')
    np.savetxt(fname+"_Sxx", Sxx_pred.reshape(X_plot.shape), delimiter=', ')
    np.savetxt(fname+"_Syy", Syy_pred.reshape(X_plot.shape), delimiter=', ')
    np.savetxt(fname+"_Sxy", Sxy_pred.reshape(X_plot.shape), delimiter=', ')
# Out:
# (3, 2760, 1)
#
# Total samples: 2760
# Batch size: 100
# Total batches: 28
# 2022-04-24 20:11:39.165117: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/mnt/c/Windows/System32/xdmf/build/lib:/mnt/c/Windows/System32/yaml-cpp/build
# 2022-04-24 20:11:39.165204: W tensorflow/stream_executor/cuda/cuda_driver.cc:326] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-04-24 20:11:39.165282: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (DESKTOP-KVJB0RN): /proc/driver/nvidia/version does not exist
# 2022-04-24 20:11:39.165634: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-04-24 20:11:39.208567: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 1608000000 Hz
# Epoch 1/1000
# 28/28 - 2s - loss: 7544.2177 - U_loss: 0.1164 - V_loss: 0.1229 - Sxx_loss: 0.0428 - Syy_loss: 7528.9816 - Sxy_loss: 0.0309 - sub_loss: 0.7792 - sub_2_loss: 29.4030 - sub_3_loss: 1.0238 - lr: 0.0010 - time: 1.6780
# Epoch 2/1000
# 28/28 - 0s - loss: 6536.1472 - U_loss: 0.0580 - V_loss: 0.1930 - Sxx_loss: 0.0104 - Syy_loss: 6361.7366 - Sxy_loss: 0.0054 - sub_loss: 0.5794 - sub_2_loss: 162.8487 - sub_3_loss: 0.6688 - lr: 0.0010 - time: 0.1660
# Epoch 3/1000
# 28/28 - 0s - loss: 6097.3320 - U_loss: 0.0494 - V_loss: 0.2911 - Sxx_loss: 0.0034 - Syy_loss: 5798.5235 - Sxy_loss: 0.0018 - sub_loss: 0.1772 - sub_2_loss: 289.4886 - sub_3_loss: 0.2396 - lr: 0.0010 - time: 0.1834
# Epoch 4/1000
# 28/28 - 0s - loss: 5829.1037 - U_loss: 0.0790 - V_loss: 0.6211 - Sxx_loss: 0.0030 - Syy_loss: 5427.8983 - Sxy_loss: 0.0026 - sub_loss: 0.2222 - sub_2_loss: 404.7050 - sub_3_loss: 0.2314 - lr: 0.0010 - time: 0.1830
# Epoch 5/1000
# 28/28 - 0s - loss: 5624.8610 - U_loss: 0.0622 - V_loss: 0.8406 - Sxx_loss: 0.0046 - Syy_loss: 5081.7861 - Sxy_loss: 0.0075 - sub_loss: 0.3505 - sub_2_loss: 520.2857 - sub_3_loss: 0.6259 - lr: 0.0010 - time: 0.1835
# Epoch 6/1000
# 28/28 - 0s - loss: 5477.8998 - U_loss: 0.0703 - V_loss: 1.0222 - Sxx_loss: 0.0027 - Syy_loss: 4837.2300 - Sxy_loss: 0.0070 - sub_loss: 0.1986 - sub_2_loss: 636.5904 - sub_3_loss: 0.4475 - lr: 0.0010 - time: 0.1837
# Epoch 7/1000
# 28/28 - 0s - loss: 5364.6251 - U_loss: 0.0686 - V_loss: 1.8986 - Sxx_loss: 0.0052 - Syy_loss: 4602.7857 - Sxy_loss: 0.0139 - sub_loss: 0.4700 - sub_2_loss: 746.9431 - sub_3_loss: 0.9015 - lr: 0.0010 - time: 0.1749
# Epoch 8/1000
# 28/28 - 0s - loss: 5285.3539 - U_loss: 0.0695 - V_loss: 1.1832 - Sxx_loss: 0.0042 - Syy_loss: 4414.9936 - Sxy_loss: 0.0144 - sub_loss: 0.3104 - sub_2_loss: 858.3128 - sub_3_loss: 0.8331 - lr: 0.0010 - time: 0.1855
# Epoch 9/1000
# 28/28 - 0s - loss: 5222.7155 - U_loss: 0.0675 - V_loss: 1.8508 - Sxx_loss: 0.0043 - Syy_loss: 4255.4279 - Sxy_loss: 0.0104 - sub_loss: 0.3958 - sub_2_loss: 955.1360 - sub_3_loss: 0.7581 - lr: 0.0010 - time: 0.1801
# Epoch 10/1000
# 28/28 - 0s - loss: 5179.0319 - U_loss: 0.0588 - V_loss: 1.8883 - Sxx_loss: 0.0041 - Syy_loss: 4140.5846 - Sxy_loss: 0.0134 - sub_loss: 0.3392 - sub_2_loss: 1043.9790 - sub_3_loss: 0.7252 - lr: 0.0010 - time: 0.1834
# Epoch 11/1000
# 28/28 - 0s - loss: 5147.8003 - U_loss: 0.0629 - V_loss: 2.5136 - Sxx_loss: 0.0066 - Syy_loss: 4021.8129 - Sxy_loss: 0.0183 - sub_loss: 0.4940 - sub_2_loss: 1124.9225 - sub_3_loss: 0.9226 - lr: 0.0010 - time: 0.1838
# Epoch 12/1000
# 28/28 - 0s - loss: 5126.3924 - U_loss: 0.0643 - V_loss: 2.5685 - Sxx_loss: 0.0058 - Syy_loss: 3934.5639 - Sxy_loss: 0.0109 - sub_loss: 0.4710 - sub_2_loss: 1199.1061 - sub_3_loss: 1.2739 - lr: 0.0010 - time: 0.1820
# Epoch 13/1000
# 28/28 - 0s - loss: 5114.8347 - U_loss: 0.0689 - V_loss: 2.2303 - Sxx_loss: 0.0064 - Syy_loss: 3841.8310 - Sxy_loss: 0.0259 - sub_loss: 0.3500 - sub_2_loss: 1268.2113 - sub_3_loss: 0.6661 - lr: 0.0010 - time: 0.1853
# Epoch 14/1000
# 28/28 - 0s - loss: 5102.6463 - U_loss: 0.0612 - V_loss: 2.2380 - Sxx_loss: 0.0059 - Syy_loss: 3786.8158 - Sxy_loss: 0.0143 - sub_loss: 0.4689 - sub_2_loss: 1313.9514 - sub_3_loss: 0.9883 - lr: 0.0010 - time: 0.1804
# Epoch 15/1000
# 28/28 - 0s - loss: 5096.1558 - U_loss: 0.0631 - V_loss: 2.7965 - Sxx_loss: 0.0121 - Syy_loss: 3739.0142 - Sxy_loss: 0.0153 - sub_loss: 0.5589 - sub_2_loss: 1358.3025 - sub_3_loss: 0.6859 - lr: 0.0010 - time: 0.1850
# Epoch 16/1000
# 28/28 - 0s - loss: 5088.7136 - U_loss: 0.0556 - V_loss: 2.9265 - Sxx_loss: 0.0079 - Syy_loss: 3670.5955 - Sxy_loss: 0.0247 - sub_loss: 0.6422 - sub_2_loss: 1400.0248 - sub_3_loss: 1.3346 - lr: 0.0010 - time: 0.1802
# Epoch 17/1000
# 28/28 - 0s - loss: 5086.1704 - U_loss: 0.1128 - V_loss: 3.0218 - Sxx_loss: 0.0095 - Syy_loss: 3663.6305 - Sxy_loss: 0.0161 - sub_loss: 0.9218 - sub_2_loss: 1424.9883 - sub_3_loss: 1.1152 - lr: 0.0010 - time: 0.1796
# Epoch 18/1000
# 28/28 - 0s - loss: 5083.4407 - U_loss: 0.1529 - V_loss: 2.9456 - Sxx_loss: 0.0153 - Syy_loss: 3619.8011 - Sxy_loss: 0.0366 - sub_loss: 1.2069 - sub_2_loss: 1447.7182 - sub_3_loss: 1.3028 - lr: 0.0010 - time: 0.1810
# Epoch 19/1000
# 28/28 - 0s - loss: 5083.7045 - U_loss: 0.1393 - V_loss: 2.3812 - Sxx_loss: 0.0136 - Syy_loss: 3616.0017 - Sxy_loss: 0.0238 - sub_loss: 0.5337 - sub_2_loss: 1456.4246 - sub_3_loss: 1.0778 - lr: 0.0010 - time: 0.1787
# Epoch 20/1000
# 28/28 - 0s - loss: 5082.8300 - U_loss: 0.0662 - V_loss: 3.2237 - Sxx_loss: 0.0053 - Syy_loss: 3604.9839 - Sxy_loss: 0.0230 - sub_loss: 0.3786 - sub_2_loss: 1485.2903 - sub_3_loss: 1.3861 - lr: 0.0010 - time: 0.1815
# Epoch 21/1000
# 28/28 - 0s - loss: 5080.0116 - U_loss: 0.0513 - V_loss: 3.4289 - Sxx_loss: 0.0069 - Syy_loss: 3581.0318 - Sxy_loss: 0.0482 - sub_loss: 0.5667 - sub_2_loss: 1492.4572 - sub_3_loss: 2.1362 - lr: 0.0010 - time: 0.1814
# Epoch 22/1000
# 28/28 - 0s - loss: 5085.5167 - U_loss: 0.0527 - V_loss: 3.7635 - Sxx_loss: 0.0054 - Syy_loss: 3573.0981 - Sxy_loss: 0.0236 - sub_loss: 0.2528 - sub_2_loss: 1512.1291 - sub_3_loss: 0.9987 - lr: 0.0010 - time: 0.1818
# Epoch 23/1000
# 28/28 - 0s - loss: 5081.2504 - U_loss: 0.0457 - V_loss: 2.9301 - Sxx_loss: 0.0039 - Syy_loss: 3563.8932 - Sxy_loss: 0.0123 - sub_loss: 0.3506 - sub_2_loss: 1511.6890 - sub_3_loss: 1.1922 - lr: 0.0010 - time: 0.1773
# Epoch 24/1000
# 28/28 - 0s - loss: 5083.1286 - U_loss: 0.0453 - V_loss: 3.7839 - Sxx_loss: 0.0041 - Syy_loss: 3555.6835 - Sxy_loss: 0.0197 - sub_loss: 0.3192 - sub_2_loss: 1518.0781 - sub_3_loss: 1.4554 - lr: 0.0010 - time: 0.1809
# Epoch 25/1000
# 28/28 - 0s - loss: 5081.0393 - U_loss: 0.0491 - V_loss: 3.4366 - Sxx_loss: 0.0042 - Syy_loss: 3554.8814 - Sxy_loss: 0.0166 - sub_loss: 0.2996 - sub_2_loss: 1513.6949 - sub_3_loss: 1.2974 - lr: 0.0010 - time: 0.1866
# Epoch 26/1000
# 28/28 - 0s - loss: 5084.9355 - U_loss: 0.0475 - V_loss: 2.9333 - Sxx_loss: 0.0020 - Syy_loss: 3544.6793 - Sxy_loss: 0.0185 - sub_loss: 0.1940 - sub_2_loss: 1540.8581 - sub_3_loss: 0.8084 - lr: 0.0010 - time: 0.1769
# Epoch 27/1000
# 28/28 - 0s - loss: 5081.0231 - U_loss: 0.0417 - V_loss: 5.0357 - Sxx_loss: 0.0044 - Syy_loss: 3548.1441 - Sxy_loss: 0.0223 - sub_loss: 0.4186 - sub_2_loss: 1524.7535 - sub_3_loss: 1.5506 - lr: 0.0010 - time: 0.1791
# Epoch 28/1000
# 28/28 - 0s - loss: 5085.9804 - U_loss: 0.0484 - V_loss: 2.0351 - Sxx_loss: 0.0023 - Syy_loss: 3549.2952 - Sxy_loss: 0.0108 - sub_loss: 0.1891 - sub_2_loss: 1536.4400 - sub_3_loss: 0.6557 - lr: 0.0010 - time: 0.1846
# Epoch 29/1000
# 28/28 - 0s - loss: 5083.6647 - U_loss: 0.0461 - V_loss: 3.3656 - Sxx_loss: 0.0028 - Syy_loss: 3552.5661 - Sxy_loss: 0.0138 - sub_loss: 0.2209 - sub_2_loss: 1534.6742 - sub_3_loss: 1.1612 - lr: 0.0010 - time: 0.1806
# Epoch 30/1000
# 28/28 - 0s - loss: 5082.8348 - U_loss: 0.0467 - V_loss: 3.4563 - Sxx_loss: 0.0023 - Syy_loss: 3539.8391 - Sxy_loss: 0.0141 - sub_loss: 0.2353 - sub_2_loss: 1523.8961 - sub_3_loss: 1.0500 - lr: 0.0010 - time: 0.1790
# Epoch 31/1000
# 28/28 - 0s - loss: 5082.3353 - U_loss: 0.0460 - V_loss: 3.7886 - Sxx_loss: 0.0054 - Syy_loss: 3536.8677 - Sxy_loss: 0.0259 - sub_loss: 0.2742 - sub_2_loss: 1534.9866 - sub_3_loss: 1.2313 - lr: 0.0010 - time: 0.1801
# Epoch 32/1000
# 28/28 - 0s - loss: 5078.9792 - U_loss: 0.0506 - V_loss: 3.7871 - Sxx_loss: 0.0040 - Syy_loss: 3538.7945 - Sxy_loss: 0.0366 - sub_loss: 0.2389 - sub_2_loss: 1526.9187 - sub_3_loss: 1.5142 - lr: 0.0010 - time: 0.1918
# Epoch 33/1000
# 28/28 - 0s - loss: 5083.9871 - U_loss: 0.0464 - V_loss: 3.8563 - Sxx_loss: 0.0042 - Syy_loss: 3555.1752 - Sxy_loss: 0.0261 - sub_loss: 0.1854 - sub_2_loss: 1517.2637 - sub_3_loss: 1.2576 - lr: 0.0010 - time: 0.1813
# Epoch 34/1000
# 28/28 - 0s - loss: 5080.5223 - U_loss: 0.0439 - V_loss: 3.8183 - Sxx_loss: 0.0077 - Syy_loss: 3533.4236 - Sxy_loss: 0.0143 - sub_loss: 0.2005 - sub_2_loss: 1536.0465 - sub_3_loss: 1.3190 - lr: 0.0010 - time: 0.1823
# Epoch 35/1000
# 28/28 - 0s - loss: 5079.1072 - U_loss: 0.0491 - V_loss: 4.2705 - Sxx_loss: 0.0052 - Syy_loss: 3562.9270 - Sxy_loss: 0.0270 - sub_loss: 0.2213 - sub_2_loss: 1520.7394 - sub_3_loss: 2.3616 - lr: 0.0010 - time: 0.1797
# Epoch 36/1000
# 28/28 - 0s - loss: 5080.7275 - U_loss: 0.0432 - V_loss: 3.6427 - Sxx_loss: 0.0036 - Syy_loss: 3549.0796 - Sxy_loss: 0.0243 - sub_loss: 0.1333 - sub_2_loss: 1530.4468 - sub_3_loss: 2.0514 - lr: 0.0010 - time: 0.1838
# Epoch 37/1000
# 28/28 - 0s - loss: 5076.6168 - U_loss: 0.0414 - V_loss: 4.2043 - Sxx_loss: 0.0047 - Syy_loss: 3544.1301 - Sxy_loss: 0.0128 - sub_loss: 0.1904 - sub_2_loss: 1528.1383 - sub_3_loss: 1.7272 - lr: 0.0010 - time: 0.1812
# Epoch 38/1000
# 28/28 - 0s - loss: 5079.8114 - U_loss: 0.0420 - V_loss: 4.1387 - Sxx_loss: 0.0033 - Syy_loss: 3536.9663 - Sxy_loss: 0.0172 - sub_loss: 0.1026 - sub_2_loss: 1531.7417 - sub_3_loss: 1.3892 - lr: 0.0010 - time: 0.1846
# Epoch 39/1000
# 28/28 - 0s - loss: 5083.6472 - U_loss: 0.0390 - V_loss: 3.6102 - Sxx_loss: 0.0015 - Syy_loss: 3542.5175 - Sxy_loss: 0.0156 - sub_loss: 0.0697 - sub_2_loss: 1531.4179 - sub_3_loss: 1.5679 - lr: 0.0010 - time: 0.1786
# Epoch 40/1000
# 28/28 - 0s - loss: 5081.5870 - U_loss: 0.0381 - V_loss: 3.7590 - Sxx_loss: 0.0015 - Syy_loss: 3547.1496 - Sxy_loss: 0.0176 - sub_loss: 0.0745 - sub_2_loss: 1543.5500 - sub_3_loss: 1.9192 - lr: 0.0010 - time: 0.1804
# Epoch 41/1000
# 28/28 - 0s - loss: 5084.2481 - U_loss: 0.0356 - V_loss: 4.0313 - Sxx_loss: 6.8790e-04 - Syy_loss: 3525.3323 - Sxy_loss: 0.0190 - sub_loss: 0.0484 - sub_2_loss: 1544.5893 - sub_3_loss: 1.9709 - lr: 0.0010 - time: 0.1825
# Epoch 42/1000
# 28/28 - 0s - loss: 5081.5600 - U_loss: 0.0369 - V_loss: 3.6220 - Sxx_loss: 6.6356e-04 - Syy_loss: 3548.8872 - Sxy_loss: 0.0232 - sub_loss: 0.0280 - sub_2_loss: 1525.2997 - sub_3_loss: 1.9768 - lr: 0.0010 - time: 0.1801
# Epoch 43/1000
# 28/28 - 0s - loss: 5080.9367 - U_loss: 0.0356 - V_loss: 3.5654 - Sxx_loss: 3.2867e-04 - Syy_loss: 3551.3362 - Sxy_loss: 0.0215 - sub_loss: 0.0197 - sub_2_loss: 1522.2160 - sub_3_loss: 1.8607 - lr: 0.0010 - time: 0.1931
# Epoch 44/1000
# 28/28 - 0s - loss: 5080.2937 - U_loss: 0.0350 - V_loss: 4.1175 - Sxx_loss: 1.4998e-04 - Syy_loss: 3532.4131 - Sxy_loss: 0.0192 - sub_loss: 0.0101 - sub_2_loss: 1538.9410 - sub_3_loss: 1.7314 - lr: 0.0010 - time: 0.1751
# Epoch 45/1000
# 28/28 - 0s - loss: 5085.1860 - U_loss: 0.0335 - V_loss: 3.5404 - Sxx_loss: 7.4842e-05 - Syy_loss: 3555.6871 - Sxy_loss: 0.0161 - sub_loss: 0.0020 - sub_2_loss: 1525.9932 - sub_3_loss: 1.6426 - lr: 0.0010 - time: 0.1811
# Epoch 46/1000
# 28/28 - 0s - loss: 5084.3149 - U_loss: 0.0321 - V_loss: 3.1421 - Sxx_loss: 1.6081e-05 - Syy_loss: 3543.2142 - Sxy_loss: 0.0153 - sub_loss: 0.0010 - sub_2_loss: 1541.6977 - sub_3_loss: 1.5000 - lr: 0.0010 - time: 0.1823
# Epoch 47/1000
# 28/28 - 0s - loss: 5085.6558 - U_loss: 0.0318 - V_loss: 4.4855 - Sxx_loss: 1.7313e-05 - Syy_loss: 3550.2242 - Sxy_loss: 0.0133 - sub_loss: 6.8297e-04 - sub_2_loss: 1541.6282 - sub_3_loss: 1.2518 - lr: 0.0010 - time: 0.1856
# Epoch 48/1000
# 28/28 - 0s - loss: 5080.2806 - U_loss: 0.0315 - V_loss: 4.4338 - Sxx_loss: 3.6108e-06 - Syy_loss: 3557.5703 - Sxy_loss: 0.0173 - sub_loss: 6.7551e-04 - sub_2_loss: 1518.6699 - sub_3_loss: 1.3192 - lr: 0.0010 - time: 0.1786
# Epoch 49/1000
# 28/28 - 0s - loss: 5084.4660 - U_loss: 0.0315 - V_loss: 3.9182 - Sxx_loss: 8.5209e-06 - Syy_loss: 3547.2753 - Sxy_loss: 0.0197 - sub_loss: 0.0012 - sub_2_loss: 1528.9511 - sub_3_loss: 1.3218 - lr: 0.0010 - time: 0.1842
# Epoch 50/1000
# 28/28 - 0s - loss: 5077.7943 - U_loss: 0.0317 - V_loss: 4.5221 - Sxx_loss: 4.8359e-05 - Syy_loss: 3563.7730 - Sxy_loss: 0.0312 - sub_loss: 0.0071 - sub_2_loss: 1521.8332 - sub_3_loss: 1.5633 - lr: 0.0010 - time: 0.1802
# Epoch 51/1000
# 28/28 - 0s - loss: 5083.3535 - U_loss: 0.0319 - V_loss: 3.8186 - Sxx_loss: 2.9652e-05 - Syy_loss: 3545.5842 - Sxy_loss: 0.0147 - sub_loss: 0.0042 - sub_2_loss: 1536.2897 - sub_3_loss: 1.1110 - lr: 0.0010 - time: 0.1824
# Epoch 52/1000
# 28/28 - 0s - loss: 5081.7627 - U_loss: 0.0311 - V_loss: 4.5100 - Sxx_loss: 4.4831e-05 - Syy_loss: 3529.3329 - Sxy_loss: 0.0105 - sub_loss: 0.0044 - sub_2_loss: 1538.4645 - sub_3_loss: 1.0445 - lr: 0.0010 - time: 0.1788
# Epoch 53/1000
# 28/28 - 0s - loss: 5083.3436 - U_loss: 0.0315 - V_loss: 4.2359 - Sxx_loss: 4.0678e-05 - Syy_loss: 3546.7417 - Sxy_loss: 0.0140 - sub_loss: 0.0061 - sub_2_loss: 1541.3167 - sub_3_loss: 1.0415 - lr: 0.0010 - time: 0.1792
# Epoch 54/1000
# 28/28 - 0s - loss: 5082.3946 - U_loss: 0.0321 - V_loss: 3.7388 - Sxx_loss: 2.1965e-05 - Syy_loss: 3557.3075 - Sxy_loss: 0.0072 - sub_loss: 0.0013 - sub_2_loss: 1528.0629 - sub_3_loss: 1.0795 - lr: 0.0010 - time: 0.1895
# Epoch 55/1000
# 28/28 - 0s - loss: 5076.4663 - U_loss: 0.0313 - V_loss: 4.0395 - Sxx_loss: 1.9915e-05 - Syy_loss: 3548.9666 - Sxy_loss: 0.0215 - sub_loss: 0.0032 - sub_2_loss: 1522.9145 - sub_3_loss: 2.2893 - lr: 0.0010 - time: 0.1819
# Epoch 56/1000
# 28/28 - 0s - loss: 5076.4080 - U_loss: 0.0321 - V_loss: 4.7095 - Sxx_loss: 1.4129e-05 - Syy_loss: 3529.0801 - Sxy_loss: 0.0281 - sub_loss: 8.7056e-04 - sub_2_loss: 1534.5645 - sub_3_loss: 1.3844 - lr: 0.0010 - time: 0.1805
# Epoch 57/1000
# 28/28 - 0s - loss: 5079.3916 - U_loss: 0.0321 - V_loss: 4.3597 - Sxx_loss: 4.3603e-06 - Syy_loss: 3535.4976 - Sxy_loss: 0.0119 - sub_loss: 2.8953e-04 - sub_2_loss: 1534.4321 - sub_3_loss: 1.6655 - lr: 0.0010 - time: 0.1814
# Epoch 58/1000
# 28/28 - 0s - loss: 5078.6387 - U_loss: 0.0314 - V_loss: 4.2566 - Sxx_loss: 2.8025e-06 - Syy_loss: 3539.0975 - Sxy_loss: 0.0150 - sub_loss: 5.0122e-04 - sub_2_loss: 1540.6293 - sub_3_loss: 1.7447 - lr: 0.0010 - time: 0.1789
# Epoch 59/1000
# 28/28 - 0s - loss: 5079.8903 - U_loss: 0.0314 - V_loss: 4.2484 - Sxx_loss: 3.6628e-06 - Syy_loss: 3542.3120 - Sxy_loss: 0.0176 - sub_loss: 2.9345e-04 - sub_2_loss: 1535.8662 - sub_3_loss: 1.2436 - lr: 0.0010 - time: 0.1887
# Epoch 60/1000
# 28/28 - 0s - loss: 5082.3815 - U_loss: 0.0311 - V_loss: 4.1737 - Sxx_loss: 5.0311e-06 - Syy_loss: 3531.2832 - Sxy_loss: 0.0102 - sub_loss: 5.3068e-04 - sub_2_loss: 1544.3514 - sub_3_loss: 0.7780 - lr: 0.0010 - time: 0.1788
# Epoch 61/1000
# 28/28 - 0s - loss: 5078.8300 - U_loss: 0.0312 - V_loss: 5.0396 - Sxx_loss: 2.6540e-06 - Syy_loss: 3532.0032 - Sxy_loss: 0.0137 - sub_loss: 4.1748e-04 - sub_2_loss: 1530.4365 - sub_3_loss: 0.9187 - lr: 0.0010 - time: 0.1791
# Epoch 62/1000
# 28/28 - 0s - loss: 5086.1244 - U_loss: 0.0308 - V_loss: 2.8553 - Sxx_loss: 4.1398e-06 - Syy_loss: 3542.9213 - Sxy_loss: 0.0058 - sub_loss: 3.8010e-04 - sub_2_loss: 1528.7806 - sub_3_loss: 0.8695 - lr: 0.0010 - time: 0.1821
# Epoch 63/1000
# 28/28 - 0s - loss: 5082.2659 - U_loss: 0.0309 - V_loss: 4.3325 - Sxx_loss: 7.7151e-06 - Syy_loss: 3547.6114 - Sxy_loss: 0.0043 - sub_loss: 4.0469e-04 - sub_2_loss: 1526.0598 - sub_3_loss: 0.6699 - lr: 0.0010 - time: 0.1768
# Epoch 64/1000
# 28/28 - 0s - loss: 5083.6290 - U_loss: 0.0309 - V_loss: 2.5133 - Sxx_loss: 7.3329e-06 - Syy_loss: 3543.7059 - Sxy_loss: 0.0093 - sub_loss: 5.6915e-04 - sub_2_loss: 1538.2497 - sub_3_loss: 0.7695 - lr: 0.0010 - time: 0.1852
# Epoch 65/1000
# 28/28 - 0s - loss: 5083.1435 - U_loss: 0.0314 - V_loss: 3.2268 - Sxx_loss: 4.3304e-06 - Syy_loss: 3565.6333 - Sxy_loss: 0.0138 - sub_loss: 3.6766e-04 - sub_2_loss: 1524.8165 - sub_3_loss: 0.7894 - lr: 0.0010 - time: 0.1900
# Epoch 66/1000
# 28/28 - 0s - loss: 5081.2341 - U_loss: 0.0306 - V_loss: 5.5516 - Sxx_loss: 6.5002e-06 - Syy_loss: 3547.3634 - Sxy_loss: 0.0140 - sub_loss: 7.4217e-04 - sub_2_loss: 1524.4613 - sub_3_loss: 1.5487 - lr: 0.0010 - time: 0.1862
# Epoch 67/1000
# 28/28 - 0s - loss: 5081.7406 - U_loss: 0.0309 - V_loss: 3.3585 - Sxx_loss: 6.2341e-06 - Syy_loss: 3543.7749 - Sxy_loss: 0.0120 - sub_loss: 5.2099e-04 - sub_2_loss: 1530.1296 - sub_3_loss: 1.2550 - lr: 0.0010 - time: 0.1878
# Epoch 68/1000
# 28/28 - 0s - loss: 5082.1063 - U_loss: 0.0311 - V_loss: 3.9253 - Sxx_loss: 3.2179e-06 - Syy_loss: 3542.5441 - Sxy_loss: 0.0127 - sub_loss: 2.9902e-04 - sub_2_loss: 1528.2075 - sub_3_loss: 1.7486 - lr: 0.0010 - time: 0.1864
# Epoch 69/1000
# 28/28 - 0s - loss: 5083.7855 - U_loss: 0.0307 - V_loss: 4.0218 - Sxx_loss: 2.2216e-06 - Syy_loss: 3543.2542 - Sxy_loss: 0.0105 - sub_loss: 3.6404e-04 - sub_2_loss: 1533.7293 - sub_3_loss: 0.9814 - lr: 0.0010 - time: 0.1874
# Epoch 70/1000
# 28/28 - 0s - loss: 5083.5176 - U_loss: 0.0307 - V_loss: 3.3787 - Sxx_loss: 4.1025e-06 - Syy_loss: 3538.0503 - Sxy_loss: 0.0176 - sub_loss: 4.7708e-04 - sub_2_loss: 1542.3027 - sub_3_loss: 1.4372 - lr: 0.0010 - time: 0.1888
# Epoch 71/1000
# 28/28 - 0s - loss: 5081.2571 - U_loss: 0.0305 - V_loss: 3.7190 - Sxx_loss: 3.7292e-06 - Syy_loss: 3547.2854 - Sxy_loss: 0.0235 - sub_loss: 5.6327e-04 - sub_2_loss: 1532.6335 - sub_3_loss: 1.4195 - lr: 0.0010 - time: 0.1836
# Epoch 72/1000
# 28/28 - 0s - loss: 5074.3578 - U_loss: 0.0307 - V_loss: 4.7218 - Sxx_loss: 3.5621e-06 - Syy_loss: 3557.2676 - Sxy_loss: 0.0194 - sub_loss: 4.2857e-04 - sub_2_loss: 1516.7657 - sub_3_loss: 1.6563 - lr: 0.0010 - time: 0.1889
# Epoch 73/1000
# 28/28 - 0s - loss: 5083.0586 - U_loss: 0.0306 - V_loss: 4.0207 - Sxx_loss: 7.3826e-06 - Syy_loss: 3547.3977 - Sxy_loss: 0.0083 - sub_loss: 3.8055e-04 - sub_2_loss: 1540.1613 - sub_3_loss: 1.1002 - lr: 0.0010 - time: 0.1851
# Epoch 74/1000
# 28/28 - 0s - loss: 5081.5362 - U_loss: 0.0332 - V_loss: 4.4452 - Sxx_loss: 3.1790e-05 - Syy_loss: 3555.9346 - Sxy_loss: 0.0153 - sub_loss: 0.0056 - sub_2_loss: 1529.2631 - sub_3_loss: 1.3210 - lr: 0.0010 - time: 0.1847
# Epoch 75/1000
# 28/28 - 0s - loss: 5080.9830 - U_loss: 0.0322 - V_loss: 3.9604 - Sxx_loss: 4.2029e-05 - Syy_loss: 3533.0274 - Sxy_loss: 0.0097 - sub_loss: 0.0057 - sub_2_loss: 1552.7842 - sub_3_loss: 1.0133 - lr: 0.0010 - time: 0.1888
# Epoch 76/1000
# 28/28 - 0s - loss: 5077.3029 - U_loss: 0.0349 - V_loss: 4.9693 - Sxx_loss: 1.4770e-05 - Syy_loss: 3551.5234 - Sxy_loss: 0.0175 - sub_loss: 7.1298e-04 - sub_2_loss: 1527.0864 - sub_3_loss: 1.8212 - lr: 0.0010 - time: 0.1816
# Epoch 77/1000
# 28/28 - 0s - loss: 5081.8643 - U_loss: 0.0382 - V_loss: 3.9957 - Sxx_loss: 4.5282e-05 - Syy_loss: 3521.2709 - Sxy_loss: 0.0144 - sub_loss: 0.0047 - sub_2_loss: 1542.3959 - sub_3_loss: 1.2157 - lr: 0.0010 - time: 0.1817
# Epoch 78/1000
# 28/28 - 0s - loss: 5078.8636 - U_loss: 0.0313 - V_loss: 4.4835 - Sxx_loss: 4.6610e-05 - Syy_loss: 3565.4311 - Sxy_loss: 0.0200 - sub_loss: 0.0019 - sub_2_loss: 1520.2383 - sub_3_loss: 2.1777 - lr: 0.0010 - time: 0.1831
# Epoch 79/1000
# 28/28 - 0s - loss: 5083.6785 - U_loss: 0.0308 - V_loss: 4.5215 - Sxx_loss: 2.1407e-05 - Syy_loss: 3545.4056 - Sxy_loss: 0.0120 - sub_loss: 0.0014 - sub_2_loss: 1529.9007 - sub_3_loss: 1.6672 - lr: 0.0010 - time: 0.1875
# Epoch 80/1000
# 28/28 - 0s - loss: 5080.1181 - U_loss: 0.0301 - V_loss: 3.9896 - Sxx_loss: 1.2312e-05 - Syy_loss: 3546.1243 - Sxy_loss: 0.0260 - sub_loss: 5.1383e-04 - sub_2_loss: 1530.5355 - sub_3_loss: 1.5683 - lr: 0.0010 - time: 0.1835
# Epoch 81/1000
# 28/28 - 0s - loss: 5083.3630 - U_loss: 0.0300 - V_loss: 4.1117 - Sxx_loss: 5.5049e-06 - Syy_loss: 3543.0998 - Sxy_loss: 0.0149 - sub_loss: 4.0905e-04 - sub_2_loss: 1539.1701 - sub_3_loss: 1.5985 - lr: 0.0010 - time: 0.1837
# Epoch 82/1000
# 28/28 - 0s - loss: 5079.3072 - U_loss: 0.0296 - V_loss: 4.3275 - Sxx_loss: 6.8983e-06 - Syy_loss: 3528.1341 - Sxy_loss: 0.0220 - sub_loss: 5.5909e-04 - sub_2_loss: 1533.9621 - sub_3_loss: 1.7015 - lr: 0.0010 - time: 0.1863
# Epoch 83/1000
# 28/28 - 0s - loss: 5081.6726 - U_loss: 0.0300 - V_loss: 4.8718 - Sxx_loss: 9.9605e-06 - Syy_loss: 3541.1667 - Sxy_loss: 0.0129 - sub_loss: 3.7208e-04 - sub_2_loss: 1528.6461 - sub_3_loss: 1.1181 - lr: 0.0010 - time: 0.1877
# Epoch 84/1000
# 28/28 - 0s - loss: 5084.5995 - U_loss: 0.0299 - V_loss: 3.3693 - Sxx_loss: 5.2500e-06 - Syy_loss: 3545.8511 - Sxy_loss: 0.0101 - sub_loss: 2.7339e-04 - sub_2_loss: 1537.3231 - sub_3_loss: 1.2176 - lr: 0.0010 - time: 0.1854
# Epoch 85/1000
# 28/28 - 0s - loss: 5079.8218 - U_loss: 0.0299 - V_loss: 4.3936 - Sxx_loss: 6.4458e-06 - Syy_loss: 3550.7503 - Sxy_loss: 0.0094 - sub_loss: 5.0205e-04 - sub_2_loss: 1523.0458 - sub_3_loss: 1.2343 - lr: 0.0010 - time: 0.1845
# Epoch 86/1000
# 28/28 - 0s - loss: 5082.1977 - U_loss: 0.0298 - V_loss: 3.5030 - Sxx_loss: 5.4693e-06 - Syy_loss: 3535.7332 - Sxy_loss: 0.0177 - sub_loss: 3.6300e-04 - sub_2_loss: 1541.1857 - sub_3_loss: 1.5340 - lr: 0.0010 - time: 0.1919
# Epoch 87/1000
# 28/28 - 0s - loss: 5079.8532 - U_loss: 0.0299 - V_loss: 4.2074 - Sxx_loss: 1.7816e-05 - Syy_loss: 3550.0612 - Sxy_loss: 0.0107 - sub_loss: 0.0017 - sub_2_loss: 1530.7399 - sub_3_loss: 1.4486 - lr: 0.0010 - time: 0.1839
# Epoch 88/1000
# 28/28 - 0s - loss: 5078.2244 - U_loss: 0.0309 - V_loss: 4.6656 - Sxx_loss: 2.3235e-05 - Syy_loss: 3543.4171 - Sxy_loss: 0.0140 - sub_loss: 8.1361e-04 - sub_2_loss: 1531.5852 - sub_3_loss: 1.6522 - lr: 0.0010 - time: 0.1834
# Epoch 89/1000
# 28/28 - 0s - loss: 5077.1522 - U_loss: 0.0312 - V_loss: 4.5640 - Sxx_loss: 5.1344e-06 - Syy_loss: 3572.0367 - Sxy_loss: 0.0252 - sub_loss: 3.2477e-04 - sub_2_loss: 1512.7419 - sub_3_loss: 1.9514 - lr: 0.0010 - time: 0.1824
# Epoch 90/1000
# 28/28 - 0s - loss: 5075.1882 - U_loss: 0.0334 - V_loss: 3.8953 - Sxx_loss: 2.8039e-05 - Syy_loss: 3550.6626 - Sxy_loss: 0.0458 - sub_loss: 0.0022 - sub_2_loss: 1520.1596 - sub_3_loss: 2.6315 - lr: 0.0010 - time: 0.1876
# Epoch 91/1000
# 28/28 - 0s - loss: 5074.0412 - U_loss: 0.0327 - V_loss: 3.9234 - Sxx_loss: 1.0356e-04 - Syy_loss: 3521.8694 - Sxy_loss: 0.0159 - sub_loss: 0.0045 - sub_2_loss: 1548.2571 - sub_3_loss: 1.5225 - lr: 0.0010 - time: 0.1851
# Epoch 92/1000
# 28/28 - 0s - loss: 5074.5166 - U_loss: 0.0307 - V_loss: 4.5141 - Sxx_loss: 4.7838e-05 - Syy_loss: 3544.3794 - Sxy_loss: 0.0125 - sub_loss: 0.0033 - sub_2_loss: 1531.3555 - sub_3_loss: 1.5322 - lr: 0.0010 - time: 0.1837
# Epoch 93/1000
# 28/28 - 0s - loss: 5075.4271 - U_loss: 0.0311 - V_loss: 4.2752 - Sxx_loss: 5.9107e-05 - Syy_loss: 3543.8691 - Sxy_loss: 0.0341 - sub_loss: 0.0040 - sub_2_loss: 1531.1377 - sub_3_loss: 1.9488 - lr: 0.0010 - time: 0.1834
# Epoch 94/1000
# 28/28 - 0s - loss: 5079.5232 - U_loss: 0.0307 - V_loss: 4.3550 - Sxx_loss: 6.3994e-05 - Syy_loss: 3539.2783 - Sxy_loss: 0.0212 - sub_loss: 0.0106 - sub_2_loss: 1537.1198 - sub_3_loss: 1.1409 - lr: 0.0010 - time: 0.1836
# Epoch 95/1000
# 28/28 - 0s - loss: 5074.0743 - U_loss: 0.0303 - V_loss: 5.0981 - Sxx_loss: 4.9924e-05 - Syy_loss: 3539.0581 - Sxy_loss: 0.0149 - sub_loss: 0.0019 - sub_2_loss: 1539.9514 - sub_3_loss: 2.5253 - lr: 0.0010 - time: 0.1854
# Epoch 96/1000
# 28/28 - 0s - loss: 5077.0445 - U_loss: 0.0312 - V_loss: 4.4717 - Sxx_loss: 1.7015e-05 - Syy_loss: 3528.4424 - Sxy_loss: 0.0190 - sub_loss: 0.0013 - sub_2_loss: 1535.4990 - sub_3_loss: 2.1472 - lr: 0.0010 - time: 0.1988
# Epoch 97/1000
# 28/28 - 0s - loss: 5076.9437 - U_loss: 0.0348 - V_loss: 4.4254 - Sxx_loss: 3.0682e-04 - Syy_loss: 3557.7447 - Sxy_loss: 0.0284 - sub_loss: 0.0191 - sub_2_loss: 1522.2291 - sub_3_loss: 2.2849 - lr: 0.0010 - time: 0.1792
# Epoch 98/1000
# 28/28 - 0s - loss: 5092.5716 - U_loss: 0.0348 - V_loss: 4.5853 - Sxx_loss: 3.9179e-04 - Syy_loss: 3538.5325 - Sxy_loss: 0.0443 - sub_loss: 0.0100 - sub_2_loss: 1547.9386 - sub_3_loss: 5.0394 - lr: 0.0010 - time: 0.1860
# Epoch 99/1000
# 28/28 - 0s - loss: 5081.4960 - U_loss: 0.0360 - V_loss: 2.1267 - Sxx_loss: 6.0595e-05 - Syy_loss: 3539.8453 - Sxy_loss: 0.0229 - sub_loss: 5.8383e-04 - sub_2_loss: 1530.2147 - sub_3_loss: 1.1968 - lr: 0.0010 - time: 0.1802
# Epoch 100/1000
# 28/28 - 0s - loss: 5081.1836 - U_loss: 0.0312 - V_loss: 4.1026 - Sxx_loss: 2.9756e-05 - Syy_loss: 3547.3957 - Sxy_loss: 0.0094 - sub_loss: 0.0014 - sub_2_loss: 1526.8816 - sub_3_loss: 1.3979 - lr: 0.0010 - time: 0.1903
# Epoch 101/1000
# 28/28 - 0s - loss: 5082.9730 - U_loss: 0.0312 - V_loss: 3.6105 - Sxx_loss: 1.4295e-05 - Syy_loss: 3556.7947 - Sxy_loss: 0.0227 - sub_loss: 0.0011 - sub_2_loss: 1518.9739 - sub_3_loss: 1.8151 - lr: 0.0010 - time: 0.1875
# Epoch 102/1000
# 28/28 - 0s - loss: 5083.0605 - U_loss: 0.0307 - V_loss: 3.6446 - Sxx_loss: 2.7561e-05 - Syy_loss: 3544.4802 - Sxy_loss: 0.0227 - sub_loss: 0.0011 - sub_2_loss: 1548.0988 - sub_3_loss: 0.7158 - lr: 0.0010 - time: 0.1843
# Epoch 103/1000
# 28/28 - 0s - loss: 5080.1365 - U_loss: 0.0350 - V_loss: 4.7416 - Sxx_loss: 2.7391e-04 - Syy_loss: 3541.4987 - Sxy_loss: 0.0103 - sub_loss: 0.0071 - sub_2_loss: 1534.7348 - sub_3_loss: 1.1978 - lr: 0.0010 - time: 0.1852
# Epoch 104/1000
# 28/28 - 0s - loss: 5079.2769 - U_loss: 0.1027 - V_loss: 5.2061 - Sxx_loss: 0.0011 - Syy_loss: 3540.0360 - Sxy_loss: 0.0082 - sub_loss: 0.0914 - sub_2_loss: 1531.8558 - sub_3_loss: 1.2527 - lr: 0.0010 - time: 0.1834
# Epoch 105/1000
# 28/28 - 0s - loss: 5080.4699 - U_loss: 0.0734 - V_loss: 5.9312 - Sxx_loss: 0.0017 - Syy_loss: 3553.8735 - Sxy_loss: 0.0147 - sub_loss: 0.0387 - sub_2_loss: 1528.5171 - sub_3_loss: 1.9029 - lr: 0.0010 - time: 0.1840
# Epoch 106/1000
# 28/28 - 0s - loss: 5077.7467 - U_loss: 0.0454 - V_loss: 5.0016 - Sxx_loss: 2.8234e-04 - Syy_loss: 3574.0391 - Sxy_loss: 0.0122 - sub_loss: 0.0132 - sub_2_loss: 1513.4361 - sub_3_loss: 1.5378 - lr: 0.0010 - time: 0.1878
# Epoch 107/1000
# 28/28 - 0s - loss: 5080.8092 - U_loss: 0.0343 - V_loss: 6.1923 - Sxx_loss: 1.0075e-04 - Syy_loss: 3536.8373 - Sxy_loss: 0.0077 - sub_loss: 0.0071 - sub_2_loss: 1549.9424 - sub_3_loss: 1.0910 - lr: 0.0010 - time: 0.1905
# Epoch 108/1000
# 28/28 - 0s - loss: 5078.1506 - U_loss: 0.0327 - V_loss: 6.5394 - Sxx_loss: 5.0192e-05 - Syy_loss: 3567.3088 - Sxy_loss: 0.0077 - sub_loss: 0.0013 - sub_2_loss: 1522.7410 - sub_3_loss: 0.8708 - lr: 0.0010 - time: 0.1832
# Epoch 109/1000
# 28/28 - 0s - loss: 5075.0318 - U_loss: 0.0309 - V_loss: 7.1652 - Sxx_loss: 1.8538e-05 - Syy_loss: 3528.7633 - Sxy_loss: 0.0062 - sub_loss: 0.0023 - sub_2_loss: 1540.9774 - sub_3_loss: 1.1348 - lr: 0.0010 - time: 0.1869
# Epoch 110/1000
# 28/28 - 0s - loss: 5076.0132 - U_loss: 0.0313 - V_loss: 8.6063 - Sxx_loss: 1.2732e-04 - Syy_loss: 3534.2607 - Sxy_loss: 0.0056 - sub_loss: 0.0045 - sub_2_loss: 1516.0030 - sub_3_loss: 0.8288 - lr: 0.0010 - time: 0.1823
# Epoch 111/1000
# 28/28 - 0s - loss: 5077.7262 - U_loss: 0.0312 - V_loss: 6.4129 - Sxx_loss: 3.3489e-05 - Syy_loss: 3538.0459 - Sxy_loss: 0.0047 - sub_loss: 0.0016 - sub_2_loss: 1530.1273 - sub_3_loss: 0.9856 - lr: 0.0010 - time: 0.1894
# Epoch 112/1000
# 28/28 - 0s - loss: 5068.3393 - U_loss: 0.0335 - V_loss: 7.9368 - Sxx_loss: 1.9563e-04 - Syy_loss: 3538.9240 - Sxy_loss: 0.0086 - sub_loss: 0.0132 - sub_2_loss: 1516.2914 - sub_3_loss: 1.3907 - lr: 0.0010 - time: 0.1849
# Epoch 113/1000
# 28/28 - 0s - loss: 5073.8958 - U_loss: 0.0374 - V_loss: 7.2288 - Sxx_loss: 1.7862e-04 - Syy_loss: 3551.5253 - Sxy_loss: 0.0186 - sub_loss: 0.0133 - sub_2_loss: 1517.2739 - sub_3_loss: 1.7205 - lr: 0.0010 - time: 0.1891
# Epoch 114/1000
# 28/28 - 0s - loss: 5069.2012 - U_loss: 0.0341 - V_loss: 8.5602 - Sxx_loss: 1.2754e-04 - Syy_loss: 3544.4333 - Sxy_loss: 0.0115 - sub_loss: 0.0085 - sub_2_loss: 1532.2425 - sub_3_loss: 1.7039 - lr: 0.0010 - time: 0.1841
# Epoch 115/1000
# 28/28 - 0s - loss: 5070.9856 - U_loss: 0.0311 - V_loss: 6.7781 - Sxx_loss: 1.6069e-04 - Syy_loss: 3534.6653 - Sxy_loss: 0.0123 - sub_loss: 0.0109 - sub_2_loss: 1520.9074 - sub_3_loss: 1.2902 - lr: 0.0010 - time: 0.1857
# Epoch 116/1000
# 28/28 - 0s - loss: 5068.5415 - U_loss: 0.0304 - V_loss: 6.3601 - Sxx_loss: 3.8921e-05 - Syy_loss: 3545.3672 - Sxy_loss: 0.0183 - sub_loss: 0.0104 - sub_2_loss: 1514.1099 - sub_3_loss: 2.2985 - lr: 0.0010 - time: 0.1858
# Epoch 117/1000
# 28/28 - 0s - loss: 5068.0295 - U_loss: 0.0312 - V_loss: 6.6226 - Sxx_loss: 1.4113e-04 - Syy_loss: 3519.8924 - Sxy_loss: 0.0141 - sub_loss: 0.0062 - sub_2_loss: 1527.4153 - sub_3_loss: 2.3780 - lr: 0.0010 - time: 0.1819
# Epoch 118/1000
# 28/28 - 0s - loss: 5074.4262 - U_loss: 0.0313 - V_loss: 7.1714 - Sxx_loss: 1.6614e-04 - Syy_loss: 3528.7818 - Sxy_loss: 0.0142 - sub_loss: 0.0065 - sub_2_loss: 1531.1362 - sub_3_loss: 1.6969 - lr: 0.0010 - time: 0.1834
# Epoch 119/1000
# 28/28 - 0s - loss: 5072.0657 - U_loss: 0.0318 - V_loss: 6.1632 - Sxx_loss: 1.1123e-04 - Syy_loss: 3522.9832 - Sxy_loss: 0.0089 - sub_loss: 5.8668e-04 - sub_2_loss: 1542.5093 - sub_3_loss: 1.7384 - lr: 0.0010 - time: 0.1820
# Epoch 120/1000
# 28/28 - 0s - loss: 5075.6118 - U_loss: 0.0315 - V_loss: 6.2948 - Sxx_loss: 1.2693e-05 - Syy_loss: 3564.6660 - Sxy_loss: 0.0130 - sub_loss: 2.1360e-04 - sub_2_loss: 1490.3748 - sub_3_loss: 1.4501 - lr: 0.0010 - time: 0.1807
# Epoch 121/1000
# 28/28 - 0s - loss: 5068.1236 - U_loss: 0.0310 - V_loss: 6.8247 - Sxx_loss: 1.0557e-05 - Syy_loss: 3521.5266 - Sxy_loss: 0.0128 - sub_loss: 5.4078e-04 - sub_2_loss: 1537.4703 - sub_3_loss: 2.1863 - lr: 0.0010 - time: 0.1840
# Epoch 122/1000
# 28/28 - 0s - loss: 5069.5218 - U_loss: 0.0314 - V_loss: 6.2768 - Sxx_loss: 7.2990e-06 - Syy_loss: 3520.2019 - Sxy_loss: 0.0179 - sub_loss: 2.9039e-04 - sub_2_loss: 1542.1562 - sub_3_loss: 2.3112 - lr: 0.0010 - time: 0.1895
# Epoch 123/1000
# 28/28 - 0s - loss: 5068.1552 - U_loss: 0.0311 - V_loss: 8.1309 - Sxx_loss: 1.3438e-05 - Syy_loss: 3523.5827 - Sxy_loss: 0.0196 - sub_loss: 9.8591e-04 - sub_2_loss: 1524.0659 - sub_3_loss: 1.7896 - lr: 0.0010 - time: 0.1816
# Epoch 124/1000
# 28/28 - 0s - loss: 5071.1994 - U_loss: 0.0317 - V_loss: 7.5705 - Sxx_loss: 1.0044e-04 - Syy_loss: 3552.2951 - Sxy_loss: 0.0122 - sub_loss: 0.0111 - sub_2_loss: 1507.4906 - sub_3_loss: 1.5887 - lr: 0.0010 - time: 0.1836
# Epoch 125/1000
# 28/28 - 0s - loss: 5069.4307 - U_loss: 0.0315 - V_loss: 7.3955 - Sxx_loss: 1.7397e-04 - Syy_loss: 3516.7106 - Sxy_loss: 0.0068 - sub_loss: 0.0036 - sub_2_loss: 1541.3937 - sub_3_loss: 1.4784 - lr: 0.0010 - time: 0.1808
# Epoch 126/1000
# 28/28 - 0s - loss: 5074.7892 - U_loss: 0.0325 - V_loss: 6.4348 - Sxx_loss: 1.4242e-04 - Syy_loss: 3532.8357 - Sxy_loss: 0.0172 - sub_loss: 0.0032 - sub_2_loss: 1529.4825 - sub_3_loss: 2.0244 - lr: 0.0010 - time: 0.1919
# Epoch 127/1000
# 28/28 - 0s - loss: 5074.3158 - U_loss: 0.0312 - V_loss: 6.2754 - Sxx_loss: 1.8501e-05 - Syy_loss: 3528.1364 - Sxy_loss: 0.0084 - sub_loss: 8.9031e-04 - sub_2_loss: 1541.8835 - sub_3_loss: 1.6734 - lr: 0.0010 - time: 0.1830
# Epoch 128/1000
# 28/28 - 0s - loss: 5070.3446 - U_loss: 0.0304 - V_loss: 7.1862 - Sxx_loss: 5.3978e-05 - Syy_loss: 3542.3951 - Sxy_loss: 0.0334 - sub_loss: 0.0051 - sub_2_loss: 1518.9712 - sub_3_loss: 2.7193 - lr: 0.0010 - time: 0.1859
# Epoch 129/1000
# 28/28 - 0s - loss: 5075.1443 - U_loss: 0.0320 - V_loss: 6.0126 - Sxx_loss: 8.6921e-05 - Syy_loss: 3542.4080 - Sxy_loss: 0.0140 - sub_loss: 0.0039 - sub_2_loss: 1522.1790 - sub_3_loss: 1.3180 - lr: 0.0010 - time: 0.1826
# Epoch 130/1000
# 28/28 - 0s - loss: 5076.3716 - U_loss: 0.0333 - V_loss: 5.6214 - Sxx_loss: 7.1117e-05 - Syy_loss: 3545.8391 - Sxy_loss: 0.0124 - sub_loss: 0.0031 - sub_2_loss: 1525.6273 - sub_3_loss: 2.1915 - lr: 0.0010 - time: 0.1822
# Epoch 131/1000
# 28/28 - 0s - loss: 5076.0793 - U_loss: 0.0312 - V_loss: 4.6721 - Sxx_loss: 2.5404e-05 - Syy_loss: 3516.7057 - Sxy_loss: 0.0064 - sub_loss: 6.7394e-04 - sub_2_loss: 1546.9901 - sub_3_loss: 1.2803 - lr: 0.0010 - time: 0.1839
# Epoch 132/1000
# 28/28 - 0s - loss: 5072.5961 - U_loss: 0.0311 - V_loss: 6.5102 - Sxx_loss: 1.2127e-05 - Syy_loss: 3536.2612 - Sxy_loss: 0.0129 - sub_loss: 9.1147e-04 - sub_2_loss: 1534.7277 - sub_3_loss: 1.8159 - lr: 0.0010 - time: 0.1853
# Epoch 133/1000
# 28/28 - 0s - loss: 5072.7387 - U_loss: 0.0308 - V_loss: 6.6031 - Sxx_loss: 6.6010e-06 - Syy_loss: 3547.0965 - Sxy_loss: 0.0139 - sub_loss: 4.2797e-04 - sub_2_loss: 1523.2741 - sub_3_loss: 1.8386 - lr: 0.0010 - time: 0.1884
# Epoch 134/1000
# 28/28 - 0s - loss: 5072.1409 - U_loss: 0.0311 - V_loss: 6.2687 - Sxx_loss: 1.1716e-05 - Syy_loss: 3554.4290 - Sxy_loss: 0.0079 - sub_loss: 2.6554e-04 - sub_2_loss: 1519.9078 - sub_3_loss: 1.5424 - lr: 0.0010 - time: 0.1808
# Epoch 135/1000
# 28/28 - 0s - loss: 5072.1363 - U_loss: 0.0316 - V_loss: 6.8945 - Sxx_loss: 2.9677e-06 - Syy_loss: 3528.3852 - Sxy_loss: 0.0109 - sub_loss: 2.7086e-04 - sub_2_loss: 1531.4131 - sub_3_loss: 1.9017 - lr: 0.0010 - time: 0.1836
# Epoch 136/1000
# 28/28 - 0s - loss: 5073.3540 - U_loss: 0.0312 - V_loss: 5.8090 - Sxx_loss: 2.8233e-06 - Syy_loss: 3519.2447 - Sxy_loss: 0.0153 - sub_loss: 1.5048e-04 - sub_2_loss: 1540.7127 - sub_3_loss: 2.2962 - lr: 0.0010 - time: 0.1805
# Epoch 137/1000
# 28/28 - 0s - loss: 5075.1234 - U_loss: 0.0310 - V_loss: 5.9415 - Sxx_loss: 5.7004e-06 - Syy_loss: 3545.4255 - Sxy_loss: 0.0109 - sub_loss: 2.1011e-04 - sub_2_loss: 1513.6022 - sub_3_loss: 1.7756 - lr: 0.0010 - time: 0.1822
# Epoch 138/1000
# 28/28 - 0s - loss: 5071.0468 - U_loss: 0.0309 - V_loss: 5.9409 - Sxx_loss: 2.4588e-06 - Syy_loss: 3547.8167 - Sxy_loss: 0.0112 - sub_loss: 3.6444e-04 - sub_2_loss: 1525.0736 - sub_3_loss: 2.1048 - lr: 0.0010 - time: 0.1865
# Epoch 139/1000
# 28/28 - 0s - loss: 5076.7048 - U_loss: 0.0310 - V_loss: 5.2434 - Sxx_loss: 2.9474e-06 - Syy_loss: 3515.7132 - Sxy_loss: 0.0110 - sub_loss: 2.2634e-04 - sub_2_loss: 1539.5234 - sub_3_loss: 1.7610 - lr: 0.0010 - time: 0.1846
# Epoch 140/1000
# 28/28 - 0s - loss: 5071.5853 - U_loss: 0.0312 - V_loss: 5.8746 - Sxx_loss: 3.6439e-06 - Syy_loss: 3564.8222 - Sxy_loss: 0.0097 - sub_loss: 2.4894e-04 - sub_2_loss: 1501.0139 - sub_3_loss: 1.6966 - lr: 0.0010 - time: 0.1872
# Epoch 141/1000
# 28/28 - 0s - loss: 5072.8918 - U_loss: 0.0307 - V_loss: 6.8884 - Sxx_loss: 5.7234e-06 - Syy_loss: 3503.8722 - Sxy_loss: 0.0103 - sub_loss: 4.3584e-04 - sub_2_loss: 1559.7722 - sub_3_loss: 1.9265 - lr: 0.0010 - time: 0.1875
# Epoch 142/1000
# 28/28 - 0s - loss: 5069.4111 - U_loss: 0.0304 - V_loss: 6.5493 - Sxx_loss: 9.3225e-06 - Syy_loss: 3538.3188 - Sxy_loss: 0.0130 - sub_loss: 0.0013 - sub_2_loss: 1514.4516 - sub_3_loss: 1.9961 - lr: 0.0010 - time: 0.1854
# Epoch 143/1000
# 28/28 - 0s - loss: 5065.5153 - U_loss: 0.0308 - V_loss: 8.1464 - Sxx_loss: 2.6369e-05 - Syy_loss: 3513.3718 - Sxy_loss: 0.0154 - sub_loss: 0.0013 - sub_2_loss: 1539.0471 - sub_3_loss: 1.8220 - lr: 0.0010 - time: 0.1844
# Epoch 144/1000
# 28/28 - 0s - loss: 5074.3557 - U_loss: 0.0311 - V_loss: 7.6204 - Sxx_loss: 3.5170e-04 - Syy_loss: 3527.5554 - Sxy_loss: 0.0070 - sub_loss: 0.0219 - sub_2_loss: 1533.4969 - sub_3_loss: 1.6707 - lr: 0.0010 - time: 0.1929
# Epoch 145/1000
# 28/28 - 0s - loss: 5068.6990 - U_loss: 0.0357 - V_loss: 7.6859 - Sxx_loss: 4.4630e-04 - Syy_loss: 3543.1639 - Sxy_loss: 0.0132 - sub_loss: 0.0086 - sub_2_loss: 1511.4527 - sub_3_loss: 1.9846 - lr: 0.0010 - time: 0.1869
# Epoch 146/1000
# 28/28 - 0s - loss: 5067.9101 - U_loss: 0.0320 - V_loss: 8.2512 - Sxx_loss: 8.7261e-05 - Syy_loss: 3548.1688 - Sxy_loss: 0.0119 - sub_loss: 0.0017 - sub_2_loss: 1508.9420 - sub_3_loss: 2.1295 - lr: 0.0010 - time: 0.1839
# Epoch 147/1000
# 28/28 - 0s - loss: 5066.2286 - U_loss: 0.0307 - V_loss: 7.9679 - Sxx_loss: 1.7981e-05 - Syy_loss: 3538.7778 - Sxy_loss: 0.0153 - sub_loss: 0.0015 - sub_2_loss: 1536.2827 - sub_3_loss: 1.9930 - lr: 0.0010 - time: 0.1848
# Epoch 148/1000
# 28/28 - 0s - loss: 5068.4430 - U_loss: 0.0305 - V_loss: 6.9627 - Sxx_loss: 2.2609e-05 - Syy_loss: 3510.7934 - Sxy_loss: 0.0117 - sub_loss: 0.0013 - sub_2_loss: 1544.6919 - sub_3_loss: 1.9618 - lr: 0.0010 - time: 0.1901
# Epoch 149/1000
# 28/28 - 0s - loss: 5067.1437 - U_loss: 0.0315 - V_loss: 6.9253 - Sxx_loss: 9.0446e-06 - Syy_loss: 3538.2844 - Sxy_loss: 0.0146 - sub_loss: 3.4610e-04 - sub_2_loss: 1520.7351 - sub_3_loss: 2.0885 - lr: 0.0010 - time: 0.1874
# Epoch 150/1000
# 28/28 - 0s - loss: 5064.2136 - U_loss: 0.0311 - V_loss: 6.4205 - Sxx_loss: 5.3209e-06 - Syy_loss: 3541.5209 - Sxy_loss: 0.0179 - sub_loss: 2.4131e-04 - sub_2_loss: 1528.9956 - sub_3_loss: 2.2365 - lr: 0.0010 - time: 0.1840
# Epoch 151/1000
# 28/28 - 0s - loss: 5071.5473 - U_loss: 0.0309 - V_loss: 6.2322 - Sxx_loss: 3.2999e-06 - Syy_loss: 3528.2381 - Sxy_loss: 0.0150 - sub_loss: 2.0567e-04 - sub_2_loss: 1518.0180 - sub_3_loss: 2.5680 - lr: 0.0010 - time: 0.1849
# Epoch 152/1000
# 28/28 - 0s - loss: 5068.8489 - U_loss: 0.0309 - V_loss: 5.9048 - Sxx_loss: 2.5412e-06 - Syy_loss: 3520.9049 - Sxy_loss: 0.0149 - sub_loss: 2.7991e-04 - sub_2_loss: 1539.4516 - sub_3_loss: 2.6764 - lr: 0.0010 - time: 0.1860
# Epoch 153/1000
# 28/28 - 0s - loss: 5069.7517 - U_loss: 0.0312 - V_loss: 7.1751 - Sxx_loss: 4.9722e-06 - Syy_loss: 3528.2791 - Sxy_loss: 0.0223 - sub_loss: 2.1353e-04 - sub_2_loss: 1531.8934 - sub_3_loss: 2.4446 - lr: 0.0010 - time: 0.1837
# Epoch 154/1000
# 28/28 - 0s - loss: 5065.6475 - U_loss: 0.0312 - V_loss: 7.6983 - Sxx_loss: 2.5484e-06 - Syy_loss: 3528.9070 - Sxy_loss: 0.0230 - sub_loss: 1.1525e-04 - sub_2_loss: 1528.7399 - sub_3_loss: 2.5065 - lr: 0.0010 - time: 0.1896
# Epoch 155/1000
# 28/28 - 0s - loss: 5068.3152 - U_loss: 0.0311 - V_loss: 7.2373 - Sxx_loss: 4.2199e-06 - Syy_loss: 3510.3750 - Sxy_loss: 0.0252 - sub_loss: 2.0715e-04 - sub_2_loss: 1550.9598 - sub_3_loss: 2.4759 - lr: 0.0010 - time: 0.1821
# Epoch 156/1000
# 28/28 - 0s - loss: 5069.1269 - U_loss: 0.0312 - V_loss: 6.5083 - Sxx_loss: 4.4960e-06 - Syy_loss: 3545.4780 - Sxy_loss: 0.0200 - sub_loss: 1.6279e-04 - sub_2_loss: 1515.8091 - sub_3_loss: 2.6566 - lr: 0.0010 - time: 0.1799
# Epoch 157/1000
# 28/28 - 0s - loss: 5071.6290 - U_loss: 0.0310 - V_loss: 6.7452 - Sxx_loss: 3.7777e-06 - Syy_loss: 3535.3832 - Sxy_loss: 0.0201 - sub_loss: 2.3127e-04 - sub_2_loss: 1522.1553 - sub_3_loss: 2.2304 - lr: 0.0010 - time: 0.1812
# Epoch 158/1000
# 28/28 - 0s - loss: 5062.5973 - U_loss: 0.0307 - V_loss: 6.8554 - Sxx_loss: 4.6686e-06 - Syy_loss: 3523.3181 - Sxy_loss: 0.0431 - sub_loss: 3.4681e-04 - sub_2_loss: 1517.7947 - sub_3_loss: 2.7596 - lr: 0.0010 - time: 0.1853
# Epoch 159/1000
# 28/28 - 0s - loss: 5070.3546 - U_loss: 0.0306 - V_loss: 6.9649 - Sxx_loss: 9.4869e-06 - Syy_loss: 3522.6210 - Sxy_loss: 0.0278 - sub_loss: 9.2073e-04 - sub_2_loss: 1530.9765 - sub_3_loss: 2.4159 - lr: 0.0010 - time: 0.1818
# Epoch 160/1000
# 28/28 - 0s - loss: 5061.0461 - U_loss: 0.0313 - V_loss: 7.9179 - Sxx_loss: 1.4980e-05 - Syy_loss: 3501.2472 - Sxy_loss: 0.0372 - sub_loss: 6.1761e-04 - sub_2_loss: 1547.6087 - sub_3_loss: 3.4135 - lr: 0.0010 - time: 0.1819
# Epoch 161/1000
# 28/28 - 0s - loss: 5070.4454 - U_loss: 0.0321 - V_loss: 6.3089 - Sxx_loss: 9.1810e-06 - Syy_loss: 3534.5248 - Sxy_loss: 0.0208 - sub_loss: 1.7350e-04 - sub_2_loss: 1518.8639 - sub_3_loss: 1.9477 - lr: 0.0010 - time: 0.1841
# Epoch 162/1000
# 28/28 - 0s - loss: 5063.4196 - U_loss: 0.0314 - V_loss: 7.0899 - Sxx_loss: 2.7518e-05 - Syy_loss: 3535.6041 - Sxy_loss: 0.0219 - sub_loss: 0.0013 - sub_2_loss: 1517.7898 - sub_3_loss: 1.8953 - lr: 0.0010 - time: 0.1832
# Epoch 163/1000
# 28/28 - 0s - loss: 5066.0909 - U_loss: 0.0354 - V_loss: 7.3206 - Sxx_loss: 1.7813e-05 - Syy_loss: 3507.1879 - Sxy_loss: 0.0251 - sub_loss: 0.0034 - sub_2_loss: 1543.4324 - sub_3_loss: 2.1170 - lr: 0.0010 - time: 0.1846
# Epoch 164/1000
# 28/28 - 0s - loss: 5068.2568 - U_loss: 0.0462 - V_loss: 7.6814 - Sxx_loss: 8.7477e-05 - Syy_loss: 3553.6265 - Sxy_loss: 0.0234 - sub_loss: 0.0029 - sub_2_loss: 1508.9706 - sub_3_loss: 2.6795 - lr: 0.0010 - time: 0.1854
# Epoch 165/1000
# 28/28 - 0s - loss: 5070.9038 - U_loss: 0.0339 - V_loss: 7.2110 - Sxx_loss: 1.6361e-05 - Syy_loss: 3516.4190 - Sxy_loss: 0.0214 - sub_loss: 5.1370e-04 - sub_2_loss: 1541.3082 - sub_3_loss: 2.1136 - lr: 0.0010 - time: 0.1905
# Epoch 166/1000
# 28/28 - 0s - loss: 5073.6759 - U_loss: 0.0315 - V_loss: 7.2474 - Sxx_loss: 1.2539e-05 - Syy_loss: 3530.6347 - Sxy_loss: 0.0144 - sub_loss: 7.9368e-04 - sub_2_loss: 1532.4887 - sub_3_loss: 1.8172 - lr: 0.0010 - time: 0.1815
# Epoch 167/1000
# 28/28 - 0s - loss: 5076.1998 - U_loss: 0.0313 - V_loss: 6.9460 - Sxx_loss: 4.9668e-06 - Syy_loss: 3546.7236 - Sxy_loss: 0.0164 - sub_loss: 1.4343e-04 - sub_2_loss: 1525.6223 - sub_3_loss: 1.9184 - lr: 0.0010 - time: 0.1845
# Epoch 168/1000
# 28/28 - 0s - loss: 5071.6677 - U_loss: 0.0311 - V_loss: 6.7576 - Sxx_loss: 2.8478e-06 - Syy_loss: 3525.8921 - Sxy_loss: 0.0158 - sub_loss: 2.4320e-04 - sub_2_loss: 1539.5238 - sub_3_loss: 1.8962 - lr: 0.0010 - time: 0.1819
# Epoch 169/1000
# 28/28 - 0s - loss: 5067.7827 - U_loss: 0.0311 - V_loss: 7.7534 - Sxx_loss: 2.9766e-06 - Syy_loss: 3526.1766 - Sxy_loss: 0.0217 - sub_loss: 2.5482e-04 - sub_2_loss: 1533.7921 - sub_3_loss: 2.4518 - lr: 0.0010 - time: 0.1857
# Epoch 170/1000
# 28/28 - 0s - loss: 5074.3325 - U_loss: 0.0311 - V_loss: 5.9575 - Sxx_loss: 3.0847e-06 - Syy_loss: 3554.5704 - Sxy_loss: 0.0182 - sub_loss: 1.3838e-04 - sub_2_loss: 1499.8896 - sub_3_loss: 2.3344 - lr: 0.0010 - time: 0.1844
# Epoch 171/1000
# 28/28 - 0s - loss: 5067.6990 - U_loss: 0.0317 - V_loss: 6.8105 - Sxx_loss: 3.3941e-06 - Syy_loss: 3521.1115 - Sxy_loss: 0.0168 - sub_loss: 2.0924e-04 - sub_2_loss: 1538.4543 - sub_3_loss: 2.2302 - lr: 0.0010 - time: 0.1832
# Epoch 172/1000
# 28/28 - 0s - loss: 5068.3956 - U_loss: 0.0313 - V_loss: 8.8827 - Sxx_loss: 3.1397e-06 - Syy_loss: 3497.7682 - Sxy_loss: 0.0286 - sub_loss: 1.4074e-04 - sub_2_loss: 1553.7909 - sub_3_loss: 2.5969 - lr: 0.0010 - time: 0.1811
# Epoch 173/1000
# 28/28 - 0s - loss: 5063.5734 - U_loss: 0.0316 - V_loss: 7.6244 - Sxx_loss: 5.1536e-06 - Syy_loss: 3534.3502 - Sxy_loss: 0.0255 - sub_loss: 1.3267e-04 - sub_2_loss: 1529.1166 - sub_3_loss: 1.3386 - lr: 0.0010 - time: 0.1919
# Epoch 174/1000
# 28/28 - 0s - loss: 5067.3115 - U_loss: 0.0308 - V_loss: 7.4589 - Sxx_loss: 4.0614e-06 - Syy_loss: 3540.4124 - Sxy_loss: 0.0435 - sub_loss: 2.7305e-04 - sub_2_loss: 1513.3787 - sub_3_loss: 2.3573 - lr: 0.0010 - time: 0.1844
# Epoch 175/1000
# 28/28 - 0s - loss: 5065.3404 - U_loss: 0.0312 - V_loss: 6.6305 - Sxx_loss: 4.3126e-06 - Syy_loss: 3526.9671 - Sxy_loss: 0.0155 - sub_loss: 1.5005e-04 - sub_2_loss: 1528.3614 - sub_3_loss: 2.0917 - lr: 0.0010 - time: 0.1848
# Epoch 176/1000
# 28/28 - 0s - loss: 5065.1042 - U_loss: 0.0312 - V_loss: 7.9522 - Sxx_loss: 4.1516e-06 - Syy_loss: 3518.9889 - Sxy_loss: 0.0316 - sub_loss: 2.0348e-04 - sub_2_loss: 1533.7233 - sub_3_loss: 2.2161 - lr: 0.0010 - time: 0.1845
# Epoch 177/1000
# 28/28 - 0s - loss: 5070.1973 - U_loss: 0.0307 - V_loss: 7.5076 - Sxx_loss: 2.9537e-05 - Syy_loss: 3521.1708 - Sxy_loss: 0.0292 - sub_loss: 0.0026 - sub_2_loss: 1535.6240 - sub_3_loss: 2.8806 - lr: 0.0010 - time: 0.1823
# Epoch 178/1000
# 28/28 - 0s - loss: 5066.7137 - U_loss: 0.0312 - V_loss: 7.2146 - Sxx_loss: 1.8743e-05 - Syy_loss: 3539.1245 - Sxy_loss: 0.0268 - sub_loss: 2.5794e-04 - sub_2_loss: 1508.7777 - sub_3_loss: 2.6037 - lr: 0.0010 - time: 0.1842
# Epoch 179/1000
# 28/28 - 0s - loss: 5070.7871 - U_loss: 0.0312 - V_loss: 7.5990 - Sxx_loss: 1.0270e-05 - Syy_loss: 3543.1923 - Sxy_loss: 0.0188 - sub_loss: 1.7677e-04 - sub_2_loss: 1530.0718 - sub_3_loss: 1.9516 - lr: 0.0010 - time: 0.1850
# Epoch 180/1000
# 28/28 - 0s - loss: 5073.1241 - U_loss: 0.0310 - V_loss: 7.4390 - Sxx_loss: 4.9916e-06 - Syy_loss: 3529.6256 - Sxy_loss: 0.0235 - sub_loss: 2.2563e-04 - sub_2_loss: 1535.7463 - sub_3_loss: 1.9126 - lr: 0.0010 - time: 0.1837
# Epoch 181/1000
# 28/28 - 0s - loss: 5100.1423 - U_loss: 0.0308 - V_loss: 7.3221 - Sxx_loss: 6.7461e-06 - Syy_loss: 3533.7782 - Sxy_loss: 0.0089 - sub_loss: 1.5609e-04 - sub_2_loss: 1544.5811 - sub_3_loss: 18.9780 - lr: 0.0010 - time: 0.1829
# Epoch 182/1000
# 28/28 - 0s - loss: 5076.3445 - U_loss: 0.0308 - V_loss: 7.0371 - Sxx_loss: 5.5601e-06 - Syy_loss: 3542.0771 - Sxy_loss: 0.0272 - sub_loss: 4.5339e-04 - sub_2_loss: 1530.3359 - sub_3_loss: 2.6906 - lr: 0.0010 - time: 0.1845
# Epoch 183/1000
# 28/28 - 0s - loss: 5076.5852 - U_loss: 0.0312 - V_loss: 6.4342 - Sxx_loss: 1.0866e-05 - Syy_loss: 3541.9507 - Sxy_loss: 0.0077 - sub_loss: 2.3713e-04 - sub_2_loss: 1524.6205 - sub_3_loss: 1.0820 - lr: 0.0010 - time: 0.1857
# Epoch 184/1000
# 28/28 - 0s - loss: 5068.5709 - U_loss: 0.0313 - V_loss: 6.8285 - Sxx_loss: 5.0849e-06 - Syy_loss: 3541.3435 - Sxy_loss: 0.0164 - sub_loss: 2.3250e-04 - sub_2_loss: 1520.1137 - sub_3_loss: 1.9870 - lr: 0.0010 - time: 0.1842
# Epoch 185/1000
# 28/28 - 0s - loss: 5071.4506 - U_loss: 0.0307 - V_loss: 7.4103 - Sxx_loss: 8.9267e-06 - Syy_loss: 3508.0721 - Sxy_loss: 0.0265 - sub_loss: 3.5178e-04 - sub_2_loss: 1550.3929 - sub_3_loss: 2.1457 - lr: 0.0010 - time: 0.1851
# Epoch 186/1000
# 28/28 - 0s - loss: 5070.8562 - U_loss: 0.0314 - V_loss: 6.6415 - Sxx_loss: 1.1452e-04 - Syy_loss: 3548.7586 - Sxy_loss: 0.0213 - sub_loss: 0.0053 - sub_2_loss: 1525.1309 - sub_3_loss: 2.0845 - lr: 0.0010 - time: 0.1843
# Epoch 187/1000
# 28/28 - 0s - loss: 5068.3026 - U_loss: 0.0318 - V_loss: 8.3658 - Sxx_loss: 6.1272e-05 - Syy_loss: 3529.9051 - Sxy_loss: 0.0324 - sub_loss: 9.4101e-04 - sub_2_loss: 1531.6694 - sub_3_loss: 2.0514 - lr: 0.0010 - time: 0.1845
# Epoch 188/1000
# 28/28 - 0s - loss: 5072.7195 - U_loss: 0.0330 - V_loss: 7.4250 - Sxx_loss: 4.2994e-04 - Syy_loss: 3555.7896 - Sxy_loss: 0.0168 - sub_loss: 0.0221 - sub_2_loss: 1519.8149 - sub_3_loss: 2.1043 - lr: 0.0010 - time: 0.1836
# Epoch 189/1000
# 28/28 - 0s - loss: 5071.8622 - U_loss: 0.0308 - V_loss: 6.4297 - Sxx_loss: 3.0237e-04 - Syy_loss: 3517.1642 - Sxy_loss: 0.0184 - sub_loss: 0.0256 - sub_2_loss: 1547.0494 - sub_3_loss: 1.9817 - lr: 0.0010 - time: 0.1834
# Epoch 190/1000
# 28/28 - 0s - loss: 5073.4577 - U_loss: 0.0308 - V_loss: 6.7664 - Sxx_loss: 4.7830e-04 - Syy_loss: 3528.8798 - Sxy_loss: 0.0259 - sub_loss: 0.0352 - sub_2_loss: 1537.1549 - sub_3_loss: 2.0700 - lr: 0.0010 - time: 0.1865
# Epoch 191/1000
# 28/28 - 0s - loss: 5073.5287 - U_loss: 0.0308 - V_loss: 5.7262 - Sxx_loss: 1.8237e-04 - Syy_loss: 3533.7450 - Sxy_loss: 0.0223 - sub_loss: 0.0162 - sub_2_loss: 1525.5388 - sub_3_loss: 1.9201 - lr: 0.0010 - time: 0.1841
# Epoch 192/1000
# 28/28 - 0s - loss: 5075.6198 - U_loss: 0.0312 - V_loss: 6.4775 - Sxx_loss: 5.2907e-04 - Syy_loss: 3566.4938 - Sxy_loss: 0.0223 - sub_loss: 0.0485 - sub_2_loss: 1498.5000 - sub_3_loss: 1.7100 - lr: 0.0010 - time: 0.1825
# Epoch 193/1000
# 28/28 - 0s - loss: 5073.6096 - U_loss: 0.0312 - V_loss: 7.2886 - Sxx_loss: 2.4088e-04 - Syy_loss: 3532.5486 - Sxy_loss: 0.0182 - sub_loss: 0.0148 - sub_2_loss: 1525.3400 - sub_3_loss: 1.8116 - lr: 0.0010 - time: 0.1827
# Epoch 194/1000
# 28/28 - 0s - loss: 5075.6440 - U_loss: 0.0338 - V_loss: 6.7412 - Sxx_loss: 4.3087e-05 - Syy_loss: 3511.1621 - Sxy_loss: 0.0131 - sub_loss: 5.3825e-04 - sub_2_loss: 1554.0511 - sub_3_loss: 1.0943 - lr: 0.0010 - time: 0.1863
# Epoch 195/1000
# 28/28 - 0s - loss: 5074.3407 - U_loss: 0.0312 - V_loss: 6.0408 - Sxx_loss: 3.9041e-06 - Syy_loss: 3553.1593 - Sxy_loss: 0.0092 - sub_loss: 2.1897e-04 - sub_2_loss: 1519.5545 - sub_3_loss: 0.9546 - lr: 0.0010 - time: 0.1842
# Epoch 196/1000
# 28/28 - 0s - loss: 5074.2536 - U_loss: 0.0312 - V_loss: 7.7018 - Sxx_loss: 5.4658e-06 - Syy_loss: 3554.9913 - Sxy_loss: 0.0132 - sub_loss: 3.5098e-04 - sub_2_loss: 1520.5693 - sub_3_loss: 1.5324 - lr: 0.0010 - time: 0.1874
# Epoch 197/1000
# 28/28 - 0s - loss: 5077.3310 - U_loss: 0.0313 - V_loss: 6.1650 - Sxx_loss: 2.4453e-06 - Syy_loss: 3500.2533 - Sxy_loss: 0.0164 - sub_loss: 1.5036e-04 - sub_2_loss: 1557.7902 - sub_3_loss: 1.3742 - lr: 0.0010 - time: 0.1810
# Epoch 198/1000
# 28/28 - 0s - loss: 5071.1373 - U_loss: 0.0307 - V_loss: 7.3777 - Sxx_loss: 8.2057e-06 - Syy_loss: 3545.1178 - Sxy_loss: 0.0199 - sub_loss: 3.6942e-04 - sub_2_loss: 1511.6304 - sub_3_loss: 2.0699 - lr: 0.0010 - time: 0.1856
# Epoch 199/1000
# 28/28 - 0s - loss: 5067.1507 - U_loss: 0.0311 - V_loss: 7.7911 - Sxx_loss: 3.8262e-06 - Syy_loss: 3544.0916 - Sxy_loss: 0.0242 - sub_loss: 2.2522e-04 - sub_2_loss: 1509.3700 - sub_3_loss: 1.9201 - lr: 0.0010 - time: 0.1816
# Epoch 200/1000
# ...
# 28/28 - 0s - loss: 5030.6452 - U_loss: 0.0295 - V_loss: 22.2602 - Sxx_loss: 7.9749e-07 - Syy_loss: 3505.1900 - Sxy_loss: 0.1959 - sub_loss: 1.2550e-04 - sub_2_loss: 1508.0005 - sub_3_loss: 1.9411 - lr: 1.2500e-04 - time: 0.2120
# Epoch 937/1000
# 28/28 - 0s - loss: 5031.2322 - U_loss: 0.0296 - V_loss: 22.5205 - Sxx_loss: 8.2717e-07 - Syy_loss: 3498.3641 - Sxy_loss: 0.2002 - sub_loss: 9.5934e-05 - sub_2_loss: 1510.9341 - sub_3_loss: 1.9031 - lr: 1.2500e-04 - time: 0.2059
# Epoch 938/1000
# 28/28 - 0s - loss: 5032.7415 - U_loss: 0.0297 - V_loss: 22.9108 - Sxx_loss: 8.2179e-07 - Syy_loss: 3496.7793 - Sxy_loss: 0.1940 - sub_loss: 1.1773e-04 - sub_2_loss: 1512.3020 - sub_3_loss: 2.0827 - lr: 1.2500e-04 - time: 0.2089
# Epoch 939/1000
# 28/28 - 0s - loss: 5032.5424 - U_loss: 0.0297 - V_loss: 22.3719 - Sxx_loss: 8.6357e-07 - Syy_loss: 3508.6018 - Sxy_loss: 0.1833 - sub_loss: 1.2743e-04 - sub_2_loss: 1509.5241 - sub_3_loss: 1.9619 - lr: 1.2500e-04 - time: 0.2133
# Epoch 940/1000
# 28/28 - 0s - loss: 5033.5042 - U_loss: 0.0296 - V_loss: 22.7287 - Sxx_loss: 8.5360e-07 - Syy_loss: 3507.8317 - Sxy_loss: 0.2065 - sub_loss: 1.0225e-04 - sub_2_loss: 1514.3208 - sub_3_loss: 1.9292 - lr: 1.2500e-04 - time: 0.2055
# Epoch 941/1000
# 28/28 - 0s - loss: 5030.7190 - U_loss: 0.0297 - V_loss: 22.7415 - Sxx_loss: 7.5221e-07 - Syy_loss: 3506.9808 - Sxy_loss: 0.1962 - sub_loss: 1.0753e-04 - sub_2_loss: 1502.5992 - sub_3_loss: 2.2037 - lr: 1.2500e-04 - time: 0.2143
# Epoch 942/1000
# 28/28 - 0s - loss: 5030.1841 - U_loss: 0.0298 - V_loss: 22.7085 - Sxx_loss: 8.8190e-07 - Syy_loss: 3493.8145 - Sxy_loss: 0.2157 - sub_loss: 1.1617e-04 - sub_2_loss: 1508.4514 - sub_3_loss: 1.8872 - lr: 1.2500e-04 - time: 0.2058
# Epoch 943/1000
# 28/28 - 0s - loss: 5030.5762 - U_loss: 0.0298 - V_loss: 22.6989 - Sxx_loss: 1.2600e-06 - Syy_loss: 3501.8454 - Sxy_loss: 0.2035 - sub_loss: 1.0780e-04 - sub_2_loss: 1513.1841 - sub_3_loss: 2.1008 - lr: 1.2500e-04 - time: 0.2077
# Epoch 944/1000
# 28/28 - 0s - loss: 5034.7420 - U_loss: 0.0296 - V_loss: 22.3192 - Sxx_loss: 8.1160e-07 - Syy_loss: 3498.5453 - Sxy_loss: 0.1950 - sub_loss: 1.0460e-04 - sub_2_loss: 1515.7745 - sub_3_loss: 2.1232 - lr: 1.2500e-04 - time: 0.2047
# Epoch 945/1000
# 28/28 - 0s - loss: 5032.8506 - U_loss: 0.0297 - V_loss: 22.6909 - Sxx_loss: 8.9336e-07 - Syy_loss: 3503.1887 - Sxy_loss: 0.2088 - sub_loss: 1.1033e-04 - sub_2_loss: 1509.3942 - sub_3_loss: 2.3018 - lr: 1.2500e-04 - time: 0.2063
# Epoch 946/1000
# 28/28 - 0s - loss: 5033.1273 - U_loss: 0.0295 - V_loss: 22.5840 - Sxx_loss: 7.8043e-07 - Syy_loss: 3491.2388 - Sxy_loss: 0.2158 - sub_loss: 1.0438e-04 - sub_2_loss: 1508.0847 - sub_3_loss: 1.9679 - lr: 1.2500e-04 - time: 0.2098
# Epoch 947/1000
# 28/28 - 0s - loss: 5030.3494 - U_loss: 0.0296 - V_loss: 22.6487 - Sxx_loss: 8.6053e-07 - Syy_loss: 3507.2576 - Sxy_loss: 0.2030 - sub_loss: 1.0077e-04 - sub_2_loss: 1503.1408 - sub_3_loss: 2.2198 - lr: 1.2500e-04 - time: 0.2056
# Epoch 948/1000
# 28/28 - 0s - loss: 5030.9407 - U_loss: 0.0296 - V_loss: 22.2952 - Sxx_loss: 8.6263e-07 - Syy_loss: 3491.7217 - Sxy_loss: 0.2124 - sub_loss: 1.1570e-04 - sub_2_loss: 1505.9071 - sub_3_loss: 2.2043 - lr: 1.2500e-04 - time: 0.2080
# Epoch 949/1000
# 28/28 - 0s - loss: 5029.7308 - U_loss: 0.0296 - V_loss: 22.1531 - Sxx_loss: 1.0438e-06 - Syy_loss: 3498.8687 - Sxy_loss: 0.2088 - sub_loss: 1.0867e-04 - sub_2_loss: 1508.8123 - sub_3_loss: 2.3035 - lr: 1.2500e-04 - time: 0.2055
# Epoch 950/1000
# 28/28 - 0s - loss: 5031.6438 - U_loss: 0.0297 - V_loss: 22.3225 - Sxx_loss: 9.3386e-07 - Syy_loss: 3502.3604 - Sxy_loss: 0.2169 - sub_loss: 1.1774e-04 - sub_2_loss: 1510.3479 - sub_3_loss: 2.3803 - lr: 1.2500e-04 - time: 0.2087
# Epoch 951/1000
# 28/28 - 0s - loss: 5029.9272 - U_loss: 0.0297 - V_loss: 22.5931 - Sxx_loss: 9.0834e-07 - Syy_loss: 3502.1882 - Sxy_loss: 0.2188 - sub_loss: 1.0155e-04 - sub_2_loss: 1513.5128 - sub_3_loss: 2.2303 - lr: 1.2500e-04 - time: 0.2076
# Epoch 952/1000
# 28/28 - 0s - loss: 5031.3759 - U_loss: 0.0295 - V_loss: 22.2549 - Sxx_loss: 8.1720e-07 - Syy_loss: 3480.3126 - Sxy_loss: 0.2155 - sub_loss: 9.4235e-05 - sub_2_loss: 1512.5013 - sub_3_loss: 2.0992 - lr: 1.2500e-04 - time: 0.2080
# Epoch 953/1000
# 28/28 - 0s - loss: 5031.5319 - U_loss: 0.0296 - V_loss: 21.9332 - Sxx_loss: 8.6802e-07 - Syy_loss: 3486.6103 - Sxy_loss: 0.2304 - sub_loss: 8.7743e-05 - sub_2_loss: 1513.4648 - sub_3_loss: 2.3015 - lr: 1.2500e-04 - time: 0.2024
# Epoch 954/1000
# 28/28 - 0s - loss: 5029.0302 - U_loss: 0.0297 - V_loss: 22.2806 - Sxx_loss: 1.1923e-06 - Syy_loss: 3498.1465 - Sxy_loss: 0.2260 - sub_loss: 9.2265e-05 - sub_2_loss: 1506.3913 - sub_3_loss: 2.3125 - lr: 1.2500e-04 - time: 0.2051
# Epoch 955/1000
# 28/28 - 0s - loss: 5031.4016 - U_loss: 0.0297 - V_loss: 21.9139 - Sxx_loss: 8.3386e-07 - Syy_loss: 3495.7157 - Sxy_loss: 0.2205 - sub_loss: 9.4991e-05 - sub_2_loss: 1512.2964 - sub_3_loss: 2.2853 - lr: 1.2500e-04 - time: 0.2087
# Epoch 956/1000
# 28/28 - 0s - loss: 5033.0043 - U_loss: 0.0297 - V_loss: 22.8787 - Sxx_loss: 7.9286e-07 - Syy_loss: 3501.1557 - Sxy_loss: 0.2271 - sub_loss: 1.0040e-04 - sub_2_loss: 1511.5048 - sub_3_loss: 2.1113 - lr: 1.2500e-04 - time: 0.2059
# Epoch 957/1000
# 28/28 - 0s - loss: 5032.5335 - U_loss: 0.0295 - V_loss: 23.0630 - Sxx_loss: 7.7256e-07 - Syy_loss: 3509.1751 - Sxy_loss: 0.2217 - sub_loss: 9.2938e-05 - sub_2_loss: 1506.1399 - sub_3_loss: 2.2121 - lr: 1.2500e-04 - time: 0.2069
# Epoch 958/1000
# 28/28 - 0s - loss: 5032.3712 - U_loss: 0.0297 - V_loss: 22.3544 - Sxx_loss: 7.2271e-07 - Syy_loss: 3497.9778 - Sxy_loss: 0.2447 - sub_loss: 8.8444e-05 - sub_2_loss: 1512.2112 - sub_3_loss: 2.1480 - lr: 1.2500e-04 - time: 0.2083
# Epoch 959/1000
# 28/28 - 0s - loss: 5032.9100 - U_loss: 0.0295 - V_loss: 22.2090 - Sxx_loss: 1.0629e-06 - Syy_loss: 3488.5954 - Sxy_loss: 0.2247 - sub_loss: 1.2336e-04 - sub_2_loss: 1512.0337 - sub_3_loss: 2.3081 - lr: 1.2500e-04 - time: 0.2061
# Epoch 960/1000
# 28/28 - 0s - loss: 5033.4040 - U_loss: 0.0297 - V_loss: 22.8380 - Sxx_loss: 1.1517e-06 - Syy_loss: 3509.0089 - Sxy_loss: 0.2172 - sub_loss: 1.2517e-04 - sub_2_loss: 1508.3671 - sub_3_loss: 2.0095 - lr: 1.2500e-04 - time: 0.2045
# Epoch 961/1000
# 28/28 - 0s - loss: 5031.7203 - U_loss: 0.0296 - V_loss: 22.4735 - Sxx_loss: 1.2467e-06 - Syy_loss: 3507.0516 - Sxy_loss: 0.2086 - sub_loss: 9.7907e-05 - sub_2_loss: 1509.2823 - sub_3_loss: 2.1716 - lr: 1.2500e-04 - time: 0.2103
# Epoch 962/1000
# 28/28 - 0s - loss: 5031.7301 - U_loss: 0.0297 - V_loss: 22.9324 - Sxx_loss: 7.1756e-07 - Syy_loss: 3499.3470 - Sxy_loss: 0.2262 - sub_loss: 8.0582e-05 - sub_2_loss: 1507.4474 - sub_3_loss: 2.1487 - lr: 1.2500e-04 - time: 0.2110
# Epoch 963/1000
# 28/28 - 0s - loss: 5031.0325 - U_loss: 0.0296 - V_loss: 22.4535 - Sxx_loss: 8.3636e-07 - Syy_loss: 3499.4225 - Sxy_loss: 0.2334 - sub_loss: 1.0600e-04 - sub_2_loss: 1511.6207 - sub_3_loss: 2.2017 - lr: 1.2500e-04 - time: 0.2137
# Epoch 964/1000
# 28/28 - 0s - loss: 5031.8760 - U_loss: 0.0295 - V_loss: 22.3858 - Sxx_loss: 1.0403e-06 - Syy_loss: 3485.5926 - Sxy_loss: 0.2425 - sub_loss: 8.4918e-05 - sub_2_loss: 1520.7832 - sub_3_loss: 2.0771 - lr: 1.2500e-04 - time: 0.2108
# Epoch 965/1000
# 28/28 - 0s - loss: 5033.5811 - U_loss: 0.0297 - V_loss: 22.2436 - Sxx_loss: 9.5232e-07 - Syy_loss: 3505.4653 - Sxy_loss: 0.2316 - sub_loss: 1.1508e-04 - sub_2_loss: 1510.1662 - sub_3_loss: 2.3927 - lr: 1.2500e-04 - time: 0.2082
# Epoch 966/1000
# 28/28 - 0s - loss: 5036.3100 - U_loss: 0.0295 - V_loss: 21.8226 - Sxx_loss: 8.0100e-07 - Syy_loss: 3480.3917 - Sxy_loss: 0.2214 - sub_loss: 1.0492e-04 - sub_2_loss: 1516.4589 - sub_3_loss: 2.0269 - lr: 1.2500e-04 - time: 0.2056
# Epoch 967/1000
# 28/28 - 0s - loss: 5032.4855 - U_loss: 0.0298 - V_loss: 21.5029 - Sxx_loss: 9.0650e-07 - Syy_loss: 3516.1443 - Sxy_loss: 0.2415 - sub_loss: 9.4168e-05 - sub_2_loss: 1506.9650 - sub_3_loss: 1.9637 - lr: 1.2500e-04 - time: 0.2056
# Epoch 968/1000
#
# Epoch 00968: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 28/28 - 0s - loss: 5031.7365 - U_loss: 0.0297 - V_loss: 21.6588 - Sxx_loss: 1.0206e-06 - Syy_loss: 3497.6585 - Sxy_loss: 0.1955 - sub_loss: 8.3028e-05 - sub_2_loss: 1515.2260 - sub_3_loss: 2.5759 - lr: 1.2500e-04 - time: 0.2123
# Epoch 969/1000
# 28/28 - 0s - loss: 5030.0877 - U_loss: 0.0295 - V_loss: 21.8903 - Sxx_loss: 9.1487e-07 - Syy_loss: 3492.8966 - Sxy_loss: 0.1867 - sub_loss: 8.6096e-05 - sub_2_loss: 1512.5717 - sub_3_loss: 2.3699 - lr: 6.2500e-05 - time: 0.2036
# Epoch 970/1000
# 28/28 - 0s - loss: 5029.6544 - U_loss: 0.0294 - V_loss: 21.8194 - Sxx_loss: 8.4143e-07 - Syy_loss: 3485.2881 - Sxy_loss: 0.1738 - sub_loss: 1.1115e-04 - sub_2_loss: 1509.5304 - sub_3_loss: 2.5211 - lr: 6.2500e-05 - time: 0.2212
# Epoch 971/1000
# 28/28 - 0s - loss: 5029.4855 - U_loss: 0.0296 - V_loss: 21.9566 - Sxx_loss: 7.2066e-07 - Syy_loss: 3496.6602 - Sxy_loss: 0.1610 - sub_loss: 9.6916e-05 - sub_2_loss: 1511.2944 - sub_3_loss: 2.4890 - lr: 6.2500e-05 - time: 0.2086
# Epoch 972/1000
# 28/28 - 0s - loss: 5029.7897 - U_loss: 0.0295 - V_loss: 21.8602 - Sxx_loss: 8.8604e-07 - Syy_loss: 3489.3695 - Sxy_loss: 0.1617 - sub_loss: 9.3330e-05 - sub_2_loss: 1511.2445 - sub_3_loss: 2.4788 - lr: 6.2500e-05 - time: 0.2128
# Epoch 973/1000
# 28/28 - 0s - loss: 5029.7878 - U_loss: 0.0294 - V_loss: 21.8995 - Sxx_loss: 6.3914e-07 - Syy_loss: 3486.7913 - Sxy_loss: 0.1504 - sub_loss: 9.9000e-05 - sub_2_loss: 1507.2736 - sub_3_loss: 2.5417 - lr: 6.2500e-05 - time: 0.2132
# Epoch 974/1000
# 28/28 - 0s - loss: 5029.8287 - U_loss: 0.0296 - V_loss: 21.8356 - Sxx_loss: 6.1999e-07 - Syy_loss: 3490.8913 - Sxy_loss: 0.1306 - sub_loss: 9.5953e-05 - sub_2_loss: 1506.7914 - sub_3_loss: 2.5290 - lr: 6.2500e-05 - time: 0.2152
# Epoch 975/1000
# 28/28 - 0s - loss: 5030.3143 - U_loss: 0.0297 - V_loss: 22.1692 - Sxx_loss: 8.0072e-07 - Syy_loss: 3498.0016 - Sxy_loss: 0.1493 - sub_loss: 9.1778e-05 - sub_2_loss: 1507.2861 - sub_3_loss: 2.3859 - lr: 6.2500e-05 - time: 0.2087
# Epoch 976/1000
# 28/28 - 0s - loss: 5029.8824 - U_loss: 0.0296 - V_loss: 22.0365 - Sxx_loss: 6.4200e-07 - Syy_loss: 3497.5106 - Sxy_loss: 0.1533 - sub_loss: 8.3087e-05 - sub_2_loss: 1509.5325 - sub_3_loss: 2.2675 - lr: 6.2500e-05 - time: 0.2181
# Epoch 977/1000
# 28/28 - 0s - loss: 5029.6671 - U_loss: 0.0295 - V_loss: 22.1318 - Sxx_loss: 6.5712e-07 - Syy_loss: 3506.9040 - Sxy_loss: 0.1687 - sub_loss: 9.3534e-05 - sub_2_loss: 1511.6298 - sub_3_loss: 2.2272 - lr: 6.2500e-05 - time: 0.2082
# Epoch 978/1000
# 28/28 - 0s - loss: 5028.6732 - U_loss: 0.0296 - V_loss: 22.1306 - Sxx_loss: 8.7205e-07 - Syy_loss: 3493.7254 - Sxy_loss: 0.1876 - sub_loss: 9.2533e-05 - sub_2_loss: 1509.0098 - sub_3_loss: 2.2539 - lr: 6.2500e-05 - time: 0.2128
# Epoch 979/1000
# 28/28 - 0s - loss: 5032.7099 - U_loss: 0.0295 - V_loss: 22.2695 - Sxx_loss: 6.7456e-07 - Syy_loss: 3482.7484 - Sxy_loss: 0.1932 - sub_loss: 8.8224e-05 - sub_2_loss: 1511.1309 - sub_3_loss: 2.2277 - lr: 6.2500e-05 - time: 0.2154
# Epoch 980/1000
# 28/28 - 0s - loss: 5029.6374 - U_loss: 0.0296 - V_loss: 22.1803 - Sxx_loss: 6.5129e-07 - Syy_loss: 3498.4083 - Sxy_loss: 0.1906 - sub_loss: 9.9356e-05 - sub_2_loss: 1506.8570 - sub_3_loss: 2.3656 - lr: 6.2500e-05 - time: 0.2067
# Epoch 981/1000
# 28/28 - 0s - loss: 5028.5681 - U_loss: 0.0295 - V_loss: 21.9392 - Sxx_loss: 7.3011e-07 - Syy_loss: 3490.7302 - Sxy_loss: 0.1699 - sub_loss: 8.4319e-05 - sub_2_loss: 1507.9165 - sub_3_loss: 2.5385 - lr: 6.2500e-05 - time: 0.2125
# Epoch 982/1000
# 28/28 - 0s - loss: 5029.8734 - U_loss: 0.0296 - V_loss: 22.0788 - Sxx_loss: 5.9022e-07 - Syy_loss: 3499.1829 - Sxy_loss: 0.1891 - sub_loss: 9.6920e-05 - sub_2_loss: 1511.6729 - sub_3_loss: 2.3453 - lr: 6.2500e-05 - time: 0.2148
# Epoch 983/1000
# 28/28 - 0s - loss: 5029.4443 - U_loss: 0.0295 - V_loss: 22.3812 - Sxx_loss: 9.7128e-07 - Syy_loss: 3490.0069 - Sxy_loss: 0.1934 - sub_loss: 1.0405e-04 - sub_2_loss: 1507.5508 - sub_3_loss: 2.4131 - lr: 6.2500e-05 - time: 0.2110
# Epoch 984/1000
# 28/28 - 0s - loss: 5028.8666 - U_loss: 0.0296 - V_loss: 22.4957 - Sxx_loss: 7.6019e-07 - Syy_loss: 3491.2519 - Sxy_loss: 0.2136 - sub_loss: 8.1239e-05 - sub_2_loss: 1508.0479 - sub_3_loss: 2.2995 - lr: 6.2500e-05 - time: 0.2092
# Epoch 985/1000
# 28/28 - 0s - loss: 5028.4903 - U_loss: 0.0296 - V_loss: 22.2583 - Sxx_loss: 6.3136e-07 - Syy_loss: 3492.0608 - Sxy_loss: 0.2069 - sub_loss: 8.4109e-05 - sub_2_loss: 1505.4772 - sub_3_loss: 2.4846 - lr: 6.2500e-05 - time: 0.2107
# Epoch 986/1000
# 28/28 - 0s - loss: 5028.4596 - U_loss: 0.0295 - V_loss: 22.4348 - Sxx_loss: 6.8218e-07 - Syy_loss: 3494.8802 - Sxy_loss: 0.2269 - sub_loss: 8.3405e-05 - sub_2_loss: 1506.2541 - sub_3_loss: 2.3162 - lr: 6.2500e-05 - time: 0.2112
# Epoch 987/1000
# 28/28 - 0s - loss: 5029.2040 - U_loss: 0.0295 - V_loss: 22.6687 - Sxx_loss: 7.3538e-07 - Syy_loss: 3491.4079 - Sxy_loss: 0.2226 - sub_loss: 9.3629e-05 - sub_2_loss: 1510.2024 - sub_3_loss: 2.3021 - lr: 6.2500e-05 - time: 0.2124
# Epoch 988/1000
# 28/28 - 0s - loss: 5030.8639 - U_loss: 0.0295 - V_loss: 22.5246 - Sxx_loss: 8.0719e-07 - Syy_loss: 3506.3373 - Sxy_loss: 0.2251 - sub_loss: 8.8006e-05 - sub_2_loss: 1509.1581 - sub_3_loss: 2.3592 - lr: 6.2500e-05 - time: 0.2144
# Epoch 989/1000
# 28/28 - 0s - loss: 5028.8957 - U_loss: 0.0297 - V_loss: 22.4309 - Sxx_loss: 7.0118e-07 - Syy_loss: 3495.5453 - Sxy_loss: 0.2392 - sub_loss: 9.6471e-05 - sub_2_loss: 1507.2838 - sub_3_loss: 2.4960 - lr: 6.2500e-05 - time: 0.2163
# Epoch 990/1000
# 28/28 - 0s - loss: 5028.5827 - U_loss: 0.0296 - V_loss: 22.3581 - Sxx_loss: 6.4148e-07 - Syy_loss: 3499.0342 - Sxy_loss: 0.2555 - sub_loss: 8.8452e-05 - sub_2_loss: 1508.2603 - sub_3_loss: 2.3834 - lr: 6.2500e-05 - time: 0.2077
# Epoch 991/1000
# 28/28 - 0s - loss: 5029.0026 - U_loss: 0.0296 - V_loss: 22.4079 - Sxx_loss: 7.4517e-07 - Syy_loss: 3496.9294 - Sxy_loss: 0.2639 - sub_loss: 9.6533e-05 - sub_2_loss: 1511.2795 - sub_3_loss: 2.1929 - lr: 6.2500e-05 - time: 0.2097
# Epoch 992/1000
# 28/28 - 0s - loss: 5028.5763 - U_loss: 0.0298 - V_loss: 22.2601 - Sxx_loss: 6.9410e-07 - Syy_loss: 3493.7557 - Sxy_loss: 0.2429 - sub_loss: 8.6040e-05 - sub_2_loss: 1509.6759 - sub_3_loss: 2.2729 - lr: 6.2500e-05 - time: 0.2122
# Epoch 993/1000
# 28/28 - 0s - loss: 5028.3783 - U_loss: 0.0297 - V_loss: 22.3222 - Sxx_loss: 7.7134e-07 - Syy_loss: 3509.8617 - Sxy_loss: 0.2539 - sub_loss: 8.6091e-05 - sub_2_loss: 1507.6452 - sub_3_loss: 2.3063 - lr: 6.2500e-05 - time: 0.2104
# Epoch 994/1000
# 28/28 - 0s - loss: 5028.7001 - U_loss: 0.0296 - V_loss: 22.4121 - Sxx_loss: 6.5181e-07 - Syy_loss: 3486.0711 - Sxy_loss: 0.2684 - sub_loss: 9.7303e-05 - sub_2_loss: 1510.9492 - sub_3_loss: 2.1769 - lr: 6.2500e-05 - time: 0.2083
# Epoch 995/1000
# 28/28 - 0s - loss: 5027.5392 - U_loss: 0.0295 - V_loss: 22.7842 - Sxx_loss: 6.9617e-07 - Syy_loss: 3488.8955 - Sxy_loss: 0.2685 - sub_loss: 1.1292e-04 - sub_2_loss: 1509.1537 - sub_3_loss: 2.2913 - lr: 6.2500e-05 - time: 0.2148
# Epoch 996/1000
# 28/28 - 0s - loss: 5029.4886 - U_loss: 0.0296 - V_loss: 22.7244 - Sxx_loss: 7.2066e-07 - Syy_loss: 3492.2393 - Sxy_loss: 0.2506 - sub_loss: 7.8852e-05 - sub_2_loss: 1505.8934 - sub_3_loss: 2.2596 - lr: 6.2500e-05 - time: 0.2095
# Epoch 997/1000
# 28/28 - 0s - loss: 5027.5366 - U_loss: 0.0297 - V_loss: 22.5412 - Sxx_loss: 8.1397e-07 - Syy_loss: 3497.2464 - Sxy_loss: 0.2526 - sub_loss: 8.6737e-05 - sub_2_loss: 1507.2347 - sub_3_loss: 2.3288 - lr: 6.2500e-05 - time: 0.2178
# Epoch 998/1000
# 28/28 - 0s - loss: 5028.3636 - U_loss: 0.0296 - V_loss: 22.5368 - Sxx_loss: 8.3207e-07 - Syy_loss: 3493.5932 - Sxy_loss: 0.2590 - sub_loss: 7.7931e-05 - sub_2_loss: 1508.1508 - sub_3_loss: 2.3871 - lr: 6.2500e-05 - time: 0.2238
# Epoch 999/1000
# 28/28 - 0s - loss: 5028.3683 - U_loss: 0.0297 - V_loss: 22.6077 - Sxx_loss: 6.0984e-07 - Syy_loss: 3490.7573 - Sxy_loss: 0.2542 - sub_loss: 8.3030e-05 - sub_2_loss: 1509.8193 - sub_3_loss: 2.3637 - lr: 6.2500e-05 - time: 0.2057
# Epoch 1000/1000
# 28/28 - 0s - loss: 5028.3642 - U_loss: 0.0296 - V_loss: 22.7581 - Sxx_loss: 7.0178e-07 - Syy_loss: 3489.7508 - Sxy_loss: 0.2559 - sub_loss: 8.9080e-05 - sub_2_loss: 1507.8911 - sub_3_loss: 2.3760 - lr: 6.2500e-05 - time: 0.2134
# Input and output dimensions need re-adjustment for post-processing.
# Input and output dimensions need re-adjustment for post-processing.

# %%
plot()
# Out:
# /tmp/ipykernel_29972/560689918.py:34: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   im = AX.pcolor(X, Y, C, cmap="jet")
# (60, 46)

# %%
# Plot "exact" pressure field
#plt.imshow(P_exact, interpolation='nearest', cmap='rainbow', 
#                  extent=[x_star.min(), x_star.max(), y_star.min(), y_star.max()], 
#                  origin='lower', aspect='auto')

plt.imshow(P_exact, cmap='rainbow', 
                  extent=[x_star.min(), x_star.max(), y_star.min(), y_star.max()], 
                  origin='lower', aspect='auto')
plt.colorbar()
